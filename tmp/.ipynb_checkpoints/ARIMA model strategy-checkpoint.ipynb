# %%
import sys
sys.path.append('../..')
from backtester import matlab, backtester
from backtester.analysis import *
import pandas as pd
import numpy as np
import glob, os

import itertools

from backtester.exoinfo import EXOInfo
from exobuilder.data.exostorage import EXOStorage
from IPython.core.display import display, HTML

import statsmodels.tsa.api as smt
import statsmodels.api as sm

import plotly.plotly as py  
import plotly.tools as tls   
import plotly.graph_objs as go

import pandas as pd
import numpy as np
import scipy
import pprint

# %pylab inline
figsize(20,10)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.5/dist-packages/IPython/core/magics/pylab.py:161: UserWarning:
#
# pylab import has clobbered these variables: ['e']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
# Loading global setting for MongoDB etc.
from scripts.settings import *

try:
    from scripts.settings_local import *
except:
    pass

storage = EXOStorage(MONGO_CONNSTR, MONGO_EXO_DB)
pp = pprint.PrettyPrinter(indent=4)

exo_list = storage.exo_list()
pp.pprint(exo_list)


df = pd.DataFrame()

for e in exo_list:
    exo_series, exo_dict = storage.load_series(e)
    
    exo_series = exo_series[exo_series.columns[0]]
    df[exo_dict['name']] = exo_series
#exo_series.plot()
# Out:
# [   'ES_BullishCollarBW',
#     'ES_BearishCollarBW',
#     'ES_CallSpread',
#     'ES_PutSpread',
#     'ES_ContFut',
#     'ZS_BullishCollarBW',
#     'ZS_BearishCollarBW',
#     'ZS_CallSpread',
#     'ZS_PutSpread',
#     'ZS_ContFut',
#     'CL_BullishCollarBW',
#     'CL_BearishCollarBW',
#     'CL_CallSpread',
#     'CL_PutSpread',
#     'CL_ContFut',
#     'ZW_BullishCollarBW',
#     'ZW_BearishCollarBW',
#     'ZW_CallSpread',
#     'ZW_PutSpread',
#     'ZW_ContFut',
#     'ZN_BullishCollarBW',
#     'ZN_BearishCollarBW',
#     'ZN_CallSpread',
#     'ZN_PutSpread',
#     'ZN_ContFut',
#     'NG_BullishCollarBW',
#     'NG_BearishCollarBW',
#     'NG_CallSpread',
#     'NG_PutSpread',
#     'NG_ContFut',
#     'ZC_BullishCollarBW',
#     'ZC_BearishCollarBW',
#     'ZC_CallSpread',
#     'ZC_PutSpread',
#     'ZC_ContFut',
#     'CL_SMART_Ichimoku_Long',
#     'ES_SMART_Ichimoku_Long',
#     'NG_SMART_Ichimoku_Long',
#     'ZC_SMART_Ichimoku_Long',
#     'ZS_SMART_Ichimoku_Long',
#     'ZW_SMART_Ichimoku_Long',
#     'ZN_SMART_Ichimoku_Long',
#     'CL_SMART_Ichimoku_VerticalSpread_Bullish',
#     'CL_SMART_Ichimoku_Straddle_Bullish',
#     'ES_SMART_Ichimoku_Straddle_Bullish',
#     'NG_SMART_Ichimoku_Straddle_Bullish',
#     'ZC_SMART_Ichimoku_Straddle_Bullish',
#     'ZS_SMART_Ichimoku_Straddle_Bullish',
#     'ZW_SMART_Ichimoku_Straddle_Bullish',
#     'ZN_SMART_Ichimoku_Straddle_Bullish',
#     'CL_SmartEXO_Ichi_Bearish_Straddle_150Delta',
#     'CL_SmartEXO_Ichi_Bullish_Straddle_150Delta',
#     'CL_SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged',
#     'CL_SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged_test']

# %%
df.tail()
# Out:
#             ES_BullishCollarBW  ES_BearishCollarBW  ES_CallSpread  \
# 2016-10-25         9147.869703       -41208.345316    9485.469912
# 2016-10-26         9098.523600       -41178.600711    9452.630198
# 2016-10-27         8931.283035       -40969.605459    9368.028293
# 2016-10-28         8774.597057       -40753.521943    9284.234630
# 2016-10-31         8787.914644       -40769.498904    9308.729608
#
#             ES_PutSpread  ES_ContFut  ZS_BullishCollarBW  ZS_BearishCollarBW  \
# 2016-10-25 -12714.329390     49137.5         6797.094054        -6114.954275
# 2016-10-26 -12710.129014     49062.5         7196.842850        -6444.165803
# 2016-10-27 -12636.539971     48687.5         7514.471841        -6633.463434
# 2016-10-28 -12566.133704     48325.0         7183.219561        -6369.510403
# 2016-10-31 -12569.647414     48375.0         7075.620229        -6376.822791
#
#             ZS_CallSpread  ZS_PutSpread  ZS_ContFut  \
# 2016-10-25    8467.080508  -6006.309294     33112.5
# 2016-10-26    8880.046083  -6206.422305     33687.5
# 2016-10-27    9297.399875  -6269.413631     34187.5
# 2016-10-28    8902.811646  -6111.517057     33675.0
# 2016-10-31    8806.693072  -6161.884901     33625.0
#
#                                       ...                              \
# 2016-10-25                            ...
# 2016-10-26                            ...
# 2016-10-27                            ...
# 2016-10-28                            ...
# 2016-10-31                            ...
#
#             ES_SMART_Ichimoku_Straddle_Bullish  \
# 2016-10-25                       -48524.395418
# 2016-10-26                       -48520.039906
# 2016-10-27                       -48515.029676
# 2016-10-28                       -48525.192529
# 2016-10-31                                 NaN
#
#             NG_SMART_Ichimoku_Straddle_Bullish  \
# 2016-10-25                        -3170.198110
# 2016-10-26                        -3191.790400
# 2016-10-27                        -3198.811330
# 2016-10-28                        -3188.706826
# 2016-10-31                                 NaN
#
#             ZC_SMART_Ichimoku_Straddle_Bullish  \
# 2016-10-25                       -29805.846642
# 2016-10-26                       -29257.009130
# 2016-10-27                       -28879.500975
# 2016-10-28                       -28714.160241
# 2016-10-31                                 NaN
#
#             ZS_SMART_Ichimoku_Straddle_Bullish  \
# 2016-10-25                        37579.451541
# 2016-10-26                        39016.360438
# 2016-10-27                        40957.750998
# 2016-10-28                        40743.519259
# 2016-10-31                                 NaN
#
#             ZW_SMART_Ichimoku_Straddle_Bullish  \
# 2016-10-25                       -30486.486436
# 2016-10-26                       -29828.717656
# 2016-10-27                       -29688.263695
# 2016-10-28                       -29725.412060
# 2016-10-31                                 NaN
#
#             ZN_SMART_Ichimoku_Straddle_Bullish  \
# 2016-10-25                        -2147.709662
# 2016-10-26                        -2147.709662
# 2016-10-27                        -2147.709662
# 2016-10-28                        -2147.709662
# 2016-10-31                                 NaN
#
#             CL_SmartEXO_Ichi_Bearish_Straddle_150Delta  \
# 2016-10-25                               172406.129349
# 2016-10-26                               172400.146641
# 2016-10-27                               172396.398770
# 2016-10-28                               172407.171725
# 2016-10-31                               172405.725132
#
#             CL_SmartEXO_Ichi_Bullish_Straddle_150Delta  \
# 2016-10-25                               -46692.623361
# 2016-10-26                               -47531.131480
# 2016-10-27                               -47063.525105
# 2016-10-28                               -48029.923676
# 2016-10-31                               -47690.154499
#
#             CL_SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged  \
# 2016-10-25                                      -30732.538510
# 2016-10-26                                      -32069.123041
# 2016-10-27                                      -31139.417932
# 2016-10-28                                      -33031.086113
# 2016-10-31                                      -32760.269479
#
#             CL_SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged_test
# 2016-10-25                                                NaN
# 2016-10-26                                                NaN
# 2016-10-27                                                NaN
# 2016-10-28                                                NaN
# 2016-10-31                                                NaN
#
# [5 rows x 54 columns]

# %%
px_ser = df.ES_BearishCollarBW
px_ser.asfreq('B').dropna().plot()

# %% [markdown]
# # Data examination

# %%
#ts = px_ser.asfreq('B').dropna()
#ts = px_ser.ewm(2).mean().dropna() - px_ser.ewm(3).mean().dropna()
#ts = ts - ts.ewm(1).mean().dropna()
#ts = (px_ser - px_ser.ewm(10).mean()).dropna()
#ts = px_ser.diff(10).dropna()

#ts = (px_ser - px_ser.shift(1)).dropna()
#ts = ((px_ser - px_ser.ewm(1).mean()) / px_ser.ewm(1).std()).dropna()
ts = px_ser.rolling(10).mean().diff().dropna()

# %%
#ts.cumsum().ix['2010':].plot()
ts.ix['2015':].plot(secondary_y=True)

#px_ser.ix['2010':].plot()
px_ser.ix['2015':].plot()

# %%
smt.adfuller(ts)
# Out:
# (-6.7966075412067344,
#  2.2924530678703256e-09,
#  24,
#  1925,
#  {'1%': -3.433751579966644,
#   '10%': -2.5675699268679373,
#   '5%': -2.8630426027458258},
#  20311.841851750105)

# %%
sm.graphics.tsa.plot_acf(ts, lags=70)

# %% [markdown]
# # Model

# %%
i = 1

empty_ser = pd.Series(False, index=px_ser.dropna().index)

signals_df = pd.DataFrame()

signals_df['long_entry_signal'] = empty_ser
signals_df['long_exit_signal'] = empty_ser

signals_df['short_entry_signal'] = empty_ser
signals_df['short_exit_signal'] = empty_ser

while True:
    forecast_period = 2
    
    try:
        model = smt.ARIMA(ts.iloc[:i], order=(1,1,0)).fit()
    
    except Exception:
        i += forecast_period
        continue


    forecast_daterange = pd.date_range(start=ts.iloc[:i].index[-1] + BDay(1), periods=forecast_period)
    #forecast_daterange = pd.date_range(start=ts.iloc[:i].index[-1] + pd.DateOffset(1), freq='B')
    
    # Handling missing dates
    if (forecast_daterange.isin(px_ser.dropna().index).all() == False) & (forecast_daterange[-1] < ts.index[-1]):
        i += forecast_period
        print('DATES IS NOT EXIST', ts.iloc[:i].index[-4:])
        continue
    
    # If daterange is out of TSeries index, break while loop
    if forecast_daterange[-1] > ts.index[-1]:
        break
    
    forecast_values = model.forecast(forecast_period)

    forecast_series = pd.Series(forecast_values[0], index=forecast_daterange)
    
    if forecast_series[0] > forecast_series[-1]:
    #if forecast_series[0] > ts.iloc[:i][-1]:
        signals_df['long_entry_signal'].ix[ts.iloc[:i].index[-1]: 
                                           forecast_series.index[-1]] = True
        
        if (signals_df['long_entry_signal'].ix[forecast_series.index[-1]] == True):
            signals_df['long_exit_signal'].ix[forecast_series.index[-1] + BDay(1)] = True
            
           
    
    if forecast_series[0] < forecast_series[-1]:
    #if forecast_series[0] < ts.iloc[:i][-1]:
        signals_df['short_entry_signal'].ix[ts.iloc[:i].index[-1]: 
                                           forecast_series.index[-1]] = True
        
        if (signals_df['short_entry_signal'].ix[forecast_series.index[-1]] == True):
            signals_df['short_exit_signal'].ix[forecast_series.index[-1] + BDay(1)] = True
            
    print('last dates-', ts.iloc[:i].index[-3:])
    i += forecast_period
    
    
#signals_df.loc[(signals_df.long_exit_signal == True) & (signals_df.long_entry_signal == True), 'long_exit_signal'] = False
#signals_df.loc[(signals_df.short_exit_signal == True) & (signals_df.short_entry_signal == True), 'short_exit_signal'] = False
# Out:
# last dates- DatetimeIndex(['2011-06-15', '2011-06-16', '2011-06-17'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-06-17', '2011-06-18', '2011-06-19'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-06-19', '2011-06-20', '2011-06-21'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-06-21', '2011-06-22', '2011-06-23'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-06-23', '2011-06-24', '2011-06-25'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-06-25', '2011-06-26', '2011-06-27'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-06-27', '2011-06-28', '2011-06-29'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-06-29', '2011-06-30', '2011-07-01'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-01', '2011-07-02', '2011-07-03'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-03', '2011-07-04', '2011-07-05'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-05', '2011-07-06', '2011-07-07'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-07', '2011-07-08', '2011-07-09'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-09', '2011-07-10', '2011-07-11'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-11', '2011-07-12', '2011-07-13'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-13', '2011-07-14', '2011-07-15'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-15', '2011-07-16', '2011-07-17'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-17', '2011-07-18', '2011-07-19'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-19', '2011-07-20', '2011-07-21'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-21', '2011-07-22', '2011-07-23'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-23', '2011-07-24', '2011-07-25'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-25', '2011-07-26', '2011-07-27'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-27', '2011-07-28', '2011-07-29'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-29', '2011-07-30', '2011-07-31'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-07-31', '2011-08-01', '2011-08-02'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-02', '2011-08-03', '2011-08-04'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-04', '2011-08-05', '2011-08-06'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-06', '2011-08-07', '2011-08-08'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-08', '2011-08-09', '2011-08-10'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-10', '2011-08-11', '2011-08-12'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-12', '2011-08-13', '2011-08-14'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-14', '2011-08-15', '2011-08-16'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-16', '2011-08-17', '2011-08-18'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-18', '2011-08-19', '2011-08-20'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-20', '2011-08-21', '2011-08-22'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-22', '2011-08-23', '2011-08-24'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-24', '2011-08-25', '2011-08-26'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-26', '2011-08-27', '2011-08-28'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-28', '2011-08-29', '2011-08-30'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-08-30', '2011-08-31', '2011-09-01'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-01', '2011-09-02', '2011-09-03'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-03', '2011-09-04', '2011-09-05'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-05', '2011-09-06', '2011-09-07'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-07', '2011-09-08', '2011-09-09'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-09', '2011-09-10', '2011-09-11'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-11', '2011-09-12', '2011-09-13'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-13', '2011-09-14', '2011-09-15'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-15', '2011-09-16', '2011-09-17'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-17', '2011-09-18', '2011-09-19'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-19', '2011-09-20', '2011-09-21'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-21', '2011-09-22', '2011-09-23'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-23', '2011-09-24', '2011-09-25'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-25', '2011-09-26', '2011-09-27'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-27', '2011-09-28', '2011-09-29'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-09-29', '2011-09-30', '2011-10-01'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-10-01', '2011-10-02', '2011-10-03'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-10-03', '2011-10-04', '2011-10-05'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-10-05', '2011-10-06', '2011-10-07'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-10-07', '2011-10-08', '2011-10-09'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-10-09', '2011-10-10', '2011-10-11'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-10-11', '2011-10-12', '2011-10-13'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-10-13', '2011-10-14', '2011-10-15'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-10-15', '2011-10-16', '2011-10-17'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-10-17', '2011-10-18', '2011-10-19'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-10-19', '2011-10-20', '2011-10-21'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2011-10
28'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-06-28', '2016-06-29', '2016-06-30'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-06-30', '2016-07-01', '2016-07-02'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-02', '2016-07-03', '2016-07-04'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-04', '2016-07-05', '2016-07-06'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-06', '2016-07-07', '2016-07-08'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-08', '2016-07-09', '2016-07-10'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-10', '2016-07-11', '2016-07-12'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-12', '2016-07-13', '2016-07-14'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-14', '2016-07-15', '2016-07-16'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-16', '2016-07-17', '2016-07-18'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-18', '2016-07-19', '2016-07-20'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-20', '2016-07-21', '2016-07-22'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-22', '2016-07-23', '2016-07-24'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-24', '2016-07-25', '2016-07-26'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-26', '2016-07-27', '2016-07-28'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-28', '2016-07-29', '2016-07-30'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-07-30', '2016-07-31', '2016-08-01'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-01', '2016-08-02', '2016-08-03'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-03', '2016-08-04', '2016-08-05'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-05', '2016-08-06', '2016-08-07'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-07', '2016-08-08', '2016-08-09'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-09', '2016-08-10', '2016-08-11'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-11', '2016-08-12', '2016-08-13'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-13', '2016-08-14', '2016-08-15'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-15', '2016-08-16', '2016-08-17'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-17', '2016-08-18', '2016-08-19'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-19', '2016-08-20', '2016-08-21'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-21', '2016-08-22', '2016-08-23'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-23', '2016-08-24', '2016-08-25'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-25', '2016-08-26', '2016-08-27'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-27', '2016-08-28', '2016-08-29'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-29', '2016-08-30', '2016-08-31'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-08-31', '2016-09-01', '2016-09-02'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-02', '2016-09-03', '2016-09-04'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-04', '2016-09-05', '2016-09-06'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-06', '2016-09-07', '2016-09-08'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-08', '2016-09-09', '2016-09-10'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-10', '2016-09-11', '2016-09-12'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-12', '2016-09-13', '2016-09-14'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-14', '2016-09-15', '2016-09-16'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-16', '2016-09-17', '2016-09-18'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-18', '2016-09-19', '2016-09-20'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-20', '2016-09-21', '2016-09-22'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-22', '2016-09-23', '2016-09-24'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-24', '2016-09-25', '2016-09-26'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-26', '2016-09-27', '2016-09-28'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-28', '2016-09-29', '2016-09-30'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-09-30', '2016-10-01', '2016-10-02'], dtype='datetime64[ns]', freq=None)
# DATES IS NOT EXIST DatetimeIndex(['2016-10-03', '2016-10-04', '2016-10-05', '2016-10-23'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-10-04', '2016-10-05', '2016-10-23'], dtype='datetime64[ns]', freq=None)
# last dates- DatetimeIndex(['2016-10-23', '2016-10-24', '2016-10-25'], dtype='datetime64[ns]', freq=None)

# %%
entry = signals_df.long_entry_signal
exit = signals_df.long_exit_signal

#entry = signals_df.short_entry_signal
#exit = signals_df.short_exit_signal

exodf = pd.DataFrame()
exodf['exo'] = px_ser.dropna()

direction = -1
pl, inposition = backtester.backtest(exodf.iloc[:], entry, exit, direction)
equity, stats = backtester.stats(pl, inposition)

equity.plot()

(px_ser*-1).plot()

# %%
(equity.diff() - 6).cumsum().plot()

# %%
#stats

# %%
#entry = signals_df.long_entry_signal
#exit = signals_df.long_exit_signal

entry = signals_df.short_entry_signal
exit = signals_df.short_exit_signal

exodf = pd.DataFrame()
exodf['exo'] = px_ser.asfreq('B').dropna()

direction = -1
pl, inposition = backtester.backtest(exodf.iloc[:], entry, exit, direction)
equity, stats = backtester.stats(pl, inposition)

equity.plot()

(px_ser*-1).plot()
