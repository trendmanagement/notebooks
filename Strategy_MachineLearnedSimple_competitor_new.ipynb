# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys,os
sys.path.append('..')
from backtester import matlab, backtester
from backtester.analysis import *
from backtester.strategy import StrategyBase, OptParam, OptParamArray
from backtester.swarms.ranking import SwarmRanker
from backtester.swarms.rebalancing import SwarmRebalance
from backtester.swarms.filters import SwarmFilter
from backtester.costs import CostsManagerEXOFixed
from backtester.exoinfo import EXOInfo
from backtester.swarms.rankingclasses import *
from backtester.swarms.swarm import Swarm


import pandas as pd
import numpy as np
import scipy

# %%
from strategies.strategy_machinelearned_competitor import StrategyMachineLearnedCompetitor

# %%
from scripts.settings import *
try:
    from scripts.settings_local import *
except:
    pass

from exobuilder.data.exostorage import EXOStorage

storage = EXOStorage(MONGO_CONNSTR, MONGO_EXO_DB)


exo_filter = '*'     # All 
#exo_filter = 'ES_'  # ES only
exo_filter = 'ES*Collar'  # ES Collars (incl Bearish, Bullish, BW and vanilla)

[print(exo) for exo in storage.exo_list(exo_filter)];
# Out:
# ES_BullishCollarBW
# ES_BearishCollarBW

# %% [markdown]
# ## Script settings

# %%
STRATEGY_CONTEXT = {
    'strategy': { 
        'class': StrategyMachineLearnedCompetitor,
        'exo_name': 'ES_BullishCollarBW',        # <---- Select and paste EXO name from cell above
        'exo_storage': storage,
        'opt_params': [
                        #OptParam(name, default_value, min_value, max_value, step)
                        OptParamArray('Direction', [-1]),
                        OptParam('rolling_window_period', 5, 1, 100, 10),
                        OptParam('pct_rank_value', 1, 10, 90, 5),
                        OptParamArray('RuleIndex', np.arange(5)),
                        OptParam('MedianPeriod', 5, 1, 5, 1)
            ],
    },
    'swarm': {
        'members_count': 5,
        'ranking_class': RankerBestWithCorrel(window_size=-1, correl_threshold=0.5),
        'rebalance_time_function': SwarmRebalance.every_friday,

    },
    'costs':{
        'manager': CostsManagerEXOFixed,
        'context': {
            'costs_options': 3.0,
            'costs_futures': 3.0,
        }
    }
}

# %% [markdown]
# # Backtest class based strategy

# %%
smgr = Swarm(STRATEGY_CONTEXT)
smgr.run_swarm()
smgr.pick()

# Saving results to swarms directory
smgr.save('./swarms/')

# %% [markdown]
# ### WARNING! Loading swarm from file (don't run next cell if you want new swarm instance)

# %%
#smgr = Swarm.load(strategy_context=STRATEGY_CONTEXT, directory='./swarms/')
#print('Loading: '+smgr.get_swarm_name())

# %%
figsize(10,10)
smgr.picked_equity.plot(label='Picked swarm equity');
smgr.raw_equity.plot(label='Average swarm equity');
legend(loc=2);

# %%
smgr.raw_swarm.plot(legend=False)

# %%
#
# To export swarms above to .csv, uncomment this
#

#swarm_df = smgr.swarm
#swarm_df.to_csv('./temp_swarms/ichi_swarm.csv')

# %%
figsize(10,10)
smgr.picked_equity.plot(label='Picked swarm equity');
smgr.raw_equity.plot(label='Average swarm equity');
legend(loc=2);

# %%
smgr.picked_swarm.plot()

# %% [markdown]
# # Swarm exposure

# %%
smgr.picked_exposure.sum(axis=1).rolling(10).mean().plot()

# %% [markdown]
# # Swarm statistics

# %% [markdown]
# #### Non-picked swarm stats

# %%
smgr.picked_stats

# %% [markdown]
# ## Exo information

# %%
smgr.strategy.exoinfo.exo_info

# %%
smgr.strategy.exoinfo.data.exo.plot()

# %% [markdown]
# ### Global filter information (obsolete)

# %% [markdown]
# ## Costs information (per 1-exo unit)

# %%
figsize(10,5)
smgr.strategy.costs.plot()

# %% [markdown]
# ## Margin graphs

# %% [markdown]
# ### EXO Margin (per 1 EXO unit)

# %%
smgr.strategy.exoinfo.margin().plot()

# %% [markdown]
# # Saving results

# %%
smgr.save('./swarms/')
