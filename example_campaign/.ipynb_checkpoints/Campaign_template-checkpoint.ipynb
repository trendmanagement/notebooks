# %%
import sys,os
sys.path.append('..')
sys.path.append('../..')
from backtester import matlab, backtester
from backtester.analysis import *
from backtester.swarms.manager import SwarmManager
from backtester.exoinfo import EXOInfo

import pandas as pd
import numpy as np
import scipy

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
TMQRPATH = os.getenv("TMQRPATH", '/var/data/tmqrengine')

swarms = {}
for file in os.listdir(os.path.join(TMQRPATH, 'swarms')):
    swarm_name = file.replace('.swm','')
    swarms[swarm_name] = SwarmManager.load(os.path.join(TMQRPATH, 'swarms', file))

# %% [markdown]
# ### Available swarms

# %%
print("Swarms list:")
for swarm_name in sorted(swarms.keys()):
    print(swarm_name)
# Out:
# Swarms list:
# CLE_BearishCollarBrokenWing_Long_BollingerBands
# CLE_BearishCollarBrokenWing_Long_IchimokuCloud
# CLE_BearishCollarBrokenWing_Long_MACross
# CLE_BearishCollarBrokenWing_Long_PointAndFigurePatterns
# CLE_BearishCollarBrokenWing_Long_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# CLE_BearishCollarBrokenWing_Long_SwingPoint
# CLE_BearishCollarBrokenWing_Long_VolatilityCompression
# CLE_BearishCollarBrokenWing_Short_BollingerBands
# CLE_BearishCollarBrokenWing_Short_IchimokuCloud
# CLE_BearishCollarBrokenWing_Short_MACross
# CLE_BearishCollarBrokenWing_Short_PointAndFigurePatterns
# CLE_BearishCollarBrokenWing_Short_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# CLE_BearishCollarBrokenWing_Short_SwingPoint
# CLE_BearishCollarBrokenWing_Short_VolatilityCompression
# CLE_BullishCollarBrokenWing_Long_BollingerBands
# CLE_BullishCollarBrokenWing_Long_IchimokuCloud
# CLE_BullishCollarBrokenWing_Long_MACross
# CLE_BullishCollarBrokenWing_Long_PointAndFigurePatterns
# CLE_BullishCollarBrokenWing_Long_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# CLE_BullishCollarBrokenWing_Long_SwingPoint
# CLE_BullishCollarBrokenWing_Long_VolatilityCompression
# CLE_BullishCollarBrokenWing_Short_BollingerBands
# CLE_BullishCollarBrokenWing_Short_IchimokuCloud
# CLE_BullishCollarBrokenWing_Short_MACross
# CLE_BullishCollarBrokenWing_Short_PointAndFigurePatterns
# CLE_BullishCollarBrokenWing_Short_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# CLE_BullishCollarBrokenWing_Short_SwingPoint
# CLE_BullishCollarBrokenWing_Short_VolatilityCompression
# CLE_PutSpread_Long_BollingerBands
# CLE_PutSpread_Long_IchimokuCloud
# CLE_PutSpread_Long_MACross
# CLE_PutSpread_Long_PointAndFigurePatterns
# CLE_PutSpread_Long_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# CLE_PutSpread_Long_SwingPoint
# CLE_PutSpread_Long_VolatilityCompression
# CLE_PutSpread_Short_BollingerBands
# CLE_PutSpread_Short_IchimokuCloud
# CLE_PutSpread_Short_MACross
# CLE_PutSpread_Short_PointAndFigurePatterns
# CLE_PutSpread_Short_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# CLE_PutSpread_Short_SwingPoint
# CLE_PutSpread_Short_VolatilityCompression
# EP_BearishCollarBrokenWing_Long_BollingerBands
# EP_BearishCollarBrokenWing_Long_IchimokuCloud
# EP_BearishCollarBrokenWing_Long_MACross
# EP_BearishCollarBrokenWing_Long_PointAndFigurePatterns
# EP_BearishCollarBrokenWing_Long_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# EP_BearishCollarBrokenWing_Long_SwingPoint
# EP_BearishCollarBrokenWing_Long_VolatilityCompression
# EP_BearishCollarBrokenWing_Short_BollingerBands
# EP_BearishCollarBrokenWing_Short_IchimokuCloud
# EP_BearishCollarBrokenWing_Short_MACross
# EP_BearishCollarBrokenWing_Short_PointAndFigurePatterns
# EP_BearishCollarBrokenWing_Short_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# EP_BearishCollarBrokenWing_Short_SwingPoint
# EP_BearishCollarBrokenWing_Short_VolatilityCompression
# EP_BullishCollarBrokenWing_Long_BollingerBands
# EP_BullishCollarBrokenWing_Long_IchimokuCloud
# EP_BullishCollarBrokenWing_Long_MACross
# EP_BullishCollarBrokenWing_Long_PointAndFigurePatterns
# EP_BullishCollarBrokenWing_Long_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# EP_BullishCollarBrokenWing_Long_SwingPoint
# EP_BullishCollarBrokenWing_Long_VolatilityCompression
# EP_BullishCollarBrokenWing_Short_BollingerBands
# EP_BullishCollarBrokenWing_Short_IchimokuCloud
# EP_BullishCollarBrokenWing_Short_MACross
# EP_BullishCollarBrokenWing_Short_PointAndFigurePatterns
# EP_BullishCollarBrokenWing_Short_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# EP_BullishCollarBrokenWing_Short_SwingPoint
# EP_BullishCollarBrokenWing_Short_VolatilityCompression
# EP_CallSpread_Long_PointAndFigurePatterns
# EP_CallSpread_Short_PointAndFigurePatterns
# EP_CallSpread_Short_SwingPoint
# NGE_BullishCollarBrokenWing_Long_BollingerBands
# NGE_BullishCollarBrokenWing_Long_IchimokuCloud
# NGE_BullishCollarBrokenWing_Long_MACross
# NGE_BullishCollarBrokenWing_Long_PointAndFigurePatterns
# NGE_BullishCollarBrokenWing_Long_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# NGE_BullishCollarBrokenWing_Long_SwingPoint
# NGE_BullishCollarBrokenWing_Long_VolatilityCompression
# NGE_BullishCollarBrokenWing_Short_BollingerBands
# NGE_BullishCollarBrokenWing_Short_IchimokuCloud
# NGE_BullishCollarBrokenWing_Short_MACross
# NGE_BullishCollarBrokenWing_Short_PointAndFigurePatterns
# NGE_BullishCollarBrokenWing_Short_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# NGE_BullishCollarBrokenWing_Short_SwingPoint
# NGE_BullishCollarBrokenWing_Short_VolatilityCompression
# TYA_CallSpread_Long_BollingerBands
# TYA_CallSpread_Long_IchimokuCloud
# TYA_CallSpread_Long_MACross
# TYA_CallSpread_Long_PointAndFigurePatterns
# TYA_CallSpread_Long_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# TYA_CallSpread_Long_SwingPoint
# TYA_CallSpread_Long_VolatilityCompression
# TYA_CallSpread_Short_BollingerBands
# TYA_CallSpread_Short_IchimokuCloud
# TYA_CallSpread_Short_MACross
# TYA_CallSpread_Short_PointAndFigurePatterns
# TYA_CallSpread_Short_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# TYA_CallSpread_Short_SwingPoint
# TYA_CallSpread_Short_VolatilityCompression
# ZCE_BearishCollarBrokenWing_Long_BollingerBands
# ZCE_BearishCollarBrokenWing_Long_IchimokuCloud
# ZCE_BearishCollarBrokenWing_Long_MACross
# ZCE_BearishCollarBrokenWing_Long_PointAndFigurePatterns
# ZCE_BearishCollarBrokenWing_Long_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# ZCE_BearishCollarBrokenWing_Long_SwingPoint
# ZCE_BearishCollarBrokenWing_Long_VolatilityCompression
# ZCE_BearishCollarBrokenWing_Short_BollingerBands
# ZCE_BearishCollarBrokenWing_Short_IchimokuCloud
# ZCE_BearishCollarBrokenWing_Short_MACross
# ZCE_BearishCollarBrokenWing_Short_PointAndFigurePatterns
# ZCE_BearishCollarBrokenWing_Short_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# ZCE_BearishCollarBrokenWing_Short_SwingPoint
# ZCE_BearishCollarBrokenWing_Short_VolatilityCompression
# ZCE_BullishCollarBrokenWing_Long_BollingerBands
# ZCE_BullishCollarBrokenWing_Long_IchimokuCloud
# ZCE_BullishCollarBrokenWing_Long_MACross
# ZCE_BullishCollarBrokenWing_Long_PointAndFigurePatterns
# ZCE_BullishCollarBrokenWing_Long_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# ZCE_BullishCollarBrokenWing_Long_SwingPoint
# ZCE_BullishCollarBrokenWing_Long_VolatilityCompression
# ZCE_BullishCollarBrokenWing_Short_BollingerBands
# ZCE_BullishCollarBrokenWing_Short_IchimokuCloud
# ZCE_BullishCollarBrokenWing_Short_MACross
# ZCE_BullishCollarBrokenWing_Short_PointAndFigurePatterns
# ZCE_BullishCollarBrokenWing_Short_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# ZCE_BullishCollarBrokenWing_Short_SwingPoint
# ZCE_BullishCollarBrokenWing_Short_VolatilityCompression
# ZCE_PutSpread_Long_BollingerBands
# ZCE_PutSpread_Long_IchimokuCloud
# ZCE_PutSpread_Long_MACross
# ZCE_PutSpread_Long_PointAndFigurePatterns
# ZCE_PutSpread_Long_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# ZCE_PutSpread_Long_SwingPoint
# ZCE_PutSpread_Long_VolatilityCompression
# ZCE_PutSpread_Short_BollingerBands
# ZCE_PutSpread_Short_IchimokuCloud
# ZCE_PutSpread_Short_MACross
# ZCE_PutSpread_Short_PointAndFigurePatterns
# ZCE_PutSpread_Short_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# ZCE_PutSpread_Short_SwingPoint
# ZCE_PutSpread_Short_VolatilityCompression
# ZSE_BearishCollarBrokenWing_Long_BollingerBands
# ZSE_BearishCollarBrokenWing_Long_IchimokuCloud
# ZSE_BearishCollarBrokenWing_Long_MACross
# ZSE_BearishCollarBrokenWing_Long_PointAndFigurePatterns
# ZSE_BearishCollarBrokenWing_Long_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# ZSE_BearishCollarBrokenWing_Long_SwingPoint
# ZSE_BearishCollarBrokenWing_Long_VolatilityCompression
# ZSE_BearishCollarBrokenWing_Short_BollingerBands
# ZSE_BearishCollarBrokenWing_Short_IchimokuCloud
# ZSE_BearishCollarBrokenWing_Short_MACross
# ZSE_BearishCollarBrokenWing_Short_PointAndFigurePatterns
# ZSE_BearishCollarBrokenWing_Short_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# ZSE_BearishCollarBrokenWing_Short_SwingPoint
# ZSE_BearishCollarBrokenWing_Short_VolatilityCompression
# ZSE_PutSpread_Long_BollingerBands
# ZSE_PutSpread_Long_IchimokuCloud
# ZSE_PutSpread_Long_MACross
# ZSE_PutSpread_Long_PointAndFigurePatterns
# ZSE_PutSpread_Long_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# ZSE_PutSpread_Long_SwingPoint
# ZSE_PutSpread_Long_VolatilityCompression
# ZSE_PutSpread_Short_BollingerBands
# ZSE_PutSpread_Short_IchimokuCloud
# ZSE_PutSpread_Short_MACross
# ZSE_PutSpread_Short_PointAndFigurePatterns
# ZSE_PutSpread_Short_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns
# ZSE_PutSpread_Short_SwingPoint
# ZSE_PutSpread_Short_VolatilityCompression

# %% [markdown]
# ### Available EXOs

# %%
passive_exo = {}


print('Passive EXO list')
for matfile in os.listdir(os.path.join(TMQRPATH, 'mat')):    
    if 'strategy_' in matfile and '.mat' in matfile:
        exo = EXOInfo.from_matfile(os.path.join(TMQRPATH, 'mat', matfile))
        passive_exo[exo.exo_name()] = exo.exo_price_index()    

for exo in sorted(passive_exo.keys()):
    print(exo)
# Out:
# Passive EXO list
# CLE_BearishCollarBrokenWing_EXO
# CLE_BullishCollarBrokenWing_EXO
# CLE_CallSpread_EXO
# CLE_PutSpread_EXO
# EP_BearishCollarBrokenWing_EXO
# EP_BullishCollarBrokenWing_EXO
# EP_CallSpread_EXO
# EP_PutSpread_EXO
# NGE_BearishCollarBrokenWing_EXO
# NGE_BullishCollarBrokenWing_EXO
# NGE_CallSpread_EXO
# NGE_PutSpread_EXO
# TYA_BearishCollarBrokenWing_EXO
# TYA_BullishCollarBrokenWing_EXO
# TYA_CallSpread_EXO
# TYA_PutSpread_EXO
# ZCE_BearishCollarBrokenWing_EXO
# ZCE_BullishCollarBrokenWing_EXO
# ZCE_CallSpread_EXO
# ZCE_PutSpread_EXO
# ZSE_BearishCollarBrokenWing_EXO
# ZSE_BullishCollarBrokenWing_EXO
# ZSE_CallSpread_EXO
# ZSE_PutSpread_EXO

# %% [markdown]
# # Campaign composition

# %% [markdown]
# Copy/paste EXO or swarm names to the 'campaign_exposure' dictionary from lists above

# %%
campaign_exposure = {
     'CLE_BearishCollarBrokenWing_Short_SwingPoint': 1,
     'CLE_PutSpread_Long_RenkoPatterns_no_exit_on_patterns_no-exit-on-patterns': 1,
     #'EP_BearishCollarBrokenWing_SwingPoint_Short': 1,
     
     #
     # Passive EXO positions
     #
     'CLE_PutSpread_EXO': -1, # Short 1 EXO units
     
}

# %%
#def campaign_equity(swarms, exposure):

campaign_dict = {}
campaign_stats = {'NetProfit': 0.0, 'TradesCount': 0, 'CommissionSum': 0.0}

for camp_name, exposure in campaign_exposure.items():
    if camp_name in swarms:
        swarm_name = camp_name
        smgr = swarms[swarm_name]
        campaign_dict[swarm_name] = smgr.swarm_picked.diff().sum(axis=1) * exposure
        s = smgr.get_swarm_stats(smgr.swarm_picked_stats)
        
        campaign_stats['NetProfit'] += s['NetProfit']
        campaign_stats['TradesCount'] += s['TradesCount']
        campaign_stats['CommissionSum'] += s['CommissionSum']
        
    elif camp_name in passive_exo:
        exo_equity = passive_exo[camp_name]
        campaign_dict[camp_name] = exo_equity.diff() * exposure
    
    
campaign_portfolio = pd.DataFrame(campaign_dict).cumsum()
campaign_equity = campaign_portfolio.sum(axis=1)

# %% [markdown]
# ### Campaign members equities

# %%
figsize(10,10)
campaign_portfolio.plot()

# %% [markdown]
# ### Cumulative campaign equity

# %%
campaign_portfolio.sum(axis=1).plot()

# %% [markdown]
# # Campaign statistics

# %%
print(campaign_stats)
# Out:
# {'TradesCount': 691.0, 'CommissionSum': -12474.0, 'NetProfit': 11114.50000000002}
