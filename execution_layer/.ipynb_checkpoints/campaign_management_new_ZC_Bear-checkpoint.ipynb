# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from tradingcore.execution_manager import ExecutionManager
from tradingcore.campaign import Campaign
from tradingcore.account import Account
from tradingcore.moneymanagement import PlainMM

from exobuilder.data.datasource_mongo import DataSourceMongo
from exobuilder.data.datasource_sql import DataSourceSQL
from exobuilder.data.assetindex_mongo import AssetIndexMongo
from exobuilder.data.exostorage import EXOStorage

import pprint

# %%
try:
    from .settings import *
except SystemError:
    from scripts.settings import *

try:
    from .settings_local import *
except SystemError:
    try:
        from scripts.settings_local import *
    except ImportError:
        pass
    pass

# %%
assetindex = AssetIndexMongo(MONGO_CONNSTR, MONGO_EXO_DB)
storage = EXOStorage(MONGO_CONNSTR, MONGO_EXO_DB)
#datasource = DataSourceSQL(SQL_HOST, SQL_USER, SQL_PASS, assetindex, futures_limit=10, options_limit=10)
datasource = DataSourceMongo(MONGO_CONNSTR, MONGO_EXO_DB, assetindex, futures_limit=10, options_limit=10, exostorage=storage)

# %%
exmgr = ExecutionManager(MONGO_CONNSTR, datasource, dbname=MONGO_EXO_DB)

# %%
campaigns = exmgr.campaign_load_all()
accounts = exmgr.account_load_all()
pp = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# ## List of available campaigns

# %%
[print(x) for x in campaigns.keys()];
# Out:
# test_campaign
# NG_Bear
# CL_Sample
# ZS_Bear
# ZW_Bull
# ZS_Bull
# ZN_Bear
# CL_Bullish
# CL_Bear
# ZW_Bear
# NG_Bull
# CL_Bull
# ZN_Bull

# %%
swm_info = storage.swarms_info()
pp.pprint(swm_info)
# Out:
# {   '_id': None,
#     'alphas': [   'RenkoPatternsNoExits',
#                   'SwingPoint',
#                   'EXO',
#                   'PointAndFigure',
#                   'IchimokuCloud',
#                   'MACross',
#                   'BolllingerBands'],
#     'exo_types': [   'CallSpread',
#                      'PutSpread',
#                      'ContFut',
#                      'BullishCollarBW',
#                      'BearishCollarBW'],
#     'instruments': ['ZC', 'NG', 'ZN', 'ES', 'ZS', 'CL', 'ZW']}

# %% [markdown]
# # Alphas list

# %%
instruments_filter = ['ZC']  # Select ALL
#instruments_filter = ['ES', 'CL']

exo_filter = ['*'] # Select ALL
#exo_filter = ['BullishCollar']

direction_filter = [0, -1, 1] # Select ALL
#direction_filter = [1]

alpha_filter = ['']  # Select ALL
#alpha_filter = ['MaCross', 'PointAndFigurePatterns']

swmdf, swm_data = storage.swarms_list(instruments_filter, direction_filter, alpha_filter, exo_filter)

[print(s) for s in sorted(swmdf.columns)];
# Out:
# ZC_BearishCollarBW_Long_EXO
# ZC_BearishCollarBW_Short_EXO
# ZC_BullishCollarBW_Long_EXO
# ZC_BullishCollarBW_Short_EXO
# ZC_CallSpread_Long_BolllingerBands_bullish-custom
# ZC_CallSpread_Long_EXO
# ZC_CallSpread_Long_IchimokuCloud_alt2-bullish-custom
# ZC_CallSpread_Long_IchimokuCloud_bullish-custom
# ZC_CallSpread_Long_SwingPoint_bullish-custom
# ZC_CallSpread_Short_EXO
# ZC_CallSpread_Short_IchimokuCloud_bearish-custom
# ZC_CallSpread_Short_IchimokuCloud_bullish-custom
# ZC_CallSpread_Short_MACross_bearish-custom
# ZC_ContFut_Long_EXO
# ZC_ContFut_Short_EXO
# ZC_PutSpread_Long_BolllingerBands_alt2-bearish-custom
# ZC_PutSpread_Long_BolllingerBands_bearish-custom
# ZC_PutSpread_Long_EXO
# ZC_PutSpread_Long_IchimokuCloud_bearish-custom
# ZC_PutSpread_Long_MACross_bearish-custom
# ZC_PutSpread_Short_BolllingerBands_bullish-custom
# ZC_PutSpread_Short_EXO

# %%
passive_exo = {}

exo_filter = '*'     # All 
#exo_filter = 'ES_'  # ES only
exo_filter = 'ZS*'  # ES Collars (incl Bearish, Bullish, BW and vanilla)


print('==== Passive EXO list')
for exo_name in storage.exo_list(exo_filter):
    passive_exo[exo_name], exo_dict = storage.load_series(exo_name)

for exo in sorted(passive_exo.keys()):
    print(exo)
    
print('==== Alphas EXO list')
[print(s) for s in sorted(swmdf.columns)];
# Out:
# ==== Passive EXO list
# ZS_BearishCollarBW
# ZS_BullishCollarBW
# ZS_CallSpread
# ZS_ContFut
# ZS_PutSpread
# ==== Alphas EXO list
# ZC_BearishCollarBW_Long_EXO
# ZC_BearishCollarBW_Short_EXO
# ZC_BullishCollarBW_Long_EXO
# ZC_BullishCollarBW_Short_EXO
# ZC_CallSpread_Long_BolllingerBands_bullish-custom
# ZC_CallSpread_Long_EXO
# ZC_CallSpread_Long_IchimokuCloud_alt2-bullish-custom
# ZC_CallSpread_Long_IchimokuCloud_bullish-custom
# ZC_CallSpread_Long_SwingPoint_bullish-custom
# ZC_CallSpread_Short_EXO
# ZC_CallSpread_Short_IchimokuCloud_bearish-custom
# ZC_CallSpread_Short_IchimokuCloud_bullish-custom
# ZC_CallSpread_Short_MACross_bearish-custom
# ZC_ContFut_Long_EXO
# ZC_ContFut_Short_EXO
# ZC_PutSpread_Long_BolllingerBands_alt2-bearish-custom
# ZC_PutSpread_Long_BolllingerBands_bearish-custom
# ZC_PutSpread_Long_EXO
# ZC_PutSpread_Long_IchimokuCloud_bearish-custom
# ZC_PutSpread_Long_MACross_bearish-custom
# ZC_PutSpread_Short_BolllingerBands_bullish-custom
# ZC_PutSpread_Short_EXO

# %%
swmdf.plot().legend(loc='best', bbox_to_anchor=(1, 0.5));

# %% [markdown]
# # Campaign composition

# %%
 campaign_dict = {
            'name': 'ZC_Bear',
            'description': 'Bearish Expression of Corn',
            'alphas': {
                 'ZC_CallSpread_Short_IchimokuCloud_bearish-custom': {
                    'qty': 1.0,
                },
            'ZC_CallSpread_Short_MACross_bearish-custom': {
                    'qty': 1.0,
                },
            'ZC_PutSpread_Long_BolllingerBands_alt2-bearish-custom': {
                    'qty': 1.0,
                },
             'ZC_PutSpread_Long_BolllingerBands_bearish-custom': {
                    'qty': 1.0,
                },
             'ZC_PutSpread_Long_IchimokuCloud_bearish-custom': {
                    'qty': 1.0,
                },
             'ZC_PutSpread_Long_MACross_bearish-custom': {
                    'qty': 1.0,
                },
            }
        }

# %%
cmp = Campaign(campaign_dict, datasource)

# %% [markdown]
# ### Save campaign

# %%
exmgr.campaign_save(cmp)

# %% [markdown]
# ## Campaign positions

# %% [markdown]
# ### Alphas positions

# %%
pp.pprint(cmp.alphas_positions)
# Out:
# {   'ZC_CallSpread_Short_IchimokuCloud_bearish-custom': {   'exo_name': 'ZC_CallSpread',
#                                                             'exposure': -1.0,
#                                                             'prev_exposure': -1.0},
#     'ZC_CallSpread_Short_MACross_bearish-custom': {   'exo_name': 'ZC_CallSpread',
#                                                       'exposure': 0.0,
#                                                       'prev_exposure': 0.0},
#     'ZC_PutSpread_Long_BolllingerBands_alt2-bearish-custom': {   'exo_name': 'ZC_PutSpread',
#                                                                  'exposure': 1.0,
#                                                                  'prev_exposure': 1.0},
#     'ZC_PutSpread_Long_BolllingerBands_bearish-custom': {   'exo_name': 'ZC_PutSpread',
#                                                             'exposure': 1.0,
#                                                             'prev_exposure': 1.0},
#     'ZC_PutSpread_Long_IchimokuCloud_bearish-custom': {   'exo_name': 'ZC_PutSpread',
#                                                           'exposure': 1.0,
#                                                           'prev_exposure': 1.0},
#     'ZC_PutSpread_Long_MACross_bearish-custom': {   'exo_name': 'ZC_PutSpread',
#                                                     'exposure': 1.0,
#                                                     'prev_exposure': 1.0}}

# %% [markdown]
# ### EXO net positions

# %%
pp.pprint(cmp.exo_positions)
# Out:
# {   'ZC_CallSpread': {'exposure': -1.0, 'prev_exposure': -1.0},
#     'ZC_PutSpread': {'exposure': 4.0, 'prev_exposure': 4.0}}

# %% [markdown]
# ### Contracts positions

# %%
pp.pprint(cmp.positions)
# Out:
# {   'C_US_ZCEX163300': {   'asset': {   '_id': ObjectId('57aae7e634ac2255e598a5ef'),
#                                         '_type': 'opt',
#                                         'callorput': 'C',
#                                         'cqgsymbol': 'C.US.ZCEX163300',
#                                         'expirationdate': datetime.datetime(2016, 10, 21, 0, 0),
#                                         'idcontract': 4794,
#                                         'idinstrument': 31,
#                                         'idoption': 11832238,
#                                         'name': 'C.US.ZCEX163300',
#                                         'optionmonth': 'X',
#                                         'optionmonthint': 11,
#                                         'optionname': 'C.US.ZCEX163300',
#                                         'optionyear': 2016,
#                                         'strikeprice': 330.0},
#                            'prev_qty': -1.0,
#                            'qty': -1.0},
#     'C_US_ZCEX163900': {   'asset': {   '_id': ObjectId('57aae7e634ac2255e598a5fb'),
#                                         '_type': 'opt',
#                                         'callorput': 'C',
#                                         'cqgsymbol': 'C.US.ZCEX163900',
#                                         'expirationdate': datetime.datetime(2016, 10, 21, 0, 0),
#                                         'idcontract': 4794,
#                                         'idinstrument': 31,
#                                         'idoption': 11832250,
#                                         'name': 'C.US.ZCEX163900',
#                                         'optionmonth': 'X',
#                                         'optionmonthint': 11,
#                                         'optionname': 'C.US.ZCEX163900',
#                                         'optionyear': 2016,
#                                         'strikeprice': 390.0},
#                            'prev_qty': 1.0,
#                            'qty': 1.0},
#     'P_US_ZCEX162900': {   'asset': {   '_id': ObjectId('57aae7e634ac2255e598a631'),
#                                         '_type': 'opt',
#                                         'callorput': 'P',
#                                         'cqgsymbol': 'P.US.ZCEX162900',
#                                         'expirationdate': datetime.datetime(2016, 10, 21, 0, 0),
#                                         'idcontract': 4794,
#                                         'idinstrument': 31,
#                                         'idoption': 11832304,
#                                         'name': 'P.US.ZCEX162900',
#                                         'optionmonth': 'X',
#                                         'optionmonthint': 11,
#                                         'optionname': 'P.US.ZCEX162900',
#                                         'optionyear': 2016,
#                                         'strikeprice': 290.0},
#                            'prev_qty': -4.0,
#                            'qty': -4.0},
#     'P_US_ZCEX163500': {   'asset': {   '_id': ObjectId('57aae7e634ac2255e598a63d'),
#                                         '_type': 'opt',
#                                         'callorput': 'P',
#                                         'cqgsymbol': 'P.US.ZCEX163500',
#                                         'expirationdate': datetime.datetime(2016, 10, 21, 0, 0),
#                                         'idcontract': 4794,
#                                         'idinstrument': 31,
#                                         'idoption': 11832316,
#                                         'name': 'P.US.ZCEX163500',
#                                         'optionmonth': 'X',
#                                         'optionmonthint': 11,
#                                         'optionname': 'P.US.ZCEX163500',
#                                         'optionyear': 2016,
#                                         'strikeprice': 350.0},
#                            'prev_qty': 4.0,
#                            'qty': 4.0}}
