# %%
import sys
sys.path.append('../..')
from backtester import matlab, backtester
from backtester.analysis import *
import pandas as pd
import numpy as np
import glob, os

import itertools

import statsmodels.tsa.stattools as ts

from backtester.exoinfo import EXOInfo
from exobuilder.data.exostorage import EXOStorage
from IPython.core.display import display, HTML

import pandas as pd
import numpy as np
import scipy
import pprint

# %pylab inline
figsize(20,10)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def hurst(ts):
    """Returns the Hurst Exponent of the time series vector ts"""
    # Create the range of lag values
    lags = range(2, 100)
    # Calculate the array of the variances of the lagged differences
    tau = [sqrt(std(subtract(ts[lag:], ts[:-lag]))) for lag in lags]
    # Use a linear fit to estimate the Hurst Exponent
    poly = polyfit(log(lags), log(tau), 1)
    # Return the Hurst exponent from the polyfit output
    return poly[0]*2.0

#hurst(ticker)

# %%
#
# random time series
#
df = pd.DataFrame()
for i in range(100):
    
    date = pd.date_range(start='2015-01', end='2016-10', freq='D')
    price = np.random.randint(-100, 101, size=len(date))
    
    ser = pd.Series(price, index=date, name='rng_system'+str(i))
    df['rng_system'+str(i)] = ser.cumsum()

# %%
# Only Cont Fut Flag
only_cont_fut = False

# %%
# Loading global setting for MongoDB etc.
from scripts.settings import *

try:
    from scripts.settings_local import *
except:
    pass

storage = EXOStorage(MONGO_CONNSTR, MONGO_EXO_DB)
pp = pprint.PrettyPrinter(indent=4)

exo_list = storage.exo_list()
pp.pprint(exo_list)


df = pd.DataFrame()

for e in exo_list:
    exo_series, exo_dict = storage.load_series(e)
    if only_cont_fut == True:   
        if 'Fut' in exo_dict['name']:   
            exo_series = exo_series[exo_series.columns[0]]
            df[exo_dict['name']] = exo_series
            
    if only_cont_fut == False:
        exo_series = exo_series[exo_series.columns[0]]
        df[exo_dict['name']] = exo_series
#exo_series.plot()
# Out:
# [   'ES_BullishCollarBW',
#     'ES_BearishCollarBW',
#     'ES_CallSpread',
#     'ES_PutSpread',
#     'ES_ContFut',
#     'ZS_BullishCollarBW',
#     'ZS_BearishCollarBW',
#     'ZS_CallSpread',
#     'ZS_PutSpread',
#     'ZS_ContFut',
#     'CL_BullishCollarBW',
#     'CL_BearishCollarBW',
#     'CL_CallSpread',
#     'CL_PutSpread',
#     'CL_ContFut',
#     'ZW_BullishCollarBW',
#     'ZW_BearishCollarBW',
#     'ZW_CallSpread',
#     'ZW_PutSpread',
#     'ZW_ContFut',
#     'ZN_BullishCollarBW',
#     'ZN_BearishCollarBW',
#     'ZN_CallSpread',
#     'ZN_PutSpread',
#     'ZN_ContFut',
#     'NG_BullishCollarBW',
#     'NG_BearishCollarBW',
#     'NG_CallSpread',
#     'NG_PutSpread',
#     'NG_ContFut',
#     'ZC_BullishCollarBW',
#     'ZC_BearishCollarBW',
#     'ZC_CallSpread',
#     'ZC_PutSpread',
#     'ZC_ContFut',
#     'CL_SMART_Ichimoku_Long',
#     'ES_SMART_Ichimoku_Long',
#     'NG_SMART_Ichimoku_Long',
#     'ZC_SMART_Ichimoku_Long',
#     'ZS_SMART_Ichimoku_Long',
#     'ZW_SMART_Ichimoku_Long',
#     'ZN_SMART_Ichimoku_Long',
#     'CL_SMART_Ichimoku_Straddle_Bullish',
#     'ES_SMART_Ichimoku_Straddle_Bullish']

# %%
df.head()
# Out:
#             ES_BullishCollarBW  ES_BearishCollarBW  ES_CallSpread  \
# 2011-03-01            0.000000            0.000000       0.000000
# 2011-03-02           39.272825          -14.130179      27.871356
# 2011-03-03          686.457895         -613.541434     604.899626
# 2011-03-04          219.643233         -323.818926     222.541720
# 2011-03-05          320.430076         -456.161686     302.033420
#
#             ES_PutSpread  ES_ContFut  ZS_BullishCollarBW  ZS_BearishCollarBW  \
# 2011-03-01      0.000000         0.0                 NaN                 NaN
# 2011-03-02      2.632618        62.5                 NaN                 NaN
# 2011-03-03   -361.312387      1187.5                 NaN                 NaN
# 2011-03-04   -177.722224       462.5                 NaN                 NaN
# 2011-03-05   -262.602220       650.0                 NaN                 NaN
#
#             ZS_CallSpread  ZS_PutSpread  ZS_ContFut  \
# 2011-03-01            NaN           NaN         NaN
# 2011-03-02            NaN           NaN         NaN
# 2011-03-03            NaN           NaN         NaN
# 2011-03-04            NaN           NaN         NaN
# 2011-03-05            NaN           NaN         NaN
#
#                            ...                  ZC_ContFut  \
# 2011-03-01                 ...                         NaN
# 2011-03-02                 ...                         NaN
# 2011-03-03                 ...                         NaN
# 2011-03-04                 ...                         NaN
# 2011-03-05                 ...                         NaN
#
#             CL_SMART_Ichimoku_Long  ES_SMART_Ichimoku_Long  \
# 2011-03-01                     NaN                     NaN
# 2011-03-02                     NaN                     NaN
# 2011-03-03                     NaN                     NaN
# 2011-03-04                     NaN                     NaN
# 2011-03-05                     NaN                     NaN
#
#             NG_SMART_Ichimoku_Long  ZC_SMART_Ichimoku_Long  \
# 2011-03-01                     NaN                     NaN
# 2011-03-02                     NaN                     NaN
# 2011-03-03                     NaN                     NaN
# 2011-03-04                     NaN                     NaN
# 2011-03-05                     NaN                     NaN
#
#             ZS_SMART_Ichimoku_Long  ZW_SMART_Ichimoku_Long  \
# 2011-03-01                     NaN                     NaN
# 2011-03-02                     NaN                     NaN
# 2011-03-03                     NaN                     NaN
# 2011-03-04                     NaN                     NaN
# 2011-03-05                     NaN                     NaN
#
#             ZN_SMART_Ichimoku_Long  CL_SMART_Ichimoku_Straddle_Bullish  \
# 2011-03-01                     NaN                                 NaN
# 2011-03-02                     NaN                                 NaN
# 2011-03-03                     NaN                                 NaN
# 2011-03-04                     NaN                                 NaN
# 2011-03-05                     NaN                                 NaN
#
#             ES_SMART_Ichimoku_Straddle_Bullish
# 2011-03-01                                 NaN
# 2011-03-02                                 NaN
# 2011-03-03                                 NaN
# 2011-03-04                                 NaN
# 2011-03-05                                 NaN
#
# [5 rows x 44 columns]

# %% [markdown]
# # 2 legs spreads

# %%
combinations_l = []
for L in range(0, len(df.columns)+1):
    for comb in itertools.combinations(df.columns, L):
        combinations_l.append(comb)

# %%
combination_ser = pd.Series(combinations_l)

# %%
combination_ser = combination_ser[combination_ser.str.len() == 2].reset_index(drop=True)

# %%
combination_ser.tail()
# Out:
# 295    (ZN_BearishCollarBW, ZN_PutSpread)
# 296      (ZN_BearishCollarBW, ZN_ContFut)
# 297         (ZN_CallSpread, ZN_PutSpread)
# 298           (ZN_CallSpread, ZN_ContFut)
# 299            (ZN_PutSpread, ZN_ContFut)
# dtype: object

# %%
for i in combination_ser:
    spread_df = df[list(i)]
    df[spread_df.columns[0] + '+' + spread_df.columns[1]] = spread_df[spread_df.columns[0]] + \
                                                                       spread_df[spread_df.columns[1]]

    df[spread_df.columns[0] + '-' + spread_df.columns[1]] = spread_df[spread_df.columns[0]] - \
                                                                       spread_df[spread_df.columns[1]]

# %%
df.head()
# Out:
#             ES_BullishCollarBW  ES_BearishCollarBW  ES_CallSpread  \
# 2011-06-01            0.000000            0.000000       0.000000
# 2011-06-02          -12.457409           71.272134     -22.735297
# 2011-06-03         -362.867533          473.373690    -341.005658
# 2011-06-04         -558.620863          611.124218    -535.107570
# 2011-06-05         -583.079787          603.900590    -560.981909
#
#             ES_PutSpread  CL_BullishCollarBW  CL_BearishCollarBW  \
# 2011-06-01      0.000000            0.000000            0.000000
# 2011-06-02     52.961586          111.636773         -295.800884
# 2011-06-03    326.849675         -549.227336           88.331157
# 2011-06-04    493.710175         -150.852076         -579.142734
# 2011-06-05    501.012394         -214.349181         -646.260653
#
#             CL_CallSpread  CL_PutSpread  NG_BullishCollarBW  \
# 2011-06-01       0.000000      0.000000            0.000000
# 2011-06-02      57.247423    -95.784181          915.084959
# 2011-06-03    -357.077029    161.802251          584.026209
# 2011-06-04     -80.153319   -213.110493          223.704196
# 2011-06-05    -103.391379   -241.545082          207.243883
#
#             NG_BearishCollarBW           ...             \
# 2011-06-01            0.000000           ...
# 2011-06-02         -844.361522           ...
# 2011-06-03         -652.955420           ...
# 2011-06-04         -412.381561           ...
# 2011-06-05         -432.232346           ...
#
#             ZN_BearishCollarBW+ZN_PutSpread  ZN_BearishCollarBW-ZN_PutSpread  \
# 2011-06-01                     -9431.352560                      -782.372497
# 2011-06-02                     -9179.424586                      -682.613453
# 2011-06-03                     -9376.962011                      -783.622743
# 2011-06-04                     -9589.863018                      -819.942669
# 2011-06-05                     -9616.172178                      -827.021045
#
#             ZN_BearishCollarBW+ZN_ContFut  ZN_BearishCollarBW-ZN_ContFut  \
# 2011-06-01                     643.137472                  -10856.862528
# 2011-06-02                     522.105981                  -10384.144019
# 2011-06-03                     654.082623                  -10814.667377
# 2011-06-04                     607.597157                  -11017.402843
# 2011-06-05                     590.903388                  -11034.096612
#
#             ZN_CallSpread+ZN_PutSpread  ZN_CallSpread-ZN_PutSpread  \
# 2011-06-01                 -353.774365                 8295.205698
# 2011-06-02                 -550.442243                 7946.368891
# 2011-06-03                 -320.853279                 8272.485989
# 2011-06-04                 -319.910054                 8450.010296
# 2011-06-05                 -328.669087                 8460.482047
#
#             ZN_CallSpread+ZN_ContFut  ZN_CallSpread-ZN_ContFut  \
# 2011-06-01               9720.715667              -1779.284333
# 2011-06-02               9151.088324              -1755.161676
# 2011-06-03               9710.191355              -1758.558645
# 2011-06-04               9877.550121              -1747.449879
# 2011-06-05               9878.406480              -1746.593520
#
#             ZN_PutSpread+ZN_ContFut  ZN_PutSpread-ZN_ContFut
# 2011-06-01              1425.509969            -10074.490031
# 2011-06-02              1204.719433             -9701.530567
# 2011-06-03              1437.705366            -10031.044634
# 2011-06-04              1427.539825            -10197.460175
# 2011-06-05              1417.924433            -10207.075567
#
# [5 rows x 625 columns]

# %%
temp_data_l = []
temp_name_l = []

for col in df.columns:
    ticker = df[col].dropna()
        
    price_change = ticker - ticker.shift(1)
    max_dd = (ticker - ticker.expanding().max()).min()

    period_end_price = ticker[-1]
    period_start_price = ticker[0]

    median_vola = (ticker - ticker.shift(1)).rolling(30).median()

    
    d = {}
    
    adf = ts.adfuller(ticker, 1)
    adf_teststats = adf[0]
    adf_pvalue = adf[1] 
    
    d = {'hurst': hurst(ticker), 'adf_teststats': adf_teststats, 'adf_pvalue': np.round(adf_pvalue, decimals=4)}
    
    for period in [2,5,10]:
        ema = ticker.ewm(period).mean()

        crossup = CrossUp(ticker, ema)
        crossdn = CrossDown(ticker, ema)

        days_wo_crossings_count = np.zeros_like(ticker.values)
        days_wo_crossings_counter = 0

        for i in range(len(ticker)):
            if (crossup[i] == False) | (crossdn[i] == False):
                days_wo_crossings_counter += 1
                days_wo_crossings_count[i] = days_wo_crossings_counter

            if (crossup[i] == True) | (crossdn[i] == True):
                days_wo_crossings_counter = 0
                days_wo_crossings_count[i] = days_wo_crossings_counter

        d['avg_days_wo_crossings_ema'+str(period)] = pd.Series(days_wo_crossings_count).mean()       

    temp_data_l.append(d)
    temp_name_l.append(ticker.name)

# %%
np.round(adf_pvalue, decimals=2)
# Out:
# 0.17000000000000001

# %%
ts.adfuller(df.ZN_ContFut.dropna())
# Out:
# (-2.1774954435608884,
#  0.21451445409384512,
#  0,
#  1721,
#  {'1%': -3.4341553924755388,
#   '10%': -2.5676648472926131,
#   '5%': -2.8632208679350253},
#  24557.654157273009)

# %%
ticker_stats_df = pd.DataFrame(temp_data_l, index=temp_name_l).dropna()

ticker_stats_df['avg_days_wo_crossings_sum'] = ticker_stats_df.filter(like='crossings', axis=1).sum(1)

#ticker_stats_df.sort_values('avg_days_wo_crossings_sum', ascending=False)
sorted_df = ticker_stats_df.sort_values('avg_days_wo_crossings_sum', ascending=False)#.reset_index()
sorted_df.reset_index()
# Out:
#                                  index  adf_pvalue  adf_teststats  \
# 0               ZN_SMART_Ichimoku_Long      0.0262      -3.104119
# 1               CL_SMART_Ichimoku_Long      0.8061      -0.843104
# 2               ZW_SMART_Ichimoku_Long      0.6355      -1.286079
# 3                         CL_PutSpread      0.9141      -0.375814
# 4   CL_SMART_Ichimoku_Straddle_Bullish      0.6912      -1.158457
# 5                   CL_BearishCollarBW      0.9046      -0.431870
# 6               ZC_SMART_Ichimoku_Long      0.4993      -1.568594
# 7               ZS_SMART_Ichimoku_Long      0.2848      -2.004080
# 8               NG_SMART_Ichimoku_Long      0.6053      -1.351458
# 9   ES_SMART_Ichimoku_Straddle_Bullish      0.1665      -2.317244
# 10                  ES_BearishCollarBW      0.8896      -0.512447
# 11                        ZS_PutSpread      0.2882      -1.996268
# 12                       ZS_CallSpread      0.5261      -1.514959
# 13              ES_SMART_Ichimoku_Long      0.4576      -1.648970
# 14                       NG_CallSpread      0.0726      -2.708192
# 15                        ES_PutSpread      0.8294      -0.764175
# 16                       ZW_CallSpread      0.8685      -0.610754
# 17                       ZC_CallSpread      0.4927      -1.581916
# 18                       CL_CallSpread      0.3590      -1.843611
# 19                  ZS_BearishCollarBW      0.0000      -6.610545
# 20                  CL_BullishCollarBW      0.6484      -1.257360
# 21                  NG_BullishCollarBW      0.4226      -1.716615
# 22                          CL_ContFut      0.8842      -0.538806
# 23                        ZC_PutSpread      0.2497      -2.087218
# 24                  ZS_BullishCollarBW      0.0000      -4.838282
# 25                  ZW_BullishCollarBW      0.4205      -1.720645
# 26                  ZC_BullishCollarBW      0.0919      -2.605386
# 27                        ZN_PutSpread      0.4706      -1.624110
# 28                        ZW_PutSpread      0.6933      -1.153404
# 29                  ZC_BearishCollarBW      0.0825      -2.653017
# 30                        NG_PutSpread      0.0377      -2.970978
# 31                          ZS_ContFut      0.1709      -2.303474
# 32                          ZW_ContFut      0.4806      -1.605890
# 33                       ES_CallSpread      0.6322      -1.293415
# 34                          ZC_ContFut      0.0833      -2.648836
# 35                  ZW_BearishCollarBW      0.1696      -2.307315
# 36                          ES_ContFut      0.8250      -0.779827
# 37                          NG_ContFut      0.3476      -1.867265
# 38                  NG_BearishCollarBW      0.4524      -1.658944
# 39                       ZN_CallSpread      0.1548      -2.355188
# 40                  ZN_BearishCollarBW      0.4071      -1.746960
# 41                  ES_BullishCollarBW      0.6623      -1.225955
# 42                  ZN_BullishCollarBW      0.2441      -2.100925
# 43                          ZN_ContFut      0.2145      -2.177495
#
#     avg_days_wo_crossings_ema10  avg_days_wo_crossings_ema2  \
# 0                     31.283376                   20.014322
# 1                     21.678261                    4.725320
# 2                     19.517647                    5.313043
# 3                     19.029949                    4.760406
# 4                     17.786735                    4.578571
# 5                     17.730964                    4.188325
# 6                     17.214834                    5.098210
# 7                     18.277238                    5.003069
# 8                     15.651662                    5.660870
# 9                     15.872998                    3.942792
# 10                    14.211930                    5.392823
# 11                    13.860406                    5.261421
# 12                    15.730457                    4.765482
# 13                    13.710997                    4.953453
# 14                    13.353628                    5.254693
# 15                    13.403007                    5.278371
# 16                    12.950229                    5.428644
# 17                    14.413110                    4.335874
# 18                    13.567005                    5.061929
# 19                    12.347208                    4.834518
# 20                    14.262677                    4.365112
# 21                    13.349391                    4.751014
# 22                    14.572589                    3.784772
# 23                    12.920732                    4.201220
# 24                    12.744929                    4.097363
# 25                    11.929985                    4.850330
# 26                    13.004063                    3.833926
# 27                    11.981998                    4.346690
# 28                    11.142204                    4.898933
# 29                    12.362805                    3.949187
# 30                    11.873668                    4.519026
# 31                    11.501015                    4.209137
# 32                    11.351447                    4.033520
# 33                    10.830747                    4.583899
# 34                    11.873984                    3.707825
# 35                    11.084815                    4.258507
# 36                    10.870029                    4.201261
# 37                    10.771182                    3.906139
# 38                    10.455099                    4.202435
# 39                    10.759001                    3.736353
# 40                    10.460511                    4.023229
# 41                     9.503391                    3.841570
# 42                     9.801394                    3.703252
# 43                     9.159698                    3.616725
#
#     avg_days_wo_crossings_ema5     hurst  avg_days_wo_crossings_sum
# 0                    22.086445  0.492685                  73.384143
# 1                    10.544246  0.493552                  36.947826
# 2                    10.753964  0.501196                  35.584655
# 3                    10.216244  0.540066                  34.006599
# 4                    10.797959  0.509112                  33.163265
# 5                    10.072081  0.510723                  31.991371
# 6                     9.633760  0.511241                  31.946803
# 7                     8.534015  0.449151                  31.814322
# 8                     9.468031  0.456235                  30.780563
# 9                     9.686499  0.422570                  29.502288
# 10                    9.129486  0.468230                  28.734239
# 11                    9.482741  0.510986                  28.604569
# 12                    7.998985  0.494681                  28.494924
# 13                    8.777494  0.473344                  27.441944
# 14                    8.787925  0.392608                  27.396246
# 15                    8.594568  0.487722                  27.275946
# 16                    8.655663  0.505087                  27.034535
# 17                    7.960366  0.480862                  26.709350
# 18                    7.757360  0.511890                  26.386294
# 19                    8.794924  0.013273                  25.976650
# 20                    7.271805  0.469886                  25.899594
# 21                    7.774341  0.464498                  25.874746
# 22                    7.308122  0.427736                  25.665482
# 23                    7.900915  0.520060                  25.022866
# 24                    8.162779  0.013811                  25.005071
# 25                    8.008118  0.230840                  24.788432
# 26                    7.726765  0.240806                  24.564754
# 27                    7.456446  0.499303                  23.785134
# 28                    7.706450  0.492759                  23.747588
# 29                    7.364329  0.222563                  23.676321
# 30                    6.920345  0.591984                  23.313039
# 31                    7.488832  0.114299                  23.198985
# 32                    7.649060  0.325589                  23.034027
# 33                    7.312803  0.465141                  22.727449
# 34                    6.722561  0.338457                  22.304370
# 35                    6.865922  0.200651                  22.209243
# 36                    7.096508  0.463765                  22.167798
# 37                    7.020802  0.492179                  21.698123
# 38                    6.895485  0.438348                  21.553019
# 39                    6.063298  0.494409                  20.558653
# 40                    6.054007  0.494848                  20.537747
# 41                    6.420058  0.462656                  19.765019
# 42                    6.061556  0.494170                  19.566202
# 43                    5.302555  0.485552                  18.078978

# %%
#
# Select an index of ticker or spread from DF above
#
i = 10

print(sorted_df.index[i])
df[sorted_df.index[i]].plot()
# Out:
# ES_BearishCollarBW

# %%
ticker = df[ticker_stats_df.sort_values('avg_days_wo_crossings_sum', ascending=False).index[i]]

ema = ticker.ewm(10).mean()

ticker.plot()
CrossUp(ticker, ema).plot(secondary_y=True)
CrossDown(ticker, ema).plot(secondary_y=True)

crossup = CrossUp(ticker, ema)
crossdn = CrossDown(ticker, ema)

days_wo_crossings_count = np.zeros_like(ticker.values)
days_wo_crossings_counter = 0

for i in range(len(ticker)):
    if (crossup[i] == False) | (crossdn[i] == False):
        days_wo_crossings_counter += 1
        days_wo_crossings_count[i] = days_wo_crossings_counter
                
    if (crossup[i] == True) | (crossdn[i] == True):
        days_wo_crossings_counter = 0
        days_wo_crossings_count[i] = days_wo_crossings_counter
        
        
ticker.plot()
ticker.ewm(10).mean().plot()
#CrossUp(ticker, ema).plot(secondary_y=True)
#CrossDown(ticker, ema).plot(secondary_y=True)

pd.Series(days_wo_crossings_count, index=ticker.index).plot(secondary_y=True)

axhline(pd.Series(days_wo_crossings_count, index=ticker.index).mean())

axhline(pd.Series(days_wo_crossings_count, index=ticker.index).quantile(0.8))
