# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from exobuilder.contracts.futureschain import FuturesChain
from exobuilder.contracts.futurecontract import FutureContract
from exobuilder.tests.assetindexdict import AssetIndexDicts
from datetime import datetime, date, timedelta, time as dttime
from exobuilder.contracts.instrument import Instrument
from exobuilder.data.datasource_mongo import DataSourceMongo
from exobuilder.data.datasource_sql import DataSourceSQL
from exobuilder.data.assetindex_mongo import AssetIndexMongo
from exobuilder.data.exostorage import EXOStorage
from exobuilder.exo.exoenginebase import ExoEngineBase
from exobuilder.exo.transaction import Transaction
import time
from exobuilder.algorithms.rollover_helper import RolloverHelper

import importlib
import logging
importlib.reload(logging);
import matplotlib.pyplot as plt

# %%
EXO_NAME = 'SmartEXO_Ichi_Put_Spread_150Delta_Bi_no_neutral'

# TODO: set to 'False' if EXO building output is too verbosive
verbosive_logging = True # or True - for debug log feed

# TODO: select instruments list for SMART EXO calculation
#instruments = ['CL', 'ES', 'NG', 'ZC', 'ZS', 'ZW', 'ZN']
instruments = ['CL','ES','NG','ZC','ZS','ZW']


# TODO: select start date for SmartEXO calculation
base_date = datetime(2014, 1, 13, 12, 45, 0)

# %% [markdown]
# # Define Bull/Bear/Neutral areas rules

# %%
def ichimoku_regimes(date, price_series):    
    '''
    Calculates Bull/Bear/Neutral areas based on Ichimoku zones
    
    param date: Current date time
    param price_series: price Pandas.Series
    
    Returns:
        -1 - for bearish zone
        0  - for neutral zone
        +1 - for bullish zone
        None - for unknown
    '''
    #
    #  TODO: Change values to fine tune zoning algorithm
    #
    conversion_line_period = 9 # subject of optimization
    base_line_period = 26  # subject of optimization
    leading_spans_lookahead_period = 52  # subject of optimization
    leading_span_b_period = 52 # subject of optimization
        
        
    conversion_line_high = price_series.rolling(window=conversion_line_period).max()
    conversion_line_low = price_series.rolling(window=conversion_line_period).min()
    conversion_line = (conversion_line_high + conversion_line_low) / 2

    base_line_high = price_series.rolling(window=base_line_period).max()
    base_line_low = price_series.rolling(window=base_line_period).min()
    base_line = (base_line_high + base_line_low) / 2

    leading_span_a = ((conversion_line + base_line) / 2).shift(leading_spans_lookahead_period)
    leading_span_b = ((price_series.rolling(window=leading_span_b_period).max() + price_series.rolling(
        window=leading_span_b_period).min()) / 2).shift(leading_spans_lookahead_period)


    #
    # Rules calculation
    #

    # Cloud top and bottom series are defined using leading span A and B
    cloud_top = leading_span_a.rolling(1).max()
    cloud_bottom = leading_span_a.rolling(1).min()

    rule_price_above_cloud_top = price_series > cloud_top
    rule_price_below_cloud_bottom = price_series < cloud_bottom
    rule_price_in_cloud = (price_series < cloud_top) & (price_series > cloud_bottom)

    def get_regime(date):
        if date not in rule_price_above_cloud_top.index:
            logging.debug("Date not found at {0}".format(date))
            return None


        if rule_price_above_cloud_top[date]:
            return 1
        elif rule_price_below_cloud_bottom[date]:
            return -1
        elif rule_price_in_cloud[date]:
            return 0
        return None

    regime = get_regime(date.date())
    logging.debug("Ichi regime at {0}: {1}".format(date, regime))
    return regime

# %%
# Toolbox
def transactions_delta(trans_list):
    return sum([t.delta for t in trans_list])

def log_transactions(trans_list, msg):
    logging.debug(msg)
    [logging.debug(t) for t in trans_list]
    logging.debug('Transactions delta: {0}'.format(transactions_delta(trans_list)))

# %% [markdown]
# # Option position management

# %% [markdown]
# According to https://tmqrexo.slack.com/files/nikolasjoyce/F2PHLEETZ/pasted_image_at_2016_10_14_10_05_am.png

# %% [markdown]
# ## New bullish zone position

# %%
def new_position_bullish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bullish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening long ITM straddle in bullish zone
    #
    # https://files.slack.com/files-tmb/T0484J7T7-F2QBLK53R-93b4252806/pasted_image_at_2016_10_17_10_08_am_720.png
   
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                 Transaction(opt_chain[-2].c, date, 1.0, leg_name='bullish'),
                Transaction(opt_chain[-2].p, date, 1.0), 
                Transaction(opt_chain[10].c, date, -1.0),
                Transaction(opt_chain[-10].p, date, -1.0),
                ]
    log_transactions(trans_list,'New bullish zone position')
    return trans_list

# %% [markdown]
# ## New bearish zone position

# %%
def new_position_bearish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bearish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    #
    # Opening small ITM straddle in bearish zone
    #

    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[2].p, date, 6.0, leg_name='bearish'),
                Transaction(opt_chain[-5].p, date, -6.0),  
                ]
    
    log_transactions(trans_list,'New bearish zone position')
    return trans_list

# %% [markdown]
# ## New neutral zone position

# %%
def new_position_neutral_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for neutral zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    # Opening long asymmetric butterfly in neutral zone
    #    
    # https://files.slack.com/files-tmb/T0484J7T7-F2PGU8QNQ-6344e6a04c/pasted_image_at_2016_10_14_09_43_am_720.png
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-2].c, date, 0.0, leg_name='neutral'),
                Transaction(opt_chain[2].c, date, -0.0),
                
                Transaction(opt_chain[8].c, date, 0.0),
                Transaction(opt_chain[3].c, date,  0.0),

                ]
    log_transactions(trans_list,'New neutral zone position')

    return trans_list

# %% [markdown]
# ## Manage opened positions

# %%
def manage_opened_position(date, fut, opt_chain, regime, opened_position):
    logging.debug('Current position delta: {0}'.format(opened_position.delta))
    
    # By default: do nothing
    return []

# %% [markdown]
# # Define EXO builder class

# %%
class SmartEXOIchimoku(ExoEngineBase):
    def __init__(self, symbol, direction, date, datasource, log_file_path=''):
        self._symbol = symbol
        self.custom_values = {}
        super().__init__(symbol, direction, date, datasource, log_file_path=log_file_path)

    @staticmethod
    def direction_type():
        return 0

    @staticmethod
    def names_list(symbol):
        return ['{0}_{1}'.format(self._symbol, EXO_NAME)]

    @property
    def exo_name(self):
            return '{0}_{1}'.format(self._symbol, EXO_NAME)

    def is_rollover(self):
        if len(self.position) != 0:
            for p in self.position.legs.values():
                rh = RolloverHelper(p.instrument)
                if rh.is_rollover(p):
                    return True
        return False

    def process_rollover(self):
        trans_list = self.position.close_all_translist()
        logging.info('Rollover occured, new series used')
        return trans_list
    
    def get_custom_values(self):
        """
        Method that return custom EXO data frame values, to store inside EXO Dataframe in the DB
        :return: dictionary {'string_key': (int or float) value}
        """
        return self.custom_values
    

    def process_day(self):
        """
        Main EXO's position management method
        :return: list of Transactions to process
        """

        # Get cont futures price for EXO
        exo_df, exo_info = self.datasource.exostorage.load_series("{0}_ContFut".format(self._symbol))

        regime = ichimoku_regimes(self.date, exo_df['exo'])

        trans_list = []

        if regime is None and len(self.position) > 0:
            return self.position.close_all_translist()
        
        instr = self.datasource.get(self._symbol, self.date)
        rh = RolloverHelper(instr)
        fut, opt_chain = rh.get_active_chains()

        if regime == 1 and 'bullish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bullish_zone(self.date, fut, opt_chain)
            
            return trans_list
        if regime == -1 and 'bearish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bearish_zone(self.date, fut, opt_chain)
            return trans_list

        if regime == 0 and 'neutral' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_neutral_zone(self.date, fut, opt_chain)
            return trans_list
        
        #
        # Writing custom values to store inside DB 
        #
        self.custom_values = {
            'ichi_regime': regime if regime is not None else float('nan')
        }
        
        #
        # Manage opened position
        #
        return manage_opened_position(self.date, fut, opt_chain, regime, self.position)

# %% [markdown]
# # Run EXO build process (WARN: long-running task!)

# %%
from pymongo import MongoClient

if verbosive_logging:
    logging.basicConfig(format='%(message)s', level=logging.DEBUG)
else:
    logging.basicConfig(format='%(message)s', level=logging.INFO)

mongo_connstr = 'mongodb://exowriter:qmWSy4K3@10.0.1.2/tmldb?authMechanism=SCRAM-SHA-1'
mongo_db_name = 'tmldb'
assetindex = AssetIndexMongo(mongo_connstr, mongo_db_name)
exostorage = EXOStorage(mongo_connstr, mongo_db_name)

#base_date = datetime(2011, 6, 13, 12, 45, 0)


futures_limit = 3
options_limit = 10

DEBUG = '.'

datasource = DataSourceMongo(mongo_connstr, mongo_db_name, assetindex, futures_limit, options_limit, exostorage)

server = 'h9ggwlagd1.database.windows.net'
user = 'modelread'
password = '4fSHRXwd4u'
datasource = DataSourceSQL(server, user, password, assetindex, futures_limit, options_limit, exostorage)

enddate = datetime.combine(datetime.now().date(), dttime(12, 45, 0))
currdate = base_date


logging.info("Deleting all SmartEXO of :" + EXO_NAME)
client = MongoClient(mongo_connstr)
db = client[mongo_db_name]
db['exo_data'].delete_many({'name': {'$regex': '.*{0}*.'.format(EXO_NAME)}})


logging.info("Starting EXO calculation process from: {0}".format(currdate))
for ticker in instruments:
    logging.info("Processing: "+ticker)
    currdate = base_date
    while currdate <= enddate:
        
        start_time = time.time()
        date = currdate

        asset_info = assetindex.get_instrument_info(ticker)
        exec_time_end, decision_time_end = AssetIndexMongo.get_exec_time(date, asset_info)
        
        logging.info("\t\tRun on {0}".format(decision_time_end))

        with SmartEXOIchimoku(ticker, 0, decision_time_end, datasource) as exo_engine:
            # Load EXO information from mongo
            exo_engine.load()
            exo_engine.calculate()

        end_time = time.time()
        currdate += timedelta(days=1)
        logging.debug("Elapsed: {0}".format(end_time-start_time))
logging.info('Done')
# Out:
# Deleting all SmartEXO of :SmartEXO_Ichi_Put_Spread_150Delta_Bi_no_neutral
# Starting EXO calculation process from: 2014-01-13 12:45:00
# Processing: CL
# 		Run on 2014-01-13 11:10:00
# Ichi regime at 2014-01-13 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEH149300 x 6.0 Price: 2.5770828236036962 Delta: -3.437166488742888
# Leg:  / P.US.CLEH148950 x -6.0 Price: 1.1294837578570274 Delta: 1.8804016327873678
# Transactions delta: -1.55676485595552
# Elapsed: 0.8380310535430908
# 		Run on 2014-01-14 11:10:00
# Ichi regime at 2014-01-14 11:10:00: -1
# Current position delta: -1.4524470750959484
# Elapsed: 1.0927205085754395
# 		Run on 2014-01-15 11:10:00
# Ichi regime at 2014-01-15 11:10:00: -1
# Current position delta: -1.2050041011494397
# Elapsed: 0.9183292388916016
# 		Run on 2014-01-16 11:10:00
# Ichi regime at 2014-01-16 11:10:00: -1
# Current position delta: -1.279756557449721
# Elapsed: 0.9220497608184814
# 		Run on 2014-01-17 11:10:00
# Ichi regime at 2014-01-17 11:10:00: -1
# Current position delta: -1.2706690136304293
# Elapsed: 0.9302124977111816
# 		Run on 2014-01-18 11:10:00
# Ichi regime at 2014-01-18 11:10:00: -1
# Current position delta: -1.346137273858961
# Elapsed: 0.9327101707458496
# 		Run on 2014-01-19 11:10:00
# Ichi regime at 2014-01-19 11:10:00: -1
# Current position delta: -1.3605744291830408
# Elapsed: 0.8779017925262451
# 		Run on 2014-01-20 11:10:00
# Ichi regime at 2014-01-20 11:10:00: -1
# Current position delta: -1.4368029517737941
# Elapsed: 0.8868086338043213
# 		Run on 2014-01-21 11:10:00
# Ichi regime at 2014-01-21 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEH149400 x 1.0 Price: 2.3355258393186844 Delta: 0.6071994688988152
# Leg:  / P.US.CLEH149400 x 1.0 Price: 1.2655435104730088 Delta: -0.3935894623779542
# Leg:  / C.US.CLEH1410000 x -1.0 Price: 0.29285742621211774 Delta: -0.1371713675845723
# Leg:  / P.US.CLEH149000 x -1.0 Price: 0.3450341429033905 Delta: 0.13644798034279512
# Transactions delta: 0.21288661927908376
# Elapsed: 1.5845322608947754
# 		Run on 2014-01-22 11:10:00
# Ichi regime at 2014-01-22 11:10:00: 1
# Current position delta: 0.325685292919813
# Elapsed: 1.562314510345459
# 		Run on 2014-01-23 11:10:00
# Ichi regime at 2014-01-23 11:10:00: 1
# Current position delta: 0.37087258058062267
# Elapsed: 1.5489614009857178
# 		Run on 2014-01-24 11:10:00
# Ichi regime at 2014-01-24 11:10:00: 1
# Current position delta: 0.3309299997082166
# Elapsed: 1.5542750358581543
# 		Run on 2014-01-25 11:10:00
# Ichi regime at 2014-01-25 11:10:00: 1
# Current position delta: 0.3528413277941861
# Elapsed: 1.5377957820892334
# 		Run on 2014-01-26 11:10:00
# Ichi regime at 2014-01-26 11:10:00: 1
# Current position delta: 0.36453326561260735
# Elapsed: 1.5127036571502686
# 		Run on 2014-01-27 11:10:00
# Ichi regime at 2014-01-27 11:10:00: 1
# Current position delta: 0.29622002798101227
# Elapsed: 1.5311222076416016
# 		Run on 2014-01-28 11:10:00
# Ichi regime at 2014-01-28 11:10:00: 1
# Current position delta: 0.3712690229088673
# Elapsed: 1.5496814250946045
# 		Run on 2014-01-29 11:10:00
# Ichi regime at 2014-01-29 11:10:00: 1
# Current position delta: 0.37006799155080605
# Elapsed: 1.53558349609375
# 		Run on 2014-01-30 11:10:00
# Ichi regime at 2014-01-30 11:10:00: 1
# Current position delta: 0.39601340835285187
# Elapsed: 1.559352159500122
# 		Run on 2014-01-31 11:10:00
# Ichi regime at 2014-01-31 11:10:00: 1
# Current position delta: 0.44726383650117657
# Elapsed: 1.5296807289123535
# 		Run on 2014-02-01 11:10:00
# Ichi regime at 2014-02-01 11:10:00: 1
# Current position delta: 0.45784703980749075
# Elapsed: 1.5138404369354248
# 		Run on 2014-02-02 11:10:00
# Ichi regime at 2014-02-02 11:10:00: 1
# Current position delta: 0.48029199467062966
# Elapsed: 1.4926016330718994
# 		Run on 2014-02-03 11:10:00
# Ichi regime at 2014-02-03 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEH149750 x 6.0 Price: 1.7969472807312599 Delta: -3.660658804059537
# Leg:  / P.US.CLEH149400 x -6.0 Price: 0.4528545856527266 Delta: 1.33485875121755
# Transactions delta: -2.325800052841987
# Elapsed: 1.8296434879302979
# 		Run on 2014-02-04 11:10:00
# Ichi regime at 2014-02-04 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEH149600 x 1.0 Price: 2.0592359254236214 Delta: 0.6420738019303026
# Leg:  / P.US.CLEH149600 x 1.0 Price: 0.8692096960009863 Delta: -0.3585408288089066
# Leg:  / C.US.CLEH1410200 x -1.0 Price: 0.13406966103247697 Delta: -0.08682401820963355
# Leg:  / P.US.CLEH149200 x -1.0 Price: 0.16214733777472645 Delta: 0.08687982016096006
# Transactions delta: 0.28358877507272257
# Elapsed: 1.5688238143920898
# 		Run on 2014-02-05 11:10:00
# Ichi regime at 2014-02-05 11:10:00: 1
# Current position delta: 0.30744902646549616
# Elapsed: 1.5400478839874268
# 		Run on 2014-02-06 11:10:00
# Ichi regime at 2014-02-06 11:10:00: 1
# Current position delta: 0.4034454960847548
# Elapsed: 1.5485730171203613
# 		Run on 2014-02-07 11:10:00
# Ichi regime at 2014-02-07 11:10:00: 1
# Current position delta: 0.6472415834792189
# Elapsed: 1.5463578701019287
# 		Run on 2014-02-08 11:10:00
# Ichi regime at 2014-02-08 11:10:00: 1
# Current position delta: 0.6814551600410256
# Elapsed: 1.5327482223510742
# 		Run on 2014-02-09 11:10:00
# Ichi regime at 2014-02-09 11:10:00: 1
# Current position delta: 0.7291217731021822
# Elapsed: 1.494051218032837
# 		Run on 2014-02-10 11:10:00
# Ichi regime at 2014-02-10 11:10:00: 1
# Current position delta: 0.7935597836580752
# Elapsed: 1.5177404880523682
# 		Run on 2014-02-11 11:10:00
# Ichi regime at 2014-02-11 11:10:00: 1
# Current position delta: 0.7804791345577123
# Elapsed: 1.5579023361206055
# 		Run on 2014-02-12 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-02-12 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEJ149850 x 1.0 Price: 2.774891228031983 Delta: 0.6036333765153066
# Leg:  / P.US.CLEJ149850 x 1.0 Price: 1.55490512512403 Delta: -0.3972049921492671
# Leg:  / C.US.CLEJ1410450 x -1.0 Price: 0.4800307607130172 Delta: -0.18160806562724555
# Leg:  / P.US.CLEJ149450 x -1.0 Price: 0.5567121029877669 Delta: 0.17206108461091704
# Transactions delta: 0.196881403349711
# Elapsed: 2.4616599082946777
# 		Run on 2014-02-13 11:10:00
# Ichi regime at 2014-02-13 11:10:00: 1
# Current position delta: 0.21878987656376503
# Elapsed: 1.7476940155029297
# 		Run on 2014-02-14 11:10:00
# Ichi regime at 2014-02-14 11:10:00: 1
11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEM1410150 x 6.0 Price: 2.006479797060841 Delta: -3.4181597797319205
# Leg:  / P.US.CLEM149800 x -6.0 Price: 0.6847870918668875 Delta: 1.5360900720178783
# Transactions delta: -1.8820697077140423
# Elapsed: 1.8534502983093262
# 		Run on 2014-04-26 11:10:00
# Ichi regime at 2014-04-26 11:10:00: -1
# Current position delta: -1.9736974234044895
# Elapsed: 0.8887476921081543
# 		Run on 2014-04-27 11:10:00
# Ichi regime at 2014-04-27 11:10:00: -1
# Current position delta: -2.021691541855815
# Elapsed: 0.8935236930847168
# 		Run on 2014-04-28 11:10:00
# Ichi regime at 2014-04-28 11:10:00: -1
# Current position delta: -2.0936033530311127
# Elapsed: 0.89453125
# 		Run on 2014-04-29 11:10:00
# Ichi regime at 2014-04-29 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEM1410050 x 1.0 Price: 1.9214715198681205 Delta: 0.5881596103620221
# Leg:  / P.US.CLEM1410050 x 1.0 Price: 1.1615714787331513 Delta: -0.4123374775984501
# Leg:  / C.US.CLEM1410650 x -1.0 Price: 0.1897115173436852 Delta: -0.10236680755268289
# Leg:  / P.US.CLEM149650 x -1.0 Price: 0.27281126870851047 Delta: 0.12479622605336418
# Transactions delta: 0.19825155126425337
# Elapsed: 1.5913445949554443
# 		Run on 2014-04-30 11:10:00
# Ichi regime at 2014-04-30 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEM1410050 x 6.0 Price: 1.9392934983031438 Delta: -3.565389494859146
# Leg:  / P.US.CLEM149700 x -6.0 Price: 0.6035183155132628 Delta: 1.495955057350486
# Transactions delta: -2.0694344375086597
# Elapsed: 1.8591132164001465
# 		Run on 2014-05-01 11:10:00
# Ichi regime at 2014-05-01 11:10:00: -1
# Current position delta: -2.212113644962937
# Elapsed: 0.9086723327636719
# 		Run on 2014-05-02 11:10:00
# Ichi regime at 2014-05-02 11:10:00: -1
# Current position delta: -2.3066378680400312
# Elapsed: 0.9213216304779053
# 		Run on 2014-05-03 11:10:00
# Ichi regime at 2014-05-03 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEM149900 x 1.0 Price: 1.7555585186396527 Delta: 0.6364407459578567
# Leg:  / P.US.CLEM149900 x 1.0 Price: 0.7656828159209326 Delta: -0.36432829007562123
# Leg:  / C.US.CLEM1410500 x -1.0 Price: 0.08858594859073765 Delta: -0.06459308258123665
# Leg:  / P.US.CLEM149500 x -1.0 Price: 0.10275283085896092 Delta: 0.0668283490785368
# Transactions delta: 0.27434772237953564
# Elapsed: 1.6016366481781006
# 		Run on 2014-05-04 11:10:00
# Ichi regime at 2014-05-04 11:10:00: 1
# Current position delta: 0.2850474170719425
# Elapsed: 1.5111405849456787
# 		Run on 2014-05-05 11:10:00
# Ichi regime at 2014-05-05 11:10:00: 1
# Current position delta: 0.15622776296103297
# Elapsed: 1.5326731204986572
# 		Run on 2014-05-06 11:10:00
# Ichi regime at 2014-05-06 11:10:00: 1
# Current position delta: 0.2579055081804784
# Elapsed: 1.614222526550293
# 		Run on 2014-05-07 11:10:00
# Ichi regime at 2014-05-07 11:10:00: 1
# Current position delta: 0.4327204027716961
# Elapsed: 1.536501169204712
15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-06-15 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEQ1410500 x 1.0 Price: 2.630094395751435 Delta: 0.5910725388294584
# Leg:  / P.US.CLEQ1410500 x 1.0 Price: 1.5907632550775972 Delta: -0.40968312058676914
# Leg:  / C.US.CLEQ1411100 x -1.0 Price: 0.7253011372245268 Delta: -0.2179196138425524
# Leg:  / P.US.CLEQ1410100 x -1.0 Price: 0.393920724157768 Delta: 0.14750261279850216
# Transactions delta: 0.11097241719863904
# Elapsed: 2.4410762786865234
# 		Run on 2014-06-16 11:10:00
# Ichi regime at 2014-06-16 11:10:00: 1
# Current position delta: 0.12018643517928748
# Elapsed: 1.6827843189239502
# 		Run on 2014-06-17 11:10:00
# Ichi regime at 2014-06-17 11:10:00: 1
# Current position delta: 0.11400911423941407
# Elapsed: 1.5599617958068848
# 		Run on 2014-06-18 11:10:00
# Ichi regime at 2014-06-18 11:10:00: 1
# Current position delta: 0.10125180108188903
# Elapsed: 1.5631120204925537
# 		Run on 2014-06-19 11:10:00
# Ichi regime at 2014-06-19 11:10:00: 1
# Current position delta: 0.15337129249547402
# Elapsed: 1.544848918914795
# 		Run on 2014-06-20 11:10:00
# Ichi regime at 2014-06-20 11:10:00: 1
# Current position delta: 0.20748101728324783
# Elapsed: 1.5401008129119873
# 		Run on 2014-06-21 11:10:00
# Ichi regime at 2014-06-21 11:10:00: 1
# Current position delta: 0.19711555396886926
# Elapsed: 1.5524547100067139
# 		Run on 2014-06-22 11:10:00
# Ichi regime at 2014-06-22 11:10:00: 1
# Current position delta: 0.20297398240337627
# Elapsed: 1.5157432556152344
# 		Run on 2014-06-23 11:10:00
# Ichi regime at 2014-06-23 11:10:00: 1
# Current position delta: 0.17174609920803466
# Elapsed: 1.5080628395080566
# 		Run on 2014-06-24 11:10:00
# Ichi regime at 2014-06-24 11:10:00: 1
# Current position delta: 0.14323994830639472
# Elapsed: 1.6838736534118652
# 		Run on 2014-06-25 11:10:00
# Ichi regime at 2014-06-25 11:10:00: 1
# Current position delta: 0.21769471354586503
# Elapsed: 1.551569938659668
# 		Run on 2014-06-26 11:10:00
# Ichi regime at 2014-06-26 11:10:00: 1
# Current position delta: 0.1818505034571983
# Elapsed: 1.5639762878417969
# 		Run on 2014-06-27 11:10:00
# Ichi regime at 2014-06-27 11:10:00: 1
# Current position delta: 0.15189771044365424
# Elapsed: 1.5676195621490479
# 		Run on 2014-06-28 11:10:00
# Ichi regime at 2014-06-28 11:10:00: 1
# Current position delta: 0.17053507285538513
# Elapsed: 1.5647938251495361
# 		Run on 2014-06-29 11:10:00
# Ichi regime at 2014-06-29 11:10:00: 1
# Current position delta: 0.1760799449767403
# Elapsed: 1.514050006866455
# 		Run on 2014-06-30 11:10:00
# Ichi regime at 2014-06-30 11:10:00: 1
# Current position delta: 0.13092030243239106
# Elapsed: 1.509547472000122
# 		Run on 2014-07-01 11:10:00
# Ichi regime at 2014-07-01 11:10:00: 1
# Current position delta: 0.08476312620240843
# Elapsed: 1.5621862411499023
# 		Run on 2014-07-02 11:10:00
# Ichi regime at 2014-07-02 11:10:00: 1
# Current position delta: -0.03972736617030328
# Elapsed: 1.55039644241333
# 		Run on 2014-07-03 11:10:00
# Ichi regime at 2014-07-03 11:10:00: 1
# Current position delta: -0.16970765789471182
# Elapsed: 1.5489757061004639
# 		Run on 2014-07-04 11:10:00
# Ichi regime at 2014-07-04 11:10:00: 1
# Current position delta: -0.24528484076618423
# Elapsed: 1.5447895526885986
# 		Run on 2014-07-05 11:10:00
# Ichi regime at 2014-07-05 11:10:00: 1
# Current position delta: -0.24688479732408775
# Elapsed: 1.6084153652191162
# 		Run on 2014-07-06 11:10:00
# Ichi regime at 2014-07-06 11:10:00: 1
# Current position delta: -0.2687748342045953
# Elapsed: 1.5458626747131348
# 		Run on 2014-07-07 11:10:00
# Ichi regime at 2014-07-07 11:10:00: 1
# Current position delta: -0.37530729705757127
# Elapsed: 1.5606193542480469
# 		Run on 2014-07-08 11:10:00
# Ichi regime at 2014-07-08 11:10:00: 1
# Current position delta: -0.401392106316089
# Elapsed: 1.606546401977539
# 		Run on 2014-07-09 11:10:00
# Ichi regime at 2014-07-09 11:10:00: 1
# Current position delta: -0.5192031754428097
# Elapsed: 1.603062629699707
# 		Run on 2014-07-10 11:10:00
# Ichi regime at 2014-07-10 11:10:00: 1
# Current position delta: -0.4874204893391209
# Elapsed: 1.6024627685546875
# 		Run on 2014-07-11 11:10:00
# Ichi regime at 2014-07-11 11:10:00: 1
# Current position delta: -0.4013859266915145
# Elapsed: 1.6263489723205566
# 		Run on 2014-07-12 11:10:00
# Ichi regime at 2014-07-12 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEQ1410150 x 6.0 Price: 1.3595889920740092 Delta: -4.201503802770659
# Leg:  / P.US.CLEQ149800 x -6.0 Price: 0.13855879145735628 Delta: 0.749136498620014
# Transactions delta: -3.452367304150645
# Elapsed: 1.9576454162597656
# 		Run on 2014-07-13 11:10:00
# Ichi regime at 2014-07-13 11:10:00: -1
# Current position delta: -3.736283397741662
# Elapsed: 0.9078731536865234
# 		Run on 2014-07-14 11:10:00
# Ichi regime at 2014-07-14 11:10:00: -1
# Current position delta: -4.074833595061606
# Elapsed: 0.9229428768157959
# 		Run on 2014-07-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-07-15 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEU1410000 x 6.0 Price: 2.2184656520871258 Delta: -3.337825791042313
# Leg:  / P.US.CLEU149650 x -6.0 Price: 0.8526259970271042 Delta: 1.6554528466439764
# Transactions delta: -1.6823729443983366
# Elapsed: 1.5438954830169678
# 		Run on 2014-07-16 11:10:00
# Ichi regime at 2014-07-16 11:10:00: -1
# Current position delta: -1.5259611738547187
# Elapsed: 1.1340899467468262
# 		Run on 2014-07-17 11:10:00
# Ichi regime at 2014-07-17 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEU1410100 x 1.0 Price: 2.2878303412820955 Delta: 0.6095659594795553
# Leg:  / P.US.CLEU1410100 x 1.0 Price: 1.2176423282292177 Delta: -0.39145925122993236
# Leg:  / C.US.CLEU1410700 x -1.0 Price: 0.41975734243471763 Delta: -0.16668844377975803
# Leg:  / P.US.CLEU149700 x -1.0 Price: 0.27655802706265575 Delta: 0.12101333605902045
# Transactions delta: 0.17243160052888534
# Elapsed: 1.7130086421966553
# 		Run on 2014-07-18 11:10:00
# Ichi regime at 2014-07-18 11:10:00: 1
# Current position delta: 0.1580005104874527
# Elapsed: 1.6005804538726807
# 		Run on 2014-07-19 11:10:00
# Ichi regime at 2014-07-19 11:10:00: 1
# Current position delta: 0.14397983834667127
# Elapsed: 1.5774428844451904
# 		Run on 2014-07-20 11:10:00
# Ichi regime at 2014-07-20 11:10:00: 1
# Current position delta: 0.14650304375262477
# Elapsed: 1.5465455055236816
# 		Run on 2014-07-21 11:10:00
# Ichi regime at 2014-07-21 11:10:00: 1
# Current position delta: 0.24530153073355956
# Elapsed: 1.5551235675811768
# 		Run on 2014-07-22 11:10:00
# Ichi regime at 2014-07-22 11:10:00: 1
# Current position delta: 0.24789767537293184
# Elapsed: 1.6103298664093018
# 		Run on 2014-07-23 11:10:00
# Ichi regime at 2014-07-23 11:10:00: 1
# Current position delta: 0.32270481250517474
# Elapsed: 1.6138627529144287
# 		Run on 2014-07-24 11:10:00
# Ichi regime at 2014-07-24 11:10:00: 1
# Current position delta: 0.24636947923162378
# Elapsed: 1.6011345386505127
# 		Run on 2014-07-25 11:10:00
# Ichi regime at 2014-07-25 11:10:00: 1
# Current position delta: 0.23302465052418872
# Elapsed: 1.618272066116333
# 		Run on 2014-07-26 11:10:00
# Ichi regime at 2014-07-26 11:10:00: 1
# Current position delta: 0.22353623032594375
# Elapsed: 1.6047048568725586
# 		Run on 2014-07-27 11:10:00
# Ichi regime at 2014-07-27 11:10:00: 1
# Current position delta: 0.2283696716928797
# Elapsed: 1.5700879096984863
# 		Run on 2014-07-28 11:10:00
# Ichi regime at 2014-07-28 11:10:00: 1
# Current position delta: 0.2447562062231698
# Elapsed: 1.5623447895050049
# 		Run on 2014-07-29 11:10:00
# Ichi regime at 2014-07-29 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEU1410200 x 6.0 Price: 1.9366548991550445 Delta: -3.735716091273677
# Leg:  / P.US.CLEU149850 x -6.0 Price: 0.49102702035632007 Delta: 1.4184483264504675
# Transactions delta: -2.3172677648232094
# Elapsed: 1.9791955947875977
# 		Run on 2014-07-30 11:10:00
# Ichi regime at 2014-07-30 11:10:00: -1
# Current position delta: -2.444393129878364
# Elapsed: 0.9402449131011963
# 		Run on 2014-07-31 11:10:00
# Ichi regime at 2014-07-31 11:10:00: -1
# Current position delta: -2.2493778992990006
# Elapsed: 0.9362022876739502
# 		Run on 2014-08-01 11:10:00
# Ichi regime at 2014-08-01 11:10:00: -1
# Current position delta: -1.969800970767476
# Elapsed: 0.9433438777923584
# 		Run on 2014-08-02 11:10:00
# Ichi regime at 2014-08-02 11:10:00: -1
# Current position delta: -1.9152653553482146
# Elapsed: 0.9461638927459717
# 		Run on 2014-08-03 11:10:00
10:55:00: -1
# New bearish zone position
# Leg: bearish / P.US.ZWAX164050 x 6.0 Price: 14.234712101803268 Delta: -4.022781364932558
# Leg:  / P.US.ZWAX163700 x -6.0 Price: 0.8312144048892023 Delta: 0.5363002197238308
# Transactions delta: -3.486481145208727
# Elapsed: 0.5308222770690918
# 		Run on 2016-10-08 10:55:00
# Date not found at 2016-10-08
# Ichi regime at 2016-10-08 10:55:00: None
# Elapsed: 0.6806392669677734
# 		Run on 2016-10-09 10:55:00
# Date not found at 2016-10-09
# Ichi regime at 2016-10-09 10:55:00: None
# Current position delta: 0.0
# Elapsed: 0.18625855445861816
# 		Run on 2016-10-10 10:55:00
# Ichi regime at 2016-10-10 10:55:00: -1
# New bearish zone position
# Leg: bearish / P.US.ZWAX164100 x 6.0 Price: 12.02161739790057 Delta: -3.831233474762552
# Leg:  / P.US.ZWAX163750 x -6.0 Price: 0.34596874809111355 Delta: 0.2843022510210181
# Transactions delta: -3.546931223741534
# Elapsed: 0.5138022899627686
# 		Run on 2016-10-11 10:55:00
# Ichi regime at 2016-10-11 10:55:00: -1
# Current position delta: -2.9958294211250096
# Elapsed: 0.8420636653900146
# 		Run on 2016-10-12 10:55:00
# Ichi regime at 2016-10-12 10:55:00: -1
# Current position delta: -3.6198101815136745
# Elapsed: 0.8315701484680176
# 		Run on 2016-10-13 10:55:00
# Date not found at 2016-10-13
# Ichi regime at 2016-10-13 10:55:00: None
# Elapsed: 0.6503920555114746
# 		Run on 2016-10-14 10:55:00
# Ichi regime at 2016-10-14 10:55:00: -1
# New bearish zone position
# Leg: bearish / P.US.ZWAX164350 x 6.0 Price: 14.628471826641487 Delta: -4.084409066454721
# Leg:  / P.US.ZWAX164000 x -6.0 Price: 0.5262641853261449 Delta: 0.40948090648592056
# Transactions delta: -3.6749281599688004
# Elapsed: 0.5463652610778809
# 		Run on 2016-10-15 10:55:00
# Date not found at 2016-10-15
# Ichi regime at 2016-10-15 10:55:00: None
# Elapsed: 0.6769273281097412
# 		Run on 2016-10-16 10:55:00
# Ichi regime at 2016-10-16 10:55:00: -1
# New bearish zone position
# Leg: bearish / P.US.ZWAX164300 x 6.0 Price: 12.114929724811134 Delta: -4.313672830390446
# Leg:  / P.US.ZWAX163950 x -6.0 Price: 0.31079573853395814 Delta: 0.2800062093920323
# Transactions delta: -4.033666620998414
# Elapsed: 0.4927511215209961
# 		Run on 2016-10-17 10:55:00
# Ichi regime at 2016-10-17 10:55:00: -1
# Current position delta: -4.0374114564730235
# Elapsed: 0.8278145790100098
# 		Run on 2016-10-18 10:55:00
# Ichi regime at 2016-10-18 10:55:00: -1
# Current position delta: -4.337711599649712
# Elapsed: 0.8326535224914551
# 		Run on 2016-10-19 10:55:00
# Rollover occured, new series used
# Date not found at 2016-10-19
# Ichi regime at 2016-10-19 10:55:00: None
# Current position delta: 0.0
# Elapsed: 0.8432614803314209
# 		Run on 2016-10-20 10:55:00
# Ichi regime at 2016-10-20 10:55:00: -1
# New bearish zone position
# Leg: bearish / P.US.ZWAZ164250 x 6.0 Price: 17.31288452976696 Delta: -3.5073234500204915
# Leg:  / P.US.ZWAZ163900 x -6.0 Price: 2.7332122062492914 Delta: 1.0007457232626613
# Transactions delta: -2.50657772675783
# Elapsed: 0.5382320880889893
# 		Run on 2016-10-21 10:55:00
# Ichi regime at 2016-10-21 10:55:00: -1
# Current position delta: -2.6287639093085686
# Elapsed: 0.8282163143157959
# 		Run on 2016-10-22 10:55:00
# Date not found at 2016-10-22
# Ichi regime at 2016-10-22 10:55:00: None
# Elapsed: 0.7163455486297607
# 		Run on 2016-10-23 10:55:00
# Ichi regime at 2016-10-23 10:55:00: -1
# New bearish zone position
# Leg: bearish / P.US.ZWAZ164250 x 6.0 Price: 17.590843118057023 Delta: -3.7532088945714337
# Leg:  / P.US.ZWAZ163900 x -6.0 Price: 2.2310495213852164 Delta: 0.9490632809845092
# Transactions delta: -2.8041456135869245
# Elapsed: 0.4993476867675781
# 		Run on 2016-10-24 10:55:00
# Ichi regime at 2016-10-24 10:55:00: -1
# Current position delta: -2.8859556845889345
# Elapsed: 0.8272738456726074
# 		Run on 2016-10-25 10:55:00
# Ichi regime at 2016-10-25 10:55:00: -1
# Current position delta: -2.8235519930374164
# Elapsed: 0.8447771072387695
# 		Run on 2016-10-26 10:55:00
# Ichi regime at 2016-10-26 10:55:00: -1
# Current position delta: -2.8284635750637035
# Elapsed: 0.9065899848937988
# 		Run on 2016-10-27 10:55:00
# Ichi regime at 2016-10-27 10:55:00: -1
# Current position delta: -2.827215807070035
# Elapsed: 0.8240435123443604
# 		Run on 2016-10-28 10:55:00
# Ichi regime at 2016-10-28 10:55:00: -1
# Current position delta: -2.953307365528162
# Elapsed: 0.8387007713317871
# 		Run on 2016-10-29 10:55:00
# Date not found at 2016-10-29
# Ichi regime at 2016-10-29 10:55:00: None
# Elapsed: 0.6628627777099609
# 		Run on 2016-10-30 10:55:00
# Ichi regime at 2016-10-30 10:55:00: -1
# New bearish zone position
# Leg: bearish / P.US.ZWAZ164200 x 6.0 Price: 16.701958388981552 Delta: -3.87917367661937
# Leg:  / P.US.ZWAZ163850 x -6.0 Price: 1.7281578347264244 Delta: 0.8365230359083784
# Transactions delta: -3.042650640710992
# Elapsed: 0.4970581531524658
# 		Run on 2016-10-31 10:55:00
# Ichi regime at 2016-10-31 10:55:00: -1
# Current position delta: -2.824371312400666
# Elapsed: 0.8126118183135986
# 		Run on 2016-11-01 10:55:00
# Ichi regime at 2016-11-01 10:55:00: -1
# Current position delta: -3.0212183881755053
# Elapsed: 0.8106932640075684
# 		Run on 2016-11-02 10:55:00
# Ichi regime at 2016-11-02 10:55:00: 1
# New bullish zone position
# Leg: bullish / C.US.ZWAZ164050 x 1.0 Price: 15.238211656348142 Delta: 0.702904817557614
# Leg:  / P.US.ZWAZ164050 x 1.0 Price: 4.485022275805363 Delta: -0.30206804509449026
# Leg:  / C.US.ZWAZ164650 x -1.0 Price: 0.6402995317786271 Delta: -0.054703129093756755
# Leg:  / P.US.ZWAZ163650 x -1.0 Price: 0.18937157688993533 Delta: 0.019065687366493195
# Transactions delta: 0.3651993307358602
# Elapsed: 1.4554591178894043
# 		Run on 2016-11-03 10:55:00
# Date not found at 2016-11-03
# Ichi regime at 2016-11-03 10:55:00: None
# Elapsed: 1.273930311203003
# Done

# %% [markdown]
# # View EXO price series

# %%
for ticker in instruments:
    exo_df, exo_info = exostorage.load_series('{0}_{1}'.format(ticker, EXO_NAME))    
    
    exo_df['exo'].plot(title='{0}_{1}'.format(ticker, EXO_NAME))
    ax = exo_df['ichi_regime'].plot(secondary_y=True)
    ax.set_ylim(-2,2)
    plt.show()
