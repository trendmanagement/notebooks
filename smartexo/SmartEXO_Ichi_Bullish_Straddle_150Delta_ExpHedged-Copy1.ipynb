# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from exobuilder.contracts.futureschain import FuturesChain
from exobuilder.contracts.futurecontract import FutureContract
from exobuilder.tests.assetindexdict import AssetIndexDicts
from datetime import datetime, date, timedelta, time as dttime
from exobuilder.contracts.instrument import Instrument
from exobuilder.data.datasource_mongo import DataSourceMongo
from exobuilder.data.datasource_sql import DataSourceSQL
from exobuilder.data.assetindex_mongo import AssetIndexMongo
from exobuilder.data.exostorage import EXOStorage
from exobuilder.exo.exoenginebase import ExoEngineBase
from exobuilder.exo.transaction import Transaction
import time
from exobuilder.algorithms.rollover_helper import RolloverHelper

import importlib
import logging
importlib.reload(logging);
import matplotlib.pyplot as plt

# %%
EXO_NAME = 'SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged_test'

# TODO: set to 'False' if EXO building output is too verbosive
verbosive_logging = True # or True - for debug log feed

# TODO: select instruments list for SMART EXO calculation
#instruments = ['CL', 'ES', 'NG', 'ZC', 'ZS', 'ZW', 'ZN']
instruments = ['CL']


# TODO: select start date for SmartEXO calculation
base_date = datetime(2013, 1, 13, 12, 45, 0)

# %% [markdown]
# # Define Bull/Bear/Neutral areas rules

# %%
def ichimoku_regimes(date, price_series):    
    '''
    Calculates Bull/Bear/Neutral areas based on Ichimoku zones
    
    param date: Current date time
    param price_series: price Pandas.Series
    
    Returns:
        -1 - for bearish zone
        0  - for neutral zone
        +1 - for bullish zone
        None - for unknown
    '''
    #
    #  TODO: Change values to fine tune zoning algorithm
    #
    conversion_line_period = 9 # subject of optimization
    base_line_period = 26  # subject of optimization
    leading_spans_lookahead_period = 26  # subject of optimization
    leading_span_b_period = 52 # subject of optimization
        
        
    conversion_line_high = price_series.rolling(window=conversion_line_period).max()
    conversion_line_low = price_series.rolling(window=conversion_line_period).min()
    conversion_line = (conversion_line_high + conversion_line_low) / 2

    base_line_high = price_series.rolling(window=base_line_period).max()
    base_line_low = price_series.rolling(window=base_line_period).min()
    base_line = (base_line_high + base_line_low) / 2

    leading_span_a = ((conversion_line + base_line) / 2).shift(leading_spans_lookahead_period)
    leading_span_b = ((price_series.rolling(window=leading_span_b_period).max() + price_series.rolling(
        window=leading_span_b_period).min()) / 2).shift(leading_spans_lookahead_period)


    #
    # Rules calculation
    #

    # Cloud top and bottom series are defined using leading span A and B
    cloud_top = leading_span_a.rolling(1).max()
    cloud_bottom = leading_span_a.rolling(1).min()

    rule_price_above_cloud_top = price_series > cloud_top
    rule_price_below_cloud_bottom = price_series < cloud_bottom
    rule_price_in_cloud = (price_series < cloud_top) & (price_series > cloud_bottom)

    def get_regime(date):
        if date not in rule_price_above_cloud_top.index:
            logging.debug("Date not found at {0}".format(date))
            return None


        if rule_price_above_cloud_top[date]:
            return 1
        elif rule_price_below_cloud_bottom[date]:
            return -1
        elif rule_price_in_cloud[date]:
            return 0
        return None

    regime = get_regime(date.date())
    logging.debug("Ichi regime at {0}: {1}".format(date, regime))
    return regime

# %%
# Toolbox
def transactions_delta(trans_list):
    return sum([t.delta for t in trans_list])

def log_transactions(trans_list, msg):
    logging.debug(msg)
    [logging.debug(t) for t in trans_list]
    logging.debug('Transactions delta: {0}'.format(transactions_delta(trans_list)))

# %% [markdown]
# # Option position management

# %% [markdown]
# According to https://tmqrexo.slack.com/files/nikolasjoyce/F2PHLEETZ/pasted_image_at_2016_10_14_10_05_am.png

# %% [markdown]
# ## New bullish zone position

# %%
def new_position_bullish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bullish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening long ITM straddle in bullish zone
    #
    # https://files.slack.com/files-tmb/T0484J7T7-F2QBLK53R-93b4252806/pasted_image_at_2016_10_17_10_08_am_720.png
   
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-2].c, date, 2.0, leg_name='bullish'),
                Transaction(opt_chain[-2].p, date, 1.0), 
                Transaction(opt_chain[-9].p, date, -4.0),
                Transaction(opt_chain[9].c, date,  -2.0),
                ]
    log_transactions(trans_list,'New bullish zone position')
    return trans_list

# %% [markdown]
# ## New bearish zone position

# %%
def new_position_bearish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bearish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening short butterfly in bearish zone
    #
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
               # Transaction(opt_chain[-6].p, date, -1.0, leg_name='bearish'),
               # Transaction(opt_chain[2].p, date, 1.0),
                
               # Transaction(opt_chain[3].c, date, 1.0),
               # Transaction(opt_chain[5].c, date,  -1.0),
                Transaction(opt_chain[5].c, date,  0.0),
                ]
    
 
    log_transactions(trans_list,'New bearish zone position')
    return trans_list

# %% [markdown]
# ## New neutral zone position

# %%
def new_position_neutral_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for neutral zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening long asymmetric butterfly in neutral zone
    #    
    # https://files.slack.com/files-tmb/T0484J7T7-F2PGU8QNQ-6344e6a04c/pasted_image_at_2016_10_14_09_43_am_720.png
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-4].p, date, 3.0, leg_name='bearish'),
                Transaction(opt_chain[1].p, date, -6.0),
                
                Transaction(opt_chain[2].p, date, 3.0),
                Transaction(opt_chain[3].c, date,  0.0),
           ]
    log_transactions(trans_list,'New neutral zone position')
    return trans_list

# %% [markdown]
# ## Manage opened positions

# %%
def manage_opened_position(date, fut, opt_chain, regime, opened_position):
    logging.debug('Current position delta: {0}'.format(opened_position.delta))
    
    # By default: do nothing
    return []

# %% [markdown]
# # Define EXO builder class

# %%
class SmartEXOIchimoku(ExoEngineBase):
    def __init__(self, symbol, direction, date, datasource, log_file_path=''):
        self._symbol = symbol
        self.custom_values = {}
        super().__init__(symbol, direction, date, datasource, log_file_path=log_file_path)

    @staticmethod
    def direction_type():
        return 0

    @staticmethod
    def names_list(symbol):
        return ['{0}_{1}'.format(self._symbol, EXO_NAME)]

    @property
    def exo_name(self):
            return '{0}_{1}'.format(self._symbol, EXO_NAME)

    def is_rollover(self):
        if len(self.position) != 0:
            for p in self.position.legs.values():
                rh = RolloverHelper(p.instrument)
                if rh.is_rollover(p):
                    return True
        return False

    def process_rollover(self):
        trans_list = self.position.close_all_translist()
        logging.info('Rollover occured, new series used')
        return trans_list
    
    def get_custom_values(self):
        """
        Method that return custom EXO data frame values, to store inside EXO Dataframe in the DB
        :return: dictionary {'string_key': (int or float) value}
        """
        return self.custom_values
    

    def process_day(self):
        """
        Main EXO's position management method
        :return: list of Transactions to process
        """

        # Get cont futures price for EXO
        exo_df, exo_info = self.datasource.exostorage.load_series("{0}_ContFut".format(self._symbol))

        regime = ichimoku_regimes(self.date, exo_df['exo'])

        trans_list = []

        if regime is None and len(self.position) > 0:
            return self.position.close_all_translist()
        
        instr = self.datasource.get(self._symbol, self.date)
        rh = RolloverHelper(instr)
        fut, opt_chain = rh.get_active_chains()

        if regime == 1 and 'bullish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bullish_zone(self.date, fut, opt_chain)
            
            return trans_list
        if regime == -1 and 'bearish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bearish_zone(self.date, fut, opt_chain)
            return trans_list

        if regime == 0 and 'neutral' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_neutral_zone(self.date, fut, opt_chain)
            return trans_list
        
        #
        # Writing custom values to store inside DB 
        #
        self.custom_values = {
            'ichi_regime': regime if regime is not None else float('nan')
        }
        
        #
        # Manage opened position
        #
        return manage_opened_position(self.date, fut, opt_chain, regime, self.position)

# %% [markdown]
# # Run EXO build process (WARN: long-running task!)

# %%
from pymongo import MongoClient

if verbosive_logging:
    logging.basicConfig(format='%(message)s', level=logging.DEBUG)
else:
    logging.basicConfig(format='%(message)s', level=logging.INFO)

mongo_connstr = 'mongodb://exowriter:qmWSy4K3@10.0.1.2/tmldb?authMechanism=SCRAM-SHA-1'
mongo_db_name = 'tmldb'
assetindex = AssetIndexMongo(mongo_connstr, mongo_db_name)
exostorage = EXOStorage(mongo_connstr, mongo_db_name)

#base_date = datetime(2011, 6, 13, 12, 45, 0)


futures_limit = 3
options_limit = 10

DEBUG = '.'

datasource = DataSourceMongo(mongo_connstr, mongo_db_name, assetindex, futures_limit, options_limit, exostorage)

server = 'h9ggwlagd1.database.windows.net'
user = 'modelread'
password = '4fSHRXwd4u'
datasource = DataSourceSQL(server, user, password, assetindex, futures_limit, options_limit, exostorage)

enddate = datetime.combine(datetime.now().date(), dttime(12, 45, 0))
currdate = base_date


logging.info("Deleting all SmartEXO of :" + EXO_NAME)
client = MongoClient(mongo_connstr)
db = client[mongo_db_name]
db['exo_data'].delete_many({'name': {'$regex': '.*{0}*.'.format(EXO_NAME)}})


logging.info("Starting EXO calculation process from: {0}".format(currdate))
for ticker in instruments:
    logging.info("Processing: "+ticker)
    currdate = base_date
    while currdate <= enddate:
        
        start_time = time.time()
        date = currdate

        asset_info = assetindex.get_instrument_info(ticker)
        exec_time_end, decision_time_end = AssetIndexMongo.get_exec_time(date, asset_info)
        
        logging.info("\t\tRun on {0}".format(decision_time_end))

        with SmartEXOIchimoku(ticker, 0, decision_time_end, datasource) as exo_engine:
            # Load EXO information from mongo
            exo_engine.load()
            exo_engine.calculate()

        end_time = time.time()
        currdate += timedelta(days=1)
        logging.debug("Elapsed: {0}".format(end_time-start_time))
logging.info('Done')
# Out:
# Deleting all SmartEXO of :SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged_test
# Starting EXO calculation process from: 2013-01-13 12:45:00
# Processing: CL
# 		Run on 2013-01-13 11:10:00
# Ichi regime at 2013-01-13 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEG139300 x 2.0 Price: 1.0791097160161058 Delta: 1.3878407152939527
# Leg:  / P.US.CLEG139300 x 1.0 Price: 0.30954900759183346 Delta: -0.30691322591903214
# Leg:  / P.US.CLEG138950 x -4.0 Price: 0.013586934479616009 Delta: 0.07124370900668707
# Leg:  / C.US.CLEG139850 x -2.0 Price: 0.010008749255600469 Delta: -0.02756656565470818
# Transactions delta: 1.1246046327268995
# Elapsed: 0.8244397640228271
# 		Run on 2013-01-14 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-01-14 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEH139300 x 2.0 Price: 3.027019254864676 Delta: 1.1611994906019085
# Leg:  / P.US.CLEH139300 x 1.0 Price: 1.9979989685098474 Delta: -0.41992168085504855
# Leg:  / P.US.CLEH138950 x -4.0 Price: 0.9802228673097915 Delta: 0.9441481043875204
# Leg:  / C.US.CLEH139850 x -2.0 Price: 0.792843202449312 Delta: -0.47619065363729884
# Transactions delta: 1.2092352604970815
# Elapsed: 2.38456130027771
# 		Run on 2013-01-15 11:10:00
# Ichi regime at 2013-01-15 11:10:00: 1
# Current position delta: 1.1979770181473008
# Elapsed: 1.7095818519592285
# 		Run on 2013-01-16 11:10:00
# Ichi regime at 2013-01-16 11:10:00: 1
# Current position delta: 1.1717527842612578
# Elapsed: 1.552292823791504
# 		Run on 2013-01-17 11:10:00
# Ichi regime at 2013-01-17 11:10:00: 1
# Current position delta: 1.0256885915405418
# Elapsed: 1.5583562850952148
# 		Run on 2013-01-18 11:10:00
# Ichi regime at 2013-01-18 11:10:00: 1
# Current position delta: 1.0711401096863105
# Elapsed: 1.5682544708251953
# 		Run on 2013-01-19 11:10:00
# Ichi regime at 2013-01-19 11:10:00: 1
# Current position delta: 1.1017490915903845
# Elapsed: 1.553438425064087
# 		Run on 2013-01-20 11:10:00
# Ichi regime at 2013-01-20 11:10:00: 1
# Current position delta: 1.1023100736045666
# Elapsed: 1.565234899520874
# 		Run on 2013-01-21 11:10:00
# Ichi regime at 2013-01-21 11:10:00: 1
# Current position delta: 1.093376224415383
# Elapsed: 1.539874792098999
# 		Run on 2013-01-22 11:10:00
# Ichi regime at 2013-01-22 11:10:00: 1
# Current position delta: 0.9951610260987014
# Elapsed: 1.5468230247497559
# 		Run on 2013-01-23 11:10:00
# Ichi regime at 2013-01-23 11:10:00: 1
# Current position delta: 1.1938311372137604
# Elapsed: 1.5795872211456299
# 		Run on 2013-01-24 11:10:00
# Ichi regime at 2013-01-24 11:10:00: 1
# Current position delta: 1.0873925278178593
# Elapsed: 1.560450553894043
# 		Run on 2013-01-25 11:10:00
# Ichi regime at 2013-01-25 11:10:00: 1
# Current position delta: 1.126507517764558
# Elapsed: 1.5498807430267334
# 		Run on 2013-01-26 11:10:00
# Ichi regime at 2013-01-26 11:10:00: 1
# Current position delta: 1.1144253293090796
# Elapsed: 1.56123948097229
# 		Run on 2013-01-27 11:10:00
# Ichi regime at 2013-01-27 11:10:00: 1
# Current position delta: 1.1186419821083826
# Elapsed: 1.5723586082458496
# 		Run on 2013-01-28 11:10:00
# Ichi regime at 2013-01-28 11:10:00: 1
# Current position delta: 1.1159977860093617
# Elapsed: 1.5466995239257812
# 		Run on 2013-01-29 11:10:00
# Ichi regime at 2013-01-29 11:10:00: 1
# Current position delta: 0.9759180156654278
# Elapsed: 1.5890591144561768
# 		Run on 2013-01-30 11:10:00
# Ichi regime at 2013-01-30 11:10:00: 1
# Current position delta: 0.9287640361581933
# Elapsed: 1.5910325050354004
# 		Run on 2013-01-31 11:10:00
# Ichi regime at 2013-01-31 11:10:00: 1
# Current position delta: 1.0243893060096958
# Elapsed: 1.5482871532440186
# 		Run on 2013-02-01 11:10:00
# Ichi regime at 2013-02-01 11:10:00: 1
# Current position delta: 0.9836696075649577
# Elapsed: 1.5443193912506104
# 		Run on 2013-02-02 11:10:00
# Ichi regime at 2013-02-02 11:10:00: 1
# Current position delta: 0.9963203136529066
# Elapsed: 1.558659553527832
# 		Run on 2013-02-03 11:10:00
# Ichi regime at 2013-02-03 11:10:00: 1
# Current position delta: 1.0096926048457537
# Elapsed: 1.5758295059204102
# 		Run on 2013-02-04 11:10:00
# Ichi regime at 2013-02-04 11:10:00: 1
# Current position delta: 1.2116352269926005
# Elapsed: 1.539433240890503
# 		Run on 2013-02-05 11:10:00
# Ichi regime at 2013-02-05 11:10:00: 1
# Current position delta: 1.1519577045700762
# Elapsed: 1.5479249954223633
# 		Run on 2013-02-06 11:10:00
# Ichi regime at 2013-02-06 11:10:00: 1
# Current position delta: 1.2374725029289155
# Elapsed: 1.5437207221984863
# 		Run on 2013-02-07 11:10:00
# Ichi regime at 2013-02-07 11:10:00: 1
# Current position delta: 1.319903801257193
# Elapsed: 1.5774412155151367
# 		Run on 2013-02-08 11:10:00
# Ichi regime at 2013-02-08 11:10:00: 1
# Current position delta: 1.3771104432882992
# Elapsed: 1.5571627616882324
# 		Run on 2013-02-09 11:10:00
# Ichi regime at 2013-02-09 11:10:00: 1
# Current position delta: 1.505993296305185
# Elapsed: 1.5625908374786377
# 		Run on 2013-02-10 11:10:00
# Ichi regime at 2013-02-10 11:10:00: 1
# Current position delta: 1.5863267172287434
# Elapsed: 1.5334677696228027
# 		Run on 2013-02-11 11:10:00
# Ichi regime at 2013-02-11 11:10:00: 1
# Current position delta: 1.6473180218158179
# Elapsed: 1.5798909664154053
# 		Run on 2013-02-12 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-02-12 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEJ139700 x 2.0 Price: 2.835800192647831 Delta: 1.2034625233700234
# Leg:  / P.US.CLEJ139700 x 1.0 Price: 1.6158086483616927 Delta: -0.3991612905326583
# Leg:  / P.US.CLEJ139350 x -4.0 Price: 0.7653560740454601 Delta: 0.8379628420453957
# Leg:  / C.US.CLEJ1310250 x -2.0 Price: 0.5823510301527328 Delta: -0.4205458346857952
# Transactions delta: 1.2217182401969655
# Elapsed: 2.391345977783203
# 		Run on 2013-02-13 11:10:00
# Ichi regime at 2013-02-13 11:10:00: 1
# Current position delta: 1.2940082790449692
# Elapsed: 1.7234585285186768
# 		Run on 2013-02-14 11:10:00
# Ichi regime at 2013-02-14 11:10:00: 1
# Current position delta: 1.2526694870386332
# Elapsed: 1.5491068363189697
# 		Run on 2013-02-15 11:10:00
# Ichi regime at 2013-02-15 11:10:00: 1
# Current position delta: 1.4040596558372267
# Elapsed: 1.5465295314788818
# 		Run on 2013-02-16 11:10:00
# 		Run on 2013-05-08 11:10:00
# Ichi regime at 2013-05-08 11:10:00: 1
# Current position delta: 1.1841042513349715
# Elapsed: 1.5595922470092773
# 		Run on 2013-05-09 11:10:00
# Ichi regime at 2013-05-09 11:10:00: 1
# Current position delta: 1.2229706654846808
# Elapsed: 1.6043004989624023
# 		Run on 2013-05-10 11:10:00
# Ichi regime at 2013-05-10 11:10:00: 1
# Current position delta: 1.1891232012563244
# Elapsed: 1.5518288612365723
# 		Run on 2013-05-11 11:10:00
# Ichi regime at 2013-05-11 11:10:00: 1
# Current position delta: 1.3040867342284432
# Elapsed: 1.5556902885437012
# 		Run on 2013-05-12 11:10:00
# Ichi regime at 2013-05-12 11:10:00: 1
# Current position delta: 1.3406859458211953
# Elapsed: 1.55332350730896
# 		Run on 2013-05-13 11:10:00
# Ichi regime at 2013-05-13 11:10:00: 1
# Current position delta: 1.1553780362955632
# Elapsed: 1.5482673645019531
# 		Run on 2013-05-14 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-05-14 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEN139350 x 2.0 Price: 3.089548719633946 Delta: 1.1556116424517398
# Leg:  / P.US.CLEN139350 x 1.0 Price: 2.0805498144842858 Delta: -0.42268901029324674
# Leg:  / P.US.CLEN139000 x -4.0 Price: 1.0839039056005753 Delta: 0.9834478806292677
# Leg:  / C.US.CLEN139900 x -2.0 Price: 0.7414427808549107 Delta: -0.46127963054771565
# Transactions delta: 1.255090882240045
# Elapsed: 2.378235101699829
# 		Run on 2013-05-15 11:10:00
# Ichi regime at 2013-05-15 11:10:00: 1
# Current position delta: 1.2598047122258988
# Elapsed: 1.709768295288086
# 		Run on 2013-05-16 11:10:00
# Ichi regime at 2013-05-16 11:10:00: 1
# Current position delta: 1.1362017606716435
# Elapsed: 1.5590205192565918
# 		Run on 2013-05-17 11:10:00
# Ichi regime at 2013-05-17 11:10:00: 1
# Current position delta: 1.0739346926835922
# Elapsed: 1.5517935752868652
# 		Run on 2013-05-18 11:10:00
# Ichi regime at 2013-05-18 11:10:00: 1
# Current position delta: 1.0946698918612623
# Elapsed: 1.6344265937805176
# 		Run on 2013-05-19 11:10:00
# Ichi regime at 2013-05-19 11:10:00: 1
# Current position delta: 1.0937340551474708
# Elapsed: 1.5634899139404297
# 		Run on 2013-05-20 11:10:00
# Ichi regime at 2013-05-20 11:10:00: 1
# Current position delta: 1.0112301838863957
# Elapsed: 1.540229320526123
# 		Run on 2013-05-21 11:10:00
# Ichi regime at 2013-05-21 11:10:00: 1
# Current position delta: 1.0726193905869326
# Elapsed: 1.5600922107696533
# 		Run on 2013-05-22 11:10:00
# Ichi regime at 2013-05-22 11:10:00: 1
# Current position delta: 1.2796886993086962
# Elapsed: 1.6007463932037354
# 		Run on 2013-05-23 11:10:00
# Ichi regime at 2013-05-23 11:10:00: 1
# Current position delta: 1.3201217927767828
# Elapsed: 1.5669527053833008
# 		Run on 2013-05-24 11:10:00
# Ichi regime at 2013-05-24 11:10:00: 1
# Current position delta: 1.2660866279494158
# Elapsed: 1.5698933601379395
# 		Run on 2013-05-25 11:10:00
# Ichi regime at 2013-05-25 11:10:00: 1
# Current position delta: 1.2665363174411763
# Elapsed: 1.540184736251831
# 		Run on 2013-05-26 11:10:00
# Ichi regime at 2013-05-26 11:10:00: 1
# Current position delta: 1.2601498617461375
# Elapsed: 1.564192533493042
# 		Run on 2013-05-27 11:10:00
# Ichi regime at 2013-05-27 11:10:00: 1
# Current position delta: 1.2674417630489876
# Elapsed: 1.5806760787963867
# 		Run on 2013-05-28 11:10:00
# Ichi regime at 2013-05-28 11:10:00: 1
# Current position delta: 1.1742403609026506
# Elapsed: 1.5894150733947754
# 		Run on 2013-05-29 11:10:00
# Ichi regime at 2013-05-29 11:10:00: 1
# Current position delta: 1.3141961317242477
# Elapsed: 1.619727611541748
# 		Run on 2013-05-30 11:10:00
# Ichi regime at 2013-05-30 11:10:00: 1
# Current position delta: 1.2760604098188184
# Elapsed: 1.5685298442840576
# 		Run on 2013-05-31 11:10:00
# Ichi regime at 2013-05-31 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEN139500 x 0.0 Price: 0.732371946444939 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 1.7410335540771484
# 		Run on 2013-06-01 11:10:00
# Ichi regime at 2013-06-01 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEN139400 x 0.0 Price: 0.7248823533585238 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7456274032592773
# 		Run on 2013-06-02 11:10:00
# Ichi regime at 2013-06-02 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEN139400 x 0.0 Price: 0.6805872018839381 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7388851642608643
# 		Run on 2013-06-03 11:10:00
# Ichi regime at 2013-06-03 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEN139250 x 2.0 Price: 2.111447247613768 Delta: 1.2022240026344484
# Leg:  / P.US.CLEN139250 x 1.0 Price: 1.1823236143776015 Delta: -0.39945603690284676
# Leg:  / P.US.CLEN138900 x -4.0 Price: 0.3500528759604933 Delta: 0.5940986371181962
# Leg:  / C.US.CLEN139800 x -2.0 Price: 0.20456178551268778 Delta: -0.23225121193263829
# Transactions delta: 1.1646153909171595
# Elapsed: 1.2219862937927246
# 		Run on 2013-06-04 11:10:00
# Ichi regime at 2013-06-04 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEN139550 x 0.0 Price: 0.6239717272957463 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 1.7073602676391602
# 		Run on 2013-06-05 11:10:00
# Ichi regime at 2013-06-05 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEN139300 x 2.0 Price: 2.2623076069948382 Delta: 1.241423505136605
# Leg:  / P.US.CLEN139300 x 1.0 Price: 1.1124116738830665 Delta: -0.379835800998188
# Leg:  / P.US.CLEN138950 x -4.0 Price: 0.3020600504244193 Delta: 0.5341476588980885
# Leg:  / C.US.CLEN139850 x -2.0 Price: 0.24747157169637113 Delta: -0.2664702120126868
# Transactions delta: 1.1292651510238187
# Elapsed: 1.2750978469848633
# 		Run on 2013-06-06 11:10:00
# Ichi regime at 2013-06-06 11:10:00: 1
# Current position delta: 1.135363785667862
# Elapsed: 1.5665080547332764
# 		Run on 2013-06-07 11:10:00
# Ichi regime at 2013-06-07 11:10:00: 1
# Current position delta: 1.158202845649144
# Elapsed: 1.5492372512817383
# 		Run on 2013-06-08 11:10:00
# Ichi regime at 2013-06-08 11:10:00: 1
# Current position delta: 1.2583751519119721
# Elapsed: 1.6077053546905518
# 		Run on 2013-06-09 11:10:00
# Ichi regime at 2013-06-09 11:10:00: 1
# Current position delta: 1.2952746403147304
# Elapsed: 1.5999877452850342
# 		Run on 2013-06-10 11:10:00
# Ichi regime at 2013-06-10 11:10:00: 1
# Current position delta: 1.362466707624835
# Elapsed: 1.565495252609253
# 		Run on 2013-06-11 11:10:00
# Ichi regime at 2013-06-11 11:10:00: 1
# Current position delta: 1.3705186178989526
# Elapsed: 1.5982263088226318
# 		Run on 2013-06-12 11:10:00
# Ichi regime at 2013-06-12 11:10:00: 1
# Current position delta: 1.4917728257766523
# Elapsed: 1.560549259185791
# 		Run on 2013-06-13 11:10:00
# Ichi regime at 2013-06-13 11:10:00: 1
# Current position delta: 1.5558515667900616
# Elapsed: 1.5633373260498047
# 		Run on 2013-06-14 11:10:00
# Ichi regime at 2013-06-14 11:10:00: 1
# Current position delta: 1.3071382629378547
# Elapsed: 1.5630927085876465
# 		Run on 2013-06-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-06-15 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEQ139700 x 2.0 Price: 2.809856299459504 Delta: 1.1762495491121208
# Leg:  / P.US.CLEQ139700 x 1.0 Price: 1.7502063447276157 Delta: -0.41256621371322955
# Leg:  / P.US.CLEQ139350 x -4.0 Price: 0.7744092064154806 Delta: 0.8560867289294268
# Leg:  / C.US.CLEQ1310250 x -2.0 Price: 0.5946145514882879 Delta: -0.4178748585686776
# Transactions delta: 1.2018952057596406
# Elapsed: 2.352205276489258
# 		Run on 2013-06-16 11:10:00
# Ichi regime at 2013-06-16 11:10:00: 1
# Current position delta: 1.1993772226316048
# Elapsed: 1.7960798740386963
# 		Run on 2013-06-17 11:10:00
# Ichi regime at 2013-06-17 11:10:00: 1
# Current position delta: 1.1994571309970024
# Elapsed: 1.5895159244537354
# 		Run on 2013-06-18 11:10:00
# Ichi regime at 2013-06-18 11:10:00: 1
# Current position delta: 1.1608737404724112
# Elapsed: 1.5644421577453613
# 		Run on 2013-06-19 11:10:00
# Ichi regime at 2013-06-19 11:10:00: 1
# Current position delta: 1.1814149550729411
# Elapsed: 1.5613882541656494
# 		Run on 2013-06-20 11:10:00
# Ichi regime at 2013-06-20 11:10:00: 1
# Current position delta: 1.4289536343875102
# Elapsed: 1.5618376731872559
# 		Run on 2013-06-21 11:10:00
# Ichi regime at 2013-06-21 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEQ139600 x 0.0 Price: 1.13668184342891 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 1.7435166835784912
# 		Run on 2013-06-22 11:10:00
# Ichi regime at 2013-06-22 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEQ139650 x 0.0 Price: 1.0365993640951565 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.8098287582397461
# 		Run on 2013-06-23 11:10:00
# Ichi regime at 2013-06-23 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEQ139650 x 0.0 Price: 0.9995567025195449 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7441394329071045
# 		Run on 2013-06-24 11:10:00
# Ichi regime at 2013-06-24 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEQ139450 x 2.0 Price: 2.512633540709089 Delta: 1.1519939996916402
# Leg:  / P.US.CLEQ139450 x 1.0 Price: 1.683905790693835 Delta: -0.42454202031969657
# Leg:  / P.US.CLEQ139100 x -4.0 Price: 0.6916288867057894 Delta: 0.8347771541769403
# Leg:  / C.US.CLEQ1310000 x -2.0 Price: 0.4751748921285923 Delta: -0.36587349213282616
# Transactions delta: 1.1963556414160577
# Elapsed: 1.219001293182373
# 		Run on 2013-06-25 11:10:00
# Ichi regime at 2013-06-25 11:10:00: 1
# Current position delta: 1.2190935682097832
# Elapsed: 1.5648164749145508
# 		Run on 2013-06-26 11:10:00
# Ichi regime at 2013-06-26 11:10:00: 1
# Current position delta: 1.2266808842943864
# Elapsed: 1.5767121315002441
# 		Run on 2013-06-27 11:10:00
# Ichi regime at 2013-06-27 11:10:00: 1
# Current position delta: 1.07612593402452
# Elapsed: 1.5491414070129395
# 		Run on 2013-06-28 11:10:00
# Ichi regime at 2013-06-28 11:10:00: 1
# Current position delta: 1.055515979283172
# Elapsed: 1.5659477710723877
# 		Run on 2013-06-29 11:10:00
# Ichi regime at 2013-06-29 11:10:00: 1
# Current position delta: 1.1322384929141642
# Elapsed: 1.5594871044158936
# 		Run on 2013-06-30 11:10:00
# Ichi regime at 2013-06-30 11:10:00: 1
# Current position delta: 1.134200361014676
# Elapsed: 1.5530834197998047
# 		Run on 2013-07-01 11:10:00
# Ichi regime at 2013-07-01 11:10:00: 1
# Current position delta: 1.0566536625411176
# Elapsed: 1.5451674461364746
# 		Run on 2013-07-02 11:10:00
# Ichi regime at 2013-07-02 11:10:00: 1
# Current position delta: 0.8645452131137603
# Elapsed: 1.5400893688201904
# 		Run on 2013-07-03 11:10:00
# Ichi regime at 2013-07-03 11:10:00: 1
# Current position delta: 0.6531140615940051
# Elapsed: 1.5700352191925049
# 		Run on 2013-07-04 11:10:00
# Ichi regime at 2013-07-04 11:10:00: 1
# Current position delta: 0.6550186492517951
# Elapsed: 1.5694177150726318
# 		Run on 2013-07-05 11:10:00
# Ichi regime at 2013-07-05 11:10:00: 1
# Current position delta: 0.43049276865239144
# Elapsed: 1.560378074645996
# 		Run on 2013-07-06 11:10:00
# Ichi regime at 2013-07-06 11:10:00: 1
# Current position delta: 0.34424613682387856
# Elapsed: 1.5468614101409912
# 		Run on 2013-07-07 11:10:00
# Ichi regime at 2013-07-07 11:10:00: 1
# Current position delta: 0.32701109048744714
# Elapsed: 1.5787804126739502
# 		Run on 2013-07-08 11:10:00
# Ichi regime at 2013-07-08 11:10:00: 1
# Current position delta: 0.38270939900471185
# Elapsed: 1.640986442565918
# 		Run on 2013-07-09 11:10:00
# Ichi regime at 2013-07-09 11:10:00: 1
# Current position delta: 0.2969349761279426
# Elapsed: 1.5748274326324463
# 		Run on 2013-07-10 11:10:00
# Ichi regime at 2013-07-10 11:10:00: 1
# Current position delta: 0.06957088850187734
# Elapsed: 1.5508050918579102
# 		Run on 2013-07-11 11:10:00
# Ichi regime at 2013-07-11 11:10:00: 1
# Current position delta: 0.19305880185506002
# Elapsed: 1.5466959476470947
# 		Run on 2013-07-12 11:10:00
# Ichi regime at 2013-07-12 11:10:00: 1
# Current position delta: 0.072697743460241
# Elapsed: 1.5647871494293213
# 		Run on 2013-07-13 11:10:00
# Ichi regime at 2013-07-13 11:10:00: 1
# Current position delta: 0.041346862930226096
# Elapsed: 1.5417160987854004
# 		Run on 2013-07-14 11:10:00
# Ichi regime at 2013-07-14 11:10:00: 1
# Current position delta: 0.018007769646905626
# Elapsed: 1.5467941761016846
# 		Run on 2013-07-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-07-15 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEU1310500 x 2.0 Price: 2.995997348903302 Delta: 1.1237238884521585
# Leg:  / P.US.CLEU1310500 x 1.0 Price: 2.2266740097001616 Delta: -0.43867383937101956
# Leg:  / P.US.CLEU1310150 x -4.0 Price: 1.092999020580212 Delta: 1.0132399654722046
# Leg:  / C.US.CLEU1311050 x -2.0 Price: 0.9201334428246781 Delta: -0.4950577190226732
# Transactions delta: 1.2032322955306702
# Elapsed: 2.3838698863983154
# 		Run on 2013-07-16 11:10:00
# Ichi regime at 2013-07-16 11:10:00: 1
# Current position delta: 1.2037464329499954
# Elapsed: 1.753143310546875
# 		Run on 2013-07-17 11:10:00
# Ichi regime at 2013-07-17 11:10:00: 1
# Current position delta: 1.1958357821651344
# Elapsed: 1.574861764907837
# 		Run on 2013-07-18 11:10:00
# Ichi regime at 2013-07-18 11:10:00: 1
# Current position delta: 1.0309307522500513
# Elapsed: 1.5659270286560059
# 		Run on 2013-07-19 11:10:00
# Ichi regime at 2013-07-19 11:10:00: 1
# Current position delta: 1.0602028801913819
# Elapsed: 1.5474400520324707
# 		Run on 2013-07-20 11:10:00
# Ichi regime at 2013-07-20 11:10:00: 1
# Current position delta: 0.9999472098641411
# Elapsed: 1.5542340278625488
# 		Run on 2013-07-21 11:10:00
# Ichi regime at 2013-07-21 11:10:00: 1
# Current position delta: 0.9979813427234326
# Elapsed: 1.5715932846069336
# 		Run on 2013-07-22 11:10:00
# Ichi regime at 2013-07-22 11:10:00: 1
# Current position delta: 1.1180474203431512
# Elapsed: 1.53969407081604
# 		Run on 2013-07-23 11:10:00
# Ichi regime at 2013-07-23 11:10:00: 1
# Current position delta: 1.0819663148165621
# Elapsed: 1.552107572555542
# 		Run on 2013-07-24 11:10:00
# Ichi regime at 2013-07-24 11:10:00: 1
# Current position delta: 1.2886178659444285
# Elapsed: 1.560368537902832
# 		Run on 2013-07-25 11:10:00
# Ichi regime at 2013-07-25 11:10:00: 1
# Current position delta: 1.236465129618549
# Elapsed: 1.5452508926391602
# 		Run on 2013-07-26 11:10:00
# Ichi regime at 2013-07-26 11:10:00: 1
# Current position delta: 1.3348043782833279
# Elapsed: 1.5581238269805908
# 		Run on 2013-07-27 11:10:00
# Ichi regime at 2013-07-27 11:10:00: 1
# Current position delta: 1.3051200086478465
# Elapsed: 1.5639123916625977
# 		Run on 2013-07-28 11:10:00
# Ichi regime at 2013-07-28 11:10:00: 1
# Current position delta: 1.2941656821747438
# Elapsed: 1.5467796325683594
# 		Run on 2013-07-29 11:10:00
# Ichi regime at 2013-07-29 11:10:00: 1
# Current position delta: 1.2809927809578765
# Elapsed: 1.5486855506896973
# 		Run on 2013-07-30 11:10:00
# Ichi regime at 2013-07-30 11:10:00: 1
# Current position delta: 1.4095281016274153
# Elapsed: 1.551365852355957
# 		Run on 2013-07-31 11:10:00
# Ichi regime at 2013-07-31 11:10:00: 1
# Current position delta: 1.2483835211135261
# Elapsed: 1.5457055568695068
# 		Run on 2013-08-01 11:10:00
# Ichi regime at 2013-08-01 11:10:00: 1
# Current position delta: 1.0024291010726714
# Elapsed: 1.5599370002746582
# 		Run on 2013-08-02 11:10:00
# Ichi regime at 2013-08-02 11:10:00: 1
# Current position delta: 1.0860757148882265
# Elapsed: 1.6134138107299805
# 		Run on 2013-08-03 11:10:00
# Ichi regime at 2013-08-03 11:10:00: 1
# Current position delta: 1.0790107152640278
# Elapsed: 1.5570595264434814
# 		Run on 2013-08-04 11:10:00
# Ichi regime at 2013-08-04 11:10:00: 1
# Current position delta: 1.0840064277320942
# Elapsed: 1.5575778484344482
# 		Run on 2013-08-05 11:10:00
# Ichi regime at 2013-08-05 11:10:00: 1
# Current position delta: 1.0923543478614057
# Elapsed: 1.579836130142212
# 		Run on 2013-08-06 11:10:00
# Ichi regime at 2013-08-06 11:10:00: 1
# Current position delta: 1.110041492876777
# Elapsed: 1.5538697242736816
# 		Run on 2013-08-07 11:10:00
# Ichi regime at 2013-08-07 11:10:00: 1
# Current position delta: 1.0552325534138824
# Elapsed: 1.548518180847168
# 		Run on 2013-08-08 11:10:00
# Ichi regime at 2013-08-08 11:10:00: 1
# Current position delta: 1.0864574579529809
# Elapsed: 1.580094575881958
# 		Run on 2013-08-09 11:10:00
# Ichi regime at 2013-08-09 11:10:00: 1
# Current position delta: 1.0094810156540683
# Elapsed: 1.5534088611602783
# 		Run on 2013-08-10 11:10:00
# Ichi regime at 2013-08-10 11:10:00: 1
# Current position delta: 1.0895673912028412
# Elapsed: 1.558666706085205
# 		Run on 2013-08-11 11:10:00
# Ichi regime at 2013-08-11 11:10:00: 1
# Current position delta: 1.0956222548359151
# Elapsed: 1.5516636371612549
# 		Run on 2013-08-12 11:10:00
# Ichi regime at 2013-08-12 11:10:00: 1
# Current position delta: 1.0668899207214415
# Elapsed: 1.5422508716583252
# 		Run on 2013-08-13 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-08-13 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEV1310550 x 2.0 Price: 3.309763582675174 Delta: 1.1295016132060987
# Leg:  / P.US.CLEV1310550 x 1.0 Price: 2.419976768502096 Delta: -0.4356292884199115
# Leg:  / P.US.CLEV1310200 x -4.0 Price: 1.2112497398209712 Delta: 1.0412647475644627
# Leg:  / C.US.CLEV1311100 x -2.0 Price: 1.1285280781617288 Delta: -0.5435053615107173
# Transactions delta: 1.1916317108399326
# Elapsed: 2.363940954208374
# 		Run on 2013-08-14 11:10:00
# Ichi regime at 2013-08-14 11:10:00: 1
# Current position delta: 1.1761064073433254
# Elapsed: 1.7768847942352295
# 		Run on 2013-08-15 11:10:00
# Ichi regime at 2013-08-15 11:10:00: 1
# Current position delta: 1.1175479337003673
# Elapsed: 1.571234941482544
# 		Run on 2013-08-16 11:10:00
# Ichi regime at 2013-08-16 11:10:00: 1
# Current position delta: 1.1251140087754306
# Elapsed: 1.6287837028503418
# 		Run on 2013-08-17 11:10:00
# Ichi regime at 2013-08-17 11:10:00: 1
# Current position delta: 1.0797499198596792
# Elapsed: 1.5441417694091797
# 		Run on 2013-08-18 11:10:00
# Ichi regime at 2013-08-18 11:10:00: 1
# Current position delta: 1.0770967954874002
# Elapsed: 1.5633354187011719
# 		Run on 2013-08-19 11:10:00
# Ichi regime at 2013-08-19 11:10:00: 1
# Current position delta: 1.1297718692882972
# Elapsed: 1.5470740795135498
# 		Run on 2013-08-20 11:10:00
# Ichi regime at 2013-08-20 11:10:00: 1
# Current position delta: 1.3436368898355362
# Elapsed: 1.5757861137390137
# 		Run on 2013-08-21 11:10:00
# Ichi regime at 2013-08-21 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEV1310650 x 0.0 Price: 1.4144906218332025 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 1.7209181785583496
# 		Run on 2013-08-22 11:10:00
# Ichi regime at 2013-08-22 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEV1310400 x 2.0 Price: 3.0149370453753406 Delta: 1.1465843875940211
# Leg:  / P.US.CLEV1310400 x 1.0 Price: 2.065151955802115 Delta: -0.4271043147263359
# Leg:  / P.US.CLEV1310050 x -4.0 Price: 0.9848659251055345 Delta: 0.9582651770523848
# Leg:  / C.US.CLEV1310950 x -2.0 Price: 0.8111677569004669 Delta: -0.4754371143350579
# Transactions delta: 1.202308135585012
# Elapsed: 1.2376620769500732
# 		Run on 2013-08-23 11:10:00
# Ichi regime at 2013-08-23 11:10:00: 1
# Current position delta: 1.0492674077241797
# Elapsed: 1.5812458992004395
# 		Run on 2013-08-24 11:10:00
# Ichi regime at 2013-08-24 11:10:00: 1
# Current position delta: 1.0424363288437952
# Elapsed: 1.5409984588623047
# 		Run on 2013-08-25 11:10:00
# Ichi regime at 2013-08-25 11:10:00: 1
# Current position delta: 1.0406434089661052
# Elapsed: 1.55430269241333
# 		Run on 2013-08-26 11:10:00
# Ichi regime at 2013-08-26 11:10:00: 1
# Current position delta: 1.0590844721730615
# Elapsed: 1.559845209121704
# 		Run on 2013-08-27 11:10:00
# Ichi regime at 2013-08-27 11:10:00: 1
# Current position delta: 0.7969007885203938
# Elapsed: 1.59822678565979
# 		Run on 2013-08-28 11:10:00
# Ichi regime at 2013-08-28 11:10:00: 1
# Current position delta: 0.661878293921254
# Elapsed: 1.5549840927124023
# 		Run on 2013-08-29 11:10:00
# Ichi regime at 2013-08-29 11:10:00: 1
# Current position delta: 0.7113094141093588
# Elapsed: 1.546706199645996
# 		Run on 2013-08-30 11:10:00
# Ichi regime at 2013-08-30 11:10:00: 1
# Current position delta: 0.8658536154865016
# Elapsed: 1.5532770156860352
# 		Run on 2013-08-31 11:10:00
# Ichi regime at 2013-08-31 11:10:00: 1
# Current position delta: 0.8793598931984827
# Elapsed: 1.551605224609375
# 		Run on 2013-09-01 11:10:00
# Ichi regime at 2013-09-01 11:10:00: 1
# Current position delta: 0.8774980229296243
# Elapsed: 1.5460522174835205
# 		Run on 2013-09-02 11:10:00
# Ichi regime at 2013-09-02 11:10:00: 1
# Current position delta: 0.9563679605229001
# Elapsed: 1.5453510284423828
# 		Run on 2013-09-03 11:10:00
# Ichi regime at 2013-09-03 11:10:00: 1
# Current position delta: 0.8082584501458024
# Elapsed: 1.5913591384887695
# 		Run on 2013-09-04 11:10:00
# Ichi regime at 2013-09-04 11:10:00: 1
# Current position delta: 0.9289081320895355
# Elapsed: 1.5675737857818604
# 		Run on 2013-09-05 11:10:00
# Ichi regime at 2013-09-05 11:10:00: 1
# Current position delta: 0.8282865059900163
# Elapsed: 1.5873351097106934
# 		Run on 2013-09-06 11:10:00
# Ichi regime at 2013-09-06 11:10:00: 1
# Current position delta: 0.664307544811249
# Elapsed: 1.5902268886566162
# 		Run on 2013-09-07 11:10:00
# Ichi regime at 2013-09-07 11:10:00: 1
# Current position delta: 0.6973084543957908
# Elapsed: 1.553638219833374
# 		Run on 2013-09-08 11:10:00
# Ichi regime at 2013-09-08 11:10:00: 1
# Current position delta: 0.7004358009496241
# Elapsed: 1.589599847793579
# 		Run on 2013-09-09 11:10:00
# Ichi regime at 2013-09-09 11:10:00: 1
# Current position delta: 0.7731316165766311
# Elapsed: 1.5836787223815918
# 		Run on 2013-09-10 11:10:00
# Ichi regime at 2013-09-10 11:10:00: 1
# Current position delta: 1.0807888238324912
# Elapsed: 1.5773594379425049
# 		Run on 2013-09-11 11:10:00
# Ichi regime at 2013-09-11 11:10:00: 1
# Current position delta: 1.0235039311134562
# Elapsed: 1.5367076396942139
# 		Run on 2013-09-12 11:10:00
# Ichi regime at 2013-09-12 11:10:00: 1
# Current position delta: 1.0591564241551275
# Elapsed: 1.571237564086914
# 		Run on 2013-09-13 11:10:00
# Ichi regime at 2013-09-13 11:10:00: 1
# Current position delta: 1.3339530179861852
# Elapsed: 1.5843861103057861
# 		Run on 2013-09-14 11:10:00
# Ichi regime at 2013-09-14 11:10:00: 1
# Current position delta: 1.2964215870696583
# Elapsed: 1.5716443061828613
# 		Run on 2013-09-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-09-15 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX1310700 x 2.0 Price: 3.2004285540704203 Delta: 1.138344649714631
# Leg:  / P.US.CLEX1310700 x 1.0 Price: 2.2610007075642145 Delta: -0.431225855128551
# Leg:  / P.US.CLEX1310350 x -4.0 Price: 1.0947295761715807 Delta: 0.9996949804649172
# Leg:  / C.US.CLEX1311250 x -2.0 Price: 1.0362086118175071 Delta: -0.5266985422639505
# Transactions delta: 1.1801152327870466
# Elapsed: 2.342280387878418
# 		Run on 2013-09-16 11:10:00
# Ichi regime at 2013-09-16 11:10:00: 1
# Current position delta: 1.3247890276106158
# Elapsed: 1.7081336975097656
# 		Run on 2013-09-17 11:10:00
# Ichi regime at 2013-09-17 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEX1310750 x 0.0 Price: 1.4535704639693776 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 1.7330918312072754
# 		Run on 2013-09-18 11:10:00
# Ichi regime at 2013-09-18 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX1310600 x 2.0 Price: 3.011348604492049 Delta: 1.128204559531579
# Leg:  / P.US.CLEX1310600 x 1.0 Price: 2.1922496619425473 Delta: -0.43628158819293467
# Leg:  / P.US.CLEX1310250 x -4.0 Price: 1.0428078919215373 Delta: 0.9923728325613533
# Leg:  / C.US.CLEX1311150 x -2.0 Price: 0.9177247032435965 Delta: -0.4958522978588004
# Transactions delta: 1.1884435060411973
# Elapsed: 1.2290427684783936
# 		Run on 2013-09-19 11:10:00
# Ichi regime at 2013-09-19 11:10:00: 1
# Current position delta: 1.3077033431604823
# Elapsed: 1.5565006732940674
# 		Run on 2013-09-20 11:10:00
# Ichi regime at 2013-09-20 11:10:00: 1
# Current position delta: 1.3759234055412288
# Elapsed: 1.544480323791504
# 		Run on 2013-09-21 11:10:00
# Ichi regime at 2013-09-21 11:10:00: 1
# Current position delta: 1.3669978873968738
# Elapsed: 1.5573649406433105
# 		Run on 2013-09-22 11:10:00
# Ichi regime at 2013-09-22 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEX1310750 x 0.0 Price: 1.0840377856753847 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 1.7706959247589111
# 		Run on 2013-09-23 11:10:00
# Ichi regime at 2013-09-23 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEX1310600 x 0.0 Price: 1.1191748683269935 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7451753616333008
# 		Run on 2013-09-24 11:10:00
# Ichi regime at 2013-09-24 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEX1310550 x 0.0 Price: 1.0936116208896252 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7701599597930908
# 		Run on 2013-09-25 11:10:00
# Ichi regime at 2013-09-25 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEX1310500 x 0.0 Price: 1.1308365976768258 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.8216536045074463
# 		Run on 2013-09-26 11:10:00
# Ichi regime at 2013-09-26 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEX1310500 x 0.0 Price: 1.0182098278724396 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7439544200897217
# 		Run on 2013-09-27 11:10:00
# Ichi regime at 2013-09-27 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEX1310550 x 0.0 Price: 0.8799046115672589 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7603442668914795
# 		Run on 2013-09-28 11:10:00
# Ichi regime at 2013-09-28 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEX1310550 x 0.0 Price: 0.7918613327960813 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7566077709197998
# 		Run on 2013-09-29 11:10:00
# Ichi regime at 2013-09-29 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEX1310550 x 0.0 Price: 0.7507848606985519 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7505948543548584
# 		Run on 2013-09-30 11:10:00
# Ichi regime at 2013-09-30 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEX1310450 x 0.0 Price: 0.8080924051717631 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7796671390533447
# 		Run on 2013-10-01 11:10:00
# Ichi regime at 2013-10-01 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEX1310400 x 0.0 Price: 0.8439464618317203 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7536404132843018
# 		Run on 2013-10-02 11:10:00
# Ichi regime at 2013-10-02 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEX1310650 x 0.0 Price: 0.7077416196103954 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7509446144104004
# 		Run on 2013-10-03 11:10:00
# Ichi regime at 2013-10-03 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEX1310600 x 0.0 Price: 0.6312262955309862 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.74605393409729
# 		Run on 2013-10-04 11:10:00
# ...
# Transactions delta: 0.0
# Elapsed: 0.7908568382263184
# 		Run on 2016-08-12 11:10:00
# Ichi regime at 2016-08-12 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEU164700 x 0.0 Price: 0.1743963660039638 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7992608547210693
# 		Run on 2016-08-13 11:10:00
# Ichi regime at 2016-08-13 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEU164700 x 0.0 Price: 0.10979497593713905 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7818279266357422
# 		Run on 2016-08-14 11:10:00
# Ichi regime at 2016-08-14 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEU164700 x 0.0 Price: 0.06425152678131996 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.7555398941040039
# 		Run on 2016-08-15 11:10:00
# Ichi regime at 2016-08-15 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEV164900 x 0.0 Price: 0.8687545751621535 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.9055027961730957
# 		Run on 2016-08-16 11:10:00
# Ichi regime at 2016-08-16 11:10:00: -1
# New bearish zone position
# Leg:  / C.US.CLEV164950 x 0.0 Price: 0.9317192659413731 Delta: 0.0
# Transactions delta: 0.0
# Elapsed: 0.9210128784179688
# 		Run on 2016-08-17 11:10:00
# Ichi regime at 2016-08-17 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CL
11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX164850 x 2.0 Price: 1.8438346549498377 Delta: 1.3732428247590278
# Leg:  / P.US.CLEX164850 x 1.0 Price: 0.5960049014151956 Delta: -0.31562291533239717
# Leg:  / P.US.CLEX164500 x -4.0 Price: 0.07832824188298915 Delta: 0.2235701278373033
# Leg:  / C.US.CLEX165400 x -2.0 Price: 0.06973215453782133 Delta: -0.12563549050823136
# Transactions delta: 1.1555545467557027
# Elapsed: 0.9301788806915283
# 		Run on 2016-10-08 11:10:00
# Date not found at 2016-10-08
# Ichi regime at 2016-10-08 11:10:00: None
# Elapsed: 1.3961741924285889
# 		Run on 2016-10-09 11:10:00
# Date not found at 2016-10-09
# Ichi regime at 2016-10-09 11:10:00: None
# Current position delta: 0.0
# Elapsed: 0.1999344825744629
# 		Run on 2016-10-10 11:10:00
# Ichi regime at 2016-10-10 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX165050 x 2.0 Price: 1.4061637000438338 Delta: 1.3092896328368506
# Leg:  / P.US.CLEX165050 x 1.0 Price: 0.5576932719853858 Delta: -0.3469742246871238
# Leg:  / P.US.CLEX164700 x -4.0 Price: 0.0368897351046833 Delta: 0.1426015405246305
# Leg:  / C.US.CLEX165600 x -2.0 Price: 0.045377346952951925 Delta: -0.0879598127182342
# Transactions delta: 1.0169571359561231
# Elapsed: 0.9136514663696289
# 		Run on 2016-10-11 11:10:00
# Ichi regime at 2016-10-11 11:10:00: 1
# Current position delta: 0.8341754518031648
# Elapsed: 1.5339510440826416
# 		Run on 2016-10-12 11:10:00
# Ichi regime at 2016-10-12 11:10:00: 1
# Current position delta: 0.659468225174044
# Elapsed: 1.5617702007293701
# 		Run on 2016-10-13 11:10:00
# Date not found at 2016-10-13
# Ichi regime at 2016-10-13 11:10:00: None
# Elapsed: 1.3596341609954834
# 		Run on 2016-10-14 11:10:00
# Ichi regime at 2016-10-14 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX164900 x 2.0 Price: 1.1817251573729308 Delta: 1.5276686138403497
# Leg:  / P.US.CLEX164900 x 1.0 Price: 0.20298034205447557 Delta: -0.23860498524886034
# Leg:  / P.US.CLEX164550 x -4.0 Price: 0.006415002129678715 Delta: 0.037383186088398745
# Leg:  / C.US.CLEX165450 x -2.0 Price: 0.0033510302740661357 Delta: -0.01225496163673554
# Transactions delta: 1.3141918530431527
# Elapsed: 0.909949779510498
# 		Run on 2016-10-15 11:10:00
# Rollover occured, new series used
# Date not found at 2016-10-15
# Ichi regime at 2016-10-15 11:10:00: None
# Current position delta: 0.0
# Elapsed: 1.6956167221069336
# 		Run on 2016-10-16 11:10:00
# Ichi regime at 2016-10-16 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEZ164950 x 2.0 Price: 2.6139044248942973 Delta: 1.2474862454975475
# Leg:  / P.US.CLEZ164950 x 1.0 Price: 1.3751121492023834 Delta: -0.37804818062907647
# Leg:  / P.US.CLEZ164600 x -4.0 Price: 0.47056678472796243 Delta: 0.6399412888238987
# Leg:  / C.US.CLEZ165500 x -2.0 Price: 0.4769790152074318 Delta: -0.3950647447005872
# Transactions delta: 1.1143146089917824
# Elapsed: 1.0895054340362549
# 		Run on 2016-10-17 11:10:00
# Ichi regime at 2016-10-17 11:10:00: 1
# Current position delta: 1.1430525005108356
# Elapsed: 1.520312786102295
# 		Run on 2016-10-18 11:10:00
# Ichi regime at 2016-10-18 11:10:00: 1
# Current position delta: 1.1295236916113558
# Elapsed: 1.5689489841461182
# 		Run on 2016-10-19 11:10:00
# Ichi regime at 2016-10-19 11:10:00: 1
# Current position delta: 1.0440924807213094
# Elapsed: 1.5440394878387451
# 		Run on 2016-10-20 11:10:00
# Ichi regime at 2016-10-20 11:10:00: 1
# Current position delta: 1.1360062509470596
# Elapsed: 1.5197179317474365
# 		Run on 2016-10-21 11:10:00
# Ichi regime at 2016-10-21 11:10:00: 1
# Current position delta: 1.0908000081168674
# Elapsed: 1.5167531967163086
# 		Run on 2016-10-22 11:10:00
# Date not found at 2016-10-22
# Ichi regime at 2016-10-22 11:10:00: None
# Elapsed: 1.3780620098114014
# 		Run on 2016-10-23 11:10:00
# Ichi regime at 2016-10-23 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEZ165000 x 2.0 Price: 2.1568756439173207 Delta: 1.234598924240161
# Leg:  / P.US.CLEZ165000 x 1.0 Price: 1.1578597894567118 Delta: -0.3844152986259694
# Leg:  / P.US.CLEZ164650 x -4.0 Price: 0.317942965995206 Delta: 0.5403227504644447
# Leg:  / C.US.CLEZ165550 x -2.0 Price: 0.285068690695379 Delta: -0.2922126515964819
# Transactions delta: 1.0982937244821542
# Elapsed: 0.9280216693878174
# 		Run on 2016-10-24 11:10:00
# Ichi regime at 2016-10-24 11:10:00: 1
# Current position delta: 1.1102305032437922
# Elapsed: 1.5434746742248535
# 		Run on 2016-10-25 11:10:00
# Ichi regime at 2016-10-25 11:10:00: 1
# Current position delta: 1.117842229859806
# Elapsed: 1.526407241821289
# 		Run on 2016-10-26 11:10:00
# Ichi regime at 2016-10-26 11:10:00: 1
# Current position delta: 1.1300488443654948
# Elapsed: 1.5384793281555176
# 		Run on 2016-10-27 11:10:00
# Ichi regime at 2016-10-27 11:10:00: 1
# Current position delta: 1.0787866295866813
# Elapsed: 1.5514216423034668
# 		Run on 2016-10-28 11:10:00
# Ichi regime at 2016-10-28 11:10:00: 1
# Current position delta: 1.1342104325494358
# Elapsed: 1.5223534107208252
# 		Run on 2016-10-29 11:10:00
# Date not found at 2016-10-29
# Ichi regime at 2016-10-29 11:10:00: None
# Elapsed: 1.401726484298706
# 		Run on 2016-10-30 11:10:00
# Date not found at 2016-10-30
# Ichi regime at 2016-10-30 11:10:00: None
# Current position delta: 0.0
# Elapsed: 0.25760364532470703
# 		Run on 2016-10-31 11:10:00
# Ichi regime at 2016-10-31 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEZ164600 x 2.0 Price: 2.111939882893491 Delta: 1.2781743073668055
# Leg:  / P.US.CLEZ164600 x 1.0 Price: 0.9771626018232205 Delta: -0.3627016406930935
# Leg:  / P.US.CLEZ164250 x -4.0 Price: 0.25214955768128977 Delta: 0.46492957804839935
# Leg:  / C.US.CLEZ165150 x -2.0 Price: 0.1760627506775867 Delta: -0.22492472105485944
# Transactions delta: 1.1554775236672519
# Elapsed: 0.9315004348754883
# Done

# %% [markdown]
# # View EXO price series

# %%
for ticker in instruments:
    exo_df, exo_info = exostorage.load_series('{0}_{1}'.format(ticker, EXO_NAME))    
    
    exo_df['exo'].plot(title='{0}_{1}'.format(ticker, EXO_NAME))
    ax = exo_df['ichi_regime'].plot(secondary_y=True)
    ax.set_ylim(-2,2)
    plt.show()
