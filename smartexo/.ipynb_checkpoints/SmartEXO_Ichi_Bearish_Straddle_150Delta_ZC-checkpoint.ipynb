# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from exobuilder.contracts.futureschain import FuturesChain
from exobuilder.contracts.futurecontract import FutureContract
from exobuilder.tests.assetindexdict import AssetIndexDicts
from datetime import datetime, date, timedelta, time as dttime
from exobuilder.contracts.instrument import Instrument
from exobuilder.data.datasource_mongo import DataSourceMongo
from exobuilder.data.datasource_sql import DataSourceSQL
from exobuilder.data.assetindex_mongo import AssetIndexMongo
from exobuilder.data.exostorage import EXOStorage
from exobuilder.exo.exoenginebase import ExoEngineBase
from exobuilder.exo.transaction import Transaction
import time
from exobuilder.algorithms.rollover_helper import RolloverHelper

import importlib
import logging
importlib.reload(logging);
import matplotlib.pyplot as plt

# %%
EXO_NAME = 'SmartEXO_Ichi_Bearish_Straddle_150Delta'

# TODO: set to 'False' if EXO building output is too verbosive
verbosive_logging = True # or True - for debug log feed

# TODO: select instruments list for SMART EXO calculation
#instruments = ['CL', 'ES', 'NG', 'ZC', 'ZS', 'ZW', 'ZN']
instruments = ['ZC']


# TODO: select start date for SmartEXO calculation
base_date = datetime(2013, 6, 13, 12, 45, 0)

# %% [markdown]
# # Define Bull/Bear/Neutral areas rules

# %%
def ichimoku_regimes(date, price_series):    
    '''
    Calculates Bull/Bear/Neutral areas based on Ichimoku zones
    
    param date: Current date time
    param price_series: price Pandas.Series
    
    Returns:
        -1 - for bearish zone
        0  - for neutral zone
        +1 - for bullish zone
        None - for unknown
    '''
    #
    #  TODO: Change values to fine tune zoning algorithm
    #
    conversion_line_period = 9 # subject of optimization
    base_line_period = 26  # subject of optimization
    leading_spans_lookahead_period = 26  # subject of optimization
    leading_span_b_period = 52 # subject of optimization
        
        
    conversion_line_high = price_series.rolling(window=conversion_line_period).max()
    conversion_line_low = price_series.rolling(window=conversion_line_period).min()
    conversion_line = (conversion_line_high + conversion_line_low) / 2

    base_line_high = price_series.rolling(window=base_line_period).max()
    base_line_low = price_series.rolling(window=base_line_period).min()
    base_line = (base_line_high + base_line_low) / 2

    leading_span_a = ((conversion_line + base_line) / 2).shift(leading_spans_lookahead_period)
    leading_span_b = ((price_series.rolling(window=leading_span_b_period).max() + price_series.rolling(
        window=leading_span_b_period).min()) / 2).shift(leading_spans_lookahead_period)


    #
    # Rules calculation
    #

    # Cloud top and bottom series are defined using leading span A and B
    cloud_top = leading_span_a.rolling(1).max()
    cloud_bottom = leading_span_a.rolling(1).min()

    rule_price_above_cloud_top = price_series > cloud_top
    rule_price_below_cloud_bottom = price_series < cloud_bottom
    rule_price_in_cloud = (price_series < cloud_top) & (price_series > cloud_bottom)

    def get_regime(date):
        if date not in rule_price_above_cloud_top.index:
            logging.debug("Date not found at {0}".format(date))
            return None


        if rule_price_above_cloud_top[date]:
            return 1
        elif rule_price_below_cloud_bottom[date]:
            return -1
        elif rule_price_in_cloud[date]:
            return 0
        return None

    regime = get_regime(date.date())
    logging.debug("Ichi regime at {0}: {1}".format(date, regime))
    return regime

# %%
# Toolbox
def transactions_delta(trans_list):
    return sum([t.delta for t in trans_list])

def log_transactions(trans_list, msg):
    logging.debug(msg)
    [logging.debug(t) for t in trans_list]
    logging.debug('Transactions delta: {0}'.format(transactions_delta(trans_list)))

# %% [markdown]
# # Option position management

# %% [markdown]
# According to https://tmqrexo.slack.com/files/nikolasjoyce/F2PHLEETZ/pasted_image_at_2016_10_14_10_05_am.png

# %% [markdown]
# ## New bullish zone position

# %%
def new_position_bullish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bullish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening long ITM straddle in bullish zone
    #
    # https://files.slack.com/files-tmb/T0484J7T7-F2QBLK53R-93b4252806/pasted_image_at_2016_10_17_10_08_am_720.png
    
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[0].p, date, -1.0, leg_name='bullish'),
                Transaction(opt_chain[2].p, date, 1.0),
                
                Transaction(opt_chain[3].c, date, 1.0),
                Transaction(opt_chain[6].c, date,  -1.0),
           ]
    log_transactions(trans_list,'New bullish zone position')
    return trans_list

# %% [markdown]
# ## New bearish zone position

# %%
def new_position_bearish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bearish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening short butterfly in bearish zone
    #
    
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[2].c, date, 2.0, leg_name='bearish'),
                Transaction(opt_chain[2].p, date, 4.0),                
                ]
    log_transactions(trans_list,'New bearish zone position')
    return trans_list

# %% [markdown]
# ## New neutral zone position

# %%
def new_position_neutral_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for neutral zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening long asymmetric butterfly in neutral zone
    #    
    # https://files.slack.com/files-tmb/T0484J7T7-F2PGU8QNQ-6344e6a04c/pasted_image_at_2016_10_14_09_43_am_720.png
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-2].c, date, -3.0, leg_name='neutral'),
                Transaction(opt_chain[2].c, date, 6.0),
                
                Transaction(opt_chain[8].c, date, -3.0),
                Transaction(opt_chain[3].c, date,  0.0),
           ]
    log_transactions(trans_list,'New neutral zone position')
    return trans_list

# %% [markdown]
# ## Manage opened positions

# %%
def manage_opened_position(date, fut, opt_chain, regime, opened_position):
    logging.debug('Current position delta: {0}'.format(opened_position.delta))
    
    # By default: do nothing
    return []

# %% [markdown]
# # Define EXO builder class

# %%
class SmartEXOIchimoku(ExoEngineBase):
    def __init__(self, symbol, direction, date, datasource, log_file_path=''):
        self._symbol = symbol
        super().__init__(symbol, direction, date, datasource, log_file_path=log_file_path)

    @staticmethod
    def direction_type():
        return 0

    @staticmethod
    def names_list(symbol):
        return ['{0}_{1}'.format(self._symbol, EXO_NAME)]

    @property
    def exo_name(self):
            return '{0}_{1}'.format(self._symbol, EXO_NAME)

    def is_rollover(self):
        if len(self.position) != 0:
            for p in self.position.legs.values():
                rh = RolloverHelper(p.instrument)
                if rh.is_rollover(p):
                    return True
        return False

    def process_rollover(self):
        trans_list = self.position.close_all_translist()
        logging.info('Rollover occured, new series used')
        return trans_list

    

    def process_day(self):
        """
        Main EXO's position management method
        :return: list of Transactions to process
        """

        # Get cont futures price for EXO
        exo_df, exo_info = self.datasource.exostorage.load_series("{0}_ContFut".format(self._symbol))

        regime = ichimoku_regimes(self.date, exo_df['exo'])

        trans_list = []

        if regime is None and len(self.position) > 0:
            return self.position.close_all_translist()
        
        instr = self.datasource.get(self._symbol, self.date)
        rh = RolloverHelper(instr)
        fut, opt_chain = rh.get_active_chains()

        if regime == 1 and 'bullish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bullish_zone(self.date, fut, opt_chain)
            
            return trans_list
        if regime == -1 and 'bearish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bearish_zone(self.date, fut, opt_chain)
            return trans_list

        if regime == 0 and 'neutral' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_neutral_zone(self.date, fut, opt_chain)
            return trans_list
        
        #
        # Manage opened position
        #
        return manage_opened_position(self.date, fut, opt_chain, regime, self.position)

# %% [markdown]
# # Run EXO build process (WARN: long-running task!)

# %%
from pymongo import MongoClient

if verbosive_logging:
    logging.basicConfig(format='%(message)s', level=logging.DEBUG)
else:
    logging.basicConfig(format='%(message)s', level=logging.INFO)

mongo_connstr = 'mongodb://exowriter:qmWSy4K3@10.0.1.2/tmldb?authMechanism=SCRAM-SHA-1'
mongo_db_name = 'tmldb'
assetindex = AssetIndexMongo(mongo_connstr, mongo_db_name)
exostorage = EXOStorage(mongo_connstr, mongo_db_name)

#base_date = datetime(2011, 6, 13, 12, 45, 0)


futures_limit = 3
options_limit = 10

DEBUG = '.'

datasource = DataSourceMongo(mongo_connstr, mongo_db_name, assetindex, futures_limit, options_limit, exostorage)

server = 'h9ggwlagd1.database.windows.net'
user = 'modelread'
password = '4fSHRXwd4u'
datasource = DataSourceSQL(server, user, password, assetindex, futures_limit, options_limit, exostorage)

enddate = datetime.combine(datetime.now().date(), dttime(12, 45, 0))
currdate = base_date


logging.info("Deleting all SmartEXO of :" + EXO_NAME)
client = MongoClient(mongo_connstr)
db = client[mongo_db_name]
db['exo_data'].delete_many({'name': {'$regex': '.*{0}*.'.format(EXO_NAME)}})


logging.info("Starting EXO calculation process from: {0}".format(currdate))
for ticker in instruments:
    logging.info("Processing: "+ticker)
    currdate = base_date
    while currdate <= enddate:
        
        start_time = time.time()
        date = currdate

        asset_info = assetindex.get_instrument_info(ticker)
        exec_time_end, decision_time_end = AssetIndexMongo.get_exec_time(date, asset_info)
        
        logging.info("\t\tRun on {0}".format(decision_time_end))

        with SmartEXOIchimoku(ticker, 0, decision_time_end, datasource) as exo_engine:
            # Load EXO information from mongo
            exo_engine.load()
            exo_engine.calculate()

        end_time = time.time()
        currdate += timedelta(days=1)
        logging.debug("Elapsed: {0}".format(end_time-start_time))
logging.info('Done')
# Out:
# Deleting all SmartEXO of :SmartEXO_Ichi_Bearish_Straddle_150Delta
# Starting EXO calculation process from: 2013-06-13 12:45:00
# Processing: ZC
# 		Run on 2013-06-13 10:55:00
# Ichi regime at 2013-06-13 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEN136450 x -1.0 Price: 9.98650132780773 Delta: 0.5042015567329357
# Leg:  / P.US.ZCEN136550 x 1.0 Price: 15.804947404870518 Delta: -0.6666836355853194
# Leg:  / C.US.ZCEN136600 x 1.0 Price: 3.694333669936128 Delta: 0.26219253336984905
# Leg:  / C.US.ZCEN136750 x -1.0 Price: 1.3155137042387253 Delta: -0.11290004292330078
# Transactions delta: -0.013189588405835478
# Elapsed: 1.5752792358398438
# 		Run on 2013-06-14 10:55:00
# Ichi regime at 2013-06-14 10:55:00: 1
# Current position delta: 0.033764145834678044
# Elapsed: 1.5759706497192383
# 		Run on 2013-06-15 10:55:00
# Ichi regime at 2013-06-15 10:55:00: 1
# Current position delta: 0.037979314290195354
# Elapsed: 1.57936429977417
# 		Run on 2013-06-16 10:55:00
# Ichi regime at 2013-06-16 10:55:00: 1
# Current position delta: 0.032410189694143665
# Elapsed: 1.5471594333648682
# 		Run on 2013-06-17 10:55:00
# Ichi regime at 2013-06-17 10:55:00: 1
# Current position delta: 0.1998949945854644
# Elapsed: 1.544210433959961
# 		Run on 2013-06-18 10:55:00
# Ichi regime at 2013-06-18 10:55:00: 1
# Current position delta: 0.1976016352606071
# Elapsed: 1.587179183959961
# 		Run on 2013-06-19 10:55:00
# Rollover occured, new series used
# Ichi regime at 2013-06-19 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEQ136050 x -1.0 Price: 26.52799719893136 Delta: 0.4737969004692158
# Leg:  / P.US.ZCEQ136150 x 1.0 Price: 32.221939405555645 Delta: -0.5318567602611408
# Leg:  / C.US.ZCEQ136200 x 1.0 Price: 20.75891314303317 Delta: 0.4391918217545532
# Leg:  / C.US.ZCEQ136350 x -1.0 Price: 15.638377715794235 Delta: -0.3583445220970809
# Transactions delta: 0.022787439865547265
# Elapsed: 2.525284767150879
# 		Run on 2013-06-20 10:55:00
# Ichi regime at 2013-06-20 10:55:00: 1
# Current position delta: 0.020211827852615827
# Elapsed: 1.7433278560638428
# 		Run on 2013-06-21 10:55:00
# Ichi regime at 2013-06-21 10:55:00: 1
# Current position delta: 0.01890682080301298
# Elapsed: 1.5919997692108154
# 		Run on 2013-06-22 10:55:00
# Ichi regime at 2013-06-22 10:55:00: 1
# Current position delta: 0.018004149078936105
# Elapsed: 1.5877585411071777
# 		Run on 2013-06-23 10:55:00
# Ichi regime at 2013-06-23 10:55:00: 1
# Current position delta: 0.018046225380643932
# Elapsed: 1.560858964920044
# 		Run on 2013-06-24 10:55:00
# Ichi regime at 2013-06-24 10:55:00: 1
# Current position delta: 0.013826934977576255
# Elapsed: 1.573988914489746
# 		Run on 2013-06-25 10:55:00
# Ichi regime at 2013-06-25 10:55:00: 1
# Current position delta: 0.012595173671272497
# Elapsed: 1.609269380569458
# 		Run on 2013-06-26 10:55:00
# Ichi regime at 2013-06-26 10:55:00: 1
# Current position delta: 0.010290825875148846
# Elapsed: 1.562593936920166
# 		Run on 2013-06-27 10:55:00
# Ichi regime at 2013-06-27 10:55:00: 1
# Current position delta: 0.009598081856353469
# Elapsed: 1.5916168689727783
# 		Run on 2013-06-28 10:55:00
# Ichi regime at 2013-06-28 10:55:00: 1
# Current position delta: 0.0029277030923772207
# Elapsed: 1.624483585357666
# 		Run on 2013-06-29 10:55:00
# Ichi regime at 2013-06-29 10:55:00: 1
# Current position delta: 0.0009661529854142481
# Elapsed: 1.6022312641143799
# 		Run on 2013-06-30 10:55:00
# Ichi regime at 2013-06-30 10:55:00: 1
# Current position delta: 0.0005518022194256345
# Elapsed: 1.5366060733795166
# 		Run on 2013-07-01 10:55:00
# Ichi regime at 2013-07-01 10:55:00: 1
# Current position delta: -0.0007447059470157003
# Elapsed: 1.5676860809326172
# 		Run on 2013-07-02 10:55:00
# Ichi regime at 2013-07-02 10:55:00: 1
# Current position delta: 0.004395307387977443
# Elapsed: 1.5865817070007324
# 		Run on 2013-07-03 10:55:00
# Ichi regime at 2013-07-03 10:55:00: 1
# Current position delta: -0.0035169187102812582
# Elapsed: 1.5961661338806152
# 		Run on 2013-07-04 10:55:00
# Ichi regime at 2013-07-04 10:55:00: 1
# Current position delta: 0.004672121613506719
# Elapsed: 1.5690178871154785
# 		Run on 2013-07-05 10:55:00
# Ichi regime at 2013-07-05 10:55:00: 1
# Current position delta: 0.0039675476608870275
# Elapsed: 1.5864944458007812
# 		Run on 2013-07-06 10:55:00
# Ichi regime at 2013-07-06 10:55:00: 1
# Current position delta: -0.000298297790593649
# Elapsed: 1.5773394107818604
# 		Run on 2013-07-07 10:55:00
# Ichi regime at 2013-07-07 10:55:00: 1
# Current position delta: -0.00046557952639070255
# Elapsed: 1.5526108741760254
# 		Run on 2013-07-08 10:55:00
# Ichi regime at 2013-07-08 10:55:00: 1
# Current position delta: -0.0009693461903100831
# Elapsed: 1.5502283573150635
# 		Run on 2013-07-09 10:55:00
# Ichi regime at 2013-07-09 10:55:00: 1
# Current position delta: 0.00040682976623118705
# Elapsed: 1.6048617362976074
# 		Run on 2013-07-10 10:55:00
# Ichi regime at 2013-07-10 10:55:00: 1
# Current position delta: -1.7344349310999263e-05
# Elapsed: 1.5664441585540771
# 		Run on 2013-07-11 10:55:00
# Ichi regime at 2013-07-11 10:55:00: 1
# Current position delta: 0.0008238802691892255
# Elapsed: 1.5953519344329834
# 		Run on 2013-07-12 10:55:00
# Ichi regime at 2013-07-12 10:55:00: 1
# Current position delta: -0.0035463881764378202
# Elapsed: 1.5564446449279785
# 		Run on 2013-07-13 10:55:00
# Ichi regime at 2013-07-13 10:55:00: 1
# Current position delta: -0.004585722353619981
# Elapsed: 1.5912916660308838
# 		Run on 2013-07-14 10:55:00
# Ichi regime at 2013-07-14 10:55:00: 1
# Current position delta: -0.005194254598924974
# Elapsed: 1.5528144836425781
# 		Run on 2013-07-15 10:55:00
# Ichi regime at 2013-07-15 10:55:00: 1
# Current position delta: -0.004351645091011935
# Elapsed: 1.5489401817321777
# 		Run on 2013-07-16 10:55:00
# Ichi regime at 2013-07-16 10:55:00: 1
# Current position delta: -0.0018807633894301068
# Elapsed: 1.5671522617340088
# 		Run on 2013-07-17 10:55:00
# Ichi regime at 2013-07-17 10:55:00: 1
# Current position delta: -0.005173151429012091
# Elapsed: 1.612678050994873
# 		Run on 2013-07-18 10:55:00
# Ichi regime at 2013-07-18 10:55:00: 1
# Current position delta: -0.00808577898789209
# Elapsed: 1.6001434326171875
# 		Run on 2013-07-19 10:55:00
# Ichi regime at 2013-07-19 10:55:00: 1
# Current position delta: -0.00175162260831907
# Elapsed: 1.5719060897827148
# 		Run on 2013-07-20 10:55:00
# Ichi regime at 2013-07-20 10:55:00: 1
# Current position delta: -0.0021536738024134916
# Elapsed: 1.5520083904266357
# 		Run on 2013-07-21 10:55:00
# Ichi regime at 2013-07-21 10:55:00: 1
# Current position delta: -0.002381276565035617
# Elapsed: 1.5451388359069824
# 		Run on 2013-07-22 10:55:00
# Ichi regime at 2013-07-22 10:55:00: 1
# Current position delta: -0.001556627715553538
# Elapsed: 1.589876651763916
# 		Run on 2013-07-23 10:55:00
# Ichi regime at 2013-07-23 10:55:00: 1
# Current position delta: -0.0009646521090345139
# Elapsed: 1.590226650238037
# 		Run on 2013-07-24 10:55:00
# Rollover occured, new series used
# Ichi regime at 2013-07-24 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEU135100 x -1.0 Price: 16.508084999274416 Delta: 0.49834577623897064
# Leg:  / P.US.ZCEU135200 x 1.0 Price: 22.369413794398326 Delta: -0.5962632687292437
# Leg:  / C.US.ZCEU135250 x 1.0 Price: 9.281810061678925 Delta: 0.3576539543177734
# Leg:  / C.US.ZCEU135400 x -1.0 Price: 5.5768782846870835 Delta: -0.24063531763180765
# Transactions delta: 0.01910114419569267
# Elapsed: 2.308168411254883
# 		Run on 2013-07-25 10:55:00
# Ichi regime at 2013-07-25 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZCEU135050 x 2.0 Price: 11.168792503320503 Delta: 0.8417224884702306
# Leg:  / P.US.ZCEU135050 x 4.0 Price: 20.416137336611598 Delta: -2.3132708971564675
# Transactions delta: -1.471548408686237
# Elapsed: 1.9171454906463623
# 		Run on 2013-07-26 10:55:00
# Ichi regime at 2013-07-26 10:55:00: -1
# Current position delta: -1.6060771335720083
# Elapsed: 0.9390161037445068
# 		Run on 2013-07-27 10:55:00
# Ichi regime at 2013-07-27 10:55:00: -1
# Current position delta: -1.7913719102707129
# Elapsed: 0.9675281047821045
# 		Run on 2013-07-28 10:55:00
# Ichi regime at 2013-07-28 10:55:00: -1
# Current position delta: -1.8090907997829415
# Elapsed: 0.9077856540679932
# 		Run on 2013-07-29 10:55:00
# Ichi regime at 2013-07-29 10:55:00: -1
# Current position delta: -2.062598771192085
# Elapsed: 0.91361403465271
# 		Run on 2013-07-30 10:55:00
# Ichi regime at 2013-07-30 10:55:00: -1
# Current position delta: -1.8185878272626528
# Elapsed: 0.9814283847808838
# 		Run on 2013-07-31 10:55:00
# Ichi regime at 2013-07-31 10:55:00: -1
# Current position delta: -1.3730507550924704
# Elapsed: 0.962033748626709
# 		Run on 2013-08-01 10:55:00
# Ichi regime at 2013-08-01 10:55:00: -1
# Current position delta: -2.1928072069584483
# Elapsed: 0.9819166660308838
# 		Run on 2013-08-02 10:55:00
# Ichi regime at 2013-08-02 10:55:00: -1
# Current position delta: -2.7067596934662874
# Elapsed: 0.9294352531433105
# 		Run on 2013-08-03 10:55:00
# Ichi regime at 2013-08-03 10:55:00: -1
# Current position delta: -2.8885013387946104
# Elapsed: 0.9234440326690674
# 		Run on 2013-08-04 10:55:00
# Ichi regime at 2013-08-04 10:55:00: -1
# Current position delta: -2.928155369436462
# Elapsed: 0.8966481685638428
# 		Run on 2013-08-05 10:55:00
# Ichi regime at 2013-08-05 10:55:00: -1
# Current position delta: -3.3220398258130093
# Elapsed: 0.9594414234161377
# 		Run on 2013-08-24 10:55:00
# Ichi regime at 2013-08-24 10:55:00: -1
# Current position delta: -2.320117135925084
# Elapsed: 0.9271259307861328
# 		Run on 2013-08-25 10:55:00
# Ichi regime at 2013-08-25 10:55:00: -1
# Current position delta: -2.345783060386478
# Elapsed: 0.9275786876678467
# 		Run on 2013-08-26 10:55:00
# Ichi regime at 2013-08-26 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEV135050 x -1.0 Price: 15.696420459943823 Delta: 0.47077707567316546
# Leg:  / P.US.ZCEV135150 x 1.0 Price: 21.608462966272896 Delta: -0.5644689692923331
# Leg:  / C.US.ZCEV135200 x 1.0 Price: 11.117904276594999 Delta: 0.39088664181907956
# Leg:  / C.US.ZCEV135350 x -1.0 Price: 7.127381743049028 Delta: -0.27619551358989725
# Transactions delta: 0.020999234610014628
# Elapsed: 1.5685417652130127
# 		Run on 2013-08-27 10:55:00
# Ichi regime at 2013-08-27 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZCEV135000 x 2.0 Price: 13.784661243254703 Delta: 0.8846216269592533
# Leg:  / P.US.ZCEV135000 x 4.0 Price: 22.283972242742948 Delta: -2.228884233863454
# Transactions delta: -1.3442626069042005
# Elapsed: 1.8978257179260254
# 		Run on 2013-08-28 10:55:00
# Ichi regime at 2013-08-28 10:55:00: -1
# Current position delta: -1.916905079422722
# Elapsed: 0.9578120708465576
# 		Run on 2013-08-29 10:55:00
# Ichi regime at 2013-08-29 10:55:00: -1
# Current position delta: -1.9876971403568142
# Elapsed: 0.9545831680297852
# 		Run on 2013-08-30 10:55:00
# Ichi regime at 2013-08-30 10:55:00: -1
# Current position delta: -2.2123268057686296
# Elapsed: 0.9530208110809326
# 		Run on 2013-08-31 10:55:00
# Ichi regime at 2013-08-31 10:55:00: -1
# Current position delta: -1.98614080818587
# Elapsed: 0.932293176651001
# 		Run on 2013-09-01 10:55:00
# Ichi regime at 2013-09-01 10:55:00: -1
# Current position delta: -2.0148022430418417
# Elapsed: 0.9080052375793457
# 		Run on 2013-09-02 10:55:00
# Ichi regime at 2013-09-02 10:55:00: -1
# Current position delta: -2.0455096121081184
# Elapsed: 0.9151818752288818
# 		Run on 2013-09-03 10:55:00
# Ichi regime at 2013-09-03 10:55:00: -1
# Current position delta: -2.4993925406783886
# Elapsed: 0.9492175579071045
# 		Run on 2013-09-04 10:55:00
# Ichi regime at 2013-09-04 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEV134700 x -1.0 Price: 14.21836606638513 Delta: 0.5059661090865988
# Leg:  / P.US.ZCEV134800 x 1.0 Price: 20.040541796067203 Delta: -0.6228505310413597
# Leg:  / C.US.ZCEV134850 x 1.0 Price: 6.693669433958462 Delta: 0.32246867179424965
# Leg:  / C.US.ZCEV135000 x -1.0 Price: 3.2774885723087266 Delta: -0.18664496593928032
# Transactions delta: 0.018939283900208437
# Elapsed: 1.6406285762786865
# 		Run on 2013-09-05 10:55:00
# Ichi regime at 2013-09-05 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZCEV134700 x 2.0 Price: 7.4606737895640265 Delta: 0.748040795504822
# Leg:  / P.US.ZCEV134700 x 4.0 Price: 18.208535120527586 Delta: -2.5013933578321477
# Transactions delta: -1.7533525623273256
# Elapsed: 1.9114022254943848
# 		Run on 2013-09-06 10:55:00
# Ichi regime at 2013-09-06 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEV134650 x -1.0 Price: 10.482030349673721 Delta: 0.4561200990832775
# Leg:  / P.US.ZCEV134750 x 1.0 Price: 16.19510707157781 Delta: -0.589103655424458
# Leg:  / C.US.ZCEV134800 x 1.0 Price: 6.7313350868871 Delta: 0.348536553729034
# Leg:  / C.US.ZCEV134950 x -1.0 Price: 3.332402671610467 Delta: -0.20005501049675864
# Transactions delta: 0.015497986891094911
# Elapsed: 1.597780704498291
# 		Run on 2013-09-07 10:55:00
# Ichi regime at 2013-09-07 10:55:00: 1
# Current position delta: 0.019543843349999507
# Elapsed: 1.5853278636932373
# 		Run on 2013-09-08 10:55:00
# Ichi regime at 2013-09-08 10:55:00: 1
# Current position delta: 0.01754387676584271
# Elapsed: 1.5413808822631836
# 		Run on 2013-09-09 10:55:00
# Ichi regime at 2013-09-09 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZCEV134750 x 2.0 Price: 5.663615611650897 Delta: 0.6806335210578748
# Leg:  / P.US.ZCEV134750 x 4.0 Price: 17.165344260922836 Delta: -2.635919549763765
# Transactions delta: -1.9552860287058902
# Elapsed: 1.903022050857544
# 		Run on 2013-09-10 10:55:00
# Ichi regime at 2013-09-10 10:55:00: -1
# Current position delta: -1.5100625622252453
# Elapsed: 0.9633357524871826
# 		Run on 2013-09-11 10:55:00
# Ichi regime at 2013-09-11 10:55:00: -1
# Current position delta: -1.444826747140368
# Elapsed: 0.9510393142700195
# 		Run on 2013-09-12 10:55:00
# Ichi regime at 2013-09-12 10:55:00: -1
# Current position delta: -2.3500594914977846
# Elapsed: 0.994697093963623
# 		Run on 2013-09-13 10:55:00
# Ichi regime at 2013-09-13 10:55:00: -1
# Current position delta: -2.8063462337726506
# Elapsed: 0.9459366798400879
# 		Run on 2013-09-14 10:55:00
# Ichi regime at 2013-09-14 10:55:00: -1
# Current position delta: -2.9862448337520364
# Elapsed: 0.9240682125091553
# 		Run on 2013-09-15 10:55:00
# Ichi regime at 2013-09-15 10:55:00: -1
# Current position delta: -3.1232095018816235
# Elapsed: 0.9143283367156982
# 		Run on 2013-09-16 10:55:00
# Ichi regime at 2013-09-16 10:55:00: -1
# Current position delta: -3.4898349606423196
# Elapsed: 0.9174349308013916
# 		Run on 2013-09-17 10:55:00
# Ichi regime at 2013-09-17 10:55:00: -1
# Current position delta: -3.387352434445285
# Elapsed: 0.9716141223907471
# 		Run on 2013-09-18 10:55:00
# Rollover occured, new series used
# Ichi regime at 2013-09-18 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZCEX134650 x 2.0 Price: 10.281267241686038 Delta: 0.809211416468263
# Leg:  / P.US.ZCEX134650 x 4.0 Price: 21.03317331832045 Delta: -2.3768763214852138
# Transactions delta: -1.5676649050169509
# Elapsed: 1.3206806182861328
# 		Run on 2013-09-19 10:55:00
# Ichi regime at 2013-09-19 10:55:00: -1
# Current position delta: -1.4239711876791827
# Elapsed: 0.9656789302825928
# Ichi regime at 2013-10-27 10:55:00: -1
# Current position delta: -2.08980821091856
# Elapsed: 0.904456615447998
# 		Run on 2013-10-28 10:55:00
# Ichi regime at 2013-10-28 10:55:00: -1
# Current position delta: -2.7017122293612106
# Elapsed: 0.9518008232116699
# 		Run on 2013-10-29 10:55:00
# Ichi regime at 2013-10-29 10:55:00: -1
# Current position delta: -2.6350446656055597
# Elapsed: 0.9353930950164795
# 		Run on 2013-10-30 10:55:00
# Ichi regime at 2013-10-30 10:55:00: -1
# Current position delta: -2.6839152925283796
# Elapsed: 0.9448351860046387
# 		Run on 2013-10-31 10:55:00
# Ichi regime at 2013-10-31 10:55:00: -1
# Current position delta: -2.9573416292625683
# Elapsed: 0.9170339107513428
# 		Run on 2013-11-01 10:55:00
# Ichi regime at 2013-11-01 10:55:00: -1
# Current position delta: -2.927370260719062
# Elapsed: 0.9585063457489014
# 		Run on 2013-11-02 10:55:00
# Ichi regime at 2013-11-02 10:55:00: -1
# Current position delta: -3.0137113555972745
# Elapsed: 0.9290494918823242
# 		Run on 2013-11-03 10:55:00
# Ichi regime at 2013-11-03 10:55:00: -1
# Current position delta: -3.0534155269395877
# Elapsed: 0.8949418067932129
# 		Run on 2013-11-04 10:55:00
# Ichi regime at 2013-11-04 10:55:00: -1
# Current position delta: -3.108949684349327
# Elapsed: 0.9075555801391602
# 		Run on 2013-11-05 10:55:00
# Ichi regime at 2013-11-05 10:55:00: -1
# Current position delta: -3.254512750864403
# Elapsed: 0.944472074508667
# 		Run on 2013-11-06 10:55:00
# Ichi regime at 2013-11-06 10:55:00: -1
# Current position delta: -3.4074674574375683
# Elapsed: 0.9290814399719238
# 		Run on 2013-11-07 10:55:00
# Ichi regime at 2013-11-07 10:55:00: -1
# Current position delta: -3.470527390973642
# Elapsed: 0.9498274326324463
# 		Run on 2013-11-08 10:55:00
# Ichi regime at 2013-11-08 10:55:00: -1
# Current position delta: -3.164064828761091
# Elapsed: 0.9765303134918213
# 		Run on 2013-11-09 10:55:00
# Ichi regime at 2013-11-09 10:55:00: -1
# Current position delta: -3.5261354324715377
# Elapsed: 0.9419760704040527
# 		Run on 2013-11-10 10:55:00
# Ichi regime at 2013-11-10 10:55:00: -1
# Current position delta: -3.576594376324969
# Elapsed: 0.906965970993042
# 		Run on 2013-11-11 10:55:00
# Ichi regime at 2013-11-11 10:55:00: -1
# Current position delta: -3.0317246061636904
# Elapsed: 0.9046177864074707
# 		Run on 2013-11-12 10:55:00
# Ichi regime at 2013-11-12 10:55:00: -1
# Current position delta: -3.355993709537824
# Elapsed: 0.9494891166687012
# 		Run on 2013-11-13 10:55:00
# Ichi regime at 2013-11-13 10:55:00: -1
# Current position delta: -3.631594335232804
# Elapsed: 0.9478304386138916
# 		Run on 2013-11-14 10:55:00
# Ichi regime at 2013-11-14 10:55:00: -1
# Current position delta: -3.824927963153446
# Elapsed: 0.9532589912414551
# 		Run on 2013-11-15 10:55:00
# Ichi regime at 2013-11-15 10:55:00: -1
# Current position delta: -3.8562885374715568
# Elapsed: 0.9308795928955078
# 		Run on 2013-11-16 10:55:00
# Ichi regime at 2013-11-16 10:55:00: -1
# Current position delta: -3.904000717205844
# Elapsed: 0.920076847076416
# 		Run on 2013-11-17 10:55:00
# Ichi regime at 2013-11-17 10:55:00: -1
# Current position delta: -3.944031931997339
# Elapsed: 0.9086251258850098
# 		Run on 2013-11-18 10:55:00
# Ichi regime at 2013-11-18 10:55:00: -1
# Current position delta: -3.997561982886984
# Elapsed: 0.9402332305908203
# 		Run on 2013-11-19 10:55:00
# Ichi regime at 2013-11-19 10:55:00: -1
# Current position delta: -3.911859346948599
# Elapsed: 0.9512777328491211
# 		Run on 2013-11-20 10:55:00
# Rollover occured, new series used
# Ichi regime at 2013-11-20 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZCEF144350 x 2.0 Price: 6.3708371585605335 Delta: 0.7553431182270725
# Leg:  / P.US.ZCEF144350 x 4.0 Price: 15.121849264434331 Delta: -2.4830692002765344
# Transactions delta: -1.727726082049462
# Elapsed: 1.5684776306152344
# 		Run on 2013-11-21 10:55:00
# Ichi regime at 2013-11-21 10:55:00: -1
# Current position delta: -1.493624860545166
# Elapsed: 1.111919641494751
# 		Run on 2013-11-22 10:55:00
# Ichi regime at 2013-11-22 10:55:00: -1
# Current position delta: -1.4555894116147539
# Elapsed: 0.9459500312805176
# 		Run on 2013-11-23 10:55:00
# Ichi regime at 2013-11-23 10:55:00: -1
# Current position delta: -1.534087961552983
# Elapsed: 0.9460458755493164
# 		Run on 2013-11-24 10:55:00
# Ichi regime at 2013-11-24 10:55:00: -1
# Current position delta: -1.5440911503653973
# Elapsed: 0.9012911319732666
# 		Run on 2013-11-25 10:55:00
# Ichi regime at 2013-11-25 10:55:00: -1
# Current position delta: -1.4737938686765282
# Elapsed: 0.9287333488464355
# 		Run on 2013-11-26 10:55:00
# Ichi regime at 2013-11-26 10:55:00: -1
# Current position delta: -2.086748808084844
# Elapsed: 0.9518730640411377
# 		Run on 2013-11-27 10:55:00
# Ichi regime at 2013-11-27 10:55:00: -1
# Current position delta: -1.8600696690436362
# Elapsed: 0.949336051940918
# 		Run on 2013-11-28 10:55:00
# Ichi regime at 2013-11-28 10:55:00: -1
# Current position delta: -1.9156755864210981
# Elapsed: 0.9370021820068359
# 		Run on 2013-11-29 10:55:00
# Ichi regime at 2013-11-29 10:55:00: -1
# Current position delta: -2.133599134566937
# Elapsed: 0.9526057243347168
# 		Run on 2013-11-30 10:55:00
# Ichi regime at 2013-11-30 10:55:00: -1
# Current position delta: -2.1091187382365635
# Elapsed: 0.9305374622344971
# 		Run on 2013-12-01 10:55:00
# Ichi regime at 2013-12-01 10:55:00: -1
# Current position delta: -2.1308363448118506
# Elapsed: 0.9028959274291992
# 		Run on 2013-12-02 10:55:00
# Ichi regime at 2013-12-02 10:55:00: -1
# Current position delta: -2.2336594064491737
# Elapsed: 0.902684211730957
# 		Run on 2013-12-03 10:55:00
# Ichi regime at 2013-12-03 10:55:00: -1
# Current position delta: -1.481814261561581
# Elapsed: 0.938962459564209
# 		Run on 2013-12-04 10:55:00
# Ichi regime at 2013-12-04 10:55:00: -1
# Current position delta: -0.8114006153290081
# Elapsed: 0.9449474811553955
# 		Run on 2013-12-05 10:55:00
# Ichi regime at 2013-12-05 10:55:00: -1
# Current position delta: -0.9703103381246816
# Elapsed: 0.9554123878479004
# 		Run on 2013-12-06 10:55:00
# Ichi regime at 2013-12-06 10:55:00: -1
# Current position delta: -1.2928622598869974
# Elapsed: 0.9495742321014404
# 		Run on 2013-12-07 10:55:00
# Ichi regime at 2013-12-07 10:55:00: -1
# Current position delta: -1.0374351204358705
# Elapsed: 0.939490556716919
# 		Run on 2013-12-08 10:55:00
# Ichi regime at 2013-12-08 10:55:00: -1
# Current position delta: -1.0414201160860252
# Elapsed: 0.9024596214294434
# 		Run on 2013-12-09 10:55:00
# Ichi regime at 2013-12-09 10:55:00: -1
# Current position delta: -0.6093801515757997
# Elapsed: 0.9217705726623535
# 		Run on 2013-12-10 10:55:00
# Ichi regime at 2013-12-10 10:55:00: -1
# Current position delta: -0.844376131560197
# Elapsed: 0.9703936576843262
# 		Run on 2013-12-11 10:55:00
# Ichi regime at 2013-12-11 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEF144400 x -1.0 Price: 7.154717038606464 Delta: 0.5218535596951231
# Leg:  / P.US.ZCEF144500 x 1.0 Price: 13.610204603209809 Delta: -0.7469771202977622
# Leg:  / C.US.ZCEF144550 x 1.0 Price: 1.427691267762654 Delta: 0.16798214734792113
# Leg:  / C.US.ZCEF144700 x -1.0 Price: 0.32246226633405684 Delta: -0.0452215972709941
# Transactions delta: -0.102363010525712
# Elapsed: 1.5948400497436523
# 		Run on 2013-12-12 10:55:00
# Ichi regime at 2013-12-12 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZCEF144450 x 2.0 Price: 1.786800341163783 Delta: 0.43259122892172314
# Leg:  / P.US.ZCEF144450 x 4.0 Price: 13.777640212669041 Delta: -3.1270660913506165
# Transactions delta: -2.6944748624288932
# Elapsed: 1.94453763961792
# 		Run on 2013-12-13 10:55:00
# Ichi regime at 2013-12-13 10:55:00: -1
# Current position delta: -3.424506558897221
# Elapsed: 0.9270172119140625
# 		Run on 2013-12-14 10:55:00
# Ichi regime at 2013-12-14 10:55:00: -1
# Current position delta: -3.3988679504150707
# Elapsed: 0.9191522598266602
# 		Run on 2013-12-15 10:55:00
# Ichi regime at 2013-12-15 10:55:00: -1
# Current position delta: -3.4537211898155054
# Elapsed: 0.9242424964904785
# 		Run on 2013-12-16 10:55:00
# Ichi regime at 2013-12-16 10:55:00: -1
# Current position delta: -3.543913034679665
# Elapsed: 0.9540088176727295
# 		Run on 2013-12-17 10:55:00
# Ichi regime at 2013-12-17 10:55:00: -1
# Current position delta: -3.330963862731818
# Elapsed: 0.923861026763916
# 		Run on 2013-12-18 10:55:00
# Ichi regime at 2013-12-18 10:55:00: -1
# Current position delta: -3.651810388523504
# Elapsed: 0.9559612274169922
# 		Run on 2013-12-19 10:55:00
# Ichi regime at 2013-12-19 10:55:00: None
# Elapsed: 0.7742631435394287
# 		Run on 2013-12-20 10:55:00
# Ichi regime at 2013-12-20 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEF144300 x -1.0 Price: 2.7438677978297505 Delta: 0.3932121162618017
# Leg:  / P.US.ZCEF144400 x 1.0 Price: 8.722125122235923 Delta: -0.7748102582691907
# Leg:  / C.US.ZCEF144450 x 1.0 Price: 0.5951829970669422 Delta: 0.1187893448539033
# Leg:  / C.US.ZCEF144600 x -1.0 Price: 0.12122129306165341 Delta: -0.024286828061382472
# Transactions delta: -0.2870956252148682
# Elapsed: 1.0010201930999756
# 		Run on 2013-12-21 10:55:00
# Ichi regime at 2013-12-21 10:55:00: 1
# Current position delta: -0.31517431320912265
# Elapsed: 1.5897293090820312
# 		Run on 2013-12-22 10:55:00
# Ichi regime at 2013-12-22 10:55:00: 1
# Current position delta: -0.3618623841222845
# Elapsed: 1.5757932662963867
# 		Run on 2013-12-23 10:55:00
# Ichi regime at 2013-12-23 10:55:00: 1
# Current position delta: -0.4114080810398203
# Elapsed: 1.608086347579956
# 		Run on 2013-12-24 10:55:00
# Ichi regime at 2013-12-24 10:55:00: 1
# Current position delta: -0.47879760655315573
# Elapsed: 1.5921242237091064
# 		Run on 2013-12-25 10:55:00
# Rollover occured, new series used
# Ichi regime at 2013-12-25 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEG144350 x -1.0 Price: 10.580860297806197 Delta: 0.4941614698322513
# Leg:  / P.US.ZCEG144450 x 1.0 Price: 16.467828028371912 Delta: -0.6430732658842535
# Leg:  / C.US.ZCEG144500 x 1.0 Price: 4.485427349397597 Delta: 0.287899166237418
# Leg:  / C.US.ZCEG144650 x -1.0 Price: 1.7814422226279234 Delta: -0.13758037915691504
# Transactions delta: 0.0014069910285007536
# Elapsed: 2.264756679534912
# 		Run on 2013-12-26 10:55:00
# Ichi regime at 2013-12-26 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZCEG144350 x 2.0 Price: 6.8153476607676 Delta: 0.7871791247608583
# Leg:  / P.US.ZCEG144350 x 4.0 Price: 14.561865094681536 Delta: -2.420742548478879
# Transactions delta: -1.6335634237180208
# Elapsed: 1.905491590499878
# 		Run on 2013-12-27 10:55:00
# Ichi regime at 2013-12-27 10:55:00: -1
# Current position delta: -1.6259363849515323
# Elapsed: 0.9356253147125244
# 		Run on 2013-12-28 10:55:00
# Ichi regime at 2013-12-28 10:55:00: -1
# Current position delta: -1.583046079882858
# Elapsed: 0.9330840110778809
# 		Run on 2013-12-29 10:55:00
# Ichi regime at 2013-12-29 10:55:00: -1
# Current position delta: -1.5969263281790564
# Elapsed: 0.9239413738250732
# 		Run on 2013-12-30 10:55:00
# Ichi regime at 2013-12-30 10:55:00: -1
# Current position delta: -1.967349587313047
# Elapsed: 0.922809362411499
# 		Run on 2013-12-31 10:55:00
# Ichi regime at 2013-12-31 10:55:00: -1
# Current position delta: -2.041652214875855
# Elapsed: 0.9416358470916748
# 		Run on 2014-01-01 10:55:00
# Ichi regime at 2014-01-01 10:55:00: -1
# Current position delta: -2.055399382102052
# Elapsed: 0.9213452339172363
# 		Run on 2014-01-02 10:55:00
# Ichi regime at 2016-09-15 10:55:00: -1
# Current position delta: -3.03625979619257
# Elapsed: 0.9546561241149902
# 		Run on 2016-09-16 10:55:00
# Ichi regime at 2016-09-16 10:55:00: -1
# Current position delta: -1.590019649746275
# Elapsed: 0.949272871017456
# 		Run on 2016-09-17 10:55:00
# Ichi regime at 2016-09-17 10:55:00: -1
# Current position delta: -1.9094266051003255
# Elapsed: 0.9425218105316162
# 		Run on 2016-09-18 10:55:00
# Ichi regime at 2016-09-18 10:55:00: -1
# Current position delta: -1.9987997283494798
# Elapsed: 0.8919169902801514
# 		Run on 2016-09-19 10:55:00
# Ichi regime at 2016-09-19 10:55:00: -1
# Current position delta: -2.458213578669691
# Elapsed: 0.9090793132781982
# 		Run on 2016-09-20 10:55:00
# Ichi regime at 2016-09-20 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEV163400 x -1.0 Price: 2.7674330982349886 Delta: 0.46799712774204866
# Leg:  / P.US.ZCEV163500 x 1.0 Price: 10.274247382450937 Delta: -0.8369614080816897
# Leg:  / C.US.ZCEV163550 x 1.0 Price: 0.39875163817061576 Delta: 0.08572330227088441
# Leg:  / C.US.ZCEV163700 x -1.0 Price: 0.08974528271840043 Delta: -0.01859445629359956
# Transactions delta: -0.3018354343623562
# Elapsed: 1.5602483749389648
# 		Run on 2016-09-21 10:55:00
# Rollover occured, new series used
# Ichi regime at 2016-09-21 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEX163400 x -1.0 Price: 8.606070950816758 Delta: 0.47325390838613013
# Leg:  / P.US.ZCEX163500 x 1.0 Price: 14.613540452218672 Delta: -0.6416586866744456
# Leg:  / C.US.ZCEX163550 x 1.0 Price: 3.751476294375152 Delta: 0.27882757191048524
# Leg:  / C.US.ZCEX163700 x -1.0 Price: 1.5395709841629 Delta: -0.13079063916613917
# Transactions delta: -0.020367845543969393
# Elapsed: 2.195277452468872
# 		Run on 2016-09-22 10:55:00
# Ichi regime at 2016-09-22 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZCEX163450 x 2.0 Price: 4.601909030309827 Delta: 0.6895792677252256
# Leg:  / P.US.ZCEX163450 x 4.0 Price: 13.83769648022755 Delta: -2.599606474870524
# Transactions delta: -1.9100272071452982
# Elapsed: 1.8544914722442627
# 		Run on 2016-09-23 10:55:00
# Ichi regime at 2016-09-23 10:55:00: -1
# Current position delta: -2.027526256830861
# Elapsed: 0.9244515895843506
# 		Run on 2016-09-24 10:55:00
# Ichi regime at 2016-09-24 10:55:00: -1
# Current position delta: -2.0537391480723914
# Elapsed: 0.9229178428649902
# 		Run on 2016-09-25 10:55:00
# Ichi regime at 2016-09-25 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEX163350 x -1.0 Price: 7.429368808306037 Delta: 0.4788226230264681
# Leg:  / P.US.ZCEX163450 x 1.0 Price: 13.448152640054786 Delta: -0.6772027695485774
# Leg:  / C.US.ZCEX163500 x 1.0 Price: 2.583810906873495 Delta: 0.23706653194711075
# Leg:  / C.US.ZCEX163650 x -1.0 Price: 0.8643739401841835 Delta: -0.09169328770345367
# Transactions delta: -0.0530069022784522
# Elapsed: 1.521928310394287
# 		Run on 2016-09-26 10:55:00
# Ichi regime at 2016-09-26 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZCEX163400 x 2.0 Price: 3.2530863990756274 Delta: 0.5910251137394981
# Leg:  / P.US.ZCEX163400 x 4.0 Price: 13.733697964978148 Delta: -2.7929924992314303
# Transactions delta: -2.2019673854919324
# Elapsed: 1.852672815322876
# 		Run on 2016-09-27 10:55:00
# Ichi regime at 2016-09-27 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEX163300 x -1.0 Price: 6.774662711157504 Delta: 0.45307313429977975
# Leg:  / P.US.ZCEX163400 x 1.0 Price: 12.808232318945528 Delta: -0.6498125674582779
# Leg:  / C.US.ZCEX163450 x 1.0 Price: 3.113886087899246 Delta: 0.2655529368689728
# Leg:  / C.US.ZCEX163600 x -1.0 Price: 1.0435641152826491 Delta: -0.10567766124981993
# Transactions delta: -0.03686415753934526
# Elapsed: 1.5331547260284424
# 		Run on 2016-09-28 10:55:00
# Ichi regime at 2016-09-28 10:55:00: 1
# Current position delta: -0.05473164694160672
# Elapsed: 1.5893588066101074
# 		Run on 2016-09-29 10:55:00
# Ichi regime at 2016-09-29 10:55:00: 1
# Current position delta: -0.055978156251352024
# Elapsed: 1.5554156303405762
# 		Run on 2016-09-30 10:55:00
# Ichi regime at 2016-09-30 10:55:00: 1
# Current position delta: -0.0333726278454507
# Elapsed: 1.5386157035827637
# 		Run on 2016-10-01 10:55:00
# Ichi regime at 2016-10-01 10:55:00: 1
# Current position delta: -0.03643616770451234
# Elapsed: 1.5411787033081055
# 		Run on 2016-10-02 10:55:00
# Ichi regime at 2016-10-02 10:55:00: 1
# Current position delta: -0.04150673489219871
# Elapsed: 1.5138320922851562
# 		Run on 2016-10-03 10:55:00
# Ichi regime at 2016-10-03 10:55:00: 1
# Current position delta: 0.11105385862527273
# Elapsed: 1.524989366531372
# 		Run on 2016-10-04 10:55:00
# Ichi regime at 2016-10-04 10:55:00: 1
# Current position delta: 0.14474144765796998
# Elapsed: 1.5970194339752197
# 		Run on 2016-10-05 10:55:00
# Ichi regime at 2016-10-05 10:55:00: 1
# Current position delta: 0.17235561154914036
# Elapsed: 1.550994634628296
# 		Run on 2016-10-06 10:55:00
# Ichi regime at 2016-10-06 10:55:00: 1
# Current position delta: 0.059228845817666936
# Elapsed: 1.5325074195861816
# 		Run on 2016-10-07 10:55:00
# Ichi regime at 2016-10-07 10:55:00: 1
# Current position delta: 0.05568833749533872
# Elapsed: 1.5654098987579346
# 		Run on 2016-10-08 10:55:00
# Date not found at 2016-10-08
# Ichi regime at 2016-10-08 10:55:00: None
# Elapsed: 1.3998405933380127
# 		Run on 2016-10-09 10:55:00
# Date not found at 2016-10-09
# Ichi regime at 2016-10-09 10:55:00: None
# Current position delta: 0.0
# Elapsed: 0.1799156665802002
# 		Run on 2016-10-10 10:55:00
# Date not found at 2016-10-10
# Ichi regime at 2016-10-10 10:55:00: None
# Current position delta: 0.0
# Elapsed: 0.21445655822753906
# 		Run on 2016-10-11 10:55:00
# Ichi regime at 2016-10-11 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEX163450 x -1.0 Price: 5.34863493470516 Delta: 0.46846188567578845
# Leg:  / P.US.ZCEX163550 x 1.0 Price: 11.797034241992037 Delta: -0.7157239826994073
# Leg:  / C.US.ZCEX163600 x 1.0 Price: 1.4877932070121815 Delta: 0.18445930529680454
# Leg:  / C.US.ZCEX163750 x -1.0 Price: 0.41809842597271185 Delta: -0.05718253915325877
# Transactions delta: -0.11998533088007307
# Elapsed: 0.9378652572631836
# 		Run on 2016-10-12 10:55:00
# Ichi regime at 2016-10-12 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZCEX163500 x 2.0 Price: 1.4624637855314688 Delta: 0.4043565911934713
# Leg:  / P.US.ZCEX163500 x 4.0 Price: 12.942915608896726 Delta: -3.174771026114066
# Transactions delta: -2.7704144349205944
# Elapsed: 1.876183271408081
# 		Run on 2016-10-13 10:55:00
# Date not found at 2016-10-13
# Ichi regime at 2016-10-13 10:55:00: None
# Elapsed: 0.7871911525726318
# 		Run on 2016-10-14 10:55:00
# Ichi regime at 2016-10-14 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEX163550 x -1.0 Price: 3.8648259166025696 Delta: 0.4190218120295977
# Leg:  / P.US.ZCEX163650 x 1.0 Price: 10.16109423890083 Delta: -0.7053859414861663
# Leg:  / C.US.ZCEX163700 x 1.0 Price: 1.482409738991464 Delta: 0.19365454371835447
# Leg:  / C.US.ZCEX163850 x -1.0 Price: 0.298235538749708 Delta: -0.0467320711753405
# Transactions delta: -0.13944165691355462
# Elapsed: 0.9297208786010742
# 		Run on 2016-10-15 10:55:00
# Date not found at 2016-10-15
# Ichi regime at 2016-10-15 10:55:00: None
# Elapsed: 1.394927740097046
# 		Run on 2016-10-16 10:55:00
# Ichi regime at 2016-10-16 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEX163550 x -1.0 Price: 5.427646286954882 Delta: 0.5429613744072701
# Leg:  / P.US.ZCEX163650 x 1.0 Price: 12.600959802453247 Delta: -0.8211064794943922
# Leg:  / C.US.ZCEX163700 x 1.0 Price: 0.6444856008322049 Delta: 0.10690212426091249
# Leg:  / C.US.ZCEX163850 x -1.0 Price: 0.12914264242998819 Delta: -0.023343488583786796
# Transactions delta: -0.19458646940999638
# Elapsed: 0.8848707675933838
# 		Run on 2016-10-17 10:55:00
# Ichi regime at 2016-10-17 10:55:00: 1
# Current position delta: -0.2217806810120685
# Elapsed: 1.5989396572113037
# 		Run on 2016-10-18 10:55:00
# Ichi regime at 2016-10-18 10:55:00: 1
# Current position delta: -0.24545289796461256
# Elapsed: 1.5419580936431885
# 		Run on 2016-10-19 10:55:00
# Rollover occured, new series used
# Date not found at 2016-10-19
# Ichi regime at 2016-10-19 10:55:00: None
# Current position delta: 0.0
# Elapsed: 1.540205717086792
# 		Run on 2016-10-20 10:55:00
# Ichi regime at 2016-10-20 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEZ163500 x -1.0 Price: 8.586022023993223 Delta: 0.4521239582736406
# Leg:  / P.US.ZCEZ163600 x 1.0 Price: 14.25462494328491 Delta: -0.6134921766181232
# Leg:  / C.US.ZCEZ163650 x 1.0 Price: 4.474346439903314 Delta: 0.30700348637960684
# Leg:  / C.US.ZCEZ163800 x -1.0 Price: 1.775527115986769 Delta: -0.14502733343856367
# Transactions delta: 0.0006079345965606109
# Elapsed: 0.9180088043212891
# 		Run on 2016-10-21 10:55:00
# Ichi regime at 2016-10-21 10:55:00: 1
# Current position delta: -0.006710183803322833
# Elapsed: 1.5551719665527344
# 		Run on 2016-10-22 10:55:00
# Date not found at 2016-10-22
# Ichi regime at 2016-10-22 10:55:00: None
# Elapsed: 1.3889565467834473
# 		Run on 2016-10-23 10:55:00
# Ichi regime at 2016-10-23 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEZ163500 x -1.0 Price: 7.494699092078122 Delta: 0.44120969589044773
# Leg:  / P.US.ZCEZ163600 x 1.0 Price: 13.161079971012242 Delta: -0.6179051592046616
# Leg:  / C.US.ZCEZ163650 x 1.0 Price: 3.943621771491266 Delta: 0.2970139789473049
# Leg:  / C.US.ZCEZ163800 x -1.0 Price: 1.5568319499100767 Delta: -0.13580410556110642
# Transactions delta: -0.01548558992801538
# Elapsed: 0.8811652660369873
# 		Run on 2016-10-24 10:55:00
# Ichi regime at 2016-10-24 10:55:00: 1
# Current position delta: -0.038567179009226876
# Elapsed: 1.5508716106414795
# 		Run on 2016-10-25 10:55:00
# Ichi regime at 2016-10-25 10:55:00: 1
# Current position delta: -0.047051779019151974
# Elapsed: 1.5667974948883057
# 		Run on 2016-10-26 10:55:00
# Ichi regime at 2016-10-26 10:55:00: 1
# Current position delta: -0.024503050362815026
# Elapsed: 1.5657110214233398
# 		Run on 2016-10-27 10:55:00
# Ichi regime at 2016-10-27 10:55:00: 1
# Current position delta: 0.0014038068594410813
# Elapsed: 1.6069421768188477
# 		Run on 2016-10-28 10:55:00
# Ichi regime at 2016-10-28 10:55:00: 1
# Current position delta: -0.007183331531438852
# Elapsed: 1.5584824085235596
# 		Run on 2016-10-29 10:55:00
# Date not found at 2016-10-29
# Ichi regime at 2016-10-29 10:55:00: None
# Elapsed: 1.3746075630187988
# 		Run on 2016-10-30 10:55:00
# Ichi regime at 2016-10-30 10:55:00: 1
# New bullish zone position
# Leg: bullish / P.US.ZCEZ163550 x -1.0 Price: 7.473216212699924 Delta: 0.47903189713880684
# Leg:  / P.US.ZCEZ163650 x 1.0 Price: 13.697346523262212 Delta: -0.6705874082660012
# Leg:  / C.US.ZCEZ163700 x 1.0 Price: 2.7009020080756017 Delta: 0.2413513726450023
# Leg:  / C.US.ZCEZ163850 x -1.0 Price: 0.897231925866393 Delta: -0.09362689918826995
# Transactions delta: -0.04383103767046197
# Elapsed: 0.8919081687927246
# 		Run on 2016-10-31 10:55:00
# Ichi regime at 2016-10-31 10:55:00: 1
# Current position delta: -0.04314313050444896
# Elapsed: 1.5175867080688477
# 		Run on 2016-11-01 10:55:00
# Date not found at 2016-11-01
# Ichi regime at 2016-11-01 10:55:00: None
# Elapsed: 1.3666975498199463
# Done

# %% [markdown]
# # View EXO price series

# %%
for ticker in instruments:
    exo_df, exo_info = exostorage.load_series('{0}_{1}'.format(ticker, EXO_NAME))    
    exo_df['exo'].plot(title='{0}_{1}'.format(ticker, EXO_NAME))
    plt.show()
