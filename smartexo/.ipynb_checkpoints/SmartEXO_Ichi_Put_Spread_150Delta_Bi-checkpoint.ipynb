# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from exobuilder.contracts.futureschain import FuturesChain
from exobuilder.contracts.futurecontract import FutureContract
from exobuilder.tests.assetindexdict import AssetIndexDicts
from datetime import datetime, date, timedelta, time as dttime
from exobuilder.contracts.instrument import Instrument
from exobuilder.data.datasource_mongo import DataSourceMongo
from exobuilder.data.datasource_sql import DataSourceSQL
from exobuilder.data.assetindex_mongo import AssetIndexMongo
from exobuilder.data.exostorage import EXOStorage
from exobuilder.exo.exoenginebase import ExoEngineBase
from exobuilder.exo.transaction import Transaction
import time
from exobuilder.algorithms.rollover_helper import RolloverHelper

import importlib
import logging
importlib.reload(logging);
import matplotlib.pyplot as plt

# %%
EXO_NAME = 'SmartEXO_Ichi_Call_Spread_150Delta_Bi'

# TODO: set to 'False' if EXO building output is too verbosive
verbosive_logging = True # or True - for debug log feed

# TODO: select instruments list for SMART EXO calculation
#instruments = ['CL', 'ES', 'NG', 'ZC', 'ZS', 'ZW', 'ZN']
instruments = ['CL','ES','NG','ZC','ZS','ZW']


# TODO: select start date for SmartEXO calculation
base_date = datetime(2014, 6, 13, 12, 45, 0)

# %% [markdown]
# # Define Bull/Bear/Neutral areas rules

# %%
def ichimoku_regimes(date, price_series):    
    '''
    Calculates Bull/Bear/Neutral areas based on Ichimoku zones
    
    param date: Current date time
    param price_series: price Pandas.Series
    
    Returns:
        -1 - for bearish zone
        0  - for neutral zone
        +1 - for bullish zone
        None - for unknown
    '''
    #
    #  TODO: Change values to fine tune zoning algorithm
    #
    conversion_line_period = 9 # subject of optimization
    base_line_period = 26  # subject of optimization
    leading_spans_lookahead_period = 26  # subject of optimization
    leading_span_b_period = 52 # subject of optimization
        
        
    conversion_line_high = price_series.rolling(window=conversion_line_period).max()
    conversion_line_low = price_series.rolling(window=conversion_line_period).min()
    conversion_line = (conversion_line_high + conversion_line_low) / 2

    base_line_high = price_series.rolling(window=base_line_period).max()
    base_line_low = price_series.rolling(window=base_line_period).min()
    base_line = (base_line_high + base_line_low) / 2

    leading_span_a = ((conversion_line + base_line) / 2).shift(leading_spans_lookahead_period)
    leading_span_b = ((price_series.rolling(window=leading_span_b_period).max() + price_series.rolling(
        window=leading_span_b_period).min()) / 2).shift(leading_spans_lookahead_period)


    #
    # Rules calculation
    #

    # Cloud top and bottom series are defined using leading span A and B
    cloud_top = leading_span_a.rolling(1).max()
    cloud_bottom = leading_span_a.rolling(1).min()

    rule_price_above_cloud_top = price_series > cloud_top
    rule_price_below_cloud_bottom = price_series < cloud_bottom
    rule_price_in_cloud = (price_series < cloud_top) & (price_series > cloud_bottom)

    def get_regime(date):
        if date not in rule_price_above_cloud_top.index:
            logging.debug("Date not found at {0}".format(date))
            return None


        if rule_price_above_cloud_top[date]:
            return 1
        elif rule_price_below_cloud_bottom[date]:
            return -1
        elif rule_price_in_cloud[date]:
            return 0
        return None

    regime = get_regime(date.date())
    logging.debug("Ichi regime at {0}: {1}".format(date, regime))
    return regime

# %%
# Toolbox
def transactions_delta(trans_list):
    return sum([t.delta for t in trans_list])

def log_transactions(trans_list, msg):
    logging.debug(msg)
    [logging.debug(t) for t in trans_list]
    logging.debug('Transactions delta: {0}'.format(transactions_delta(trans_list)))

# %% [markdown]
# # Option position management

# %% [markdown]
# According to https://tmqrexo.slack.com/files/nikolasjoyce/F2PHLEETZ/pasted_image_at_2016_10_14_10_05_am.png

# %% [markdown]
# ## New bullish zone position

# %%
def new_position_bullish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bullish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening long ITM straddle in bullish zone
    #
    # https://files.slack.com/files-tmb/T0484J7T7-F2QBLK53R-93b4252806/pasted_image_at_2016_10_17_10_08_am_720.png
   
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-2].c, date, 6.0, leg_name='bullish'),
                Transaction(opt_chain[3].c, date, -6.0),    
                ]
    log_transactions(trans_list,'New bullish zone position')
    return trans_list

# %% [markdown]
# ## New bearish zone position

# %%
def new_position_bearish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bearish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    #
    # Opening small ITM straddle in bearish zone
    #

    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[2].c, date, 1.0, leg_name='bearish'),
                Transaction(opt_chain[2].p, date, 1.0),                
                ]
    
    log_transactions(trans_list,'New bearish zone position')
    return trans_list

# %% [markdown]
# ## New neutral zone position

# %%
def new_position_neutral_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for neutral zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    # Opening long asymmetric butterfly in neutral zone
    #    
    # https://files.slack.com/files-tmb/T0484J7T7-F2PGU8QNQ-6344e6a04c/pasted_image_at_2016_10_14_09_43_am_720.png
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-2].c, date, -3.0, leg_name='neutral'),
                Transaction(opt_chain[2].c, date, 6.0),
                
                Transaction(opt_chain[8].c, date, -3.0),
                Transaction(opt_chain[3].c, date,  0.0),
                ]
    log_transactions(trans_list,'New neutral zone position')

    return trans_list

# %% [markdown]
# ## Manage opened positions

# %%
def manage_opened_position(date, fut, opt_chain, regime, opened_position):
    logging.debug('Current position delta: {0}'.format(opened_position.delta))
    
    # By default: do nothing
    return []

# %% [markdown]
# # Define EXO builder class

# %%
class SmartEXOIchimoku(ExoEngineBase):
    def __init__(self, symbol, direction, date, datasource, log_file_path=''):
        self._symbol = symbol
        self.custom_values = {}
        super().__init__(symbol, direction, date, datasource, log_file_path=log_file_path)

    @staticmethod
    def direction_type():
        return 0

    @staticmethod
    def names_list(symbol):
        return ['{0}_{1}'.format(self._symbol, EXO_NAME)]

    @property
    def exo_name(self):
            return '{0}_{1}'.format(self._symbol, EXO_NAME)

    def is_rollover(self):
        if len(self.position) != 0:
            for p in self.position.legs.values():
                rh = RolloverHelper(p.instrument)
                if rh.is_rollover(p):
                    return True
        return False

    def process_rollover(self):
        trans_list = self.position.close_all_translist()
        logging.info('Rollover occured, new series used')
        return trans_list
    
    def get_custom_values(self):
        """
        Method that return custom EXO data frame values, to store inside EXO Dataframe in the DB
        :return: dictionary {'string_key': (int or float) value}
        """
        return self.custom_values
    

    def process_day(self):
        """
        Main EXO's position management method
        :return: list of Transactions to process
        """

        # Get cont futures price for EXO
        exo_df, exo_info = self.datasource.exostorage.load_series("{0}_ContFut".format(self._symbol))

        regime = ichimoku_regimes(self.date, exo_df['exo'])

        trans_list = []

        if regime is None and len(self.position) > 0:
            return self.position.close_all_translist()
        
        instr = self.datasource.get(self._symbol, self.date)
        rh = RolloverHelper(instr)
        fut, opt_chain = rh.get_active_chains()

        if regime == 1 and 'bullish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bullish_zone(self.date, fut, opt_chain)
            
            return trans_list
        if regime == -1 and 'bearish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bearish_zone(self.date, fut, opt_chain)
            return trans_list

        if regime == 0 and 'neutral' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_neutral_zone(self.date, fut, opt_chain)
            return trans_list
        
        #
        # Writing custom values to store inside DB 
        #
        self.custom_values = {
            'ichi_regime': regime if regime is not None else float('nan')
        }
        
        #
        # Manage opened position
        #
        return manage_opened_position(self.date, fut, opt_chain, regime, self.position)

# %% [markdown]
# # Run EXO build process (WARN: long-running task!)

# %%
from pymongo import MongoClient

if verbosive_logging:
    logging.basicConfig(format='%(message)s', level=logging.DEBUG)
else:
    logging.basicConfig(format='%(message)s', level=logging.INFO)

mongo_connstr = 'mongodb://exowriter:qmWSy4K3@10.0.1.2/tmldb?authMechanism=SCRAM-SHA-1'
mongo_db_name = 'tmldb'
assetindex = AssetIndexMongo(mongo_connstr, mongo_db_name)
exostorage = EXOStorage(mongo_connstr, mongo_db_name)

#base_date = datetime(2011, 6, 13, 12, 45, 0)


futures_limit = 3
options_limit = 10

DEBUG = '.'

datasource = DataSourceMongo(mongo_connstr, mongo_db_name, assetindex, futures_limit, options_limit, exostorage)

server = 'h9ggwlagd1.database.windows.net'
user = 'modelread'
password = '4fSHRXwd4u'
datasource = DataSourceSQL(server, user, password, assetindex, futures_limit, options_limit, exostorage)

enddate = datetime.combine(datetime.now().date(), dttime(12, 45, 0))
currdate = base_date


logging.info("Deleting all SmartEXO of :" + EXO_NAME)
client = MongoClient(mongo_connstr)
db = client[mongo_db_name]
db['exo_data'].delete_many({'name': {'$regex': '.*{0}*.'.format(EXO_NAME)}})


logging.info("Starting EXO calculation process from: {0}".format(currdate))
for ticker in instruments:
    logging.info("Processing: "+ticker)
    currdate = base_date
    while currdate <= enddate:
        
        start_time = time.time()
        date = currdate

        asset_info = assetindex.get_instrument_info(ticker)
        exec_time_end, decision_time_end = AssetIndexMongo.get_exec_time(date, asset_info)
        
        logging.info("\t\tRun on {0}".format(decision_time_end))

        with SmartEXOIchimoku(ticker, 0, decision_time_end, datasource) as exo_engine:
            # Load EXO information from mongo
            exo_engine.load()
            exo_engine.calculate()

        end_time = time.time()
        currdate += timedelta(days=1)
        logging.debug("Elapsed: {0}".format(end_time-start_time))
logging.info('Done')
# Out:
# Deleting all SmartEXO of :SmartEXO_Ichi_Call_Spread_150Delta_Bi
# Starting EXO calculation process from: 2014-06-13 12:45:00
# Processing: CL
# 		Run on 2014-06-13 11:10:00
# Ichi regime at 2014-06-13 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEN1410600 x 6.0 Price: 1.3102206457811718 Delta: 3.9930467022137712
# Leg:  / C.US.CLEN1410850 x -6.0 Price: 0.3497226320945934 Delta: -1.4965563689451502
# Transactions delta: 2.4964903332686212
# Elapsed: 0.7028462886810303
# 		Run on 2014-06-14 11:10:00
# Ichi regime at 2014-06-14 11:10:00: 1
# Current position delta: 3.008646853236176
# Elapsed: 1.007509469985962
# 		Run on 2014-06-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-06-15 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEQ1410500 x 6.0 Price: 2.630094395751435 Delta: 3.5464352329767506
# Leg:  / C.US.CLEQ1410750 x -6.0 Price: 1.5501859335179589 Delta: -2.441121630233152
# Transactions delta: 1.1053136027435984
# Elapsed: 1.5218634605407715
# 		Run on 2014-06-16 11:10:00
# Ichi regime at 2014-06-16 11:10:00: 1
# Current position delta: 1.1254092651767782
# Elapsed: 1.1376056671142578
# 		Run on 2014-06-17 11:10:00
# Ichi regime at 2014-06-17 11:10:00: 1
# Current position delta: 1.174964265955107
# Elapsed: 0.9901049137115479
# 		Run on 2014-06-18 11:10:00
# Ichi regime at 2014-06-18 11:10:00: 1
# Current position delta: 1.27880229775817
# Elapsed: 0.9898974895477295
# 		Run on 2014-06-19 11:10:00
# Ichi regime at 2014-06-19 11:10:00: 1
# Current position delta: 1.3114983198949997
# Elapsed: 0.9529402256011963
# 		Run on 2014-06-20 11:10:00
# Ichi regime at 2014-06-20 11:10:00: 1
# Current position delta: 1.3614894196053111
# Elapsed: 0.9661540985107422
# 		Run on 2014-06-21 11:10:00
# Ichi regime at 2014-06-21 11:10:00: 1
# Current position delta: 1.3274588631977928
# Elapsed: 0.954451322555542
# 		Run on 2014-06-22 11:10:00
# Ichi regime at 2014-06-22 11:10:00: 1
# Current position delta: 1.352881783298705
# Elapsed: 0.9300308227539062
# 		Run on 2014-06-23 11:10:00
# Ichi regime at 2014-06-23 11:10:00: 1
# Current position delta: 1.3801532263342233
# Elapsed: 0.9446358680725098
# 		Run on 2014-06-24 11:10:00
# Ichi regime at 2014-06-24 11:10:00: 1
# Current position delta: 1.462261594794661
# Elapsed: 0.989577054977417
# 		Run on 2014-06-25 11:10:00
# Ichi regime at 2014-06-25 11:10:00: 1
# Current position delta: 1.5504924023002302
# Elapsed: 0.9793763160705566
# 		Run on 2014-06-26 11:10:00
# Ichi regime at 2014-06-26 11:10:00: 1
# Current position delta: 1.5875812834194618
# Elapsed: 0.9605305194854736
# 		Run on 2014-06-27 11:10:00
# Ichi regime at 2014-06-27 11:10:00: 1
# Current position delta: 1.6641280558150733
# Elapsed: 0.9757266044616699
# 		Run on 2014-06-28 11:10:00
# Ichi regime at 2014-06-28 11:10:00: 1
# Current position delta: 1.7320402977194003
# Elapsed: 0.9631178379058838
# 		Run on 2014-06-29 11:10:00
# Ichi regime at 2014-06-29 11:10:00: 1
# Current position delta: 1.7764786908805266
# Elapsed: 0.9569928646087646
# 		Run on 2014-06-30 11:10:00
# Ichi regime at 2014-06-30 11:10:00: 1
# Current position delta: 1.782812501093562
# Elapsed: 0.9493415355682373
# 		Run on 2014-07-01 11:10:00
# Ichi regime at 2014-07-01 11:10:00: 1
# Current position delta: 1.7598964594202355
# Elapsed: 0.9683010578155518
# 		Run on 2014-07-02 11:10:00
# Ichi regime at 2014-07-02 11:10:00: 1
# Current position delta: 1.658657459938544
# Elapsed: 0.961857795715332
# 		Run on 2014-07-03 11:10:00
# Ichi regime at 2014-07-03 11:10:00: 1
# Current position delta: 1.4540994723396912
# Elapsed: 1.0050220489501953
# 		Run on 2014-07-04 11:10:00
# Ichi regime at 2014-07-04 11:10:00: 1
# Current position delta: 1.364334593054521
# Elapsed: 0.9612016677856445
# 		Run on 2014-07-05 11:10:00
# Ichi regime at 2014-07-05 11:10:00: 1
# Current position delta: 1.3649290177697324
# Elapsed: 0.9751124382019043
# 		Run on 2014-07-06 11:10:00
# Ichi regime at 2014-07-06 11:10:00: 1
# Current position delta: 1.3739668079863758
# Elapsed: 0.9305500984191895
# 		Run on 2014-07-07 11:10:00
# Ichi regime at 2014-07-07 11:10:00: 1
# Current position delta: 1.1284088194744846
# Elapsed: 1.0163016319274902
# 		Run on 2014-07-08 11:10:00
# Ichi regime at 2014-07-08 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEQ1410400 x 1.0 Price: 0.545023674272052 Delta: 0.3622257024574834
# Leg:  / P.US.CLEQ1410400 x 1.0 Price: 1.3650072988217516 Delta: -0.6367523166390623
# Transactions delta: -0.27452661418157887
# Elapsed: 1.34617280960083
# 		Run on 2014-07-09 11:10:00
# Ichi regime at 2014-07-09 11:10:00: -1
# Current position delta: -0.6306824486024728
# Elapsed: 0.9844202995300293
# 		Run on 2014-07-10 11:10:00
# Ichi regime at 2014-07-10 11:10:00: -1
# Current position delta: -0.39485558701367923
# Elapsed: 0.9821798801422119
# 		Run on 2014-07-11 11:10:00
# Ichi regime at 2014-07-11 11:10:00: -1
# Current position delta: -0.9314901099692392
# Elapsed: 0.981086254119873
# 		Run on 2014-07-12 11:10:00
# Ichi regime at 2014-07-12 11:10:00: -1
# Current position delta: -0.9100713400378351
# Elapsed: 0.9725022315979004
# 		Run on 2014-07-13 11:10:00
# Ichi regime at 2014-07-13 11:10:00: -1
# Current position delta: -0.9423726116228779
# Elapsed: 0.9382297992706299
# 		Run on 2014-07-14 11:10:00
# Ichi regime at 2014-07-14 11:10:00: -1
# Current position delta: -0.9704471463446314
# Elapsed: 0.9507589340209961
# 		Run on 2014-07-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-07-15 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEU1410000 x 1.0 Price: 1.4484375190184693 Delta: 0.44286314742035215
# Leg:  / P.US.CLEU1410000 x 1.0 Price: 2.2184656520871258 Delta: -0.5563042985070522
# Transactions delta: -0.11344115108670005
# Elapsed: 1.6302988529205322
# 		Run on 2014-07-16 11:10:00
# Ichi regime at 2014-07-16 11:10:00: -1
# Current position delta: 0.1304223041874118
# Elapsed: 1.1796205043792725
# 		Run on 2014-07-17 11:10:00
# Ichi regime at 2014-07-17 11:10:00: -1
# Current position delta: 0.3916376567478648
# Elapsed: 1.0153992176055908
# 		Run on 2014-07-18 11:10:00
# Ichi regime at 2014-07-18 11:10:00: -1
# Current position delta: 0.36650799510599713
# Elapsed: 0.9949347972869873
# 		Run on 2014-07-19 11:10:00
# Ichi regime at 2014-07-19 11:10:00: -1
# Current position delta: 0.3348836934381469
# Elapsed: 0.9738938808441162
# 		Run on 2014-07-20 11:10:00
# Ichi regime at 2014-07-20 11:10:00: -1
# Current position delta: 0.34019226440895295
# Elapsed: 1.0264394283294678
# 		Run on 2014-07-21 11:10:00
# Ichi regime at 2014-07-21 11:10:00: -1
# Current position delta: 0.5168193901192601
# Elapsed: 0.9512631893157959
# 		Run on 2014-07-22 11:10:00
# Ichi regime at 2014-07-22 11:10:00: -1
# Current position delta: 0.45726096957925233
# Elapsed: 1.0008001327514648
# 		Run on 2014-07-23 11:10:00
# Ichi regime at 2014-07-23 11:10:00: -1
# Current position delta: 0.593168443944579
# Elapsed: 0.995631217956543
# 		Run on 2014-07-24 11:10:00
# Ichi regime at 2014-07-24 11:10:00: -1
# Current position delta: 0.46237376137798747
# Elapsed: 1.0125982761383057
# 		Run on 2014-07-25 11:10:00
# Ichi regime at 2014-07-25 11:10:00: -1
# Current position delta: 0.45530828942185037
# Elapsed: 0.9870178699493408
# 		Run on 2014-07-26 11:10:00
# Ichi regime at 2014-07-26 11:10:00: -1
# Current position delta: 0.4154360633262237
# Elapsed: 1.0002024173736572
# 		Run on 2014-07-27 11:10:00
# Ichi regime at 2014-07-27 11:10:00: -1
# Current position delta: 0.42440726483913216
# Elapsed: 0.9514360427856445
# 		Run on 2014-07-28 11:10:00
# Ichi regime at 2014-07-28 11:10:00: -1
# Current position delta: 0.44966279457971575
# Elapsed: 0.9587192535400391
# 		Run on 2014-07-29 11:10:00
# Ichi regime at 2014-07-29 11:10:00: -1
# Current position delta: 0.22627459098103092
# Elapsed: 0.9692645072937012
# 		Run on 2014-07-30 11:10:00
# Ichi regime at 2014-07-30 11:10:00: -1
# Current position delta: 0.09448368270153373
# Elapsed: 1.0115289688110352
# 		Run on 2014-07-31 11:10:00
# Ichi regime at 2014-07-31 11:10:00: -1
# Current position delta: -0.305356511935608
# Elapsed: 1.0145201683044434
# 		Run on 2014-08-01 11:10:00
# Ichi regime at 2014-08-01 11:10:00: -1
# Current position delta: -0.4850829212990536
# Elapsed: 0.9870812892913818
# 		Run on 2014-08-02 11:10:00
# Ichi regime at 2014-08-02 11:10:00: -1
# Current position delta: -0.570823827056544
# Elapsed: 0.9646213054656982
# 		Run on 2014-08-03 11:10:00
# Ichi regime at 2014-08-03 11:10:00: -1
# Current position delta: -0.590234775149672
# Elapsed: 0.9342966079711914
# 		Run on 2014-08-04 11:10:00
# Ichi regime at 2014-08-04 11:10:00: -1
# Current position delta: -0.4674030299650881
# Elapsed: 0.937225341796875
# 		Run on 2014-08-05 11:10:00
# Ichi regime at 2014-08-05 11:10:00: -1
# Current position delta: -0.7127918058725065
# Elapsed: 0.9760088920593262
# 		Run on 2014-08-06 11:10:00
# Ichi regime at 2014-08-06 11:10:00: -1
# Current position delta: -0.7313596890089543
# Elapsed: 0.9793374538421631
# 		Run on 2014-08-07 11:10:00
# Ichi regime at 2014-08-07 11:10:00: -1
# Current position delta: -0.7047657359431877
# Elapsed: 1.033423662185669
# 		Run on 2014-08-08 11:10:00
# Ichi regime at 2014-08-08 11:10:00: -1
# Current position delta: -0.6771034993986763
# Elapsed: 0.9894380569458008
# 		Run on 2014-08-09 11:10:00
# Ichi regime at 2014-08-09 11:10:00: -1
# Current position delta: -0.736665568265661
# Elapsed: 0.9674341678619385
# 		Run on 2014-08-10 11:10:00
# Ichi regime at 2014-08-10 11:10:00: -1
# Current position delta: -0.7804649529827914
# Elapsed: 0.9334392547607422
# 		Run on 2014-08-11 11:10:00
# Ichi regime at 2014-08-11 11:10:00: -1
# Current position delta: -0.6567139396764804
# Elapsed: 0.9781448841094971
# 		Run on 2014-08-12 11:10:00
# Ichi regime at 2014-08-12 11:10:00: -1
# Current position delta: -0.8334755349796238
# Elapsed: 0.9679453372955322
# 		Run on 2014-08-13 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-08-13 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEV149750 x 1.0 Price: 1.466297728720761 Delta: 0.4399154295943328
# Leg:  / P.US.CLEV149750 x 1.0 Price: 2.2967659674584837 Delta: -0.5591253259272557
# Transactions delta: -0.11920989633292295
# Elapsed: 1.5706188678741455
# 		Run on 2014-08-14 11:10:00
# Ichi regime at 2014-08-14 11:10:00: -1
# Current position delta: -0.5340391111294049
# Elapsed: 1.1687211990356445
# 		Run on 2014-08-15 11:10:00
# Ichi regime at 2014-08-15 11:10:00: -1
# Current position delta: -0.3426828078883986
# Elapsed: 0.9818365573883057
# 		Run on 2014-08-16 11:10:00
# Ichi regime at 2014-08-16 11:10:00: -1
# Current position delta: -0.3600643960743448
# Elapsed: 0.9544885158538818
# 		Run on 2014-08-17 11:10:00
# Ichi regime at 2014-08-17 11:10:00: -1
# Current position delta: -0.3660512652613519
# Elapsed: 0.9534800052642822
# 		Run on 2014-08-18 11:10:00
# Ichi regime at 2014-08-18 11:10:00: -1
# Current position delta: -0.5706206444445531
# Elapsed: 0.9499561786651611
# 		Run on 2014-08-19 11:10:00
# Ichi regime at 2014-08-19 11:10:00: -1
# Current position delta: -0.6917545434726915
# Elapsed: 1.0000243186950684
# 		Run on 2014-08-20 11:10:00
# Ichi regime at 2014-08-20 11:10:00: -1
# Current position delta: -0.6553578769274618
# Elapsed: 0.9742007255554199
# 		Run on 2014-08-21 11:10:00
# Ichi regime at 2014-08-21 11:10:00: -1
# Current position delta: -0.5677671625989886
# Elapsed: 0.9886248111724854
# 		Run on 2014-08-22 11:10:00
# Ichi regime at 2014-08-22 11:10:00: -1
# Current position delta: -0.7055145051421455
# Elapsed: 0.9838902950286865
# 		Run on 2014-08-23 11:10:00
# Ichi regime at 2014-08-23 11:10:00: -1
# Current position delta: -0.7481877450137345
# Elapsed: 0.9843072891235352
# 		Run on 2014-08-24 11:10:00
# Ichi regime at 2014-08-24 11:10:00: -1
# Current position delta: -0.7582090577225855
# Elapsed: 0.9284207820892334
# 		Run on 2014-08-25 11:10:00
# Ichi regime at 2014-08-25 11:10:00: -1
# Current position delta: -0.7823378210427254
# Elapsed: 0.9855434894561768
# 		Run on 2014-08-26 11:10:00
# Ichi regime at 2014-08-26 11:10:00: -1
# Current position delta: -0.6800135205166378
# Elapsed: 0.9774007797241211
# 		Run on 2014-08-27 11:10:00
# Ichi regime at 2014-08-27 11:10:00: -1
# Current position delta: -0.708682177113992
# Elapsed: 1.008208990097046
# 		Run on 2014-08-28 11:10:00
# Ichi regime at 2014-08-28 11:10:00: -1
# Current position delta: -0.6162992646859421
# Elapsed: 1.0053672790527344
# 		Run on 2014-08-29 11:10:00
# Ichi regime at 2014-08-29 11:10:00: -1
# Current position delta: -0.39101237159693303
# Elapsed: 0.9950206279754639
# 		Run on 2014-08-30 11:10:00
# Ichi regime at 2014-08-30 11:10:00: -1
# Current position delta: -0.3989625316325566
# Elapsed: 0.9926900863647461
# 		Run on 2014-08-31 11:10:00
# Ichi regime at 2014-08-31 11:10:00: -1
# Current position delta: -0.4102395400224723
# Elapsed: 0.932551383972168
# 		Run on 2014-09-01 11:10:00
# Ichi regime at 2014-09-01 11:10:00: -1
# Current position delta: -0.4176362215728667
# Elapsed: 0.9373018741607666
# 		Run on 2014-09-02 11:10:00
# Ichi regime at 2014-09-02 11:10:00: -1
# Current position delta: -0.861629441615036
# Elapsed: 1.0086653232574463
# 		Run on 2014-09-03 11:10:00
# Ichi regime at 2014-09-03 11:10:00: -1
# Current position delta: -0.44050448770693834
# Elapsed: 1.0096397399902344
# 		Run on 2014-09-04 11:10:00
# Ichi regime at 2014-09-04 11:10:00: -1
# Current position delta: -0.6776684654405367
# Elapsed: 0.9769842624664307
# 		Run on 2014-09-05 11:10:00
# Ichi regime at 2014-09-05 11:10:00: -1
# Current position delta: -0.8398474332505315
# Elapsed: 1.0715339183807373
# 		Run on 2014-09-06 11:10:00
# Ichi regime at 2014-09-06 11:10:00: -1
# Current position delta: -0.8321719138213058
# Elapsed: 0.969369649887085
# 		Run on 2014-09-07 11:10:00
# Ichi regime at 2014-09-07 11:10:00: -1
# Current position delta: -0.8524367894450373
# Elapsed: 0.9398226737976074
# 		Run on 2014-09-08 11:10:00
# Ichi regime at 2014-09-08 11:10:00: -1
# Current position delta: -0.9451104803223364
# Elapsed: 0.9622538089752197
# 		Run on 2014-09-09 11:10:00
# Ichi regime at 2014-09-09 11:10:00: -1
# Current position delta: -0.8888873354616467
# Elapsed: 0.9892337322235107
# 		Run on 2014-09-10 11:10:00
# Ichi regime at 2014-09-10 11:10:00: -1
# Current position delta: -0.9676647438077377
# Elapsed: 1.003119707107544
# 		Run on 2014-09-11 11:10:00
# Ichi regime at 2014-09-11 11:10:00: -1
# Current position delta: -0.9171279224113368
# Elapsed: 0.9790234565734863
# 		Run on 2014-09-12 11:10:00
# Ichi regime at 2014-09-12 11:10:00: -1
# Current position delta: -0.9512327030031258
# Elapsed: 1.0129570960998535
# 		Run on 2014-09-13 11:10:00
# Ichi regime at 2014-09-13 11:10:00: -1
# Current position delta: -0.9682590027190412
# Elapsed: 1.0146188735961914
# 		Run on 2014-09-14 11:10:00
# Ichi regime at 2014-09-14 11:10:00: -1
# Current position delta: -0.9870016144589271
# Elapsed: 0.9372227191925049
# 		Run on 2014-09-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-09-15 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEX149250 x 1.0 Price: 1.5350706838520622 Delta: 0.4437424835239681
# Leg:  / P.US.CLEX149250 x 1.0 Price: 2.3562416647483886 Delta: -0.5554676292556883
# Transactions delta: -0.11172514573172015
# Elapsed: 1.5401830673217773
# 		Run on 2014-09-16 11:10:00
# Ichi regime at 2014-09-16 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX149300 x 6.0 Price: 2.4323654804685404 Delta: 3.475269829231398
# Leg:  / C.US.CLEX149550 x -6.0 Price: 1.2483443472725426 Delta: -2.2742613926425794
# Transactions delta: 1.2010084365888187
# Elapsed: 1.6024518013000488
# 		Run on 2014-09-17 11:10:00
# Ichi regime at 2014-09-17 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEX149400 x 1.0 Price: 1.4164843432951528 Delta: 0.4299169238639553
# Leg:  / P.US.CLEX149400 x 1.0 Price: 2.366400540912842 Delta: -0.5691603689319056
# Transactions delta: -0.13924344506795028
# Elapsed: 1.3670070171356201
# 		Run on 2014-09-18 11:10:00
# Ichi regime at 2014-09-18 11:10:00: -1
# Current position delta: -0.30405911954000264
# Elapsed: 0.9911813735961914
# 		Run on 2014-09-19 11:10:00
# Ichi regime at 2014-09-19 11:10:00: -1
# Current position delta: -0.4603309504850772
# Elapsed: 1.0112969875335693
# 		Run on 2014-09-20 11:10:00
# Ichi regime at 2014-09-20 11:10:00: -1
# Current position delta: -0.4077800393290695
# Elapsed: 0.9841485023498535
# 		Run on 2014-09-21 11:10:00
# Ichi regime at 2014-09-21 11:10:00: -1
# Current position delta: -0.41578242248639546
# Elapsed: 0.9438116550445557
# 		Run on 2014-09-22 11:10:00
# Ichi regime at 2014-09-22 11:10:00: -1
# Current position delta: -0.5836254273075592
# Elapsed: 0.9854443073272705
# 		Run on 2014-09-23 11:10:00
# Ichi regime at 2014-09-23 11:10:00: -1
# Current position delta: -0.42849736447639614
# Elapsed: 0.9803686141967773
# 		Run on 2014-09-24 11:10:00
# Ichi regime at 2014-09-24 11:10:00: -1
# Current position delta: -0.2883692856661246
# Elapsed: 0.9707801342010498
# 		Run on 2014-09-25 11:10:00
# Ichi regime at 2014-09-25 11:10:00: -1
# Current position delta: -0.33127251515079964
# Elapsed: 1.0013947486877441
# 		Run on 2014-09-26 11:10:00
# Ichi regime at 2014-09-26 11:10:00: -1
# Current position delta: -0.08750740725138889
# Elapsed: 1.0006566047668457
# 		Run on 2014-09-27 11:10:00
# Ichi regime at 2014-09-27 11:10:00: -1
# Current position delta: -0.12099507858993702
# Elapsed: 0.992103099822998
# 		Run on 2014-09-28 11:10:00
# Ichi regime at 2014-09-28 11:10:00: -1
# Current position delta: -0.12526498822313453
# Elapsed: 0.9543113708496094
# 		Run on 2014-09-29 11:10:00
# Ichi regime at 2014-09-29 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX149350 x 6.0 Price: 1.888659291719783 Delta: 3.6270186994341005
# Leg:  / C.US.CLEX149600 x -6.0 Price: 0.7099942178442689 Delta: -1.947270659174321
# Transactions delta: 1.6797480402597795
# Elapsed: 1.3291916847229004
# 		Run on 2014-09-30 11:10:00
# Ichi regime at 2014-09-30 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEX149200 x 1.0 Price: 1.091671152255195 Delta: 0.4218763924971986
# Leg:  / P.US.CLEX149200 x 1.0 Price: 1.8940460855564325 Delta: -0.5773293514686448
# Transactions delta: -0.15545295897144623
# Elapsed: 1.3554611206054688
# 		Run on 2014-10-01 11:10:00
# Ichi regime at 2014-10-01 11:10:00: -1
# Current position delta: -0.16963316187744104
# Elapsed: 0.9690532684326172
# 		Run on 2014-10-02 11:10:00
# Ichi regime at 2014-10-02 11:10:00: -1
# Current position delta: -0.21715389562205478
# Elapsed: 0.9810819625854492
# 		Run on 2014-10-03 11:10:00
# Ichi regime at 2014-10-03 11:10:00: -1
# Current position delta: -0.4142427576240386
# Elapsed: 0.9984989166259766
# 		Run on 2014-10-04 11:10:00
# Ichi regime at 2014-10-04 11:10:00: -1
# Current position delta: -0.4532039757491575
# Elapsed: 0.959815502166748
# 		Run on 2014-10-05 11:10:00
# Ichi regime at 2014-10-05 11:10:00: -1
# Current position delta: -0.4721477770225341
# Elapsed: 0.9325966835021973
# 		Run on 2014-10-06 11:10:00
# Ichi regime at 2014-10-06 11:10:00: -1
# Current position delta: -0.44384941241949455
# Elapsed: 0.9578611850738525
# 		Run on 2014-10-07 11:10:00
# Ichi regime at 2014-10-07 11:10:00: -1
# Current position delta: -0.6113053588303354
# Elapsed: 1.0039827823638916
# 		Run on 2014-10-08 11:10:00
# Ichi regime at 2014-10-08 11:10:00: -1
# Current position delta: -0.8348021513469217
# Elapsed: 0.9850635528564453
# 		Run on 2014-10-09 11:10:00
# Ichi regime at 2014-10-09 11:10:00: -1
# Current position delta: -0.9733754460275228
# Elapsed: 0.9924783706665039
# 		Run on 2014-10-10 11:10:00
# Ichi regime at 2014-10-10 11:10:00: -1
# Current position delta: -0.9514908290636834
# Elapsed: 1.021594762802124
# 		Run on 2014-10-11 11:10:00
# Ichi regime at 2014-10-11 11:10:00: -1
# Current position delta: -0.9654356804643724
# Elapsed: 0.9686474800109863
# 		Run on 2014-10-12 11:10:00
# Ichi regime at 2014-10-12 11:10:00: -1
# Current position delta: -0.9820596862582023
# Elapsed: 0.9325888156890869
# 		Run on 2014-10-13 11:10:00
# Ichi regime at 2014-10-13 11:10:00: -1
# Current position delta: -0.9938918849481401
# Elapsed: 0.9430131912231445
# 		Run on 2014-10-14 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-10-14 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEZ148300 x 1.0 Price: 2.3916001835812466 Delta: 0.4680600382625598
# Leg:  / P.US.CLEZ148300 x 1.0 Price: 3.2820398835087445 Delta: -0.5312686157260966
# Transactions delta: -0.06320857746353681
# Elapsed: 1.5688047409057617
# 		Run on 2014-10-15 11:10:00
# Ichi regime at 2014-10-15 11:10:00: -1
# Current position delta: -0.2224384289156991
# Elapsed: 1.2817208766937256
# 		Run on 2014-10-16 11:10:00
# Ichi regime at 2014-10-16 11:10:00: -1
# Current position delta: -0.0516220183799323
# Elapsed: 0.9937970638275146
# 		Run on 2014-10-17 11:10:00
# Ichi regime at 2014-10-17 11:10:00: -1
# Current position delta: -0.07450019290795468
# Elapsed: 1.006711483001709
# 		Run on 2014-10-18 11:10:00
# Ichi regime at 2014-10-18 11:10:00: -1
# Current position delta: -0.05988118534425313
# Elapsed: 0.975919246673584
# 		Run on 2014-10-19 11:10:00
# Ichi regime at 2014-10-19 11:10:00: -1
# Current position delta: -0.06202227865952087
# Elapsed: 0.9476933479309082
# 		Run on 2014-10-20 11:10:00
# Ichi regime at 2014-10-20 11:10:00: -1
# Current position delta: -0.10538168644311036
# Elapsed: 0.9832003116607666
# 		Run on 2014-10-21 11:10:00
# Ichi regime at 2014-10-21 11:10:00: -1
# Current position delta: -0.10705606666370077
# Elapsed: 1.0133063793182373
# 		Run on 2014-10-22 11:10:00
# Ichi regime at 2014-10-22 11:10:00: -1
# Current position delta: -0.23954284710723467
# Elapsed: 0.9687747955322266
# 		Run on 2014-10-23 11:10:00
# Ichi regime at 2014-10-23 11:10:00: -1
# Current position delta: -0.15269963682710402
# Elapsed: 0.9668364524841309
# 		Run on 2014-10-24 11:10:00
# Ichi regime at 2014-10-24 11:10:00: -1
# Current position delta: -0.2662580668666164
# Elapsed: 0.9888825416564941
# 		Run on 2014-10-25 11:10:00
# Ichi regime at 2014-10-25 11:10:00: -1
# Current position delta: -0.2104424529438842
# Elapsed: 0.985053539276123
# 		Run on 2014-10-26 11:10:00
# Ichi regime at 2014-10-26 11:10:00: -1
# Current position delta: -0.21629874411344374
# Elapsed: 0.9401319026947021
# 		Run on 2014-10-27 11:10:00
# Ichi regime at 2014-10-27 11:10:00: -1
# Current position delta: -0.3206209957203135
# Elapsed: 0.969588041305542
# 		Run on 2014-10-28 11:10:00
# Ichi regime at 2014-10-28 11:10:00: -1
# Current position delta: -0.23527641471012645
# Elapsed: 0.9882345199584961
# 		Run on 2014-10-29 11:10:00
# Ichi regime at 2014-10-29 11:10:00: -1
# Current position delta: -0.12893679838794414
# Elapsed: 0.9865868091583252
# 		Run on 2014-10-30 11:10:00
# Ichi regime at 2014-10-30 11:10:00: -1
# Current position delta: -0.2614336809008021
# Elapsed: 0.9850633144378662
# 		Run on 2014-10-31 11:10:00
# Ichi regime at 2014-10-31 11:10:00: -1
# Current position delta: -0.4439036093636192
# Elapsed: 0.9821438789367676
# 		Run on 2014-11-01 11:10:00
# Ichi regime at 2014-11-01 11:10:00: -1
# Current position delta: -0.3847959695718909
# Elapsed: 0.9965763092041016
# 		Run on 2014-11-02 11:10:00
# Ichi regime at 2014-11-02 11:10:00: -1
# Current position delta: -0.3976193507543821
# Elapsed: 0.9497132301330566
# 		Run on 2014-11-03 11:10:00
# Ichi regime at 2014-11-03 11:10:00: -1
# Current position delta: -0.5329492747338269
# Elapsed: 0.9487311840057373
# 		Run on 2014-11-04 11:10:00
# Ichi regime at 2014-11-04 11:10:00: -1
# Current position delta: -0.8527403134893006
# Elapsed: 0.9931609630584717
# 		Run on 2014-11-05 11:10:00
# Ichi regime at 2014-11-05 11:10:00: -1
# Current position delta: -0.7055091029731542
# Elapsed: 0.9981136322021484
# 		Run on 2014-11-06 11:10:00
# Ichi regime at 2014-11-06 11:10:00: -1
# Current position delta: -0.8265380530240702
# Elapsed: 1.0591514110565186
# 		Run on 2014-11-07 11:10:00
# Ichi regime at 2014-11-07 11:10:00: -1
# Current position delta: -0.7859338062427834
# Elapsed: 0.9845960140228271
# 		Run on 2014-11-08 11:10:00
# Ichi regime at 2014-11-08 11:10:00: -1
# Current position delta: -0.8165483642039137
# Elapsed: 0.9816107749938965
# 		Run on 2014-11-09 11:10:00
# Ichi regime at 2014-11-09 11:10:00: -1
# Current position delta: -0.8424982520247609
# Elapsed: 0.9414770603179932
# 		Run on 2014-11-10 11:10:00
# Ichi regime at 2014-11-10 11:10:00: -1
# Current position delta: -0.9337814283990548
# Elapsed: 0.9535858631134033
# 		Run on 2014-11-11 11:10:00
# Ichi regime at 2014-11-11 11:10:00: -1
# Current position delta: -0.8866352834756376
# Elapsed: 1.0242469310760498
# 		Run on 2014-11-12 11:10:00
# Ichi regime at 2014-11-12 11:10:00: -1
# Current position delta: -0.951823605344774
# Elapsed: 1.0038042068481445
# 		Run on 2014-11-13 11:10:00
# Ichi regime at 2014-11-13 11:10:00: -1
# Current position delta: -0.9931211437199357
# Elapsed: 1.0087745189666748
# 		Run on 2014-11-14 11:10:00
# Ichi regime at 2014-11-14 11:10:00: -1
# Current position delta: -0.9696825027201035
# Elapsed: 0.9990272521972656
# 		Run on 2014-11-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-11-15 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEF157700 x 1.0 Price: 2.1432565926601796 Delta: 0.45327795860762454
# Leg:  / P.US.CLEF157700 x 1.0 Price: 3.2235183626938735 Delta: -0.5462294834264465
# Transactions delta: -0.09295152481882196
# Elapsed: 1.5889980792999268
# 		Run on 2014-11-16 11:10:00
# Ichi regime at 2014-11-16 11:10:00: -1
# Current position delta: -0.09567048004889056
# Elapsed: 1.1182522773742676
# 		Run on 2014-11-17 11:10:00
# Ichi regime at 2014-11-17 11:10:00: -1
# Current position delta: -0.16532403897681247
# Elapsed: 0.9730877876281738
# 		Run on 2014-11-18 11:10:00
# Ichi regime at 2014-11-18 11:10:00: -1
# Current position delta: -0.2505517803485305
# Elapsed: 0.9586169719696045
# 		Run on 2014-11-19 11:10:00
# Ichi regime at 2014-11-19 11:10:00: -1
# Current position delta: -0.22688401411582765
# Elapsed: 1.0300731658935547
# 		Run on 2014-11-20 11:10:00
# Ichi regime at 2014-11-20 11:10:00: -1
# Current position delta: -0.13334851862437008
# Elapsed: 0.9970436096191406
# 		Run on 2014-11-21 11:10:00
# Ichi regime at 2014-11-21 11:10:00: -1
# Current position delta: -0.08159527881646433
# Elapsed: 0.9834549427032471
# 		Run on 2014-11-22 11:10:00
# Ichi regime at 2014-11-22 11:10:00: -1
# Current position delta: 0.0007424028329092724
# Elapsed: 1.008204698562622
# 		Run on 2014-11-23 11:10:00
# Ichi regime at 2014-11-23 11:10:00: -1
# Current position delta: -0.0007382496572402863
# Elapsed: 0.9823555946350098
# 		Run on 2014-11-24 11:10:00
# Ichi regime at 2014-11-24 11:10:00: -1
# Current position delta: -0.11057272005381369
# Elapsed: 0.9734129905700684
# 		Run on 2014-11-25 11:10:00
# Ichi regime at 2014-11-25 11:10:00: -1
# Current position delta: -0.2944688758348822
# Elapsed: 0.9871606826782227
# 		Run on 2014-11-26 11:10:00
# Ichi regime at 2014-11-26 11:10:00: -1
# Current position delta: -0.3658210010488513
# Elapsed: 0.9879021644592285
# 		Run on 2014-11-27 11:10:00
# Ichi regime at 2014-11-27 11:10:00: -1
# Current position delta: -0.8251053579676833
# Elapsed: 0.9885468482971191
# 		Run on 2014-11-28 11:10:00
# Ichi regime at 2014-11-28 11:10:00: -1
# Current position delta: -0.9477145199711342
# Elapsed: 0.9853975772857666
# 		Run on 2014-11-29 11:10:00
# Ichi regime at 2014-11-29 11:10:00: -1
# Current position delta: -0.9293243422121141
# Elapsed: 0.9700019359588623
# 		Run on 2014-11-30 11:10:00
# Ichi regime at 2014-11-30 11:10:00: -1
# Current position delta: -0.9379275985575164
# Elapsed: 0.9316658973693848
# 		Run on 2014-12-01 11:10:00
# Ichi regime at 2014-12-01 11:10:00: -1
# Current position delta: -0.845362004326195
# Elapsed: 0.9436805248260498
# 		Run on 2014-12-02 11:10:00
# Ichi regime at 2014-12-02 11:10:00: -1
# Current position delta: -0.9376757274970448
# Elapsed: 0.9787297248840332
# 		Run on 2014-12-03 11:10:00
# Ichi regime at 2014-12-03 11:10:00: -1
# Current position delta: -0.9063681212332981
# Elapsed: 0.9857311248779297
# 		Run on 2014-12-04 11:10:00
# Ichi regime at 2014-12-04 11:10:00: -1
# Current position delta: -0.9452135782973592
# Elapsed: 0.9973833560943604
# 		Run on 2014-12-05 11:10:00
# Ichi regime at 2014-12-05 11:10:00: -1
# Current position delta: -0.9683718782865717
# Elapsed: 0.9838218688964844
# 		Run on 2014-12-06 11:10:00
# Ichi regime at 2014-12-06 11:10:00: -1
# Current position delta: -0.9739205108777759
# Elapsed: 1.000847339630127
# 		Run on 2014-12-07 11:10:00
# Ichi regime at 2014-12-07 11:10:00: -1
# Current position delta: -0.9811814864359509
# Elapsed: 0.948279619216919
# 		Run on 2014-12-08 11:10:00
# Ichi regime at 2014-12-08 11:10:00: -1
# Current position delta: -0.9984456888720483
# Elapsed: 0.9718985557556152
# 		Run on 2014-12-09 11:10:00
# Ichi regime at 2014-12-09 11:10:00: -1
# Current position delta: -0.9816309908030335
# Elapsed: 1.0135960578918457
# 		Run on 2014-12-10 11:10:00
# Ichi regime at 2014-12-10 11:10:00: -1
# Current position delta: -0.9980717248333993
# Elapsed: 0.9892604351043701
# 		Run on 2014-12-11 11:10:00
# Ichi regime at 2014-12-11 11:10:00: -1
# Current position delta: -0.995875521360456
# Elapsed: 1.0582423210144043
# 		Run on 2014-12-12 11:10:00
# Ichi regime at 2014-12-12 11:10:00: -1
# Current position delta: -0.9985496459796241
# Elapsed: 1.016099452972412
# 		Run on 2014-12-13 11:10:00
# Ichi regime at 2014-12-13 11:10:00: -1
# Current position delta: -0.9985492376016321
# Elapsed: 1.0034153461456299
# 		Run on 2014-12-14 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-12-14 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEG155850 x 1.0 Price: 2.44845340637551 Delta: 0.4822344180603867
# Leg:  / P.US.CLEG155850 x 1.0 Price: 3.198773061564488 Delta: -0.5174739541279473
# Transactions delta: -0.035239536067560584
# Elapsed: 1.5206046104431152
# 		Run on 2014-12-15 11:10:00
# Ichi regime at 2014-12-15 11:10:00: -1
# Current position delta: -0.1811449673972651
# Elapsed: 1.1403393745422363
# 		Run on 2014-12-16 11:10:00
# Ichi regime at 2014-12-16 11:10:00: -1
# Current position delta: -0.146482516896502
# Elapsed: 0.9768373966217041
# 		Run on 2014-12-17 11:10:00
# Ichi regime at 2014-12-17 11:10:00: -1
# Current position delta: -0.04366179572961315
# Elapsed: 1.0111219882965088
# 		Run on 2014-12-18 11:10:00
# Ichi regime at 2014-12-18 11:10:00: -1
# Current position delta: -0.3302025502507947
# Elapsed: 0.9988150596618652
# 		Run on 2014-12-19 11:10:00
# Ichi regime at 2014-12-19 11:10:00: -1
# Current position delta: -0.13370964203321517
# Elapsed: 0.9718470573425293
# 		Run on 2014-12-20 11:10:00
# Ichi regime at 2014-12-20 11:10:00: -1
# Current position delta: -0.020532413413830886
# Elapsed: 0.9970982074737549
# 		Run on 2014-12-21 11:10:00
# Ichi regime at 2014-12-21 11:10:00: -1
# Current position delta: -0.023179268107941797
# Elapsed: 0.9356062412261963
# 		Run on 2014-12-22 11:10:00
# Ichi regime at 2014-12-22 11:10:00: -1
# Current position delta: -0.26813991420908945
# Elapsed: 0.9450082778930664
# 		Run on 2014-12-23 11:10:00
# Ichi regime at 2014-12-23 11:10:00: -1
# Current position delta: -0.1524378950620085
# Elapsed: 1.005953311920166
# 		Run on 2014-12-24 11:10:00
# Ichi regime at 2014-12-24 11:10:00: -1
# Current position delta: -0.2625684223598569
# Elapsed: 0.9835600852966309
# 		Run on 2014-12-25 11:10:00
# Ichi regime at 2014-12-25 11:10:00: -1
# Current position delta: -0.26393656908307866
# Elapsed: 0.9824573993682861
# 		Run on 2014-12-26 11:10:00
# Ichi regime at 2014-12-26 11:10:00: -1
# Current position delta: -0.4062243900443033
# Elapsed: 0.9992766380310059
# 		Run on 2014-12-27 11:10:00
# Ichi regime at 2014-12-27 11:10:00: -1
# Current position delta: -0.3686873949726784
# Elapsed: 0.9829142093658447
# 		Run on 2014-12-28 11:10:00
# Ichi regime at 2014-12-28 11:10:00: -1
# Current position delta: -0.38082449605489793
# Elapsed: 0.9349000453948975
# 		Run on 2014-12-29 11:10:00
# Ichi regime at 2014-12-29 11:10:00: -1
# Current position delta: -0.5992189674435696
# Elapsed: 0.970062255859375
# 		Run on 2014-12-30 11:10:00
# Ichi regime at 2014-12-30 11:10:00: -1
# Current position delta: -0.5702278557328164
# Elapsed: 1.0051116943359375
# 		Run on 2014-12-31 11:10:00
# Ichi regime at 2014-12-31 11:10:00: -1
# Current position delta: -0.7269569229872117
# Elapsed: 0.9984755516052246
# 		Run on 2015-01-01 11:10:00
# Ichi regime at 2015-01-01 11:10:00: -1
# Current position delta: -0.6642964421742701
# Elapsed: 0.9864704608917236
# 		Run on 2015-01-02 11:10:00
# Ichi regime at 2015-01-02 11:10:00: -1
# Current position delta: -0.794557601453123
# Elapsed: 0.9540939331054688
# 		Run on 2015-01-03 11:10:00
# Ichi regime at 2015-01-03 11:10:00: -1
# Current position delta: -0.73717322566939
# Elapsed: 0.985623836517334
# 		Run on 2015-01-04 11:10:00
# Ichi regime at 2015-01-04 11:10:00: -1
# Current position delta: -0.7614699942776907
# Elapsed: 0.942385196685791
# 		Run on 2015-01-05 11:10:00
# Ichi regime at 2015-01-05 11:10:00: -1
# Current position delta: -0.9284946493446312
# Elapsed: 0.9818134307861328
# 		Run on 2015-01-06 11:10:00
# Ichi regime at 2015-01-06 11:10:00: -1
# Current position delta: -0.9775280460311581
# Elapsed: 0.9735374450683594
# 		Run on 2015-01-07 11:10:00
# Ichi regime at 2015-01-07 11:10:00: -1
# Current position delta: -0.9579341086520428
# Elapsed: 0.9986183643341064
# 		Run on 2015-01-08 11:10:00
# Ichi regime at 2015-01-08 11:10:00: -1
# Current position delta: -0.9862377624904075
# Elapsed: 0.992335319519043
# 		Run on 2015-01-09 11:10:00
# Ichi regime at 2015-01-09 11:10:00: -1
# Current position delta: -0.9852022560075442
# Elapsed: 1.0305757522583008
# 		Run on 2015-01-10 11:10:00
# Ichi regime at 2015-01-10 11:10:00: -1
# Current position delta: -0.99309632077863
# Elapsed: 1.0203375816345215
# 		Run on 2015-01-11 11:10:00
# Ichi regime at 2015-01-11 11:10:00: -1
# Current position delta: -0.9982467165104094
# Elapsed: 0.9301884174346924
# 		Run on 2015-01-12 11:10:00
# Rollover occured, new series used
# Ichi regime at 2015-01-12 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEH154800 x 1.0 Price: 2.2979828679308127 Delta: 0.4736520699702784
# Leg:  / P.US.CLEH154800 x 1.0 Price: 3.2681948139629107 Delta: -0.5259399190430758
# Transactions delta: -0.05228784907279738
# Elapsed: 1.5512163639068604
# 		Run on 2015-01-13 11:10:00
# Ichi regime at 2015-01-13 11:10:00: -1
# Current position delta: -0.1837811691519341
# Elapsed: 1.195647954940796
# 		Run on 2015-01-14 11:10:00
# Ichi regime at 2015-01-14 11:10:00: -1
# Current position delta: -0.030335492764638483
# Elapsed: 0.9777820110321045
# 		Run on 2015-01-15 11:10:00
# Ichi regime at 2015-01-15 11:10:00: -1
# Current position delta: 0.01987486392865656
# Elapsed: 1.0094707012176514
# 		Run on 2015-01-16 11:10:00
# Ichi regime at 2015-01-16 11:10:00: -1
# Current position delta: 0.091005024076098
# Elapsed: 0.9997797012329102
# 		Run on 2015-01-17 11:10:00
# Ichi regime at 2015-01-17 11:10:00: -1
# Current position delta: 0.15800612077415271
# Elapsed: 1.0627551078796387
# 		Run on 2015-01-18 11:10:00
# Ichi regime at 2015-01-18 11:10:00: -1
# Current position delta: 0.1585232460068819
# Elapsed: 0.9391942024230957
# 		Run on 2015-01-19 11:10:00
# Ichi regime at 2015-01-19 11:10:00: -1
# Current position delta: 0.04996221934444223
# Elapsed: 1.0015313625335693
# 		Run on 2015-01-20 11:10:00
# Ichi regime at 2015-01-20 11:10:00: -1
# Current position delta: -0.058886726461643724
# Elapsed: 0.9754836559295654
# 		Run on 2015-01-21 11:10:00
# Ichi regime at 2015-01-21 11:10:00: -1
# Current position delta: -0.00793827160359245
# Elapsed: 0.9648151397705078
# 		Run on 2015-01-22 11:10:00
# Ichi regime at 2015-01-22 11:10:00: -1
# Current position delta: -0.19113928816421533
# Elapsed: 0.974449634552002
# 		Run on 2015-01-23 11:10:00
# Ichi regime at 2015-01-23 11:10:00: -1
# Current position delta: -0.21281635554480177
# Elapsed: 0.9892730712890625
# 		Run on 2015-01-24 11:10:00
# Ichi regime at 2015-01-24 11:10:00: -1
# Current position delta: -0.26898550610849786
# Elapsed: 0.9831914901733398
# 		Run on 2015-01-25 11:10:00
# Ichi regime at 2015-01-25 11:10:00: -1
# Current position delta: -0.27681397662469703
# Elapsed: 0.9461121559143066
# 		Run on 2015-01-26 11:10:00
# Ichi regime at 2015-01-26 11:10:00: -1
# Current position delta: -0.2727711206752564
# Elapsed: 0.9563367366790771
# 		Run on 2015-01-27 11:10:00
# Ichi regime at 2015-01-27 11:10:00: -1
# Current position delta: -0.19710361625227463
# Elapsed: 0.984046220779419
# 		Run on 2015-01-28 11:10:00
# Ichi regime at 2015-01-28 11:10:00: -1
# Current position delta: -0.4597759443005243
# Elapsed: 0.9784648418426514
# 		Run on 2015-01-29 11:10:00
# Ichi regime at 2015-01-29 11:10:00: -1
# Current position delta: -0.49736233933936747
# Elapsed: 0.9914565086364746
# 		Run on 2015-01-30 11:10:00
# Ichi regime at 2015-01-30 11:10:00: -1
# Current position delta: -0.14881045562698403
# Elapsed: 0.9834818840026855
# 		Run on 2015-01-31 11:10:00
# Ichi regime at 2015-01-31 11:10:00: -1
# Current position delta: 0.028722565113682985
# Elapsed: 0.9837422370910645
# 		Run on 2015-02-01 11:10:00
# Ichi regime at 2015-02-01 11:10:00: -1
# Current position delta: 0.026619528310554974
# Elapsed: 0.9309971332550049
# 		Run on 2015-02-02 11:10:00
# Ichi regime at 2015-02-02 11:10:00: -1
# Current position delta: 0.19560883946618834
# Elapsed: 0.9863507747650146
# 		Run on 2015-02-03 11:10:00
# Ichi regime at 2015-02-03 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEH155250 x 6.0 Price: 3.059045146856924 Delta: 3.625904134966464
# Leg:  / C.US.CLEH155500 x -6.0 Price: 1.8781640302886373 Delta: -2.6490526666270635
# Transactions delta: 0.9768514683394005
# Elapsed: 1.3270573616027832
# 		Run on 2015-02-04 11:10:00
# Ichi regime at 2015-02-04 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEH154950 x 1.0 Price: 1.9664225028169113 Delta: 0.46077841078424947
# Leg:  / P.US.CLEH154950 x 1.0 Price: 2.9470430899377966 Delta: -0.5390229617317683
# Transactions delta: -0.07824455094751886
# Elapsed: 1.3450424671173096
# 		Run on 2015-02-05 11:10:00
# Ichi regime at 2015-02-05 11:10:00: -1
# Current position delta: 0.16518956660008827
# Elapsed: 0.9874334335327148
# 		Run on 2015-02-06 11:10:00
# Ichi regime at 2015-02-06 11:10:00: -1
# Current position delta: 0.295801918540703
# Elapsed: 0.9962458610534668
# 		Run on 2015-02-07 11:10:00
# Ichi regime at 2015-02-07 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEH155150 x 6.0 Price: 2.485109127321003 Delta: 3.509546764741015
# Leg:  / C.US.CLEH155400 x -6.0 Price: 1.318716381439188 Delta: -2.3488756147217345
# Transactions delta: 1.1606711500192803
# Elapsed: 1.3189849853515625
# 		Run on 2015-02-08 11:10:00
# Ichi regime at 2015-02-08 11:10:00: 1
# Current position delta: 1.2215836618859761
# Elapsed: 0.9579637050628662
# 		Run on 2015-02-09 11:10:00
# Ichi regime at 2015-02-09 11:10:00: 1
# Current position delta: 1.2654330350402856
# Elapsed: 0.9565942287445068
# 		Run on 2015-02-10 11:10:00
# Ichi regime at 2015-02-10 11:10:00: 1
# Current position delta: 1.261903796370472
# Elapsed: 0.9925096035003662
# 		Run on 2015-02-11 11:10:00
# Ichi regime at 2015-02-11 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEH155000 x 1.0 Price: 1.0631451044771367 Delta: 0.41228817722060507
# Leg:  / P.US.CLEH155000 x 1.0 Price: 2.043216996207967 Delta: -0.5875225651658115
# Transactions delta: -0.1752343879452064
# Elapsed: 1.4044249057769775
# 		Run on 2015-02-12 11:10:00
# Ichi regime at 2015-02-12 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEH155000 x 6.0 Price: 1.9118751493966712 Delta: 3.822487724352157
# Leg:  / C.US.CLEH155250 x -6.0 Price: 0.708968027339477 Delta: -2.0451544220171893
# Transactions delta: 1.7773333023349678
# Elapsed: 1.3465015888214111
# 		Run on 2015-02-13 11:10:00
# Ichi regime at 2015-02-13 11:10:00: 1
# Current position delta: 1.9039869691919988
# Elapsed: 0.9817171096801758
# 		Run on 2015-02-14 11:10:00
# Ichi regime at 2015-02-14 11:10:00: 1
# Current position delta: 2.1056712654359364
# Elapsed: 0.9997045993804932
# 		Run on 2015-02-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2015-02-15 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEJ155250 x 6.0 Price: 3.7176903094265796 Delta: 3.480323154749508
# Leg:  / C.US.CLEJ155500 x -6.0 Price: 2.4888155456194383 Delta: -2.729842764008509
# Transactions delta: 0.7504803907409991
# Elapsed: 1.5172557830810547
# 		Run on 2015-02-16 11:10:00
# Ichi regime at 2015-02-16 11:10:00: 1
# Current position delta: 0.7624946613989287
# Elapsed: 1.1445722579956055
# 		Run on 2015-02-17 11:10:00
# Ichi regime at 2015-02-17 11:10:00: 1
# Current position delta: 0.728894719181258
# Elapsed: 0.9659273624420166
# 		Run on 2015-02-18 11:10:00
# Ichi regime at 2015-02-18 11:10:00: 1
# Current position delta: 0.8016388254275628
# Elapsed: 0.9891989231109619
# 		Run on 2015-02-19 11:10:00
# Ichi regime at 2015-02-19 11:10:00: 1
# Current position delta: 0.8685019426563843
# Elapsed: 0.9590778350830078
# 		Run on 2015-02-20 11:10:00
# Ichi regime at 2015-02-20 11:10:00: 1
# Current position delta: 0.8419249228132091
# Elapsed: 0.9687080383300781
# 		Run on 2015-02-21 11:10:00
# Ichi regime at 2015-02-21 11:10:00: 1
# Current position delta: 0.8435449019525372
# Elapsed: 1.0046043395996094
# 		Run on 2015-02-22 11:10:00
# Ichi regime at 2015-02-22 11:10:00: 1
# Current position delta: 0.8576253457876044
# Elapsed: 0.9484789371490479
# 		Run on 2015-02-23 11:10:00
# Ichi regime at 2015-02-23 11:10:00: 1
# Current position delta: 0.7857381194207897
# Elapsed: 0.963348388671875
# 		Run on 2015-02-24 11:10:00
# Ichi regime at 2015-02-24 11:10:00: 1
# Current position delta: 0.7502720093096402
# Elapsed: 1.0030064582824707
# 		Run on 2015-02-25 11:10:00
# Ichi regime at 2015-02-25 11:10:00: 1
# Current position delta: 0.8506260874303009
# Elapsed: 0.9898738861083984
# 		Run on 2015-02-26 11:10:00
# Ichi regime at 2015-02-26 11:10:00: 1
# Current position delta: 0.6971483392428656
# Elapsed: 1.0002756118774414
# 		Run on 2015-02-27 11:10:00
# Ichi regime at 2015-02-27 11:10:00: 1
# Current position delta: 0.7740353388421335
# Elapsed: 0.9790999889373779
# 		Run on 2015-02-28 11:10:00
# Ichi regime at 2015-02-28 11:10:00: 1
# Current position delta: 0.8385298441725961
# Elapsed: 0.9955470561981201
# 		Run on 2015-03-01 11:10:00
# Ichi regime at 2015-03-01 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEJ155050 x 1.0 Price: 1.7564476125895823 Delta: 0.45208360627782945
# Leg:  / P.US.CLEJ155050 x 1.0 Price: 2.7367003448529204 Delta: -0.5476591304343792
# Transactions delta: -0.09557552415654974
# Elapsed: 1.3297197818756104
# 		Run on 2015-03-02 11:10:00
# Ichi regime at 2015-03-02 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEJ154850 x 6.0 Price: 2.866676239546159 Delta: 3.6471959772227014
# Leg:  / C.US.CLEJ155100 x -6.0 Price: 1.5454791900049507 Delta: -2.5497547178858997
# Transactions delta: 1.0974412593368017
# Elapsed: 1.3096506595611572
# 		Run on 2015-03-03 11:10:00
# Ichi regime at 2015-03-03 11:10:00: 1
# Current position delta: 1.1363909492396176
# Elapsed: 0.9905028343200684
# 		Run on 2015-03-04 11:10:00
# Ichi regime at 2015-03-04 11:10:00: 1
# Current position delta: 1.0363457083449448
# Elapsed: 0.9810526371002197
# 		Run on 2015-03-05 11:10:00
# Ichi regime at 2015-03-05 11:10:00: 1
# Current position delta: 1.2292727425901777
# Elapsed: 0.9588890075683594
# 		Run on 2015-03-06 11:10:00
# Ichi regime at 2015-03-06 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEJ155050 x 1.0 Price: 1.0279308839717949 Delta: 0.4037012661315343
# Leg:  / P.US.CLEJ155050 x 1.0 Price: 2.0878869200011785 Delta: -0.5959570493572609
# Transactions delta: -0.19225578322572662
# Elapsed: 1.316002368927002
# 		Run on 2015-03-07 11:10:00
# Ichi regime at 2015-03-07 11:10:00: -1
# Current position delta: -0.13470007023141978
# Elapsed: 0.9999356269836426
# 		Run on 2015-03-08 11:10:00
# Ichi regime at 2015-03-08 11:10:00: -1
# Current position delta: -0.14488662932913082
# Elapsed: 0.9564757347106934
# 		Run on 2015-03-09 11:10:00
# Ichi regime at 2015-03-09 11:10:00: -1
# Current position delta: -0.10874488722409847
# Elapsed: 0.9610283374786377
# 		Run on 2015-03-10 11:10:00
# Ichi regime at 2015-03-10 11:10:00: -1
# Current position delta: -0.4503132841631178
# Elapsed: 0.9696340560913086
# 		Run on 2015-03-11 11:10:00
# Ichi regime at 2015-03-11 11:10:00: -1
# Current position delta: -0.5470724126838049
# Elapsed: 0.9732725620269775
# 		Run on 2015-03-12 11:10:00
# Ichi regime at 2015-03-12 11:10:00: -1
# Current position delta: -0.8338970383946618
# Elapsed: 0.9936637878417969
# 		Run on 2015-03-13 11:10:00
# Ichi regime at 2015-03-13 11:10:00: -1
# Current position delta: -0.98427574085257
# Elapsed: 0.9995589256286621
# 		Run on 2015-03-14 11:10:00
# Ichi regime at 2015-03-14 11:10:00: -1
# Current position delta: -0.9868969857639369
# Elapsed: 0.9562361240386963
# 		Run on 2015-03-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2015-03-15 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEK154850 x 1.0 Price: 2.2839428552690606 Delta: 0.46314206479607656
# Leg:  / P.US.CLEK154850 x 1.0 Price: 3.4844255475930055 Delta: -0.5364489145129366
# Transactions delta: -0.07330684971686008
# Elapsed: 1.5485711097717285
# 		Run on 2015-03-16 11:10:00
# Ichi regime at 2015-03-16 11:10:00: -1
# Current position delta: -0.26347928155286543
# Elapsed: 1.1551947593688965
# 		Run on 2015-03-17 11:10:00
# Ichi regime at 2015-03-17 11:10:00: -1
# Current position delta: -0.3154027393447177
# Elapsed: 0.9991278648376465
# 		Run on 2015-03-18 11:10:00
# Ichi regime at 2015-03-18 11:10:00: -1
# Current position delta: -0.3695665486293843
# Elapsed: 0.9996664524078369
# 		Run on 2015-03-19 11:10:00
# Ichi regime at 2015-03-19 11:10:00: -1
# Current position delta: -0.3145893000298792
# Elapsed: 0.979989767074585
# 		Run on 2015-03-20 11:10:00
# Ichi regime at 2015-03-20 11:10:00: -1
# Current position delta: -0.20784680681827128
# Elapsed: 1.0009465217590332
# 		Run on 2015-03-21 11:10:00
# Ichi regime at 2015-03-21 11:10:00: -1
# Current position delta: -0.22939839775459442
# Elapsed: 1.0560755729675293
# 		Run on 2015-03-22 11:10:00
# Ichi regime at 2015-03-22 11:10:00: -1
# Current position delta: -0.23569534051470642
# Elapsed: 0.93984055519104
# 		Run on 2015-03-23 11:10:00
# Ichi regime at 2015-03-23 11:10:00: -1
# Current position delta: -0.21705788626710693
# Elapsed: 0.9532654285430908
# 		Run on 2015-03-24 11:10:00
# Ichi regime at 2015-03-24 11:10:00: -1
# Current position delta: -0.057725803250608776
# Elapsed: 0.9961507320404053
# 		Run on 2015-03-25 11:10:00
# Ichi regime at 2015-03-25 11:10:00: -1
# Current position delta: 0.17898419875999783
# Elapsed: 0.9829165935516357
# 		Run on 2015-03-26 11:10:00
# Ichi regime at 2015-03-26 11:10:00: -1
# Current position delta: 0.44656937611486824
# Elapsed: 0.9840762615203857
# 		Run on 2015-03-27 11:10:00
# Ichi regime at 2015-03-27 11:10:00: -1
# Current position delta: 0.21419731887167998
# Elapsed: 0.9988338947296143
# 		Run on 2015-03-28 11:10:00
# Ichi regime at 2015-03-28 11:10:00: -1
# Current position delta: 0.03463886628043911
# Elapsed: 0.9827024936676025
# 		Run on 2015-03-29 11:10:00
# Ichi regime at 2015-03-29 11:10:00: -1
# Current position delta: 0.03314930647947284
# Elapsed: 0.9493622779846191
# 		Run on 2015-03-30 11:10:00
# Ichi regime at 2015-03-30 11:10:00: -1
# Current position delta: -0.052770314847310096
# Elapsed: 0.949444055557251
# 		Run on 2015-03-31 11:10:00
# Ichi regime at 2015-03-31 11:10:00: -1
# Current position delta: 0.01588927950355251
# Elapsed: 0.9627974033355713
# 		Run on 2015-04-01 11:10:00
# Ichi regime at 2015-04-01 11:10:00: -1
# Current position delta: 0.2783059008856773
# Elapsed: 1.009810209274292
# 		Run on 2015-04-02 11:10:00
# Ichi regime at 2015-04-02 11:10:00: -1
# Current position delta: 0.09165656735131888
# Elapsed: 0.9979958534240723
# 		Run on 2015-04-03 11:10:00
# Ichi regime at 2015-04-03 11:10:00: -1
# Current position delta: 0.21580059374415866
# Elapsed: 1.0005128383636475
# 		Run on 2015-04-04 11:10:00
# Ichi regime at 2015-04-04 11:10:00: -1
# Current position delta: 0.21609600190321937
# Elapsed: 0.9827413558959961
# 		Run on 2015-04-05 11:10:00
# Ichi regime at 2015-04-05 11:10:00: -1
# Current position delta: 0.22221448008319422
# Elapsed: 0.9310412406921387
# 		Run on 2015-04-06 11:10:00
# Ichi regime at 2015-04-06 11:10:00: -1
# Current position delta: 0.6113139402564133
# Elapsed: 0.9452447891235352
# 		Run on 2015-04-07 11:10:00
# Ichi regime at 2015-04-07 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEK155250 x 6.0 Price: 2.139993962971179 Delta: 3.661260082109548
# Leg:  / C.US.CLEK155500 x -6.0 Price: 0.925509004374284 Delta: -2.177236753255537
# Transactions delta: 1.4840233288540112
# Elapsed: 1.3781449794769287
# 		Run on 2015-04-08 11:10:00
# Ichi regime at 2015-04-08 11:10:00: 1
# Current position delta: 1.3214882588658563
# Elapsed: 0.9838466644287109
# 		Run on 2015-04-09 11:10:00
# Ichi regime at 2015-04-09 11:10:00: 1
# Current position delta: 1.2925802651285612
# Elapsed: 0.9769744873046875
# 		Run on 2015-04-10 11:10:00
# Ichi regime at 2015-04-10 11:10:00: 1
# Current position delta: 1.4638541212768554
# Elapsed: 0.993161678314209
# 		Run on 2015-04-11 11:10:00
# Ichi regime at 2015-04-11 11:10:00: 1
# Current position delta: 1.7623036023687788
# Elapsed: 0.9622223377227783
# 		Run on 2015-04-12 11:10:00
# Ichi regime at 2015-04-12 11:10:00: 1
# Current position delta: 1.8201046831756829
# Elapsed: 0.938607931137085
# 		Run on 2015-04-13 11:10:00
# Ichi regime at 2015-04-13 11:10:00: 1
# Current position delta: 2.1033810716143595
# Elapsed: 0.9776201248168945
# 		Run on 2015-04-14 11:10:00
# Rollover occured, new series used
# ...
# Elapsed: 0.8282251358032227
# 		Run on 2016-07-30 10:55:00
# Ichi regime at 2016-07-30 10:55:00: -1
# Current position delta: -0.2219916139408663
# Elapsed: 0.8267881870269775
# 		Run on 2016-07-31 10:55:00
# Ichi regime at 2016-07-31 10:55:00: -1
# Current position delta: -0.22747966555638627
# Elapsed: 0.7981703281402588
# 		Run on 2016-08-01 10:55:00
# Ichi regime at 2016-08-01 10:55:00: -1
# Current position delta: -0.1969552420715398
# Elapsed: 0.8794474601745605
# 		Run on 2016-08-02 10:55:00
# Ichi regime at 2016-08-02 10:55:00: -1
# Current position delta: -0.409372604306017
# Elapsed: 0.8399274349212646
# 		Run on 2016-08-03 10:55:00
# Ichi regime at 2016-08-03 10:55:00: -1
# Current position delta: -0.1880274034862469
# Elapsed: 0.8213012218475342
# 		Run on 2016-08-04 10:55:00
# Ichi regime at 2016-08-04 10:55:00: -1
# Current position delta: -0.3690880249868478
# Elapsed: 0.847510814666748
# 		Run on 2016-08-05 10:55:00
# Ichi regime at 2016-08-05 10:55:00: -1
# Current position delta: -0.11374237166496681
# Elapsed: 0.8354485034942627
# 		Run on 2016-08-06 10:55:00
# Ichi regime at 2016-08-06 10:55:00: -1
# Current position delta: -0.05532527029192774
# Elapsed: 0.8258230686187744
# 		Run on 2016-08-07 10:55:00
# Ichi regime at 2016-08-07 10:55:00: -1
# Current position delta: -0.05853463644148327
# Elapsed: 0.819408655166626
# 		Run on 2016-08-08 10:55:00
# Ichi regime at 2016-08-08 10:55:00: -1
# Current position delta: -0.04838176650125414
# Elapsed: 0.8399384021759033
# 		Run on 2016-08-09 10:55:00
# Ichi regime at 2016-08-09 10:55:00: -1
# Current position delta: -0.023110425007970004
# Elapsed: 0.8395683765411377
# 		Run on 2016-08-10 10:55:00
# Ichi regime at 2016-08-10 10:55:00: -1
# Current position delta: 0.1162208423475054
# Elapsed: 0.839545488357544
# 		Run on 2016-08-11 10:55:00
# Ichi regime at 2016-08-11 10:55:00: -1
# Current position delta: -0.08466465312233934
# Elapsed: 0.8285517692565918
# 		Run on 2016-08-12 10:55:00
# Ichi regime at 2016-08-12 10:55:00: -1
# Current position delta: -0.013184918082925212
# Elapsed: 0.8626840114593506
# 		Run on 2016-08-13 10:55:00
# Ichi regime at 2016-08-13 10:55:00: -1
# Current position delta: 0.09876004810979855
# Elapsed: 0.8819398880004883
# 		Run on 2016-08-14 10:55:00
# Ichi regime at 2016-08-14 10:55:00: -1
# Current position delta: 0.10077326250176472
# Elapsed: 0.8091435432434082
# 		Run on 2016-08-15 10:55:00
# Ichi regime at 2016-08-15 10:55:00: -1
# Current position delta: 0.19143432876832384
# Elapsed: 0.8197541236877441
# 		Run on 2016-08-16 10:55:00
# Ichi regime at 2016-08-16 10:55:00: -1
# Current position delta: 0.2166628681963012
# Elapsed: 0.8173565864562988
# 		Run on 2016-08-17 10:55:00
# Ichi regime at 2016-08-17 10:55:00: -1
# Current position delta: 0.2548214142003741
# Elapsed: 0.8478684425354004
# 		Run on 2016-08-18 10:55:00
# Ichi regime at 2016-08-18 10:55:00: -1
# Current position delta: 0.3412123077081037
# Elapsed: 0.846137523651123
# 		Run on 2016-08-19 10:55:00
# Ichi regime at 2016-08-19 10:55:00: 1
# New bullish zone position
# Leg: bullish / C.US.ZWAU164200 x 6.0 Price: 12.711587811343122 Delta: 4.433322198038894
# Leg:  / C.US.ZWAU164450 x -6.0 Price: 2.5063253966827546 Delta: -1.3761807336055543
# Transactions delta: 3.05714146443334
# Elapsed: 1.1385693550109863
# 		Run on 2016-08-20 10:55:00
# Ichi regime at 2016-08-20 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZWAU164350 x 1.0 Price: 3.5409683082460504 Delta: 0.3244667098602449
# Leg:  / P.US.ZWAU164350 x 1.0 Price: 11.794389226240583 Delta: -0.6736542761845137
# Transactions delta: -0.3491875663242688
# Elapsed: 1.1686954498291016
# 		Run on 2016-08-21 10:55:00
# Ichi regime at 2016-08-21 10:55:00: 1
# New bullish zone position
# Leg: bullish / C.US.ZWAU164150 x 6.0 Price: 13.301265250139636 Delta: 4.850071384458456
# Leg:  / C.US.ZWAU164400 x -6.0 Price: 1.9078600367964356 Delta: -1.2814533894738773
# Transactions delta: 3.568617994984579
# Elapsed: 1.1252262592315674
# 		Run on 2016-08-22 10:55:00
# Ichi regime at 2016-08-22 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZWAU164250 x 1.0 Price: 2.0717148625086423 Delta: 0.2683889016089886
# Leg:  / P.US.ZWAU164250 x 1.0 Price: 10.324713804945077 Delta: -0.7294421216241668
# Transactions delta: -0.4610532200151782
# Elapsed: 1.1431100368499756
# 		Run on 2016-08-23 10:55:00
# Ichi regime at 2016-08-23 10:55:00: -1
# Current position delta: -0.779875945617557
# Elapsed: 0.9029123783111572
# 		Run on 2016-08-24 10:55:00
# Rollover occured, new series used
# Ichi regime at 2016-08-24 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZWAV164350 x 1.0 Price: 7.988476054178193 Delta: 0.39374856879575
# Leg:  / P.US.ZWAV164350 x 1.0 Price: 17.487357736063757 Delta: -0.6027681083650809
# Transactions delta: -0.2090195395693309
# Elapsed: 1.3573377132415771
# 		Run on 2016-08-25 10:55:00
# Ichi regime at 2016-08-25 10:55:00: -1
# Current position delta: -0.19764587146357343
# Elapsed: 1.0242841243743896
# 		Run on 2016-08-26 10:55:00
# Ichi regime at 2016-08-26 10:55:00: -1
# Current position delta: -0.6217521879363551
# Elapsed: 0.8251914978027344
# 		Run on 2016-08-27 10:55:00
# Ichi regime at 2016-08-27 10:55:00: -1
# Current position delta: -0.5810548807822559
# Elapsed: 0.905292272567749
# 		Run on 2016-08-28 10:55:00
# Ichi regime at 2016-08-28 10:55:00: -1
# Current position delta: -0.5908950405517076
# Elapsed: 0.7999837398529053
# 		Run on 2016-08-29 10:55:00
# Ichi regime at 2016-08-29 10:55:00: -1
# Current position delta: -0.7605048322074047
# Elapsed: 0.8188140392303467
# 		Run on 2016-08-30 10:55:00
# Ichi regime at 2016-08-30 10:55:00: -1
# Current position delta: -0.7426934257839353
# Elapsed: 0.8477470874786377
# 		Run on 2016-08-31 10:55:00
# Ichi regime at 2016-08-31 10:55:00: -1
# Current position delta: -0.7865474641949846
# Elapsed: 0.8295280933380127
# 		Run on 2016-09-01 10:55:00
# Ichi regime at 2016-09-01 10:55:00: -1
# Current position delta: -0.7494825748894612
# Elapsed: 0.84092116355896
# 		Run on 2016-09-02 10:55:00
# Ichi regime at 2016-09-02 10:55:00: -1
# Current position delta: -0.71368023280704
# Elapsed: 0.8397293090820312
# 		Run on 2016-09-03 10:55:00
# Ichi regime at 2016-09-03 10:55:00: -1
# Current position delta: -0.7415030674121492
# Elapsed: 0.8913111686706543
# 		Run on 2016-09-04 10:55:00
# Ichi regime at 2016-09-04 10:55:00: -1
# Current position delta: -0.7545614479658105
# Elapsed: 0.8278987407684326
# 		Run on 2016-09-05 10:55:00
# Ichi regime at 2016-09-05 10:55:00: -1
# Current position delta: -0.7681402247050803
# Elapsed: 0.8259260654449463
# 		Run on 2016-09-06 10:55:00
# Ichi regime at 2016-09-06 10:55:00: -1
# Current position delta: -0.7726298962582497
# Elapsed: 0.8530504703521729
# 		Run on 2016-09-07 10:55:00
# Ichi regime at 2016-09-07 10:55:00: -1
# Current position delta: -0.739723887854903
# Elapsed: 0.8332703113555908
# 		Run on 2016-09-08 10:55:00
# Ichi regime at 2016-09-08 10:55:00: -1
# Current position delta: -0.7313012614362275
# Elapsed: 0.860365629196167
# 		Run on 2016-09-09 10:55:00
# Ichi regime at 2016-09-09 10:55:00: -1
# Current position delta: -0.7933731867688786
# Elapsed: 0.8497235774993896
# 		Run on 2016-09-10 10:55:00
# Ichi regime at 2016-09-10 10:55:00: -1
# Current position delta: -0.8303229453639118
# Elapsed: 0.8446712493896484
# 		Run on 2016-09-11 10:55:00
# Ichi regime at 2016-09-11 10:55:00: -1
# Current position delta: -0.8478377316563006
# Elapsed: 0.8030805587768555
# 		Run on 2016-09-12 10:55:00
# Ichi regime at 2016-09-12 10:55:00: -1
# Current position delta: -0.7726349471469911
# Elapsed: 0.8327877521514893
# 		Run on 2016-09-13 10:55:00
# Ichi regime at 2016-09-13 10:55:00: -1
# Current position delta: -0.8830808644586391
# Elapsed: 0.8581352233886719
# 		Run on 2016-09-14 10:55:00
# Ichi regime at 2016-09-14 10:55:00: -1
# Current position delta: -0.8869593431581746
# Elapsed: 0.8345754146575928
# 		Run on 2016-09-15 10:55:00
# Ichi regime at 2016-09-15 10:55:00: -1
# Current position delta: -0.9035254158905821
# Elapsed: 0.8871035575866699
# 		Run on 2016-09-16 10:55:00
# Ichi regime at 2016-09-16 10:55:00: -1
# Current position delta: -0.8793648503959351
# Elapsed: 0.8278281688690186
# 		Run on 2016-09-17 10:55:00
# Ichi regime at 2016-09-17 10:55:00: -1
# Current position delta: -0.9167918700056452
# Elapsed: 0.8348398208618164
# 		Run on 2016-09-18 10:55:00
# Ichi regime at 2016-09-18 10:55:00: -1
# Current position delta: -0.942834065383069
# Elapsed: 0.8072893619537354
# 		Run on 2016-09-19 10:55:00
# Ichi regime at 2016-09-19 10:55:00: -1
# Current position delta: -0.9710708178858193
# Elapsed: 0.8399348258972168
# 		Run on 2016-09-20 10:55:00
# Ichi regime at 2016-09-20 10:55:00: -1
# Current position delta: -0.9445106313876033
# Elapsed: 0.8394992351531982
# 		Run on 2016-09-21 10:55:00
# Rollover occured, new series used
# Ichi regime at 2016-09-21 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZWAX164200 x 1.0 Price: 7.641414199968779 Delta: 0.37805977073134883
# Leg:  / P.US.ZWAX164200 x 1.0 Price: 18.660108221272935 Delta: -0.6176578339225045
# Transactions delta: -0.23959806319115567
# Elapsed: 1.1307859420776367
# 		Run on 2016-09-22 10:55:00
# Ichi regime at 2016-09-22 10:55:00: -1
# Current position delta: -0.35819771243181436
# Elapsed: 0.8747889995574951
# 		Run on 2016-09-23 10:55:00
# Ichi regime at 2016-09-23 10:55:00: -1
# Current position delta: -0.3868956430232868
# Elapsed: 0.8458850383758545
# 		Run on 2016-09-24 10:55:00
# Ichi regime at 2016-09-24 10:55:00: -1
# Current position delta: -0.4320590669210547
# Elapsed: 0.8197109699249268
# 		Run on 2016-09-25 10:55:00
# Ichi regime at 2016-09-25 10:55:00: -1
# Current position delta: -0.44049521932666036
# Elapsed: 0.8160052299499512
# 		Run on 2016-09-26 10:55:00
# Ichi regime at 2016-09-26 10:55:00: -1
# Current position delta: -0.6208509739809789
# Elapsed: 0.8275089263916016
# 		Run on 2016-09-27 10:55:00
# Ichi regime at 2016-09-27 10:55:00: -1
# Current position delta: -0.41891241920446226
# Elapsed: 0.9265646934509277
# 		Run on 2016-09-28 10:55:00
# Ichi regime at 2016-09-28 10:55:00: -1
# Current position delta: -0.45566690242621427
# Elapsed: 0.8272483348846436
# 		Run on 2016-09-29 10:55:00
# Ichi regime at 2016-09-29 10:55:00: -1
# Current position delta: -0.5510779860927949
# Elapsed: 0.8421766757965088
# 		Run on 2016-09-30 10:55:00
# Ichi regime at 2016-09-30 10:55:00: -1
# Current position delta: -0.5412668728629486
# Elapsed: 0.8479547500610352
# 		Run on 2016-10-01 10:55:00
# Ichi regime at 2016-10-01 10:55:00: -1
# Current position delta: -0.5019585101693408
# Elapsed: 0.82196044921875
# 		Run on 2016-10-02 10:55:00
# Ichi regime at 2016-10-02 10:55:00: -1
# Current position delta: -0.5143013449527185
# Elapsed: 0.8118772506713867
# 		Run on 2016-10-03 10:55:00
# Ichi regime at 2016-10-03 10:55:00: -1
# Current position delta: -0.6716872671087126
# Elapsed: 0.844743013381958
# 		Run on 2016-10-04 10:55:00
# Ichi regime at 2016-10-04 10:55:00: -1
# Current position delta: -0.6456603767806633
# Elapsed: 0.8880832195281982
# 		Run on 2016-10-05 10:55:00
# Ichi regime at 2016-10-05 10:55:00: -1
# Current position delta: -0.34626740963733066
# Elapsed: 0.8227198123931885
# 		Run on 2016-10-06 10:55:00
# Date not found at 2016-10-06
# Ichi regime at 2016-10-06 10:55:00: None
# Elapsed: 0.6733651161193848
# 		Run on 2016-10-07 10:55:00
# Ichi regime at 2016-10-07 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZWAX164050 x 1.0 Price: 4.233349087878793 Delta: 0.3259354840839386
# Leg:  / P.US.ZWAX164050 x 1.0 Price: 14.234712101803268 Delta: -0.670463560822093
# Transactions delta: -0.34452807673815444
# Elapsed: 0.5637915134429932
# 		Run on 2016-10-08 10:55:00
# Date not found at 2016-10-08
# Ichi regime at 2016-10-08 10:55:00: None
# Elapsed: 0.6779170036315918
# 		Run on 2016-10-09 10:55:00
# Date not found at 2016-10-09
# Ichi regime at 2016-10-09 10:55:00: None
# Current position delta: 0.0
# Elapsed: 0.18173599243164062
# 		Run on 2016-10-10 10:55:00
# Ichi regime at 2016-10-10 10:55:00: -1
# New bearish zone position
# Leg: bearish / C.US.ZWAX164100 x 1.0 Price: 4.480080503606047 Delta: 0.3580809523872113
# Leg:  / P.US.ZWAX164100 x 1.0 Price: 12.02161739790057 Delta: -0.6385389124604254
# Transactions delta: -0.28045796007321405
# Elapsed: 0.5178003311157227
# 		Run on 2016-10-11 10:55:00
# Ichi regime at 2016-10-11 10:55:00: -1
# Current position delta: -0.06340912260631149
# Elapsed: 0.9366800785064697
# 		Run on 2016-10-12 10:55:00
# Ichi regime at 2016-10-12 10:55:00: -1
# Current position delta: -0.3658545719355579
# Elapsed: 0.8415508270263672
# 		Run on 2016-10-13 10:55:00
# Date not found at 2016-10-13
# Ichi regime at 2016-10-13 10:55:00: None
# Elapsed: 0.7012324333190918
# 		Run on 2016-10-14 10:55:00
# Ichi regime at 2016-10-14 10:55:00: 1
# New bullish zone position
# Leg: bullish / C.US.ZWAX164150 x 6.0 Price: 13.040030957413535 Delta: 4.2467883414753
# Leg:  / C.US.ZWAX164400 x -6.0 Price: 3.0233410854428513 Delta: -1.4746760657436475
# Transactions delta: 2.7721122757316525
# Elapsed: 0.5298645496368408
# 		Run on 2016-10-15 10:55:00
# Date not found at 2016-10-15
# Ichi regime at 2016-10-15 10:55:00: None
# Elapsed: 0.662956714630127
# 		Run on 2016-10-16 10:55:00
# Ichi regime at 2016-10-16 10:55:00: 1
# New bullish zone position
# Leg: bullish / C.US.ZWAX164100 x 6.0 Price: 12.518407390546372 Delta: 4.634485345705707
# Leg:  / C.US.ZWAX164350 x -6.0 Price: 1.5619795694844498 Delta: -1.117039200205884
# Transactions delta: 3.5174461454998234
# Elapsed: 0.4959440231323242
# 		Run on 2016-10-17 10:55:00
# Ichi regime at 2016-10-17 10:55:00: 1
# Current position delta: 3.851857627266188
# Elapsed: 0.817497968673706
# 		Run on 2016-10-18 10:55:00
# Ichi regime at 2016-10-18 10:55:00: 1
# Current position delta: 4.064461657218209
# Elapsed: 0.8438692092895508
# 		Run on 2016-10-19 10:55:00
# Rollover occured, new series used
# Date not found at 2016-10-19
# Ichi regime at 2016-10-19 10:55:00: None
# Current position delta: 0.0
# Elapsed: 0.8297488689422607
# 		Run on 2016-10-20 10:55:00
# Ichi regime at 2016-10-20 10:55:00: 1
# New bullish zone position
# Leg: bullish / C.US.ZWAZ164050 x 6.0 Price: 18.251539694827215 Delta: 4.045979031872574
# Leg:  / C.US.ZWAZ164300 x -6.0 Price: 7.2844637520640845 Delta: -2.131639057992098
# Transactions delta: 1.9143399738804758
# Elapsed: 0.5409390926361084
# 		Run on 2016-10-21 10:55:00
# Ichi regime at 2016-10-21 10:55:00: 1
# Current position delta: 1.9654887633804285
# Elapsed: 0.8411874771118164
# 		Run on 2016-10-22 10:55:00
# Date not found at 2016-10-22
# Ichi regime at 2016-10-22 10:55:00: None
# Elapsed: 0.6642892360687256
# 		Run on 2016-10-23 10:55:00
# Ichi regime at 2016-10-23 10:55:00: 1
# New bullish zone position
# Leg: bullish / C.US.ZWAZ164050 x 6.0 Price: 15.666437315427288 Delta: 3.9504194811301403
# Leg:  / C.US.ZWAZ164300 x -6.0 Price: 5.486641713606218 Delta: -1.8620002507370406
# Transactions delta: 2.0884192303930997
# Elapsed: 0.48726344108581543
# 		Run on 2016-10-24 10:55:00
# Ichi regime at 2016-10-24 10:55:00: 1
# Current position delta: 1.794027039365599
# Elapsed: 0.8311536312103271
# 		Run on 2016-10-25 10:55:00
# Ichi regime at 2016-10-25 10:55:00: 1
# Current position delta: 1.731979267756899
# Elapsed: 0.9149188995361328
# 		Run on 2016-10-26 10:55:00
# Ichi regime at 2016-10-26 10:55:00: 1
# Current position delta: 1.981883133289526
# Elapsed: 0.83599853515625
# 		Run on 2016-10-27 10:55:00
# Ichi regime at 2016-10-27 10:55:00: 1
# Current position delta: 2.092781171468708
# Elapsed: 0.8206546306610107
# 		Run on 2016-10-28 10:55:00
# Ichi regime at 2016-10-28 10:55:00: 1
# Current position delta: 1.997015502306927
# Elapsed: 0.839571475982666
# 		Run on 2016-10-29 10:55:00
# Date not found at 2016-10-29
# Ichi regime at 2016-10-29 10:55:00: None
# Elapsed: 0.6507384777069092
# 		Run on 2016-10-30 10:55:00
# Ichi regime at 2016-10-30 10:55:00: 1
# New bullish zone position
# Leg: bullish / C.US.ZWAZ164000 x 6.0 Price: 14.49948352105389 Delta: 4.006157254609631
# Leg:  / C.US.ZWAZ164250 x -6.0 Price: 4.316358845837144 Delta: -1.6941070884821192
# Transactions delta: 2.312050166127512
# Elapsed: 0.49460482597351074
# 		Run on 2016-10-31 10:55:00
# Ichi regime at 2016-10-31 10:55:00: 1
# Current position delta: 2.3724467673542975
# Elapsed: 0.8003420829772949
# 		Run on 2016-11-01 10:55:00
# Ichi regime at 2016-11-01 10:55:00: 1
# Current position delta: 2.3662074362442604
# Elapsed: 0.8315954208374023
# 		Run on 2016-11-02 10:55:00
# Ichi regime at 2016-11-02 10:55:00: 1
# Current position delta: 2.518615531322489
# Elapsed: 0.8016893863677979
# Done

# %% [markdown]
# # View EXO price series

# %%
for ticker in instruments:
    exo_df, exo_info = exostorage.load_series('{0}_{1}'.format(ticker, EXO_NAME))    
    
    exo_df['exo'].plot(title='{0}_{1}'.format(ticker, EXO_NAME))
    ax = exo_df['ichi_regime'].plot(secondary_y=True)
    ax.set_ylim(-2,2)
    plt.show()
