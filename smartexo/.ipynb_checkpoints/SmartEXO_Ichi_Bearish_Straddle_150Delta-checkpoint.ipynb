# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from exobuilder.contracts.futureschain import FuturesChain
from exobuilder.contracts.futurecontract import FutureContract
from exobuilder.tests.assetindexdict import AssetIndexDicts
from datetime import datetime, date, timedelta, time as dttime
from exobuilder.contracts.instrument import Instrument
from exobuilder.data.datasource_mongo import DataSourceMongo
from exobuilder.data.datasource_sql import DataSourceSQL
from exobuilder.data.assetindex_mongo import AssetIndexMongo
from exobuilder.data.exostorage import EXOStorage
from exobuilder.exo.exoenginebase import ExoEngineBase
from exobuilder.exo.transaction import Transaction
import time
from exobuilder.algorithms.rollover_helper import RolloverHelper

import importlib
import logging
importlib.reload(logging);
import matplotlib.pyplot as plt

# %%
EXO_NAME = 'SmartEXO_Ichi_Bearish_Straddle_150Delta'

# TODO: set to 'False' if EXO building output is too verbosive
verbosive_logging = True # or True - for debug log feed

# TODO: select instruments list for SMART EXO calculation
#instruments = ['CL', 'ES', 'NG', 'ZC', 'ZS', 'ZW', 'ZN']
instruments = ['CL']


# TODO: select start date for SmartEXO calculation
base_date = datetime(2013, 6, 13, 12, 45, 0)

# %% [markdown]
# # Define Bull/Bear/Neutral areas rules

# %%
def ichimoku_regimes(date, price_series):    
    '''
    Calculates Bull/Bear/Neutral areas based on Ichimoku zones
    
    param date: Current date time
    param price_series: price Pandas.Series
    
    Returns:
        -1 - for bearish zone
        0  - for neutral zone
        +1 - for bullish zone
        None - for unknown
    '''
    #
    #  TODO: Change values to fine tune zoning algorithm
    #
    conversion_line_period = 9 # subject of optimization
    base_line_period = 26  # subject of optimization
    leading_spans_lookahead_period = 26  # subject of optimization
    leading_span_b_period = 52 # subject of optimization
        
        
    conversion_line_high = price_series.rolling(window=conversion_line_period).max()
    conversion_line_low = price_series.rolling(window=conversion_line_period).min()
    conversion_line = (conversion_line_high + conversion_line_low) / 2

    base_line_high = price_series.rolling(window=base_line_period).max()
    base_line_low = price_series.rolling(window=base_line_period).min()
    base_line = (base_line_high + base_line_low) / 2

    leading_span_a = ((conversion_line + base_line) / 2).shift(leading_spans_lookahead_period)
    leading_span_b = ((price_series.rolling(window=leading_span_b_period).max() + price_series.rolling(
        window=leading_span_b_period).min()) / 2).shift(leading_spans_lookahead_period)


    #
    # Rules calculation
    #

    # Cloud top and bottom series are defined using leading span A and B
    cloud_top = leading_span_a.rolling(1).max()
    cloud_bottom = leading_span_a.rolling(1).min()

    rule_price_above_cloud_top = price_series > cloud_top
    rule_price_below_cloud_bottom = price_series < cloud_bottom
    rule_price_in_cloud = (price_series < cloud_top) & (price_series > cloud_bottom)

    def get_regime(date):
        if date not in rule_price_above_cloud_top.index:
            logging.debug("Date not found at {0}".format(date))
            return None


        if rule_price_above_cloud_top[date]:
            return 1
        elif rule_price_below_cloud_bottom[date]:
            return -1
        elif rule_price_in_cloud[date]:
            return 0
        return None

    regime = get_regime(date.date())
    logging.debug("Ichi regime at {0}: {1}".format(date, regime))
    return regime

# %%
# Toolbox
def transactions_delta(trans_list):
    return sum([t.delta for t in trans_list])

def log_transactions(trans_list, msg):
    logging.debug(msg)
    [logging.debug(t) for t in trans_list]
    logging.debug('Transactions delta: {0}'.format(transactions_delta(trans_list)))

# %% [markdown]
# # Option position management

# %% [markdown]
# According to https://tmqrexo.slack.com/files/nikolasjoyce/F2PHLEETZ/pasted_image_at_2016_10_14_10_05_am.png

# %% [markdown]
# ## New bullish zone position

# %%
def new_position_bullish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bullish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening long ITM straddle in bullish zone
    #
    # https://files.slack.com/files-tmb/T0484J7T7-F2QBLK53R-93b4252806/pasted_image_at_2016_10_17_10_08_am_720.png
    
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[0].p, date, -1.0, leg_name='bullish'),
                Transaction(opt_chain[2].p, date, 1.0),
                
                Transaction(opt_chain[3].c, date, 1.0),
                Transaction(opt_chain[6].c, date,  -1.0),
           ]
    log_transactions(trans_list,'New bullish zone position')
    return trans_list

# %% [markdown]
# ## New bearish zone position

# %%
def new_position_bearish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bearish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening short butterfly in bearish zone
    #
    
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[2].c, date, 2.0, leg_name='bearish'),
                Transaction(opt_chain[2].p, date, 4.0),                
                ]
    log_transactions(trans_list,'New bearish zone position')
    return trans_list

# %% [markdown]
# ## New neutral zone position

# %%
def new_position_neutral_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for neutral zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening long asymmetric butterfly in neutral zone
    #    
    # https://files.slack.com/files-tmb/T0484J7T7-F2PGU8QNQ-6344e6a04c/pasted_image_at_2016_10_14_09_43_am_720.png
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-2].c, date, -3.0, leg_name='bearish'),
                Transaction(opt_chain[2].c, date, 6.0),
                
                Transaction(opt_chain[8].c, date, -3.0),
                Transaction(opt_chain[3].c, date,  0.0),
           ]
    log_transactions(trans_list,'New neutral zone position')
    return trans_list

# %% [markdown]
# ## Manage opened positions

# %%
def manage_opened_position(date, fut, opt_chain, regime, opened_position):
    logging.debug('Current position delta: {0}'.format(opened_position.delta))
    
    # By default: do nothing
    return []

# %% [markdown]
# # Define EXO builder class

# %%
class SmartEXOIchimoku(ExoEngineBase):
    def __init__(self, symbol, direction, date, datasource, log_file_path=''):
        self._symbol = symbol
        self.custom_values = {}
        super().__init__(symbol, direction, date, datasource, log_file_path=log_file_path)

    @staticmethod
    def direction_type():
        return 0

    @staticmethod
    def names_list(symbol):
        return ['{0}_{1}'.format(self._symbol, EXO_NAME)]

    @property
    def exo_name(self):
            return '{0}_{1}'.format(self._symbol, EXO_NAME)

    def is_rollover(self):
        if len(self.position) != 0:
            for p in self.position.legs.values():
                rh = RolloverHelper(p.instrument)
                if rh.is_rollover(p):
                    return True
        return False

    def process_rollover(self):
        trans_list = self.position.close_all_translist()
        logging.info('Rollover occured, new series used')
        return trans_list
    
    def get_custom_values(self):
        """
        Method that return custom EXO data frame values, to store inside EXO Dataframe in the DB
        :return: dictionary {'string_key': (int or float) value}
        """
        return self.custom_values
    

    def process_day(self):
        """
        Main EXO's position management method
        :return: list of Transactions to process
        """

        # Get cont futures price for EXO
        exo_df, exo_info = self.datasource.exostorage.load_series("{0}_ContFut".format(self._symbol))

        regime = ichimoku_regimes(self.date, exo_df['exo'])

        trans_list = []

        if regime is None and len(self.position) > 0:
            return self.position.close_all_translist()
        
        instr = self.datasource.get(self._symbol, self.date)
        rh = RolloverHelper(instr)
        fut, opt_chain = rh.get_active_chains()

        if regime == 1 and 'bullish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bullish_zone(self.date, fut, opt_chain)
            
            return trans_list
        if regime == -1 and 'bearish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bearish_zone(self.date, fut, opt_chain)
            return trans_list

        if regime == 0 and 'neutral' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_neutral_zone(self.date, fut, opt_chain)
            return trans_list
        
        #
        # Writing custom values to store inside DB 
        #
        self.custom_values = {
            'ichi_regime': regime if regime is not None else float('nan')
        }
        
        #
        # Manage opened position
        #
        return manage_opened_position(self.date, fut, opt_chain, regime, self.position)

# %% [markdown]
# # Run EXO build process (WARN: long-running task!)

# %%
from pymongo import MongoClient

if verbosive_logging:
    logging.basicConfig(format='%(message)s', level=logging.DEBUG)
else:
    logging.basicConfig(format='%(message)s', level=logging.INFO)

mongo_connstr = 'mongodb://exowriter:qmWSy4K3@10.0.1.2/tmldb?authMechanism=SCRAM-SHA-1'
mongo_db_name = 'tmldb'
assetindex = AssetIndexMongo(mongo_connstr, mongo_db_name)
exostorage = EXOStorage(mongo_connstr, mongo_db_name)

#base_date = datetime(2011, 6, 13, 12, 45, 0)


futures_limit = 3
options_limit = 10

DEBUG = '.'

datasource = DataSourceMongo(mongo_connstr, mongo_db_name, assetindex, futures_limit, options_limit, exostorage)

server = 'h9ggwlagd1.database.windows.net'
user = 'modelread'
password = '4fSHRXwd4u'
datasource = DataSourceSQL(server, user, password, assetindex, futures_limit, options_limit, exostorage)

enddate = datetime.combine(datetime.now().date(), dttime(12, 45, 0))
currdate = base_date


logging.info("Deleting all SmartEXO of :" + EXO_NAME)
client = MongoClient(mongo_connstr)
db = client[mongo_db_name]
db['exo_data'].delete_many({'name': {'$regex': '.*{0}*.'.format(EXO_NAME)}})


logging.info("Starting EXO calculation process from: {0}".format(currdate))
for ticker in instruments:
    logging.info("Processing: "+ticker)
    currdate = base_date
    while currdate <= enddate:
        
        start_time = time.time()
        date = currdate

        asset_info = assetindex.get_instrument_info(ticker)
        exec_time_end, decision_time_end = AssetIndexMongo.get_exec_time(date, asset_info)
        
        logging.info("\t\tRun on {0}".format(decision_time_end))

        with SmartEXOIchimoku(ticker, 0, decision_time_end, datasource) as exo_engine:
            # Load EXO information from mongo
            exo_engine.load()
            exo_engine.calculate()

        end_time = time.time()
        currdate += timedelta(days=1)
        logging.debug("Elapsed: {0}".format(end_time-start_time))
logging.info('Done')
# Out:
# Deleting all SmartEXO of :SmartEXO_Ichi_Bearish_Straddle_150Delta
# Starting EXO calculation process from: 2013-06-13 12:45:00
# Processing: CL
# 		Run on 2013-06-13 11:10:00
# Ichi regime at 2013-06-13 11:10:00: 1
# New bullish zone position
# Leg: bullish / P.US.CLEN139600 x -1.0 Price: 0.7472235862915753 Delta: 0.47526294509143624
# Leg:  / P.US.CLEN139700 x 1.0 Price: 1.2999577030715415 Delta: -0.6753041292170803
# Leg:  / C.US.CLEN139750 x 1.0 Price: 0.25311913130131813 Delta: 0.23311981334409107
# Leg:  / C.US.CLEN139900 x -1.0 Price: 0.055318645716176285 Delta: -0.0670843558222771
# Transactions delta: -0.03400572660383007
# Elapsed: 0.9017448425292969
# 		Run on 2013-06-14 11:10:00
# Ichi regime at 2013-06-14 11:10:00: 1
# Current position delta: 0.18533890300874345
# Elapsed: 1.5973269939422607
# 		Run on 2013-06-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013
# 		Run on 2013-06-27 11:10:00
# Ichi regime at 2013-06-27 11:10:00: 1
# Current position delta: 0.050537792814955684
# Elapsed: 1.5992343425750732
# 		Run on 2013-06-28 11:10:00
# Ichi regime at 2013-06-28 11:10:00: 1
# Current position delta: 0.05378629884018793
# Elapsed: 1.614109992980957
# 		Run on 2013-06-29 11:10:00
# Ichi regime at 2013-06-29 11:10:00: 1
# Current position delta: 0.04959954862795091
# Elapsed: 1.5939970016479492
# 		Run on 2013-06-30 11:10:00
# Ichi regime at 2013-06-30 11:10:00: 1
# Current position delta: 0.050645438507124385
# Elapsed: 1.598562240600586
# 		Run on 2013-07-01 11:10:00
# Ichi regime at 2013-07-01 11:10:00: 1
# Current position delta: 0.06567974779449826
# Elapsed: 1.60019850730896
# 		Run on 2013-07-02 11:10:00
# Ichi regime at 2013-07-02 11:10:00: 1
# Current position delta: 0.07246763770899425
# Elapsed: 1.8806085586547852
# 		Run on 2013-07-03 11:10:00
# Ichi regime at 2013-07-03 11:10:00: 1
# Current position delta: 0.05825672518610778
# Elapsed: 1.6066770553588867
# 		Run on 2013-07-04 11:10:00
# Ichi regime at 2013-07-04 11:10:00: 1
# Current position delta: 0.051039497519339574
# Elapsed: 1.6013078689575195
# 		Run on 2013-07-05 11:10:00
# Ichi regime at 2013-07-05 11:10:00: 1
# Current position delta: 0.037324492779126875
# Elapsed: 1.5921266078948975
# 		Run on 2013-07-06 11:10:00
# Ichi regime at 2013-07-06 11:10:00: 1
# Current position delta: 0.035708187892058034
# Elapsed: 1.5911104679107666
# 		Run on 2013-07-07 11:10:00
# Ichi regime at 2013-07-07 11:10:00: 1
# Current position delta: 0.034975189216310244
# Elapsed: 1.634270191192627
# 		Run on 2013-07-08 11:10:00
# Ichi regime at 2013-07-08 11:10:00: 1
# Current position delta: 0.04127024824902824
# Elapsed: 1.5882799625396729
# 		Run on 2013-07-09 11:10:00
# Ichi regime at 2013-07-09 11:10:00: 1
# Current position delta: 0.03287468033315706
# Elapsed: 1.6003973484039307
# 		Run on 2013-07-10 11:10:00
# Ichi regime at 2013-07-10 11:10:00: 1
# Current position delta: 0.006905938378930011
# Elapsed: 1.6084880828857422
# 		Run on 2013-07-11 11:10:00
# Ichi regime at 2013-07-11 11:10:00: 1
# Current position delta: 0.022360121079674087
# Elapsed: 1.6060702800750732
# 		Run on 2013-07-12 11:10:00
# Ichi regime at 2013-07-12 11:10:00: 1
# Current position delta: 0.008065046807924234
# Elapsed: 1.6300897598266602
# 		Run on 2013-07-13 11:10:00
# Ichi regime at 2013-07-13 11:10:00: 1
# Current position delta: 0.0035434500084147768
# Elapsed: 1.6020808219909668
# 		Run on 2013-07-14 11:10:00
# Ichi regime at 2013-07-14 11:10:00: 1
# Current position delta: 0.0017893365690411528
# Elapsed: 1.6256358623504639
# 		Run on 2013-07-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-07-15 11:10:00: 1
# New bullish zone position
# Leg: bullish / P.US.CLEU1310600 x -1.0 Price: 2.6924723615752626 Delta: 0.4995796513205402
# Leg:  / P.US.CLEU1310700 x 1.0 Price: 3.2410043346170028 Delta: -0.5605031176887442
# Leg:  / C.US.CLEU1310750 x 1.0 Price: 1.8244914929485105 Delta: 0.4086528759483382
# Leg:  / C.US.CLEU1310900 x -1.0 Price: 1.3052142334254881 Delta: -0.3226159477382537
# Transactions delta: 0.02511346184188057
# Elapsed: 2.4546008110046387
# 		Run on 2013-07-16 11:10:00
# Ichi regime at 2013-07-16 11:10:00: 1
# Current position delta: 0.02595269323290561
# Elapsed: 1.778900146484375
# 		Run on 2013-07-17 11:10:00
# Ichi regime at 2013-07-17 11:10:00: 1
# Current position delta: 0.027139734653142844
# Elapsed: 1.5905711650848389
# 		Run on 2013-07-18 11:10:00
# Ichi regime at 2013-07-18 11:10:00: 1
# Current position delta: 0.037526239549369955
# Elapsed: 1.6037170886993408
# 		Run on 2013-07-19 11:10:00
# Ichi regime at 2013-07-19 11:10:00: 1
# Current position delta: 0.039925379185832666
# Elapsed: 1.6061973571777344
# 		Run on 2013-07-20 11:10:00
# Ichi regime at 2013-07-20 11:10:00: 1
# Current position delta: 0.03743450800180326
# Elapsed: 1.60943603515625
# 		Run on 2013-07-21 11:10:00
# Ichi regime at 2013-07-21 11:10:00: 1
# Current position delta: 0.03826841604401987
# Elapsed: 1.6124851703643799
# 		Run on 2013-07-22 11:10:00
# Ichi regime at 2013-07-22 11:10:00: 1
# Current position delta: 0.03426278975856123
# Elapsed: 1.6064915657043457
# 		Run on 2013-07-23 11:10:00
# Ichi regime at 2013-07-23 11:10:00: 1
# Current position delta: 0.034035415701219096
# Elapsed: 1.5926122665405273
# 		Run on 2013-07-24 11:10:00
# Ichi regime at 2013-07-24 11:10:00: 1
# Current position delta: 0.023786140912975734
# Elapsed: 1.5935924053192139
# 		Run on 2013-07-25 11:10:00
# Ichi regime at 2013-07-25 11:10:00: 1
# Current position delta: 0.027268234508467715
# Elapsed: 1.6169850826263428
# 		Run on 2013-07-26 11:10:00
# Ichi regime at 2013-07-26 11:10:00: 1
# Current position delta: 0.019992207624813157
# Elapsed: 1.6245875358581543
# 		Run on 2013-07-27 11:10:00
# Ichi regime at 2013-07-27 11:10:00: 1
# Current position delta: 0.020759742463290237
# Elapsed: 1.620476484298706
# 		Run on 2013-07-28 11:10:00
# Ichi regime at 2013-07-28 11:10:00: 1
# Current position delta: 0.01997277790137042
# Elapsed: 1.6005585193634033
# 		Run on 2013-07-29 11:10:00
# Ichi regime at 2013-07-29 11:10:00: 1
# Current position delta: 0.019134066092896862
# Elapsed: 1.6421194076538086
# 		Run on 2013-07-30 11:10:00
# Ichi regime at 2013-07-30 11:10:00: 1
# Current position delta: 0.0009041254263644494
# Elapsed: 1.6174836158752441
# 		Run on 2013-07-31 11:10:00
# Ichi regime at 2013-07-31 11:10:00: 1
# Current position delta: 0.010249428316772918
# Elapsed: 1.5964632034301758
# 		Run on 2013-08-01 11:10:00
# Ichi regime at 2013-08-01 11:10:00: 1
# Current position delta: 0.05277529154616167
# Elapsed: 1.599259853363037
# 		Run on 2013-08-02 11:10:00
# Ichi regime at 2013-08-02 11:10:00: 1
# Current position delta: 0.04064892797496911
# Elapsed: 1.59596586227417
# 		Run on 2013-08-03 11:10:00
# Ichi regime at 2013-08-03 11:10:00: 1
# Current position delta: 0.04586527305129373
# Elapsed: 1.6167912483215332
# 		Run on 2013-08-04 11:10:00
# Ichi regime at 2013-08-04 11:10:00: 1
# Current position delta: 0.047100719492238596
# Elapsed: 1.6512353420257568
# 		Run on 2013-08-05 11:10:00
# Ichi regime at 2013-08-05 11:10:00: 1
# Current position delta: 0.04745948420336682
# Elapsed: 1.601616382598877
# 		Run on 2013-08-06 11:10:00
# Ichi regime at 2013-08-06 11:10:00: 1
# Current position delta: 0.01920514146488375
# Elapsed: 1.611480951309204
# 		Run on 2013-08-07 11:10:00
# Ichi regime at 2013-08-07 11:10:00: 1
# Current position delta: -0.0036344084036113167
# Elapsed: 1.6083760261535645
# 		Run on 2013-08-08 11:10:00
# Ichi regime at 2013-08-08 11:10:00: 1
# Current position delta: -0.029421165264191196
# Elapsed: 1.603513240814209
# 		Run on 2013-08-09 11:10:00
# Ichi regime at 2013-08-09 11:10:00: 1
# Current position delta: 0.005168944407203169
# Elapsed: 1.604954719543457
# 		Run on 2013-08-10 11:10:00
# Ichi regime at 2013-08-10 11:10:00: 1
# Current position delta: 0.011068196015640991
# Elapsed: 1.597144365310669
# 		Run on 2013-08-11 11:10:00
# Ichi regime at 2013-08-11 11:10:00: 1
# Current position delta: 0.0008740051108413471
# Elapsed: 1.5941777229309082
# 		Run on 2013-08-12 11:10:00
# Ichi regime at 2013-08-12 11:10:00: 1
# Current position delta: -0.027410707658339445
# Elapsed: 1.6192383766174316
# 		Run on 2013-08-13 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-08-13 11:10:00: 1
# New bullish zone position
# Leg: bullish / P.US.CLEV1310650 x -1.0 Price: 2.8920671889641625 Delta: 0.4911471899300397
# Leg:  / P.US.CLEV1310750 x 1.0 Price: 3.4248457610712677 Delta: -0.5468818181553975
# Leg:  / C.US.CLEV1310800 x 1.0 Price: 2.100368787744415 Delta: 0.424426798606503
# Leg:  / C.US.CLEV1310950 x -1.0 Price: 1.5449060021584842 Delta: -0.3435875665432089
# Transactions delta: 0.025104603837936335
# Elapsed: 2.4942150115966797
# 		Run on 2013-08-14 11:10:00
# Ichi regime at 2013-08-14 11:10:00: 1
# Current position delta: 0.025723182856955906
# Elapsed: 1.7708141803741455
# 		Run on 2013-08-15 11:10:00
# Ichi regime at 2013-08-15 11:10:00: 1
# Current position delta: 0.02687241579778643
# Elapsed: 1.5936388969421387
# 		Run on 2013-08-16 11:10:00
# Ichi regime at 2013-08-16 11:10:00: 1
# Current position delta: 0.027281145988172717
# Elapsed: 1.6229908466339111
# 		Run on 2013-08-17 11:10:00
# Ichi regime at 2013-08-17 11:10:00: 1
# Current position delta: 0.02985461265927003
# Elapsed: 1.6080288887023926
# 		Run on 2013-08-18 11:10:00
# Ichi regime at 2013-08-18 11:10:00: 1
# Current position delta: 0.03029931458311691
# Elapsed: 1.6022210121154785
# 		Run on 2013-08-19 11:10:00
# Ichi regime at 2013-08-19 11:10:00: 1
# Current position delta: 0.02858720155990202
# Elapsed: 1.6087675094604492
# 		Run on 2013-08-20 11:10:00
# Ichi regime at 2013-08-20 11:10:00: 1
# Current position delta: 0.019834995739885064
# Elapsed: 1.6074731349945068
# 		Run on 2013-08-21 11:10:00
# Ichi regime at 2013-08-21 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEV1310500 x 2.0 Price: 2.022638314859549 Delta: 0.893474558695057
# Leg:  / P.US.CLEV1310500 x 4.0 Price: 3.0725748456989166 Delta: -2.2104719486673967
# Transactions delta: -1.3169973899723397
# Elapsed: 1.9492716789245605
# 		Run on 2013-08-22 11:10:00
# Ichi regime at 2013-08-22 11:10:00: 1
# New bullish zone position
# Leg: bullish / P.US.CLEV1310500 x -1.0 Price: 2.5263072230195007 Delta: 0.4899250833478852
# Leg:  / P.US.CLEV1310600 x 1.0 Price: 3.03857423517627 Delta: -0.553830886339648
# Leg:  / C.US.CLEV1310650 x 1.0 Price: 1.7741954135670923 Delta: 0.4135531286206761
# Leg:  / C.US.CLEV1310800 x -1.0 Price: 1.2206960604643626 Delta: -0.3206088292083263
# Transactions delta: 0.02903849642058698
# Elapsed: 1.6018719673156738
# 		Run on 2013-08-23 11:10:00
# Ichi regime at 2013-08-23 11:10:00: 1
# Current position delta: 0.035143549054509615
# Elapsed: 1.6085596084594727
# 		Run on 2013-08-24 11:10:00
# Ichi regime at 2013-08-24 11:10:00: 1
# Current position delta: 0.03698268115797926
# Elapsed: 1.5991389751434326
# 		Run on 2013-08-25 11:10:00
# Ichi regime at 2013-08-25 11:10:00: 1
# Current position delta: 0.037737652432550284
# Elapsed: 1.5985291004180908
# 		Run on 2013-08-26 11:10:00
# Ichi regime at 2013-08-26 11:10:00: 1
# Current position delta: 0.03732209382179891
# Elapsed: 1.6520781517028809
# 		Run on 2013-08-27 11:10:00
# Ichi regime at 2013-08-27 11:10:00: 1
# Current position delta: 0.04596093750046393
# Elapsed: 1.6220483779907227
# 		Run on 2013-08-28 11:10:00
# Ichi regime at 2013-08-28 11:10:00: 1
# Current position delta: 0.039491671875581696
# Elapsed: 1.641348123550415
# 		Run on 2013-08-29 11:10:00
# Ichi regime at 2013-08-29 11:10:00: 1
# Current position delta: 0.035983006886219804
# Elapsed: 1.624406099319458
# 		Run on 2013-08-30 11:10:00
# Ichi regime at 2013-08-30 11:10:00: 1
# Current position delta: 0.03644034667291901
# Elapsed: 1.6149053573608398
# 		Run on 2013-08-31 11:10:00
# Ichi regime at 2013-08-31 11:10:00: 1
# Current position delta: 0.03512831261246341
# Elapsed: 1.6236045360565186
# 		Run on 2013-09-01 11:10:00
# Ichi regime at 2013-09-01 11:10:00: 1
# Current position delta: 0.036451381406980454
# Elapsed: 1.674344778060913
# 		Run on 2013-09-02 11:10:00
# Ichi regime at 2013-09-02 11:10:00: 1
# Current position delta: 0.03462617691709835
# Elapsed: 1.5905230045318604
# 		Run on 2013-09-03 11:10:00
# Ichi regime at 2013-09-03 11:10:00: 1
# Current position delta: 0.03693682391579406
# Elapsed: 1.6014230251312256
# 		Run on 2013-09-04 11:10:00
# Ichi regime at 2013-09-04 11:10:00: 1
# Current position delta: 0.036679806352613475
# Elapsed: 1.6099927425384521
# 		Run on 2013-09-05 11:10:00
# Ichi regime at 2013-09-05 11:10:00: 1
# Current position delta: 0.0429012227099414
# Elapsed: 1.5986108779907227
# 		Run on 2013-09-06 11:10:00
# Ichi regime at 2013-09-06 11:10:00: 1
# Current position delta: 0.05180342730396226
# Elapsed: 1.7106139659881592
# 		Run on 2013-09-07 11:10:00
# Ichi regime at 2013-09-07 11:10:00: 1
# Current position delta: 0.055615297463701224
# Elapsed: 1.6183855533599854
# 		Run on 2013-09-08 11:10:00
# Ichi regime at 2013-09-08 11:10:00: 1
# Current position delta: 0.058856507887771636
# Elapsed: 1.6067943572998047
# 		Run on 2013-09-09 11:10:00
# Ichi regime at 2013-09-09 11:10:00: 1
# Current position delta: 0.0655416628833207
# Elapsed: 1.5900192260742188
# 		Run on 2013-09-10 11:10:00
# Ichi regime at 2013-09-10 11:10:00: 1
# Current position delta: 0.06315339679639509
# Elapsed: 1.6094701290130615
# 		Run on 2013-09-11 11:10:00
# Ichi regime at 2013-09-11 11:10:00: 1
# Current position delta: 0.07191124619128769
# Elapsed: 1.6042253971099854
# 		Run on 2013-09-12 11:10:00
# Ichi regime at 2013-09-12 11:10:00: 1
# Current position delta: 0.10400061736230293
# Elapsed: 1.5971674919128418
# 		Run on 2013-09-13 11:10:00
# Ichi regime at 2013-09-13 11:10:00: 1
# Current position delta: 0.14073217561783216
# Elapsed: 1.6180946826934814
# 		Run on 2013-09-14 11:10:00
# Ichi regime at 2013-09-14 11:10:00: 1
# Current position delta: 0.17826310374364407
# Elapsed: 1.613105297088623
# 		Run on 2013-09-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-09-15 11:10:00: 1
# New bullish zone position
# Leg: bullish / P.US.CLEX1310800 x -1.0 Price: 2.727169475142638 Delta: 0.489557815620733
# Leg:  / P.US.CLEX1310900 x 1.0 Price: 3.265382157583076 Delta: -0.5480318400798627
# Leg:  / C.US.CLEX1310950 x 1.0 Price: 1.9941600370416808 Delta: 0.42213796294142253
# Leg:  / C.US.CLEX1311100 x -1.0 Price: 1.4478289769603805 Delta: -0.33804813579492393
# Transactions delta: 0.02561580268736885
# Elapsed: 2.461019992828369
# 		Run on 2013-09-16 11:10:00
# Ichi regime at 2013-09-16 11:10:00: 1
# Current position delta: 0.020690628822560453
# Elapsed: 1.7665760517120361
# 		Run on 2013-09-17 11:10:00
# Ichi regime at 2013-09-17 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEX1310600 x 2.0 Price: 2.0263315249455474 Delta: 0.87913919445537
# Leg:  / P.US.CLEX1310600 x 4.0 Price: 3.22618297642898 Delta: -2.238842733578259
# Transactions delta: -1.359703539122889
# Elapsed: 1.945629358291626
# 		Run on 2013-09-18 11:10:00
# Ichi regime at 2013-09-18 11:10:00: 1
# New bullish zone position
# Leg: bullish / P.US.CLEX1310700 x -1.0 Price: 2.671478340174062 Delta: 0.49743081418686663
# Leg:  / P.US.CLEX1310800 x 1.0 Price: 3.2150732507856787 Delta: -0.558518300511048
# Leg:  / C.US.CLEX1310850 x 1.0 Price: 1.8244065661756395 Delta: 0.4101068463188048
# Leg:  / C.US.CLEX1311000 x -1.0 Price: 1.296565907077472 Delta: -0.32292229922386545
# Transactions delta: 0.026097060770757963
# Elapsed: 1.6426646709442139
# 		Run on 2013-09-19 11:10:00
# Ichi regime at 2013-09-19 11:10:00: 1
# Current position delta: 0.02129909266981822
# Elapsed: 1.659984827041626
# 		Run on 2013-09-20 11:10:00
# Ichi regime at 2013-09-20 11:10:00: 1
# Current position delta: 0.01594102209514403
# Elapsed: 1.6251895427703857
# 		Run on 2013-09-21 11:10:00
# Ichi regime at 2013-09-21 11:10:00: 1
# Current position delta: 0.012206314574419785
# Elapsed: 1.6155064105987549
# 		Run on 2013-09-22 11:10:00
# Ichi regime at 2013-09-22 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEX1310600 x 2.0 Price: 1.64150802089312 Delta: 0.8504580423410164
# Leg:  / P.US.CLEX1310600 x 4.0 Price: 2.83229653913115 Delta: -2.295439569472248
# Transactions delta: -1.4449815271312316
# Elapsed: 1.927004098892212
# 		Run on 2013-09-23 11:10:00
# Ichi regime at 2013-09-23 11:10:00: -1
# Current position delta: -2.0002130601992922
# Elapsed: 0.9370956420898438
# 		Run on 2013-09-24 11:10:00
# Ichi regime at 2013-09-24 11:10:00: -1
# Current position delta: -2.2366914308720416
# Elapsed: 0.936173677444458
# 		Run on 2013-09-25 11:10:00
# Ichi regime at 2013-09-25 11:10:00: -1
# Current position delta: -2.3832612868793266
# Elapsed: 0.9358727931976318
# 		Run on 2013-09-26 11:10:00
# Ichi regime at 2013-09-26 11:10:00: -1
# Current position delta: -2.464583963020774
# Elapsed: 0.9351060390472412
# 		Run on 2013-09-27 11:10:00
# Ichi regime at 2013-09-27 11:10:00: -1
# Current position delta: -2.404555048565332
# Elapsed: 0.942793607711792
# 		Run on 2013-09-28 11:10:00
# Ichi regime at 2013-09-28 11:10:00: -1
# Current position delta: -2.4887323143220574
# Elapsed: 0.9901223182678223
# 		Run on 2013-09-29 11:10:00
# Ichi regime at 2013-09-29 11:10:00: -1
# Current position delta: -2.526174572008329
# Elapsed: 0.9267799854278564
# 		Run on 2013-09-30 11:10:00
# Ichi regime at 2013-09-30 11:10:00: -1
# Current position delta: -2.841536501807378
# Elapsed: 0.9338171482086182
# 		Run on 2013-10-01 11:10:00
# Ichi regime at 2013-10-01 11:10:00: -1
# Current position delta: -2.9845901175159772
# Elapsed: 0.9461753368377686
# 		Run on 2013-10-02 11:10:00
# Ichi regime at 2013-10-02 11:10:00: -1
# Current position delta: -2.0755808714656254
# Elapsed: 0.9713022708892822
# 		Run on 2013-10-03 11:10:00
# Ichi regime at 2013-10-03 11:10:00: -1
# Current position delta: -2.358134990949334
# Elapsed: 0.9443020820617676
# 		Run on 2013-10-04 11:10:00
# Ichi regime at 2013-10-04 11:10:00: -1
# Current position delta: -2.3112960099342734
# Elapsed: 0.9566471576690674
# 		Run on 2013-10-05 11:10:00
# Ichi regime at 2013-10-05 11:10:00: -1
# Current position delta: -2.4059910500649195
# Elapsed: 0.9428253173828125
# 		Run on 2013-10-06 11:10:00
# Ichi regime at 2013-10-06 11:10:00: -1
# Current position delta: -2.4635930484607784
# Elapsed: 0.9517972469329834
# 		Run on 2013-10-07 11:10:00
# Ichi regime at 2013-10-07 11:10:00: -1
# Current position delta: -3.050575147466376
# Elapsed: 0.9552502632141113
# 		Run on 2013-10-08 11:10:00
# Ichi regime at 2013-10-08 11:10:00: -1
# Current position delta: -2.665520509399993
# Elapsed: 0.9481489658355713
# 		Run on 2013-10-09 11:10:00
# Ichi regime at 2013-10-09 11:10:00: -1
# Current position delta: -3.489831708512553
# Elapsed: 0.9689044952392578
# 		Run on 2013-10-10 11:10:00
# Ichi regime at 2013-10-10 11:10:00: -1
# Current position delta: -2.885698554354299
# Elapsed: 0.9406380653381348
# 		Run on 2013-10-11 11:10:00
# Ichi regime at 2013-10-11 11:10:00: -1
# Current position delta: -3.6998363874574918
# Elapsed: 0.977078914642334
# 		Run on 2013-10-12 11:10:00
# Ichi regime at 2013-10-12 11:10:00: -1
# Current position delta: -3.770896737094306
# Elapsed: 0.9548242092132568
# 		Run on 2013-10-13 11:10:00
# Ichi regime at 2013-10-13 11:10:00: -1
# Current position delta: -3.858316526471256
# Elapsed: 0.932884931564331
# 		Run on 2013-10-14 11:10:00
# Ichi regime at 2013-10-14 11:10:00: -1
# Current position delta: -3.839662044583707
# Elapsed: 0.9386749267578125
# 		Run on 2013-10-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-10-15 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEZ1310250 x 2.0 Price: 2.096360425023825 Delta: 0.9190582508197312
# Leg:  / P.US.CLEZ1310250 x 4.0 Price: 2.9464684733531072 Delta: -2.1591585477877135
# Transactions delta: -1.2401002969679822
# Elapsed: 1.4349486827850342
# 		Run on 2013-10-16 11:10:00
# Ichi regime at 2013-10-16 11:10:00: -1
# Current position delta: -0.7725136971615656
# Elapsed: 1.1087079048156738
# 		Run on 2013-10-17 11:10:00
# Ichi regime at 2013-10-17 11:10:00: -1
# Current position delta: -1.5763863876038497
# Elapsed: 0.9368338584899902
# 		Run on 2013-10-18 11:10:00
# Ichi regime at 2013-10-18 11:10:00: -1
# Current position delta: -1.544487180008042
# Elapsed: 0.9323503971099854
# 		Run on 2013-10-19 11:10:00
# Ichi regime at 2013-10-19 11:10:00: -1
# Current position delta: -1.5508542114894495
# Elapsed: 0.9438550472259521
# 		Run on 2013-10-20 11:10:00
# Ichi regime at 2013-10-20 11:10:00: -1
# Current position delta: -1.5637160067088924
# Elapsed: 0.9434497356414795
# 		Run on 2013-10-21 11:10:00
# Ichi regime at 2013-10-21 11:10:00: -1
# Current position delta: -2.239561827362859
# Elapsed: 0.9333107471466064
# 		Run on 2013-10-22 11:10:00
# Ichi regime at 2013-10-22 11:10:00: -1
# Current position delta: -2.7512555056714643
# Elapsed: 0.9414451122283936
# 		Run on 2013-10-23 11:10:00
# Ichi regime at 2013-10-23 11:10:00: -1
# Current position delta: -3.107027427573231
# Elapsed: 0.9408853054046631
# 		Run on 2013-10-24 11:10:00
# Ichi regime at 2013-10-24 11:10:00: -1
# Current position delta: -3.1964597290413734
# Elapsed: 0.9301204681396484
# 		Run on 2013-10-25 11:10:00
# Ichi regime at 2013-10-25 11:10:00: -1
# Current position delta: -2.9847600606432425
# Elapsed: 1.6209819316864014
# 		Run on 2013-10-26 11:10:00
# Ichi regime at 2013-10-26 11:10:00: -1
# Current position delta: -3.1294903102590315
# Elapsed: 0.9557836055755615
# 		Run on 2013-10-27 11:10:00
# Ichi regime at 2013-10-27 11:10:00: -1
# Current position delta: -3.168199608104097
# Elapsed: 0.9515652656555176
# 		Run on 2013-10-28 11:10:00
# Ichi regime at 2013-10-28 11:10:00: -1
# Current position delta: -2.9475183938827927
# Elapsed: 1.003880500793457
# 		Run on 2013-10-29 11:10:00
# Ichi regime at 2013-10-29 11:10:00: -1
# Current position delta: -3.134108581016284
# Elapsed: 0.9345271587371826
# 		Run on 2013-10-30 11:10:00
# Ichi regime at 2013-10-30 11:10:00: -1
# Current position delta: -3.5509744242680736
# Elapsed: 0.933356761932373
# 		Run on 2013-10-31 11:10:00
# Ichi regime at 2013-10-31 11:10:00: -1
# Current position delta: -3.5512242827497142
# Elapsed: 0.9386177062988281
# 		Run on 2013-11-01 11:10:00
# Ichi regime at 2013-11-01 11:10:00: -1
# Current position delta: -3.8496224458588126
# Elapsed: 0.9524049758911133
# 		Run on 2013-11-02 11:10:00
# Ichi regime at 2013-11-02 11:10:00: -1
# Current position delta: -3.8210957428427763
# Elapsed: 0.9342672824859619
# 		Run on 2013-11-03 11:10:00
# Ichi regime at 2013-11-03 11:10:00: -1
# Current position delta: -3.850775820921582
# Elapsed: 0.9316649436950684
# 		Run on 2013-11-04 11:10:00
# Ichi regime at 2013-11-04 11:10:00: -1
# Current position delta: -3.8542606286428267
# Elapsed: 0.9297945499420166
# 		Run on 2013-11-05 11:10:00
# Ichi regime at 2013-11-05 11:10:00: -1
# Current position delta: -3.949891018653149
# Elapsed: 0.9335169792175293
# 		Run on 2013-11-06 11:10:00
# Ichi regime at 2013-11-06 11:10:00: -1
# Current position delta: -3.7473974361243014
# Elapsed: 0.9429798126220703
# 		Run on 2013-11-07 11:10:00
# Ichi regime at 2013-11-07 11:10:00: -1
# Current position delta: -3.949715820993637
# Elapsed: 0.9680144786834717
# 		Run on 2013-11-08 11:10:00
# Ichi regime at 2013-11-08 11:10:00: -1
# Current position delta: -3.9034302667042655
# Elapsed: 0.9443821907043457
# 		Run on 2013-11-09 11:10:00
# Ichi regime at 2013-11-09 11:10:00: -1
# Current position delta: -3.941714923823784
# Elapsed: 0.9422869682312012
# 		Run on 2013-11-10 11:10:00
# Ichi regime at 2013-11-10 11:10:00: -1
# Current position delta: -3.9689065143815383
# Elapsed: 0.9462318420410156
# 		Run on 2013-11-11 11:10:00
# Ichi regime at 2013-11-11 11:10:00: -1
# Current position delta: -3.980764924702269
# Elapsed: 0.936739444732666
# 		Run on 2013-11-12 11:10:00
# Ichi regime at 2013-11-12 11:10:00: -1
# Current position delta: -3.998109567536386
# Elapsed: 0.9490833282470703
# 		Run on 2013-11-13 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-11-13 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEF149550 x 2.0 Price: 1.6883798155907783 Delta: 0.9037232337547402
# Leg:  / P.US.CLEF149550 x 4.0 Price: 2.470147733037237 Delta: -2.1893859716711317
# Transactions delta: -1.2856627379163914
# Elapsed: 1.4346528053283691
# 		Run on 2013-11-14 11:10:00
# Ichi regime at 2013-11-14 11:10:00: -1
# Current position delta: -1.3762992087637498
# Elapsed: 1.1100387573242188
# 		Run on 2013-11-15 11:10:00
# Ichi regime at 2013-11-15 11:10:00: -1
# Current position delta: -1.45009333537029
# Elapsed: 0.9332747459411621
# 		Run on 2013-11-16 11:10:00
# Ichi regime at 2013-11-16 11:10:00: -1
# Current position delta: -1.4997042338726467
# Elapsed: 0.9545414447784424
# 		Run on 2013-11-17 11:10:00
# Ichi regime at 2013-11-17 11:10:00: -1
# Current position delta: -1.5104336283852584
# Elapsed: 1.0099949836730957
# 		Run on 2013-11-18 11:10:00
# Ichi regime at 2013-11-18 11:10:00: -1
# Current position delta: -1.8948517193625949
# Elapsed: 0.9535250663757324
# 		Run on 2013-11-19 11:10:00
# Ichi regime at 2013-11-19 11:10:00: -1
# Current position delta: -1.7828868235737225
# Elapsed: 0.9445414543151855
# 		Run on 2013-11-20 11:10:00
# Ichi regime at 2013-11-20 11:10:00: -1
# Current position delta: -1.9325788650828395
# Elapsed: 0.9686226844787598
# 		Run on 2013-11-21 11:10:00
# Ichi regime at 2013-11-21 11:10:00: -1
# Current position delta: -0.9910524996769006
# Elapsed: 0.9353432655334473
# 		Run on 2013-11-22 11:10:00
# Ichi regime at 2013-11-22 11:10:00: -1
# Current position delta: -1.3016611299473975
# Elapsed: 0.9533803462982178
# 		Run on 2013-11-23 11:10:00
# Ichi regime at 2013-11-23 11:10:00: -1
# Current position delta: -1.434995987398548
# Elapsed: 0.9270286560058594
# 		Run on 2013-11-24 11:10:00
# Ichi regime at 2013-11-24 11:10:00: -1
# Current position delta: -1.4471309284764482
# Elapsed: 0.9330935478210449
# 		Run on 2013-11-25 11:10:00
# Ichi regime at 2013-11-25 11:10:00: -1
# Current position delta: -1.8073681187837038
# Elapsed: 0.938269853591919
# 		Run on 2013-11-26 11:10:00
# Ichi regime at 2013-11-26 11:10:00: -1
# Current position delta: -1.9017097252468969
# Elapsed: 0.9363789558410645
# 		Run on 2013-11-27 11:10:00
# Ichi regime at 2013-11-27 11:10:00: -1
# Current position delta: -3.0278358869986373
# Elapsed: 0.9440443515777588
# 		Run on 2013-11-28 11:10:00
# Ichi regime at 2013-11-28 11:10:00: -1
# Current position delta: -2.910154916296297
# Elapsed: 0.9514727592468262
# 		Run on 2013-11-29 11:10:00
# Ichi regime at 2013-11-29 11:10:00: -1
# Current position delta: -2.652318736129749
# Elapsed: 0.9461331367492676
# 		Run on 2013-11-30 11:10:00
# Ichi regime at 2013-11-30 11:10:00: -1
# Current position delta: -2.65264915959075
# Elapsed: 0.9454100131988525
# 		Run on 2013-12-01 11:10:00
# Ichi regime at 2013-12-01 11:10:00: -1
# Current position delta: -2.699275762178731
# Elapsed: 0.9402499198913574
# 		Run on 2013-12-02 11:10:00
# Ichi regime at 2013-12-02 11:10:00: -1
# Current position delta: -2.142825338809713
# Elapsed: 0.9417130947113037
# 		Run on 2013-12-03 11:10:00
# Ichi regime at 2013-12-03 11:10:00: -1
# Current position delta: -0.6350654982790298
# Elapsed: 0.9443025588989258
# 		Run on 2013-12-04 11:10:00
# Ichi regime at 2013-12-04 11:10:00: -1
# Current position delta: 0.24566474445684938
# Elapsed: 0.9301300048828125
# 		Run on 2013-12-05 11:10:00
# Ichi regime at 2013-12-05 11:10:00: 1
# New bullish zone position
# Leg: bullish / P.US.CLEF149750 x -1.0 Price: 1.096713425942447 Delta: 0.47929511480741127
# Leg:  / P.US.CLEF149850 x 1.0 Price: 1.6573467025893862 Delta: -0.6153204065040816
# Leg:  / C.US.CLEF149900 x 1.0 Price: 0.5753135303084314 Delta: 0.3179633209562086
# Leg:  / C.US.CLEF1410050 x -1.0 Price: 0.25171962786172664 Delta: -0.1659794032705612
# Transactions delta: 0.01595862598897707
# Elapsed: 1.625819444656372
# 		Run on 2013-12-06 11:10:00
# Ichi regime at 2013-12-06 11:10:00: 1
# Current position delta: -0.0009382700021877133
# Elapsed: 1.6107823848724365
# 		Run on 2013-12-07 11:10:00
# Ichi regime at 2013-12-07 11:10:00: 1
# Current position delta: 0.0017926724119077253
# Elapsed: 1.6373329162597656
# 		Run on 2013-12-08 11:10:00
# Ichi regime at 2013-12-08 11:10:00: 1
# Current position delta: -0.005320861855147407
# Elapsed: 1.6038925647735596
# 		Run on 2013-12-09 11:10:00
# Ichi regime at 2013-12-09 11:10:00: 1
# Current position delta: -0.02506167652003488
# Elapsed: 1.6012921333312988
# 		Run on 2013-12-10 11:10:00
# Ichi regime at 2013-12-10 11:10:00: 1
# Current position delta: 0.03226267342040462
# Elapsed: 1.7020378112792969
# 		Run on 2013-12-11 11:10:00
# Ichi regime at 2013-12-11 11:10:00: 1
# Current position delta: -0.05800676911899727
# Elapsed: 1.6036369800567627
# 		Run on 2013-12-12 11:10:00
# Ichi regime at 2013-12-12 11:10:00: 1
# Current position delta: -0.1141319831790561
# Elapsed: 1.6077022552490234
# 		Run on 2013-12-13 11:10:00
# Ichi regime at 2013-12-13 11:10:00: 1
# Current position delta: -0.1536654849401966
# Elapsed: 1.6037437915802002
# 		Run on 2013-12-14 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-12-14 11:10:00: 1
# New bullish zone position
# Leg: bullish / P.US.CLEG149700 x -1.0 Price: 2.006333535366508 Delta: 0.5086499099975303
# Leg:  / P.US.CLEG149800 x 1.0 Price: 2.541699858334333 Delta: -0.5933351616916177
# Leg:  / C.US.CLEG149850 x 1.0 Price: 1.0999687313778637 Delta: 0.3629240525630053
# Leg:  / C.US.CLEG1410000 x -1.0 Price: 0.6346230647119278 Delta: -0.24571024169616673
# Transactions delta: 0.032528559172751215
# Elapsed: 2.4531846046447754
# 		Run on 2013-12-15 11:10:00
# Ichi regime at 2013-12-15 11:10:00: 1
# Current position delta: 0.03250762154075232
# Elapsed: 1.7641937732696533
# 		Run on 2013-12-16 11:10:00
# Ichi regime at 2013-12-16 11:10:00: 1
# Current position delta: 0.04453081559042815
# Elapsed: 1.5911450386047363
# 		Run on 2013-12-17 11:10:00
# Ichi regime at 2013-12-17 11:10:00: 1
# Current position delta: 0.04529361268251092
# Elapsed: 1.6784021854400635
# 		Run on 2013-12-18 11:10:00
# Ichi regime at 2013-12-18 11:10:00: 1
# Current position delta: 0.04934636803586723
# Elapsed: 1.6343514919281006
# 		Run on 2013-12-19 11:10:00
# Ichi regime at 2013-12-19 11:10:00: 1
# Current position delta: 0.062060429599292366
# Elapsed: 1.6062695980072021
# 		Run on 2013-12-20 11:10:00
# Ichi regime at 2013-12-20 11:10:00: 1
# Current position delta: 0.0647555785854852
# Elapsed: 1.6016156673431396
# 		Run on 2013-12-21 11:10:00
# Ichi regime at 2013-12-21 11:10:00: 1
# Current position delta: 0.07354053393448234
# Elapsed: 1.5982606410980225
# 		Run on 2013-12-22 11:10:00
# Ichi regime at 2013-12-22 11:10:00: 1
# Current position delta: 0.07535195821891072
# Elapsed: 1.615663766860962
# 		Run on 2013-12-23 11:10:00
# Ichi regime at 2013-12-23 11:10:00: 1
# Current position delta: 0.07416976589378343
# Elapsed: 1.5970251560211182
# 		Run on 2013-12-24 11:10:00
# Ichi regime at 2013-12-24 11:10:00: 1
# Current position delta: 0.08226740820317202
# Elapsed: 1.6022789478302002
# 		Run on 2013-12-25 11:10:00
# Ichi regime at 2013-12-25 11:10:00: 1
# Current position delta: 0.09067851829429308
# Elapsed: 1.6079175472259521
# 		Run on 2013-12-26 11:10:00
# Ichi regime at 2013-12-26 11:10:00: 1
# Current position delta: 0.09518894368431152
# Elapsed: 1.6025705337524414
# 		Run on 2013-12-27 11:10:00
# Ichi regime at 2013-12-27 11:10:00: 1
# Current position delta: 0.10741356103175237
# Elapsed: 1.609956979751587
# 		Run on 2013-12-28 11:10:00
# Ichi regime at 2013-12-28 11:10:00: 1
# Current position delta: 0.10116633994253343
# Elapsed: 1.5999376773834229
# 		Run on 2013-12-29 11:10:00
# Ichi regime at 2013-12-29 11:10:00: 1
# Current position delta: 0.10497042576560123
# Elapsed: 1.6255910396575928
# 		Run on 2013-12-30 11:10:00
# Ichi regime at 2013-12-30 11:10:00: 1
# Current position delta: 0.10431657435441044
# Elapsed: 1.6057510375976562
# 		Run on 2013-12-31 11:10:00
# Ichi regime at 2013-12-31 11:10:00: 1
# Current position delta: 0.08036746410124801
# Elapsed: 1.609607458114624
# 		Run on 2014-01-01 11:10:00
# Ichi regime at 2014-01-01 11:10:00: 1
# Current position delta: 0.08352124465584604
# Elapsed: 1.6172840595245361
# 		Run on 2014-01-02 11:10:00
# Ichi regime at 2014-01-02 11:10:00: 1
# Current position delta: -0.012419638564144936
# Elapsed: 1.5926451683044434
# 		Run on 2014-01-03 11:10:00
# Ichi regime at 2014-01-03 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CL
11:10:00: 1
# New bullish zone position
# Leg: bullish / P.US.CLEX164950 x -1.0 Price: 0.9671959402471373 Delta: 0.45085065695569687
# Leg:  / P.US.CLEX165050 x 1.0 Price: 1.494216730985947 Delta: -0.5961601909823375
# Leg:  / C.US.CLEX165100 x 1.0 Price: 0.5563282681556352 Delta: 0.33067757814426346
# Leg:  / C.US.CLEX165250 x -1.0 Price: 0.21510137312155386 Delta: -0.1601913722263208
# Transactions delta: 0.025176671891302016
# Elapsed: 0.9665248394012451
# 		Run on 2016-10-08 11:10:00
# Date not found at 2016-10-08
# Ichi regime at 2016-10-08 11:10:00: None
# Elapsed: 1.4766860008239746
# 		Run on 2016-10-09 11:10:00
# Date not found at 2016-10-09
# Ichi regime at 2016-10-09 11:10:00: None
# Current position delta: 0.0
# Elapsed: 0.23179149627685547
# 		Run on 2016-10-10 11:10:00
# Ichi regime at 2016-10-10 11:10:00: 1
# New bullish zone position
# Leg: bullish / P.US.CLEX165150 x -1.0 Price: 1.0006802939263508 Delta: 0.5150622349128273
# Leg:  / P.US.CLEX165250 x 1.0 Price: 1.6262590614087031 Delta: -0.675967681929913
# Leg:  / C.US.CLEX165300 x 1.0 Price: 0.3343368527393409 Delta: 0.24890075149357435
# Leg:  / C.US.CLEX165450 x -1.0 Price: 0.110982517499008 Delta: -0.10136102115314193
# Transactions delta: -0.01336571667665322
# Elapsed: 0.9808371067047119
# 		Run on 2016-10-11 11:10:00
# Ichi regime at 2016-10-11 11:10:00: 1
# Current position delta: -0.04348471866609305
# Elapsed: 1.6243135929107666
# 		Run on 2016-10-12 11:10:00
# Ichi regime at 2016-10-12 11:10:00: 1
# Current position delta: -0.0634312226908608
# Elapsed: 1.6439552307128906
# 		Run on 2016-10-13 11:10:00
# Date not found at 2016-10-13
# Ichi regime at 2016-10-13 11:10:00: None
# Elapsed: 1.4578416347503662
# 		Run on 2016-10-14 11:10:00
# Ichi regime at 2016-10-14 11:10:00: 1
# New bullish zone position
# Leg: bullish / P.US.CLEX165000 x -1.0 Price: 0.5401791657151058 Delta: 0.4995047492294767
# Leg:  / P.US.CLEX165100 x 1.0 Price: 1.1780006855217096 Delta: -0.7786306091597783
# Leg:  / C.US.CLEX165150 x 1.0 Price: 0.08055851749676624 Delta: 0.12659480076924076
# Leg:  / C.US.CLEX165300 x -1.0 Price: 0.010811758069505073 Delta: -0.020745341286531726
# Transactions delta: -0.1732764004475926
# Elapsed: 0.9815170764923096
# 		Run on 2016-10-15 11:10:00
# Rollover occured, new series used
# Date not found at 2016-10-15
# Ichi regime at 2016-10-15 11:10:00: None
# Current position delta: 0.0
# Elapsed: 1.831291675567627
# 		Run on 2016-10-16 11:10:00
# Ichi regime at 2016-10-16 11:10:00: 1
# New bullish zone position
# Leg: bullish / P.US.CLEZ165050 x -1.0 Price: 1.794699690885306 Delta: 0.4579147747181353
# Leg:  / P.US.CLEZ165150 x 1.0 Price: 2.297303845533552 Delta: -0.5408730922617037
# Leg:  / C.US.CLEZ165200 x 1.0 Price: 1.32722176734314 Delta: 0.41542199877160313
# Leg:  / C.US.CLEZ165350 x -1.0 Price: 0.8161291198123788 Delta: -0.29636437282641337
# Transactions delta: 0.0360993084016214
# Elapsed: 1.174882411956787
# 		Run on 2016-10-17 11:10:00
# Ichi regime at 2016-10-17 11:10:00: 1
# Current position delta: 0.03169697334312044
# Elapsed: 1.6296272277832031
# 		Run on 2016-10-18 11:10:00
# Ichi regime at 2016-10-18 11:10:00: 1
# Current position delta: 0.03466119172785226
# Elapsed: 1.6272952556610107
# 		Run on 2016-10-19 11:10:00
# Ichi regime at 2016-10-19 11:10:00: 1
# Current position delta: 0.05099745915449366
# Elapsed: 1.639803171157837
# 		Run on 2016-10-20 11:10:00
# Ichi regime at 2016-10-20 11:10:00: 1
# Current position delta: 0.03682480404491906
# Elapsed: 1.6829907894134521
# 		Run on 2016-10-21 11:10:00
# Ichi regime at 2016-10-21 11:10:00: 1
# Current position delta: 0.03748184085926409
# Elapsed: 1.620164394378662
# 		Run on 2016-10-22 11:10:00
# Date not found at 2016-10-22
# Ichi regime at 2016-10-22 11:10:00: None
# Elapsed: 1.4363775253295898
# 		Run on 2016-10-23 11:10:00
# Ichi regime at 2016-10-23 11:10:00: 1
# New bullish zone position
# Leg: bullish / P.US.CLEZ165100 x -1.0 Price: 1.5928282352889944 Delta: 0.4810764759210956
# Leg:  / P.US.CLEZ165200 x 1.0 Price: 2.13070574948625 Delta: -0.5800846891981342
# Leg:  / C.US.CLEZ165250 x 1.0 Price: 0.9443069219304085 Delta: 0.36893542247229766
# Leg:  / C.US.CLEZ165400 x -1.0 Price: 0.5263179221056813 Delta: -0.23973039808874297
# Transactions delta: 0.03019681110651612
# Elapsed: 0.9676370620727539
# 		Run on 2016-10-24 11:10:00
# Ichi regime at 2016-10-24 11:10:00: 1
# Current position delta: 0.018416797577628374
# Elapsed: 1.6321797370910645
# 		Run on 2016-10-25 11:10:00
# Ichi regime at 2016-10-25 11:10:00: 1
# Current position delta: 0.013512112572172441
# Elapsed: 1.6384732723236084
# 		Run on 2016-10-26 11:10:00
# Ichi regime at 2016-10-26 11:10:00: 1
# Current position delta: 0.0009741608266143897
# Elapsed: 1.6251566410064697
# 		Run on 2016-10-27 11:10:00
# Ichi regime at 2016-10-27 11:10:00: 1
# Current position delta: 0.0057271010559821756
# Elapsed: 1.6464922428131104
# 		Run on 2016-10-28 11:10:00
# Ichi regime at 2016-10-28 11:10:00: 1
# Current position delta: -0.007782935713303463
# Elapsed: 1.614954948425293
# 		Run on 2016-10-29 11:10:00
# Date not found at 2016-10-29
# Ichi regime at 2016-10-29 11:10:00: None
# Elapsed: 1.4712975025177002
# 		Run on 2016-10-30 11:10:00
# Date not found at 2016-10-30
# Ichi regime at 2016-10-30 11:10:00: None
# Current position delta: 0.0
# Elapsed: 0.25034260749816895
# 		Run on 2016-10-31 11:10:00
# Date not found at 2016-10-31
# Ichi regime at 2016-10-31 11:10:00: None
# Current position delta: 0.0
# Elapsed: 0.22163939476013184
# Done

# %% [markdown]
# # View EXO price series

# %%
for ticker in instruments:
    exo_df, exo_info = exostorage.load_series('{0}_{1}'.format(ticker, EXO_NAME))    
    
    exo_df['exo'].plot(title='{0}_{1}'.format(ticker, EXO_NAME))
    ax = exo_df['ichi_regime'].plot(secondary_y=True)
    ax.set_ylim(-2,2)
    plt.show()
