# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from exobuilder.contracts.futureschain import FuturesChain
from exobuilder.contracts.futurecontract import FutureContract
from exobuilder.tests.assetindexdict import AssetIndexDicts
from datetime import datetime, date, timedelta, time as dttime
from exobuilder.contracts.instrument import Instrument
from exobuilder.data.datasource_mongo import DataSourceMongo
from exobuilder.data.datasource_sql import DataSourceSQL
from exobuilder.data.assetindex_mongo import AssetIndexMongo
from exobuilder.data.exostorage import EXOStorage
from exobuilder.exo.exoenginebase import ExoEngineBase
from exobuilder.exo.transaction import Transaction
import time
from exobuilder.algorithms.rollover_helper import RolloverHelper

import importlib
import logging
importlib.reload(logging);
import matplotlib.pyplot as plt

# %%
EXO_NAME = 'SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged'

# TODO: set to 'False' if EXO building output is too verbosive
verbosive_logging = True # or True - for debug log feed

# TODO: select instruments list for SMART EXO calculation
#instruments = ['CL', 'ES', 'NG', 'ZC', 'ZS', 'ZW', 'ZN']
instruments = ['CL']


# TODO: select start date for SmartEXO calculation
base_date = datetime(2013, 6, 13, 12, 45, 0)

# %% [markdown]
# # Define Bull/Bear/Neutral areas rules

# %%
def ichimoku_regimes(date, price_series):    
    '''
    Calculates Bull/Bear/Neutral areas based on Ichimoku zones
    
    param date: Current date time
    param price_series: price Pandas.Series
    
    Returns:
        -1 - for bearish zone
        0  - for neutral zone
        +1 - for bullish zone
        None - for unknown
    '''
    #
    #  TODO: Change values to fine tune zoning algorithm
    #
    conversion_line_period = 9 # subject of optimization
    base_line_period = 26  # subject of optimization
    leading_spans_lookahead_period = 26  # subject of optimization
    leading_span_b_period = 52 # subject of optimization
        
        
    conversion_line_high = price_series.rolling(window=conversion_line_period).max()
    conversion_line_low = price_series.rolling(window=conversion_line_period).min()
    conversion_line = (conversion_line_high + conversion_line_low) / 2

    base_line_high = price_series.rolling(window=base_line_period).max()
    base_line_low = price_series.rolling(window=base_line_period).min()
    base_line = (base_line_high + base_line_low) / 2

    leading_span_a = ((conversion_line + base_line) / 2).shift(leading_spans_lookahead_period)
    leading_span_b = ((price_series.rolling(window=leading_span_b_period).max() + price_series.rolling(
        window=leading_span_b_period).min()) / 2).shift(leading_spans_lookahead_period)


    #
    # Rules calculation
    #

    # Cloud top and bottom series are defined using leading span A and B
    cloud_top = leading_span_a.rolling(1).max()
    cloud_bottom = leading_span_a.rolling(1).min()

    rule_price_above_cloud_top = price_series > cloud_top
    rule_price_below_cloud_bottom = price_series < cloud_bottom
    rule_price_in_cloud = (price_series < cloud_top) & (price_series > cloud_bottom)

    def get_regime(date):
        if date not in rule_price_above_cloud_top.index:
            logging.debug("Date not found at {0}".format(date))
            return None


        if rule_price_above_cloud_top[date]:
            return 1
        elif rule_price_below_cloud_bottom[date]:
            return -1
        elif rule_price_in_cloud[date]:
            return 0
        return None

    regime = get_regime(date.date())
    logging.debug("Ichi regime at {0}: {1}".format(date, regime))
    return regime

# %%
# Toolbox
def transactions_delta(trans_list):
    return sum([t.delta for t in trans_list])

def log_transactions(trans_list, msg):
    logging.debug(msg)
    [logging.debug(t) for t in trans_list]
    logging.debug('Transactions delta: {0}'.format(transactions_delta(trans_list)))

# %% [markdown]
# # Option position management

# %% [markdown]
# According to https://tmqrexo.slack.com/files/nikolasjoyce/F2PHLEETZ/pasted_image_at_2016_10_14_10_05_am.png

# %% [markdown]
# ## New bullish zone position

# %%
def new_position_bullish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bullish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening hedged long ITM straddle in bullish zone
    #
    # https://files.slack.com/files-tmb/T0484J7T7-F2QBLK53R-93b4252806/pasted_image_at_2016_10_17_10_08_am_720.png
   
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-2].c, date, 4.0, leg_name='bullish'),
                Transaction(opt_chain[-2].p, date, 2.0), 
                Transaction(opt_chain[-9].p, date, -4.0),
                Transaction(opt_chain[9].c, date,  -2.0),
                ]
    log_transactions(trans_list,'New bullish zone position')
    return trans_list

# %% [markdown]
# ## New bearish zone position

# %%
def new_position_bearish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bearish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening short butterfly in bearish zone
    #
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-6].p, date, -1.0, leg_name='bearish'),
                Transaction(opt_chain[2].p, date, 1.0),
                
                Transaction(opt_chain[3].c, date, 1.0),
                Transaction(opt_chain[5].c, date,  -1.0),
                ]
    
 
    log_transactions(trans_list,'New bearish zone position')
    return trans_list

# %% [markdown]
# ## New neutral zone position

# %%
def new_position_neutral_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for neutral zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening long asymmetric butterfly in neutral zone
    #    
    # https://files.slack.com/files-tmb/T0484J7T7-F2PGU8QNQ-6344e6a04c/pasted_image_at_2016_10_14_09_43_am_720.png
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-4].p, date, 3.0, leg_name='bearish'),
                Transaction(opt_chain[1].p, date, -6.0),
                
                Transaction(opt_chain[2].p, date, 3.0),
                Transaction(opt_chain[3].c, date,  0.0),
           ]
    log_transactions(trans_list,'New neutral zone position')
    return trans_list

# %% [markdown]
# ## Manage opened positions

# %%
def manage_opened_position(date, fut, opt_chain, regime, opened_position):
    logging.debug('Current position delta: {0}'.format(opened_position.delta))
    
    # By default: do nothing
    return []

# %% [markdown]
# # Define EXO builder class

# %%
class SmartEXOIchimoku(ExoEngineBase):
    def __init__(self, symbol, direction, date, datasource, log_file_path=''):
        self._symbol = symbol
        self.custom_values = {}
        super().__init__(symbol, direction, date, datasource, log_file_path=log_file_path)

    @staticmethod
    def direction_type():
        return 0

    @staticmethod
    def names_list(symbol):
        return ['{0}_{1}'.format(self._symbol, EXO_NAME)]

    @property
    def exo_name(self):
            return '{0}_{1}'.format(self._symbol, EXO_NAME)

    def is_rollover(self):
        if len(self.position) != 0:
            for p in self.position.legs.values():
                rh = RolloverHelper(p.instrument)
                if rh.is_rollover(p):
                    return True
        return False

    def process_rollover(self):
        trans_list = self.position.close_all_translist()
        logging.info('Rollover occured, new series used')
        return trans_list
    
    def get_custom_values(self):
        """
        Method that return custom EXO data frame values, to store inside EXO Dataframe in the DB
        :return: dictionary {'string_key': (int or float) value}
        """
        return self.custom_values
    

    def process_day(self):
        """
        Main EXO's position management method
        :return: list of Transactions to process
        """

        # Get cont futures price for EXO
        exo_df, exo_info = self.datasource.exostorage.load_series("{0}_ContFut".format(self._symbol))

        regime = ichimoku_regimes(self.date, exo_df['exo'])

        trans_list = []

        if regime is None and len(self.position) > 0:
            return self.position.close_all_translist()
        
        instr = self.datasource.get(self._symbol, self.date)
        rh = RolloverHelper(instr)
        fut, opt_chain = rh.get_active_chains()

        if regime == 1 and 'bullish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bullish_zone(self.date, fut, opt_chain)
            
            return trans_list
        if regime == -1 and 'bearish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bearish_zone(self.date, fut, opt_chain)
            return trans_list

        if regime == 0 and 'neutral' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_neutral_zone(self.date, fut, opt_chain)
            return trans_list
        
        #
        # Writing custom values to store inside DB 
        #
        self.custom_values = {
            'ichi_regime': regime if regime is not None else float('nan')
        }
        
        #
        # Manage opened position
        #
        return manage_opened_position(self.date, fut, opt_chain, regime, self.position)

# %% [markdown]
# # Run EXO build process (WARN: long-running task!)

# %%
from pymongo import MongoClient

if verbosive_logging:
    logging.basicConfig(format='%(message)s', level=logging.DEBUG)
else:
    logging.basicConfig(format='%(message)s', level=logging.INFO)

mongo_connstr = 'mongodb://exowriter:qmWSy4K3@10.0.1.2/tmldb?authMechanism=SCRAM-SHA-1'
mongo_db_name = 'tmldb'
assetindex = AssetIndexMongo(mongo_connstr, mongo_db_name)
exostorage = EXOStorage(mongo_connstr, mongo_db_name)

#base_date = datetime(2011, 6, 13, 12, 45, 0)


futures_limit = 3
options_limit = 10

DEBUG = '.'

datasource = DataSourceMongo(mongo_connstr, mongo_db_name, assetindex, futures_limit, options_limit, exostorage)

server = 'h9ggwlagd1.database.windows.net'
user = 'modelread'
password = '4fSHRXwd4u'
datasource = DataSourceSQL(server, user, password, assetindex, futures_limit, options_limit, exostorage)

enddate = datetime.combine(datetime.now().date(), dttime(12, 45, 0))
currdate = base_date


logging.info("Deleting all SmartEXO of :" + EXO_NAME)
client = MongoClient(mongo_connstr)
db = client[mongo_db_name]
db['exo_data'].delete_many({'name': {'$regex': '.*{0}*.'.format(EXO_NAME)}})


logging.info("Starting EXO calculation process from: {0}".format(currdate))
for ticker in instruments:
    logging.info("Processing: "+ticker)
    currdate = base_date
    while currdate <= enddate:
        
        start_time = time.time()
        date = currdate

        asset_info = assetindex.get_instrument_info(ticker)
        exec_time_end, decision_time_end = AssetIndexMongo.get_exec_time(date, asset_info)
        
        logging.info("\t\tRun on {0}".format(decision_time_end))

        with SmartEXOIchimoku(ticker, 0, decision_time_end, datasource) as exo_engine:
            # Load EXO information from mongo
            exo_engine.load()
            exo_engine.calculate()

        end_time = time.time()
        currdate += timedelta(days=1)
        logging.debug("Elapsed: {0}".format(end_time-start_time))
logging.info('Done')
# Out:
# Deleting all SmartEXO of :SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged
# Starting EXO calculation process from: 2013-06-13 12:45:00
# Processing: CL
# 		Run on 2013-06-13 11:10:00
# Ichi regime at 2013-06-13 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEN139500 x 4.0 Price: 1.5164769947394205 Delta: 2.8030996009365974
# Leg:  / P.US.CLEN139500 x 2.0 Price: 0.416640642643479 Delta: -0.6000313569883071
# Leg:  / P.US.CLEN139150 x -4.0 Price: 0.04404162352391161 Delta: 0.15930862166845333
# Leg:  / C.US.CLEN1310050 x -2.0 Price: 0.012720850179421372 Delta: -0.03497092305487929
# Transactions delta: 2.3274059425618643
# Elapsed: 0.8978052139282227
# 		Run on 2013-06-14 11:10:00
# Ichi regime at 2013-06-14 11:10:00: 1
# Current position delta: 3.4879106120701446
# Elapsed: 1.6358411312103271
# 		Run on 2013-06-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-06-15 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEQ139700 x 4.0 Price: 2.809856299459504 Delta: 2.3524990982242415
# Leg:  / P.US.CLEQ139700 x 2.0 Price: 1.7502063447276157 Delta: -0.8251324274264591
# Leg:  / P.US.CLEQ139350 x -4.0 Price: 0.7744092064154806 Delta: 0.8560867289294268
# Leg:  / C.US.CLEQ1310250 x -2.0 Price: 0.5946145514882879 Delta: -0.4178748585686776
# Transactions delta: 1.9655785411585318
# Elapsed: 2.4513838291168213
# 		Run on 2013-06-16 11:10:00
# Ichi regime at 2013-06-16 11:10:00: 1
# Current position delta: 1.965989602525612
# Elapsed: 1.7865891456604004
# 		Run on 2013-06-17 11:10:00
# Ichi regime at 2013-06-17 11:10:00: 1
# Current position delta: 1.9627416378056104
# Elapsed: 1.614989995956421
# 		Run on 2013-06-18 11:10:00
# Ichi regime at 2013-06-18 11:10:00: 1
# Current position delta: 2.076880772722829
# Elapsed: 1.6063742637634277
# 		Run on 2013-06-19 11:10:00
# Ichi regime at 2013-06-19 11:10:00: 1
# Current position delta: 2.04240900108939
# Elapsed: 1.5963914394378662
# 		Run on 2013-06-20 11:10:00
# Ichi regime at 2013-06-20 11:10:00: 1
# Current position delta: 1.628819131340512
# Elapsed: 1.6062920093536377
# 		Run on 2013-06-21 11:10:00
# Ichi regime at 2013-06-21 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEQ139050 x -1.0 Price: 1.1863975963711155 Delta: 0.29216820623130674
# Leg:  / P.US.CLEQ139450 x 1.0 Price: 2.6463931201343414 Delta: -0.5497657247330265
# Leg:  / C.US.CLEQ139500 x 1.0 Price: 1.5422452908799897 Delta: 0.41224126453000703
# Leg:  / C.US.CLEQ139600 x -1.0 Price: 1.13668184342891 Delta: -0.33831290965281774
# Transactions delta: -0.1836691636245305
# Elapsed: 2.2702958583831787
# 		Run on 2013-06-22 11:10:00
# Ichi regime at 2013-06-22 11:10:00: -1
# Current position delta: -0.1873853124930635
# Elapsed: 1.612081527709961
# 		Run on 2013-06-23 11:10:00
# Ichi regime at 2013-06-23 11:10:00: -1
# Current position delta: -0.19084058569504342
# Elapsed: 1.6023261547088623
# 		Run on 2013-06-24 11:10:00
# Ichi regime at 2013-06-24 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEQ139450 x 4.0 Price: 2.512633540709089 Delta: 2.3039879993832804
# Leg:  / P.US.CLEQ139450 x 2.0 Price: 1.683905790693835 Delta: -0.8490840406393931
# Leg:  / P.US.CLEQ139100 x -4.0 Price: 0.6916288867057894 Delta: 0.8347771541769403
# Leg:  / C.US.CLEQ1310000 x -2.0 Price: 0.4751748921285923 Delta: -0.36587349213282616
# Transactions delta: 1.9238076207880015
# Elapsed: 2.2628374099731445
# 		Run on 2013-06-25 11:10:00
# Ichi regime at 2013-06-25 11:10:00: 1
# Current position delta: 1.904319277375504
# Elapsed: 1.685060977935791
# 		Run on 2013-06-26 11:10:00
# Ichi regime at 2013-06-26 11:10:00: 1
# Current position delta: 1.8817073509140996
# Elapsed: 1.5979933738708496
# 		Run on 2013-06-27 11:10:00
# Ichi regime at 2013-06-27 11:10:00: 1
# Current position delta: 2.209628827113581
# Elapsed: 1.6028013229370117
# 		Run on 2013-06-28 11:10:00
# Ichi regime at 2013-06-28 11:10:00: 1
# Current position delta: 2.2596355134035413
# Elapsed: 1.6066865921020508
# 		Run on 2013-06-29 11:10:00
# Ichi regime at 2013-06-29 11:10:00: 1
# Current position delta: 2.184781752952109
# Elapsed: 1.6104342937469482
# 		Run on 2013-06-30 11:10:00
# Ichi regime at 2013-06-30 11:10:00: 1
# Current position delta: 2.1999242720945755
# Elapsed: 1.6179232597351074
# 		Run on 2013-07-01 11:10:00
# Ichi regime at 2013-07-01 11:10:00: 1
# Current position delta: 2.4209410027820617
# Elapsed: 1.6159520149230957
# 		Run on 2013-07-02 11:10:00
# Ichi regime at 2013-07-02 11:10:00: 1
# Current position delta: 2.5443111653923793
# Elapsed: 1.598421573638916
# 		Run on 2013-07-03 11:10:00
# Ichi regime at 2013-07-03 11:10:00: 1
# Current position delta: 2.4537656688234546
# Elapsed: 1.616255521774292
# 		Run on 2013-07-04 11:10:00
# Ichi regime at 2013-07-04 11:10:00: 1
# Current position delta: 2.3792673036534446
# Elapsed: 1.5963785648345947
# 		Run on 2013-07-05 11:10:00
# Ichi regime at 2013-07-05 11:10:00: 1
# Current position delta: 2.294508168486656
# Elapsed: 1.613473892211914
# 		Run on 2013-07-06 11:10:00
# Ichi regime at 2013-07-06 11:10:00: 1
# Current position delta: 2.2461419545721344
# Elapsed: 1.60798978805542
# 		Run on 2013-07-07 11:10:00
# Ichi regime at 2013-07-07 11:10:00: 1
# Current position delta: 2.2465640075241775
# Elapsed: 1.6018860340118408
# 		Run on 2013-07-08 11:10:00
# Ichi regime at 2013-07-08 11:10:00: 1
# Current position delta: 2.2963176905106546
# Elapsed: 1.6079561710357666
# 		Run on 2013-07-09 11:10:00
# Ichi regime at 2013-07-09 11:10:00: 1
# Current position delta: 2.231768950237806
# Elapsed: 1.6119120121002197
# 		Run on 2013-07-10 11:10:00
# Ichi regime at 2013-07-10 11:10:00: 1
# Current position delta: 2.0582570094547257
# Elapsed: 1.629575252532959
# 		Run on 2013-07-11 11:10:00
# Ichi regime at 2013-07-11 11:10:00: 1
# Current position delta: 2.136581416696336
# Elapsed: 1.6098742485046387
# 		Run on 2013-07-12 11:10:00
# Ichi regime at 2013-07-12 11:10:00: 1
# Current position delta: 2.0634067428052334
# Elapsed: 1.607248067855835
# 		Run on 2013-07-13 11:10:00
# Ichi regime at 2013-07-13 11:10:00: 1
# Current position delta: 2.0364518074294784
# Elapsed: 1.623509168624878
# 		Run on 2013-07-14 11:10:00
# Ichi regime at 2013-07-14 11:10:00: 1
# Current position delta: 2.016951434873161
# Elapsed: 1.6166081428527832
# 		Run on 2013-07-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-07-15 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEU1310500 x 4.0 Price: 2.995997348903302 Delta: 2.247447776904317
# Leg:  / P.US.CLEU1310500 x 2.0 Price: 2.2266740097001616 Delta: -0.8773476787420391
# Leg:  / P.US.CLEU1310150 x -4.0 Price: 1.092999020580212 Delta: 1.0132399654722046
# Leg:  / C.US.CLEU1311050 x -2.0 Price: 0.9201334428246781 Delta: -0.4950577190226732
# Transactions delta: 1.8882823446118093
# Elapsed: 2.4688150882720947
# 		Run on 2013-07-16 11:10:00
# Ichi regime at 2013-07-16 11:10:00: 1
# Current position delta: 1.8917935958739371
# Elapsed: 1.7646403312683105
# 		Run on 2013-07-17 11:10:00
# Ichi regime at 2013-07-17 11:10:00: 1
# Current position delta: 1.914369738358705
# Elapsed: 1.5854249000549316
# 		Run on 2013-07-18 11:10:00
# Ichi regime at 2013-07-18 11:10:00: 1
# Current position delta: 2.111709935668899
# Elapsed: 1.6283342838287354
# 		Run on 2013-07-19 11:10:00
# Ichi regime at 2013-07-19 11:10:00: 1
# Current position delta: 2.114215434913433
# Elapsed: 1.6698157787322998
# 		Run on 2013-07-20 11:10:00
# Ichi regime at 2013-07-20 11:10:00: 1
# Current position delta: 2.1259003715229325
# Elapsed: 1.614086389541626
# 		Run on 2013-07-21 11:10:00
# Ichi regime at 2013-07-21 11:10:00: 1
# Current position delta: 2.133764067754438
# Elapsed: 1.63612961769104
# 		Run on 2013-07-22 11:10:00
# Ichi regime at 2013-07-22 11:10:00: 1
# Current position delta: 2.0451379721282823
# Elapsed: 1.692032814025879
# 		Run on 2013-07-23 11:10:00
# Ichi regime at 2013-07-23 11:10:00: 1
# Current position delta: 2.019605742217949
# Elapsed: 1.6045050621032715
# 		Run on 2013-07-24 11:10:00
# Ichi regime at 2013-07-24 11:10:00: 1
# Current position delta: 1.8227623197205562
# Elapsed: 1.613342046737671
# 		Run on 2013-07-25 11:10:00
# Ichi regime at 2013-07-25 11:10:00: 1
# Current position delta: 1.8928380782881287
# Elapsed: 1.6265292167663574
# 		Run on 2013-07-26 11:10:00
# Ichi regime at 2013-07-26 11:10:00: 1
# Current position delta: 1.7643567395742328
# Elapsed: 1.6245155334472656
# 		Run on 2013-07-27 11:10:00
# Ichi regime at 2013-07-27 11:10:00: 1
# Current position delta: 1.7143884358043748
# Elapsed: 1.6059422492980957
# 		Run on 2013-07-28 11:10:00
# Ichi regime at 2013-07-28 11:10:00: 1
# Current position delta: 1.699221736812687
# Elapsed: 1.6327927112579346
# 		Run on 2013-07-29 11:10:00
# Ichi regime at 2013-07-29 11:10:00: 1
# Current position delta: 1.6840673250762235
# Elapsed: 1.606682538986206
# 		Run on 2013-07-30 11:10:00
# Ichi regime at 2013-07-30 11:10:00: 1
# Current position delta: 1.400440898449128
# Elapsed: 1.5952763557434082
# 		Run on 2013-07-31 11:10:00
# Ichi regime at 2013-07-31 11:10:00: 1
# Current position delta: 1.5849839462504551
# Elapsed: 1.5995986461639404
# 		Run on 2013-08-01 11:10:00
# Ichi regime at 2013-08-01 11:10:00: 1
# Current position delta: 2.2647531891866772
# Elapsed: 1.6027908325195312
# 		Run on 2013-08-02 11:10:00
# Ichi regime at 2013-08-02 11:10:00: 1
# Current position delta: 2.04573549687482
# Elapsed: 1.5959079265594482
# 		Run on 2013-08-03 11:10:00
# Ichi regime at 2013-08-03 11:10:00: 1
# Current position delta: 2.1290633805900567
# Elapsed: 1.592510461807251
# 		Run on 2013-08-04 11:10:00
# Ichi regime at 2013-08-04 11:10:00: 1
# Current position delta: 2.1545901071998625
# Elapsed: 1.671416997909546
# 		Run on 2013-08-05 11:10:00
# Ichi regime at 2013-08-05 11:10:00: 1
# Current position delta: 2.17252886975611
# Elapsed: 1.5982046127319336
# 		Run on 2013-08-06 11:10:00
# Ichi regime at 2013-08-06 11:10:00: 1
# Current position delta: 1.7137636386438544
# Elapsed: 1.6705141067504883
# 		Run on 2013-08-07 11:10:00
# Ichi regime at 2013-08-07 11:10:00: 1
# Current position delta: 1.3950246581544699
# Elapsed: 1.5883193016052246
# 		Run on 2013-08-08 11:10:00
# Ichi regime at 2013-08-08 11:10:00: 1
# Current position delta: 0.802982330055991
# Elapsed: 1.5950284004211426
# 		Run on 2013-08-09 11:10:00
# Ichi regime at 2013-08-09 11:10:00: 1
# Current position delta: 1.979109204423505
# Elapsed: 1.59421706199646
# 		Run on 2013-08-10 11:10:00
# Ichi regime at 2013-08-10 11:10:00: 1
# Current position delta: 2.0332480516937546
# Elapsed: 1.6089627742767334
# 		Run on 2013-08-11 11:10:00
# Ichi regime at 2013-08-11 11:10:00: 1
# Current position delta: 2.0851408194770262
# Elapsed: 1.5976345539093018
# 		Run on 2013-08-12 11:10:00
# Ichi regime at 2013-08-12 11:10:00: 1
# Current position delta: 2.043742175046245
# Elapsed: 1.6079387664794922
# 		Run on 2013-08-13 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-08-13 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEV1310550 x 4.0 Price: 3.309763582675174 Delta: 2.2590032264121973
# Leg:  / P.US.CLEV1310550 x 2.0 Price: 2.419976768502096 Delta: -0.871258576839823
# Leg:  / P.US.CLEV1310200 x -4.0 Price: 1.2112497398209712 Delta: 1.0412647475644627
# Leg:  / C.US.CLEV1311100 x -2.0 Price: 1.1285280781617288 Delta: -0.5435053615107173
# Transactions delta: 1.8855040356261197
# Elapsed: 2.4393973350524902
# 		Run on 2013-08-14 11:10:00
# Ichi regime at 2013-08-14 11:10:00: 1
# Current position delta: 1.9003479359136586
# Elapsed: 1.8003695011138916
# 		Run on 2013-08-15 11:10:00
# Ichi regime at 2013-08-15 11:10:00: 1
# Current position delta: 1.9193377363042545
# Elapsed: 1.619011402130127
# 		Run on 2013-08-16 11:10:00
# Ichi regime at 2013-08-16 11:10:00: 1
# Current position delta: 1.9403347609834791
# Elapsed: 1.6044151782989502
# 		Run on 2013-08-17 11:10:00
# Ichi regime at 2013-08-17 11:10:00: 1
# Current position delta: 1.9703735843029735
# Elapsed: 1.6134488582611084
# 		Run on 2013-08-18 11:10:00
# Ichi regime at 2013-08-18 11:10:00: 1
# Current position delta: 1.9726286657792698
# Elapsed: 1.606058120727539
# 		Run on 2013-08-19 11:10:00
# Ichi regime at 2013-08-19 11:10:00: 1
# Current position delta: 1.9344901693807042
# Elapsed: 1.5934979915618896
# 		Run on 2013-08-20 11:10:00
# Ichi regime at 2013-08-20 11:10:00: 1
# Current position delta: 1.7708410991746042
# Elapsed: 1.6003119945526123
# 		Run on 2013-08-21 11:10:00
# Ichi regime at 2013-08-21 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEV1310100 x -1.0 Price: 1.4321041294466283 Delta: 0.3162012893362854
# Leg:  / P.US.CLEV1310500 x 1.0 Price: 3.0725748456989166 Delta: -0.5526179871668492
# Leg:  / C.US.CLEV1310550 x 1.0 Price: 1.7998767871509784 Delta: 0.4148379878075999
# Leg:  / C.US.CLEV1310650 x -1.0 Price: 1.4144906218332025 Delta: -0.35276964784351883
# Transactions delta: -0.17434835786648273
# Elapsed: 2.2809054851531982
# 		Run on 2013-08-22 11:10:00
# Ichi regime at 2013-08-22 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEV1310400 x 4.0 Price: 3.0149370453753406 Delta: 2.2931687751880423
# Leg:  / P.US.CLEV1310400 x 2.0 Price: 2.065151955802115 Delta: -0.8542086294526718
# Leg:  / P.US.CLEV1310050 x -4.0 Price: 0.9848659251055345 Delta: 0.9582651770523848
# Leg:  / C.US.CLEV1310950 x -2.0 Price: 0.8111677569004669 Delta: -0.4754371143350579
# Transactions delta: 1.9217882084526974
# Elapsed: 2.277785062789917
# 		Run on 2013-08-23 11:10:00
# Ichi regime at 2013-08-23 11:10:00: 1
# Current position delta: 2.0394303519738184
# Elapsed: 1.650609016418457
# 		Run on 2013-08-24 11:10:00
# Ichi regime at 2013-08-24 11:10:00: 1
# Current position delta: 2.044922693670232
# Elapsed: 1.6200284957885742
# 		Run on 2013-08-25 11:10:00
# Ichi regime at 2013-08-25 11:10:00: 1
# Current position delta: 2.0518414005935948
# Elapsed: 1.6101713180541992
# 		Run on 2013-08-26 11:10:00
# Ichi regime at 2013-08-26 11:10:00: 1
# Current position delta: 2.036528063026615
# Elapsed: 1.6137609481811523
# 		Run on 2013-08-27 11:10:00
# Ichi regime at 2013-08-27 11:10:00: 1
# Current position delta: 2.247430753785244
# Elapsed: 1.6274235248565674
# 		Run on 2013-08-28 11:10:00
# Ichi regime at 2013-08-28 11:10:00: 1
# Current position delta: 2.213721227991625
# Elapsed: 1.6179320812225342
# 		Run on 2013-08-29 11:10:00
# Ichi regime at 2013-08-29 11:10:00: 1
# Current position delta: 2.159236624900842
# Elapsed: 1.6022281646728516
# 		Run on 2013-08-30 11:10:00
# Ichi regime at 2013-08-30 11:10:00: 1
# Current position delta: 2.1038767074656133
# Elapsed: 1.620100975036621
# 		Run on 2013-08-31 11:10:00
# Ichi regime at 2013-08-31 11:10:00: 1
# Current position delta: 2.1072838774136713
# Elapsed: 1.6395258903503418
# 		Run on 2013-09-01 11:10:00
# Ichi regime at 2013-09-01 11:10:00: 1
# Current position delta: 2.1229202893487624
# Elapsed: 1.6099255084991455
# 		Run on 2013-09-02 11:10:00
# Ichi regime at 2013-09-02 11:10:00: 1
# Current position delta: 2.058776738092063
# Elapsed: 1.6067473888397217
# 		Run on 2013-09-03 11:10:00
# Ichi regime at 2013-09-03 11:10:00: 1
# Current position delta: 2.1618673656469607
# Elapsed: 1.9025866985321045
# 		Run on 2013-09-04 11:10:00
# Ichi regime at 2013-09-04 11:10:00: 1
# Current position delta: 2.071254020080226
# Elapsed: 1.5927984714508057
# 		Run on 2013-09-05 11:10:00
# Ichi regime at 2013-09-05 11:10:00: 1
# Current position delta: 2.2068960744289723
# Elapsed: 1.6543145179748535
# 		Run on 2013-09-06 11:10:00
# Ichi regime at 2013-09-06 11:10:00: 1
# Current position delta: 2.409721661439974
# Elapsed: 1.6002702713012695
# 		Run on 2013-09-07 11:10:00
# Ichi regime at 2013-09-07 11:10:00: 1
# Current position delta: 2.422735376195066
# Elapsed: 1.6324725151062012
# 		Run on 2013-09-08 11:10:00
# Ichi regime at 2013-09-08 11:10:00: 1
# Current position delta: 2.458583465702354
# Elapsed: 1.5897579193115234
# 		Run on 2013-09-09 11:10:00
# Ichi regime at 2013-09-09 11:10:00: 1
# Current position delta: 2.5144810654081016
# Elapsed: 1.5996465682983398
# 		Run on 2013-09-10 11:10:00
# Ichi regime at 2013-09-10 11:10:00: 1
# Current position delta: 2.418892793245808
# Elapsed: 1.596431016921997
# 		Run on 2013-09-11 11:10:00
# Ichi regime at 2013-09-11 11:10:00: 1
# Current position delta: 2.5505144596576486
# Elapsed: 1.6173667907714844
# 		Run on 2013-09-12 11:10:00
# Ichi regime at 2013-09-12 11:10:00: 1
# Current position delta: 2.86169038422263
# Elapsed: 1.6778154373168945
# 		Run on 2013-09-13 11:10:00
# Ichi regime at 2013-09-13 11:10:00: 1
# Current position delta: 3.091832429096216
# Elapsed: 1.6024444103240967
# 		Run on 2013-09-14 11:10:00
# Ichi regime at 2013-09-14 11:10:00: 1
# Current position delta: 3.214454344037599
# Elapsed: 1.6086783409118652
# 		Run on 2013-09-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-09-15 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX1310700 x 4.0 Price: 3.2004285540704203 Delta: 2.276689299429262
# Leg:  / P.US.CLEX1310700 x 2.0 Price: 2.2610007075642145 Delta: -0.862451710257102
# Leg:  / P.US.CLEX1310350 x -4.0 Price: 1.0947295761715807 Delta: 0.9996949804649172
# Leg:  / C.US.CLEX1311250 x -2.0 Price: 1.0362086118175071 Delta: -0.5266985422639505
# Transactions delta: 1.8872340273731265
# Elapsed: 2.4904510974884033
# 		Run on 2013-09-16 11:10:00
# Ichi regime at 2013-09-16 11:10:00: 1
# Current position delta: 1.7846934490535558
# Elapsed: 1.7652220726013184
# 		Run on 2013-09-17 11:10:00
# Ichi regime at 2013-09-17 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEX1310200 x -1.0 Price: 1.4962592143290934 Delta: 0.32515351012886107
# Leg:  / P.US.CLEX1310600 x 1.0 Price: 3.22618297642898 Delta: -0.5597106833945648
# Leg:  / C.US.CLEX1310650 x 1.0 Price: 1.818930775874449 Delta: 0.4091278714774807
# Leg:  / C.US.CLEX1310750 x -1.0 Price: 1.4535704639693776 Delta: -0.350275569720179
# Transactions delta: -0.17570487150840197
# Elapsed: 2.259180784225464
# 		Run on 2013-09-18 11:10:00
# Ichi regime at 2013-09-18 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX1310600 x 4.0 Price: 3.011348604492049 Delta: 2.256409119063158
# Leg:  / P.US.CLEX1310600 x 2.0 Price: 2.1922496619425473 Delta: -0.8725631763858693
# Leg:  / P.US.CLEX1310250 x -4.0 Price: 1.0428078919215373 Delta: 0.9923728325613533
# Leg:  / C.US.CLEX1311150 x -2.0 Price: 0.9177247032435965 Delta: -0.4958522978588004
# Transactions delta: 1.8803664773798414
# Elapsed: 2.2591562271118164
# 		Run on 2013-09-19 11:10:00
# Ichi regime at 2013-09-19 11:10:00: 1
# Current position delta: 1.8112242268659868
# Elapsed: 1.647937297821045
# 		Run on 2013-09-20 11:10:00
# Ichi regime at 2013-09-20 11:10:00: 1
# Current position delta: 1.6720533187421716
# Elapsed: 1.6328868865966797
# 		Run on 2013-09-21 11:10:00
# Ichi regime at 2013-09-21 11:10:00: 1
# Current position delta: 1.6492512650132198
# Elapsed: 1.5991346836090088
# 		Run on 2013-09-22 11:10:00
# Ichi regime at 2013-09-22 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEX1310200 x -1.0 Price: 1.1240098315809526 Delta: 0.299384240315587
# Leg:  / P.US.CLEX1310600 x 1.0 Price: 2.83229653913115 Delta: -0.573859892368062
# Leg:  / C.US.CLEX1310650 x 1.0 Price: 1.441455716506681 Delta: 0.38957253767151995
# Leg:  / C.US.CLEX1310750 x -1.0 Price: 1.0840377856753847 Delta: -0.32020737828531376
# Transactions delta: -0.2051104926662688
# Elapsed: 2.289496421813965
# 		Run on 2013-09-23 11:10:00
# Ichi regime at 2013-09-23 11:10:00: -1
# Current position delta: -0.22414110058455827
# Elapsed: 1.5905325412750244
# 		Run on 2013-09-24 11:10:00
# Ichi regime at 2013-09-24 11:10:00: -1
# Current position delta: -0.22825049362887917
# Elapsed: 1.5882432460784912
# 		Run on 2013-09-25 11:10:00
# Ichi regime at 2013-09-25 11:10:00: -1
# Current position delta: -0.23196823095424446
# Elapsed: 1.6248791217803955
# 		Run on 2013-09-26 11:10:00
# Ichi regime at 2013-09-26 11:10:00: -1
# Current position delta: -0.239649912077616
# Elapsed: 1.6021552085876465
# 		Run on 2013-09-27 11:10:00
# Ichi regime at 2013-09-27 11:10:00: -1
# Current position delta: -0.25545216578499114
# Elapsed: 1.6025004386901855
# 		Run on 2013-09-28 11:10:00
# Ichi regime at 2013-09-28 11:10:00: -1
# Current position delta: -0.2668149138020646
# Elapsed: 1.6409122943878174
# 		Run on 2013-09-29 11:10:00
# Ichi regime at 2013-09-29 11:10:00: -1
# Current position delta: -0.2743881659167114
# Elapsed: 1.640139102935791
# 		Run on 2013-09-30 11:10:00
# Ichi regime at 2013-09-30 11:10:00: -1
# Current position delta: -0.27814297421187784
# Elapsed: 1.6113216876983643
# 		Run on 2013-10-01 11:10:00
# Ichi regime at 2013-10-01 11:10:00: -1
# Current position delta: -0.26274864930879627
# Elapsed: 1.5890092849731445
# 		Run on 2013-10-02 11:10:00
# Ichi regime at 2013-10-02 11:10:00: -1
# Current position delta: -0.2808951892466993
# Elapsed: 1.63565993309021
# 		Run on 2013-10-03 11:10:00
# Ichi regime at 2013-10-03 11:10:00: -1
# Current position delta: -0.31388322217472847
# Elapsed: 1.6040570735931396
# 		Run on 2013-10-04 11:10:00
# Ichi regime at 2013-10-04 11:10:00: -1
# Current position delta: -0.3213482780400859
# Elapsed: 1.6039414405822754
# 		Run on 2013-10-05 11:10:00
# Ichi regime at 2013-10-05 11:10:00: -1
# Current position delta: -0.34799852954665483
# Elapsed: 1.6112101078033447
# 		Run on 2013-10-06 11:10:00
# Ichi regime at 2013-10-06 11:10:00: -1
# Current position delta: -0.3641296718220066
# Elapsed: 1.6154060363769531
# 		Run on 2013-10-07 11:10:00
# Ichi regime at 2013-10-07 11:10:00: -1
# Current position delta: -0.3823462838933684
# Elapsed: 1.6077203750610352
# 		Run on 2013-10-08 11:10:00
# Ichi regime at 2013-10-08 11:10:00: -1
# Current position delta: -0.39083467525228993
# Elapsed: 1.600360631942749
# 		Run on 2013-10-09 11:10:00
# Ichi regime at 2013-10-09 11:10:00: -1
# Current position delta: -0.3404381765219697
# Elapsed: 1.610090732574463
# 		Run on 2013-10-10 11:10:00
# Ichi regime at 2013-10-10 11:10:00: -1
# Current position delta: -0.41208561253421444
# Elapsed: 1.6630070209503174
# 		Run on 2013-10-11 11:10:00
# Ichi regime at 2013-10-11 11:10:00: -1
# Current position delta: -0.375931020985368
# Elapsed: 1.607130527496338
# 		Run on 2013-10-12 11:10:00
# Ichi regime at 2013-10-12 11:10:00: -1
# Current position delta: -0.41204576650540636
# Elapsed: 1.5982787609100342
# 		Run on 2013-10-13 11:10:00
# Ichi regime at 2013-10-13 11:10:00: -1
# Current position delta: -0.42497568575866607
# Elapsed: 1.653883695602417
# 		Run on 2013-10-14 11:10:00
# Ichi regime at 2013-10-14 11:10:00: -1
# Current position delta: -0.5508553641544609
# Elapsed: 1.6410374641418457
# 		Run on 2013-10-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-10-15 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEZ139850 x -1.0 Price: 1.3912465699868726 Delta: 0.30669706986996464
# Leg:  / P.US.CLEZ1310250 x 1.0 Price: 2.9464684733531072 Delta: -0.5397896369469284
# Leg:  / C.US.CLEZ1310300 x 1.0 Price: 1.8731681020796174 Delta: 0.42754645010301084
# Leg:  / C.US.CLEZ1310400 x -1.0 Price: 1.467615660592692 Delta: -0.3641712409913968
# Transactions delta: -0.1697173579653497
# Elapsed: 2.461398124694824
# 		Run on 2013-10-16 11:10:00
# Ichi regime at 2013-10-16 11:10:00: -1
# Current position delta: -0.1524096909506186
# Elapsed: 1.7858726978302002
# 		Run on 2013-10-17 11:10:00
# Ichi regime at 2013-10-17 11:10:00: -1
# Current position delta: -0.1881184052716136
# Elapsed: 1.626084804534912
# 		Run on 2013-10-18 11:10:00
# Ichi regime at 2013-10-18 11:10:00: -1
# Current position delta: -0.20510885930372358
# Elapsed: 1.6153864860534668
# 		Run on 2013-10-19 11:10:00
# Ichi regime at 2013-10-19 11:10:00: -1
# Current position delta: -0.21445041423853733
# Elapsed: 1.6204419136047363
# 		Run on 2013-10-20 11:10:00
# Ichi regime at 2013-10-20 11:10:00: -1
# Current position delta: -0.21851101825633162
# Elapsed: 1.668273687362671
# 		Run on 2013-10-21 11:10:00
# Ichi regime at 2013-10-21 11:10:00: -1
# Current position delta: -0.2426378062451474
# Elapsed: 1.62247633934021
# 		Run on 2013-10-22 11:10:00
# Ichi regime at 2013-10-22 11:10:00: -1
# Current position delta: -0.2447695439208908
# Elapsed: 1.6100337505340576
# 		Run on 2013-10-23 11:10:00
# Ichi regime at 2013-10-23 11:10:00: -1
# Current position delta: -0.23083490850138455
# Elapsed: 1.6015517711639404
# 		Run on 2013-10-24 11:10:00
# Ichi regime at 2013-10-24 11:10:00: -1
# Current position delta: -0.23248502714085217
# Elapsed: 1.6189696788787842
# 		Run on 2013-10-25 11:10:00
# Ichi regime at 2013-10-25 11:10:00: -1
# Current position delta: -0.25252171169417914
# Elapsed: 1.9231846332550049
# 		Run on 2013-10-26 11:10:00
# Ichi regime at 2013-10-26 11:10:00: -1
# Current position delta: -0.272594694641754
# Elapsed: 1.632699966430664
# 		Run on 2013-10-27 11:10:00
# Ichi regime at 2013-10-27 11:10:00: -1
# Current position delta: -0.2780700535507513
# Elapsed: 1.5928077697753906
# 		Run on 2013-10-28 11:10:00
# Ichi regime at 2013-10-28 11:10:00: -1
# Current position delta: -0.301873524250651
# Elapsed: 1.6744582653045654
# 		Run on 2013-10-29 11:10:00
# Ichi regime at 2013-10-29 11:10:00: -1
# Current position delta: -0.29539436955422127
# Elapsed: 1.6141972541809082
# 		Run on 2013-10-30 11:10:00
# Ichi regime at 2013-10-30 11:10:00: -1
# Current position delta: -0.24702874069391934
# Elapsed: 1.6236751079559326
# 		Run on 2013-10-31 11:10:00
# Ichi regime at 2013-10-31 11:10:00: -1
# Current position delta: -0.24440236529947457
# Elapsed: 1.6245336532592773
# 		Run on 2013-11-01 11:10:00
# Ichi regime at 2013-11-01 11:10:00: -1
# Current position delta: -0.13378858315038789
# Elapsed: 1.599332332611084
# 		Run on 2013-11-02 11:10:00
# Ichi regime at 2013-11-02 11:10:00: -1
# Current position delta: -0.09846938253206405
# Elapsed: 1.6151072978973389
# 		Run on 2013-11-03 11:10:00
# Ichi regime at 2013-11-03 11:10:00: -1
# Current position delta: -0.09445692978414277
# Elapsed: 1.6050019264221191
# 		Run on 2013-11-04 11:10:00
# Ichi regime at 2013-11-04 11:10:00: -1
# Current position delta: -0.10329298330685
# Elapsed: 1.606868028640747
# 		Run on 2013-11-05 11:10:00
# Ichi regime at 2013-11-05 11:10:00: -1
# Current position delta: -0.04621413166182087
# Elapsed: 1.6145727634429932
# 		Run on 2013-11-06 11:10:00
# Ichi regime at 2013-11-06 11:10:00: -1
# Current position delta: -0.12667849178573698
# Elapsed: 1.6204071044921875
# 		Run on 2013-11-07 11:10:00
# Ichi regime at 2013-11-07 11:10:00: -1
# Current position delta: -0.05391668837798169
# Elapsed: 1.626673698425293
# 		Run on 2013-11-08 11:10:00
# Ichi regime at 2013-11-08 11:10:00: -1
# Current position delta: -0.051009952280044235
# Elapsed: 1.6379590034484863
# 		Run on 2013-11-09 11:10:00
# Ichi regime at 2013-11-09 11:10:00: -1
# Current position delta: -0.02714389758889002
# Elapsed: 1.6119840145111084
# 		Run on 2013-11-10 11:10:00
# Ichi regime at 2013-11-10 11:10:00: -1
# Current position delta: -0.019902110077212765
# Elapsed: 1.6061670780181885
# 		Run on 2013-11-11 11:10:00
# Ichi regime at 2013-11-11 11:10:00: -1
# Current position delta: -0.020690910232021187
# Elapsed: 1.6022281646728516
# 		Run on 2013-11-12 11:10:00
# Ichi regime at 2013-11-12 11:10:00: -1
# Current position delta: -0.0010790374772977618
# Elapsed: 1.6006462574005127
# 		Run on 2013-11-13 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-11-13 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEF149150 x -1.0 Price: 0.9526990948672314 Delta: 0.26892312914671257
# Leg:  / P.US.CLEF149550 x 1.0 Price: 2.470147733037237 Delta: -0.5473464929177829
# Leg:  / C.US.CLEF149600 x 1.0 Price: 1.4640695133728698 Delta: 0.4127933618239165
# Leg:  / C.US.CLEF149700 x -1.0 Price: 1.0789304730210922 Delta: -0.3365138986947267
# Transactions delta: -0.20214390064188054
# Elapsed: 2.4755773544311523
# 		Run on 2013-11-14 11:10:00
# Ichi regime at 2013-11-14 11:10:00: -1
# Current position delta: -0.20847174454829603
# Elapsed: 1.803008794784546
# 		Run on 2013-11-15 11:10:00
# Ichi regime at 2013-11-15 11:10:00: -1
# Current position delta: -0.21419653552323664
# Elapsed: 1.6107327938079834
# 		Run on 2013-11-16 11:10:00
# Ichi regime at 2013-11-16 11:10:00: -1
# Current position delta: -0.2235220704278223
# Elapsed: 1.6234264373779297
# 		Run on 2013-11-17 11:10:00
# Ichi regime at 2013-11-17 11:10:00: -1
# Current position delta: -0.22723274649473474
# Elapsed: 1.6382861137390137
# 		Run on 2013-11-18 11:10:00
# Ichi regime at 2013-11-18 11:10:00: -1
# Current position delta: -0.2475935147104727
# Elapsed: 1.617722988128662
# 		Run on 2013-11-19 11:10:00
# Ichi regime at 2013-11-19 11:10:00: -1
# Current position delta: -0.2501387260974848
# Elapsed: 1.5981431007385254
# 		Run on 2013-11-20 11:10:00
# Ichi regime at 2013-11-20 11:10:00: -1
# Current position delta: -0.2607281671973687
# Elapsed: 1.6127407550811768
# 		Run on 2013-11-21 11:10:00
# Ichi regime at 2013-11-21 11:10:00: -1
# Current position delta: -0.2146701873388655
# Elapsed: 1.6097412109375
# 		Run on 2013-11-22 11:10:00
# Ichi regime at 2013-11-22 11:10:00: -1
# Current position delta: -0.24128559604452193
# Elapsed: 1.5988385677337646
# 		Run on 2013-11-23 11:10:00
# Ichi regime at 2013-11-23 11:10:00: -1
# Current position delta: -0.2592352365226036
# Elapsed: 1.6432006359100342
# 		Run on 2013-11-24 11:10:00
# Ichi regime at 2013-11-24 11:10:00: -1
# Current position delta: -0.2643959007748485
# Elapsed: 1.6008398532867432
# 		Run on 2013-11-25 11:10:00
# Ichi regime at 2013-11-25 11:10:00: -1
# Current position delta: -0.2955338728312177
# Elapsed: 1.5992178916931152
# 		Run on 2013-11-26 11:10:00
# Ichi regime at 2013-11-26 11:10:00: -1
# Current position delta: -0.2922813001859277
# Elapsed: 1.5996484756469727
# 		Run on 2013-11-27 11:10:00
# Ichi regime at 2013-11-27 11:10:00: -1
# Current position delta: -0.3568085382255958
# Elapsed: 1.6037261486053467
# 		Run on 2013-11-28 11:10:00
# Ichi regime at 2013-11-28 11:10:00: -1
# Current position delta: -0.35093603458991757
# Elapsed: 1.6014869213104248
# 		Run on 2013-11-29 11:10:00
# Ichi regime at 2013-11-29 11:10:00: -1
# Current position delta: -0.35198301006785015
# Elapsed: 1.5950250625610352
# 		Run on 2013-11-30 11:10:00
# Ichi regime at 2013-11-30 11:10:00: -1
# Current position delta: -0.3557259381298605
# Elapsed: 1.586214542388916
# 		Run on 2013-12-01 11:10:00
# Ichi regime at 2013-12-01 11:10:00: -1
# Current position delta: -0.3678185223274082
# Elapsed: 1.595388412475586
# 		Run on 2013-12-02 11:10:00
# Ichi regime at 2013-12-02 11:10:00: -1
# Current position delta: -0.3585484356607892
# Elapsed: 1.6202006340026855
# 		Run on 2013-12-03 11:10:00
# Ichi regime at 2013-12-03 11:10:00: -1
# Current position delta: -0.2115513991583682
# Elapsed: 1.6119298934936523
# 		Run on 2013-12-04 11:10:00
# Ichi regime at 2013-12-04 11:10:00: -1
# Current position delta: -0.11452538220723163
# Elapsed: 1.6027462482452393
# 		Run on 2013-12-05 11:10:00
# Ichi regime at 2013-12-05 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEF149650 x 4.0 Price: 1.7913099222248476 Delta: 2.6179469179310826
# Leg:  / P.US.CLEF149650 x 2.0 Price: 0.6912667984202443 Delta: -0.6927673767873427
# Leg:  / P.US.CLEF149300 x -4.0 Price: 0.11145032191720894 Delta: 0.2974477121743416
# Leg:  / C.US.CLEF1410200 x -2.0 Price: 0.10069974706970797 Delta: -0.15263153575833227
# Transactions delta: 2.0699957175597494
# Elapsed: 2.2969563007354736
# 		Run on 2013-12-06 11:10:00
# Ichi regime at 2013-12-06 11:10:00: 1
# Current position delta: 2.019228725444897
# Elapsed: 1.6158735752105713
# 		Run on 2013-12-07 11:10:00
# Ichi regime at 2013-12-07 11:10:00: 1
# Current position delta: 2.3544897132546185
# Elapsed: 1.5954923629760742
# 		Run on 2013-12-08 11:10:00
# Ichi regime at 2013-12-08 11:10:00: 1
# Current position delta: 2.4049421011857826
# Elapsed: 1.5924072265625
# 		Run on 2013-12-09 11:10:00
# Ichi regime at 2013-12-09 11:10:00: 1
# Current position delta: 2.3679124029720104
# Elapsed: 1.636348009109497
# 		Run on 2013-12-10 11:10:00
# Ichi regime at 2013-12-10 11:10:00: 1
# Current position delta: 2.8435592509668752
# Elapsed: 1.628997564315796
# 		Run on 2013-12-11 11:10:00
# Ichi regime at 2013-12-11 11:10:00: 1
# Current position delta: 2.2049042682857656
# Elapsed: 1.6341681480407715
# 		Run on 2013-12-12 11:10:00
# Ichi regime at 2013-12-12 11:10:00: 1
# Current position delta: 2.684749060375514
# Elapsed: 1.6278488636016846
# 		Run on 2013-12-13 11:10:00
# Ichi regime at 2013-12-13 11:10:00: 1
# Current position delta: 1.3545401408117634
# Elapsed: 1.6521124839782715
# 		Run on 2013-12-14 11:10:00
# Rollover occured, new series used
# Ichi regime at 2013-12-14 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEG149600 x 4.0 Price: 2.331633115387014 Delta: 2.297263463260498
# Leg:  / P.US.CLEG149600 x 2.0 Price: 1.5721596746016147 Delta: -0.852544295517666
# Leg:  / P.US.CLEG149250 x -4.0 Price: 0.6206010759844816 Delta: 0.8022916963505641
# Leg:  / C.US.CLEG1410150 x -2.0 Price: 0.346111291546606 Delta: -0.30723763229515133
# Transactions delta: 1.939773231798245
# Elapsed: 2.496047258377075
# 		Run on 2013-12-15 11:10:00
# Ichi regime at 2013-12-15 11:10:00: 1
# Current position delta: 1.9388333099029504
# Elapsed: 1.820221185684204
# 		Run on 2013-12-16 11:10:00
# Ichi regime at 2013-12-16 11:10:00: 1
# Current position delta: 2.124808716286536
# Elapsed: 1.5984222888946533
# 		Run on 2013-12-17 11:10:00
# Ichi regime at 2013-12-17 11:10:00: 1
# Current position delta: 2.132731542451463
# Elapsed: 1.6042006015777588
# 		Run on 2013-12-18 11:10:00
# Ichi regime at 2013-12-18 11:10:00: 1
# Current position delta: 2.1688409715504
# Elapsed: 1.612088918685913
# 		Run on 2013-12-19 11:10:00
# Ichi regime at 2013-12-19 11:10:00: 1
# Current position delta: 2.3721502540671926
# Elapsed: 1.6830437183380127
# 		Run on 2013-12-20 11:10:00
# Ichi regime at 2013-12-20 11:10:00: 1
# Current position delta: 2.4178239840033555
# Elapsed: 1.6165797710418701
# 		Run on 2013-12-21 11:10:00
# Ichi regime at 2013-12-21 11:10:00: 1
# Current position delta: 2.5149806397848335
# Elapsed: 1.5911428928375244
# 		Run on 2013-12-22 11:10:00
# Ichi regime at 2013-12-22 11:10:00: 1
# Current position delta: 2.53595122101312
# Elapsed: 1.6007311344146729
# 		Run on 2013-12-23 11:10:00
# Ichi regime at 2013-12-23 11:10:00: 1
# Current position delta: 2.5219475499623654
# Elapsed: 1.6081483364105225
# 		Run on 2013-12-24 11:10:00
# Ichi regime at 2013-12-24 11:10:00: 1
# Current position delta: 2.6144241931261005
# Elapsed: 1.6057145595550537
# 		Run on 2013-12-25 11:10:00
# Ichi regime at 2013-12-25 11:10:00: 1
# Current position delta: 2.7079263403371274
# Elapsed: 1.6049327850341797
# 		Run on 2013-12-26 11:10:00
# Ichi regime at 2013-12-26 11:10:00: 1
# Current position delta: 2.74921944568339
# Elapsed: 1.597651720046997
# 		Run on 2013-12-27 11:10:00
# Ichi regime at 2013-12-27 11:10:00: 1
# Current position delta: 2.839467358242958
# Elapsed: 1.6171042919158936
# 		Run on 2013-12-28 11:10:00
# Ichi regime at 2013-12-28 11:10:00: 1
# Current position delta: 2.7654016447653498
# Elapsed: 1.6069138050079346
# 		Run on 2013-12-29 11:10:00
# Ichi regime at 2013-12-29 11:10:00: 1
# Current position delta: 2.7986105253706226
# Elapsed: 1.6241161823272705
# 		Run on 2013-12-30 11:10:00
# Ichi regime at 2013-12-30 11:10:00: 1
# Current position delta: 2.7744388593733125
# Elapsed: 1.6229076385498047
# 		Run on 2013-12-31 11:10:00
# Ichi regime at 2013-12-31 11:10:00: 1
# Current position delta: 2.626961258150366
# Elapsed: 1.6037719249725342
# 		Run on 2014-01-01 11:10:00
# Ichi regime at 2014-01-01 11:10:00: 1
# Current position delta: 2.6649833080282668
# Elapsed: 1.6538116931915283
# 		Run on 2014-01-02 11:10:00
# Ichi regime at 2014-01-02 11:10:00: 1
# Current position delta: 1.644800588024133
# Elapsed: 1.7455978393554688
# 		Run on 2014-01-03 11:10:00
# Ichi regime at 2014-01-03 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEG149100 x -1.0 Price: 0.5112061638257899 Delta: 0.21582750934108413
# Leg:  / P.US.CLEG149500 x 1.0 Price: 1.8798470748263085 Delta: -0.6020441628764955
# Leg:  / C.US.CLEG149550 x 1.0 Price: 0.7235909353727159 Delta: 0.33805512692650025
# Leg:  / C.US.CLEG149650 x -1.0 Price: 0.42674227255156794 Delta: -0.2317659139092605
# Transactions delta: -0.27992744051817164
# Elapsed: 2.3201775550842285
# 		Run on 2014-01-04 11:10:00
# Ichi regime at 2014-01-04 11:10:00: -1
# Current position delta: -0.31443671877752044
# Elapsed: 1.6080975532531738
# 		Run on 2014-01-05 11:10:00
# Ichi regime at 2014-01-05 11:10:00: -1
# Current position delta: -0.32688475502827485
# Elapsed: 1.6572461128234863
# 		Run on 2014-01-06 11:10:00
# Ichi regime at 2014-01-06 11:10:00: -1
# Current position delta: -0.4231750174201271
# Elapsed: 1.6298797130584717
# 		Run on 2014-01-07 11:10:00
# Ichi regime at 2014-01-07 11:10:00: -1
# Current position delta: -0.39378603478955354
# Elapsed: 1.690359115600586
# 		Run on 2014-01-08 11:10:00
# Ichi regime at 2014-01-08 11:10:00: -1
# Current position delta: -0.5388306263097447
# Elapsed: 1.63435697555542
# 		Run on 2014-01-09 11:10:00
# Ichi regime at 2014-01-09 11:10:00: -1
# Current position delta: -0.4925778174746631
# Elapsed: 1.6610040664672852
# 		Run on 2014-01-10 11:10:00
# Ichi regime at 2014-01-10 11:10:00: -1
# Current position delta: -0.6281257344884915
# Elapsed: 1.6018080711364746
# 		Run on 2014-01-11 11:10:00
# Ichi regime at 2014-01-11 11:10:00: -1
# Current position delta: -0.7326246616834925
# Elapsed: 1.6200830936431885
# 		Run on 2014-01-12 11:10:00
# Ichi regime at 2014-01-12 11:10:00: -1
# Current position delta: -0.8067015569159424
# Elapsed: 1.6158509254455566
# 		Run on 2014-01-13 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-01-13 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEH148900 x -1.0 Price: 0.9935454725699735 Delta: 0.28267618332670613
# Leg:  / P.US.CLEH149300 x 1.0 Price: 2.5770828236036962 Delta: -0.572861081457148
# Leg:  / C.US.CLEH149350 x 1.0 Price: 1.28961541108076 Delta: 0.3864149739796101
# Leg:  / C.US.CLEH149450 x -1.0 Price: 0.9257455376168053 Delta: -0.30883527442943765
# Transactions delta: -0.21260519858026938
# Elapsed: 2.500898599624634
# 		Run on 2014-01-14 11:10:00
# Ichi regime at 2014-01-14 11:10:00: -1
# Current position delta: -0.19367859408961935
# Elapsed: 1.889101266860962
# 		Run on 2014-01-15 11:10:00
# Ichi regime at 2014-01-15 11:10:00: -1
# Current position delta: -0.14395995868745792
# Elapsed: 1.6191880702972412
# 		Run on 2014-01-16 11:10:00
# Ichi regime at 2014-01-16 11:10:00: -1
# Current position delta: -0.15291620375622772
# Elapsed: 1.647019863128662
# 		Run on 2014-01-17 11:10:00
# Ichi regime at 2014-01-17 11:10:00: -1
# Current position delta: -0.1463660636866615
# Elapsed: 1.6506550312042236
# 		Run on 2014-01-18 11:10:00
# Ichi regime at 2014-01-18 11:10:00: -1
# Current position delta: -0.1527562534832002
# Elapsed: 1.6519606113433838
# 		Run on 2014-01-19 11:10:00
# Ichi regime at 2014-01-19 11:10:00: -1
# Current position delta: -0.15340562162172355
# Elapsed: 1.6097474098205566
# 		Run on 2014-01-20 11:10:00
# Ichi regime at 2014-01-20 11:10:00: -1
# Current position delta: -0.16479075299812673
# Elapsed: 1.59205961227417
# 		Run on 2014-01-21 11:10:00
# Ichi regime at 2014-01-21 11:10:00: -1
# Current position delta: -0.12376213443913398
# Elapsed: 1.6016185283660889
# 		Run on 2014-01-22 11:10:00
# Ichi regime at 2014-01-22 11:10:00: -1
# Current position delta: -0.07379086049508654
# Elapsed: 1.627833604812622
# 		Run on 2014-01-23 11:10:00
# Ichi regime at 2014-01-23 11:10:00: -1
# Current position delta: -0.047023933841394916
# Elapsed: 1.5975313186645508
# 		Run on 2014-01-24 11:10:00
# Ichi regime at 2014-01-24 11:10:00: -1
# Current position delta: -0.0771531371843015
# Elapsed: 1.6106631755828857
# 		Run on 2014-01-25 11:10:00
# Ichi regime at 2014-01-25 11:10:00: -1
# Current position delta: -0.06408048013925693
# Elapsed: 1.6108839511871338
# 		Run on 2014-01-26 11:10:00
# Ichi regime at 2014-01-26 11:10:00: -1
# Current position delta: -0.06147440923112968
# Elapsed: 1.6269266605377197
# 		Run on 2014-01-27 11:10:00
# Ichi regime at 2014-01-27 11:10:00: -1
# Current position delta: -0.0986355027028113
# Elapsed: 1.62087082862854
# 		Run on 2014-01-28 11:10:00
# Ichi regime at 2014-01-28 11:10:00: -1
# Current position delta: -0.05106053831580948
# Elapsed: 1.6272282600402832
# 		Run on 2014-01-29 11:10:00
# Ichi regime at 2014-01-29 11:10:00: -1
# Current position delta: -0.05736323187387926
# Elapsed: 1.595249891281128
# 		Run on 2014-01-30 11:10:00
# Ichi regime at 2014-01-30 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLE
11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEK149900 x 4.0 Price: 2.3088498148413237 Delta: 2.3471734763184124
# Leg:  / P.US.CLEK149900 x 2.0 Price: 1.4289369224665691 Delta: -0.8277606310479281
# Leg:  / P.US.CLEK149550 x -4.0 Price: 0.4823811663942621 Delta: 0.704148906337279
# Leg:  / C.US.CLEK1410450 x -2.0 Price: 0.4271178789763326 Delta: -0.34754773653094057
# Transactions delta: 1.8760140150768227
# Elapsed: 2.297996759414673
# 		Run on 2014-03-22 11:10:00
# Ichi regime at 2014-03-22 11:10:00: -1
# New bearish zone position
# ...
# Elapsed: 1.6636857986450195
# 		Run on 2016-08-07 11:10:00
# Ichi regime at 2016-08-07 11:10:00: -1
# Current position delta: -0.3403400836474749
# Elapsed: 1.6401689052581787
# 		Run on 2016-08-08 11:10:00
# Ichi regime at 2016-08-08 11:10:00: -1
# Current position delta: -0.44886736346404965
# Elapsed: 1.658907175064087
# 		Run on 2016-08-09 11:10:00
# Ichi regime at 2016-08-09 11:10:00: -1
# Current position delta: -0.4109986373417603
# Elapsed: 1.6093671321868896
# 		Run on 2016-08-10 11:10:00
# Ichi regime at 2016-08-10 11:10:00: -1
# Current position delta: -0.35435975796974517
# Elapsed: 1.6098887920379639
# 		Run on 2016-08-11 11:10:00
# Ichi regime at 2016-08-11 11:10:00: -1
# Current position delta: -0.5230184160834915
# Elapsed: 1.6177711486816406
# 		Run on 2016-08-12 11:10:00
# Ichi regime at 2016-08-12 11:10:00: -1
# Current position delta: -0.588166302824627
# Elapsed: 1.6880717277526855
# 		Run on 2016-08-13 11:10:00
# Ichi regime at 2016-08-13 11:10:00: -1
# Current position delta: -0.6762832877755235
# Elapsed: 1.618070125579834
# 		Run on 2016-08-14 11:10:00
# Ichi regime at 2016-08-14 11:10:00: -1
# Current position delta: -0.7497950806824771
# Elapsed: 1.6119096279144287
# 		Run on 2016-08-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2016-08-15 11:10:00: -1
# New bearish zone position
# Leg: bearish / P.US.CLEV164350 x -1.0 Price: 0.8947602591372643 Delta: 0.267853757610653
# Leg:  / P.US.CLEV164750 x 1.0 Price: 2.6035026709844082 Delta: -0.574115691920003
# Leg:  / C.US.CLEV164800 x 1.0 Price: 1.200190274158711 Delta: 0.38349985549420884
# Leg:  / C.US.CLEV164900 x -1.0 Price: 0.8687545751621535 Delta: -0.3063986816525882
# Transactions delta: -0.22916076046772937
# Elapsed: 2.5136115550994873
# 		Run on 2016-08-16 11:10:00
# Ichi regime at 2016-08-16 11:10:00: -1
# Current position delta: -0.2123317509980167
# Elapsed: 1.8122963905334473
# 		Run on 2016-08-17 11:10:00
# Ichi regime at 2016-08-17 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEV164650 x 4.0 Price: 2.3050370445815958 Delta: 2.3604906627968996
# Leg:  / P.US.CLEV164650 x 2.0 Price: 1.5055086573365628 Delta: -0.8214228650411303
# Leg:  / P.US.CLEV164300 x -4.0 Price: 0.5033206918048805 Delta: 0.694656602909121
# Leg:  / C.US.CLEV165200 x -2.0 Price: 0.36459270004175615 Delta: -0.3292239178893957
# Transactions delta: 1.9045004827754946
# Elapsed: 2.4269866943359375
# 		Run on 2016-08-18 11:10:00
# Ichi regime at 2016-08-18 11:10:00: 1
# Current position delta: 2.2060009029276553
11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX164850 x 4.0 Price: 1.8438346549498377 Delta: 2.7464856495180556
# Leg:  / P.US.CLEX164850 x 2.0 Price: 0.5960049014151956 Delta: -0.6312458306647943
# Leg:  / P.US.CLEX164500 x -4.0 Price: 0.07832824188298915 Delta: 0.2235701278373033
# Leg:  / C.US.CLEX165400 x -2.0 Price: 0.06973215453782133 Delta: -0.12563549050823136
# Transactions delta: 2.2131744561823337
# Elapsed: 0.9628293514251709
# 		Run on 2016-10-08 11:10:00
# Date not found at 2016-10-08
# Ichi regime at 2016-10-08 11:10:00: None
# Elapsed: 1.4659407138824463
# 		Run on 2016-10-09 11:10:00
# Date not found at 2016-10-09
# Ichi regime at 2016-10-09 11:10:00: None
# Current position delta: 0.0
# Elapsed: 0.2122361660003662
# 		Run on 2016-10-10 11:10:00
# Ichi regime at 2016-10-10 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX165050 x 4.0 Price: 1.4061637000438338 Delta: 2.6185792656737013
# Leg:  / P.US.CLEX165050 x 2.0 Price: 0.5576932719853858 Delta: -0.6939484493742476
# Leg:  / P.US.CLEX164700 x -4.0 Price: 0.0368897351046833 Delta: 0.1426015405246305
# Leg:  / C.US.CLEX165600 x -2.0 Price: 0.045377346952951925 Delta: -0.0879598127182342
# Transactions delta: 1.97927254410585
# Elapsed: 0.9668669700622559
# 		Run on 2016-10-11 11:10:00
# Ichi regime at 2016-10-11 11:10:00: 1
# Current position delta: 1.4441947809876643
# Elapsed: 1.6359450817108154
# 		Run on 2016-10-12 11:10:00
# Ichi regime at 2016-10-12 11:10:00: 1
# Current position delta: 1.0139588249601013
# Elapsed: 1.6258876323699951
# 		Run on 2016-10-13 11:10:00
# Date not found at 2016-10-13
# Ichi regime at 2016-10-13 11:10:00: None
# Elapsed: 1.4608757495880127
# 		Run on 2016-10-14 11:10:00
# Ichi regime at 2016-10-14 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX164900 x 4.0 Price: 1.1817251573729308 Delta: 3.0553372276806994
# Leg:  / P.US.CLEX164900 x 2.0 Price: 0.20298034205447557 Delta: -0.4772099704977207
# Leg:  / P.US.CLEX164550 x -4.0 Price: 0.006415002129678715 Delta: 0.037383186088398745
# Leg:  / C.US.CLEX165450 x -2.0 Price: 0.0033510302740661357 Delta: -0.01225496163673554
# Transactions delta: 2.603255481634642
# Elapsed: 0.967137336730957
# 		Run on 2016-10-15 11:10:00
# Rollover occured, new series used
# Date not found at 2016-10-15
# Ichi regime at 2016-10-15 11:10:00: None
# Current position delta: 0.0
# Elapsed: 1.7960124015808105
# 		Run on 2016-10-16 11:10:00
# Ichi regime at 2016-10-16 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEZ164950 x 4.0 Price: 2.6139044248942973 Delta: 2.494972490995095
# Leg:  / P.US.CLEZ164950 x 2.0 Price: 1.3751121492023834 Delta: -0.7560963612581529
# Leg:  / P.US.CLEZ164600 x -4.0 Price: 0.47056678472796243 Delta: 0.6399412888238987
# Leg:  / C.US.CLEZ165500 x -2.0 Price: 0.4769790152074318 Delta: -0.3950647447005872
# Transactions delta: 1.9837526738602536
# Elapsed: 1.1203370094299316
# 		Run on 2016-10-17 11:10:00
# Ichi regime at 2016-10-17 11:10:00: 1
# Current position delta: 1.910056173808765
# Elapsed: 1.6524615287780762
# 		Run on 2016-10-18 11:10:00
# Ichi regime at 2016-10-18 11:10:00: 1
# Current position delta: 1.9392215264058306
# Elapsed: 1.6645855903625488
# 		Run on 2016-10-19 11:10:00
# Ichi regime at 2016-10-19 11:10:00: 1
# Current position delta: 2.2230880525103998
# Elapsed: 1.6580164432525635
# 		Run on 2016-10-20 11:10:00
# Ichi regime at 2016-10-20 11:10:00: 1
# Current position delta: 2.0246237002218543
# Elapsed: 1.6334376335144043
# 		Run on 2016-10-21 11:10:00
# Ichi regime at 2016-10-21 11:10:00: 1
# Current position delta: 2.0105855064880767
# Elapsed: 1.6459558010101318
# 		Run on 2016-10-22 11:10:00
# Date not found at 2016-10-22
# Ichi regime at 2016-10-22 11:10:00: None
# Elapsed: 1.4471430778503418
# 		Run on 2016-10-23 11:10:00
# Ichi regime at 2016-10-23 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEZ165000 x 4.0 Price: 2.1568756439173207 Delta: 2.469197848480322
# Leg:  / P.US.CLEZ165000 x 2.0 Price: 1.1578597894567118 Delta: -0.7688305972519388
# Leg:  / P.US.CLEZ164650 x -4.0 Price: 0.317942965995206 Delta: 0.5403227504644447
# Leg:  / C.US.CLEZ165550 x -2.0 Price: 0.285068690695379 Delta: -0.2922126515964819
# Transactions delta: 1.9484773500963457
# Elapsed: 0.9600489139556885
# 		Run on 2016-10-24 11:10:00
# Ichi regime at 2016-10-24 11:10:00: 1
# Current position delta: 1.7667849452314321
# Elapsed: 1.603804588317871
# 		Run on 2016-10-25 11:10:00
# Ichi regime at 2016-10-25 11:10:00: 1
# Current position delta: 1.6882086369451839
# Elapsed: 1.6531493663787842
# 		Run on 2016-10-26 11:10:00
# Ichi regime at 2016-10-26 11:10:00: 1
# Current position delta: 1.4303118785759787
# Elapsed: 1.6231839656829834
# 		Run on 2016-10-27 11:10:00
# Ichi regime at 2016-10-27 11:10:00: 1
# Current position delta: 1.5721993058675703
# Elapsed: 1.634237289428711
# 		Run on 2016-10-28 11:10:00
# Ichi regime at 2016-10-28 11:10:00: 1
# Current position delta: 1.2074512232265777
# Elapsed: 1.6177899837493896
# 		Run on 2016-10-29 11:10:00
# Date not found at 2016-10-29
# Ichi regime at 2016-10-29 11:10:00: None
# Elapsed: 1.4673686027526855
# 		Run on 2016-10-30 11:10:00
# Date not found at 2016-10-30
# Ichi regime at 2016-10-30 11:10:00: None
# Current position delta: 0.0
# Elapsed: 0.21332573890686035
# 		Run on 2016-10-31 11:10:00
# Ichi regime at 2016-10-31 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEZ164600 x 4.0 Price: 2.111939882893491 Delta: 2.556348614733611
# Leg:  / P.US.CLEZ164600 x 2.0 Price: 0.9771626018232205 Delta: -0.725403281386187
# Leg:  / P.US.CLEZ164250 x -4.0 Price: 0.25214955768128977 Delta: 0.46492957804839935
# Leg:  / C.US.CLEZ165150 x -2.0 Price: 0.1760627506775867 Delta: -0.22492472105485944
# Transactions delta: 2.0709501903409637
# Elapsed: 0.9521000385284424
# Done

# %% [markdown]
# # View EXO price series

# %%
for ticker in instruments:
    exo_df, exo_info = exostorage.load_series('{0}_{1}'.format(ticker, EXO_NAME))    
    
    exo_df['exo'].plot(title='{0}_{1}'.format(ticker, EXO_NAME))
    ax = exo_df['ichi_regime'].plot(secondary_y=True)
    ax.set_ylim(-2,2)
    plt.show()
