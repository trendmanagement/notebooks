# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from exobuilder.contracts.futureschain import FuturesChain
from exobuilder.contracts.futurecontract import FutureContract
from exobuilder.tests.assetindexdict import AssetIndexDicts
from datetime import datetime, date, timedelta, time as dttime
from exobuilder.contracts.instrument import Instrument
from exobuilder.data.datasource_mongo import DataSourceMongo
from exobuilder.data.datasource_sql import DataSourceSQL
from exobuilder.data.assetindex_mongo import AssetIndexMongo
from exobuilder.data.exostorage import EXOStorage
from exobuilder.exo.exoenginebase import ExoEngineBase
from exobuilder.exo.transaction import Transaction
import time
from exobuilder.algorithms.rollover_helper import RolloverHelper

import importlib
import logging
importlib.reload(logging);
import matplotlib.pyplot as plt

# %%
EXO_NAME = 'Quandl-EXO-CL-CallSpread'

# TODO: set to 'False' if EXO building output is too verbosive
verbosive_logging = True # or True - for debug log feed

# TODO: select instruments list for SMART EXO calculation
#instruments = ['CL', 'ES', 'NG', 'ZC', 'ZS', 'ZW', 'ZN']
instruments = ['CL']


# TODO: select start date for SmartEXO calculation
base_date = datetime(2016, 1, 13, 12, 45, 0)

# %% [markdown]
# # Define Bull/Bear/Neutral areas rules

# %%
def ichimoku_regimes(date, price_series):    
    '''
    Calculates Bull/Bear/Neutral areas based on Ichimoku zones
    
    param date: Current date time
    param price_series: price Pandas.Series
    
    Returns:
        -1 - for bearish zone
        0  - for neutral zone
        +1 - for bullish zone
        None - for unknown
    '''
    #
    #  TODO: Change values to fine tune zoning algorithm
    #
    conversion_line_period = 9 # subject of optimization
    base_line_period = 26  # subject of optimization
    leading_spans_lookahead_period = 26  # subject of optimization
    leading_span_b_period = 52 # subject of optimization
        
        
    conversion_line_high = price_series.rolling(window=conversion_line_period).max()
    conversion_line_low = price_series.rolling(window=conversion_line_period).min()
    conversion_line = (conversion_line_high + conversion_line_low) / 2

    base_line_high = price_series.rolling(window=base_line_period).max()
    base_line_low = price_series.rolling(window=base_line_period).min()
    base_line = (base_line_high + base_line_low) / 2

    leading_span_a = ((conversion_line + base_line) / 2).shift(leading_spans_lookahead_period)
    leading_span_b = ((price_series.rolling(window=leading_span_b_period).max() + price_series.rolling(
        window=leading_span_b_period).min()) / 2).shift(leading_spans_lookahead_period)


    #
    # Rules calculation
    #

    # Cloud top and bottom series are defined using leading span A and B
    cloud_top = leading_span_a.rolling(1).max()
    cloud_bottom = leading_span_a.rolling(1).min()

    rule_price_above_cloud_top = price_series > cloud_top
    rule_price_below_cloud_bottom = price_series < cloud_bottom
    rule_price_in_cloud = (price_series < cloud_top) & (price_series > cloud_bottom)

    def get_regime(date):
        if date not in rule_price_above_cloud_top.index:
            logging.debug("Date not found at {0}".format(date))
            return None


        if rule_price_above_cloud_top[date]:
            return 1
        elif rule_price_below_cloud_bottom[date]:
            return -1
        elif rule_price_in_cloud[date]:
            return 0
        return None

    regime = get_regime(date.date())
    logging.debug("Ichi regime at {0}: {1}".format(date, regime))
    return regime

# %%
# Toolbox
def transactions_delta(trans_list):
    return sum([t.delta for t in trans_list])

def log_transactions(trans_list, msg):
    logging.debug(msg)
    [logging.debug(t) for t in trans_list]
    logging.debug('Transactions delta: {0}'.format(transactions_delta(trans_list)))

# %% [markdown]
# # Option position management

# %% [markdown]
# According to https://tmqrexo.slack.com/files/nikolasjoyce/F2PHLEETZ/pasted_image_at_2016_10_14_10_05_am.png

# %% [markdown]
# ## New bullish zone position

# %%
def new_position_bullish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bullish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening condor in bullish zone
    #
    # https://files.slack.com/files-tmb/T0484J7T7-F2QBLK53R-93b4252806/pasted_image_at_2016_10_17_10_08_am_720.png
    
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-2].c, date, 1.0, leg_name='bullish'),
                Transaction(opt_chain[5].c, date, -1.0),
                
                #Transaction(opt_chain[3].c, date, 0.0),
                #Transaction(opt_chain[-2].c, date,  1.0),
           ]
    log_transactions(trans_list,'New bullish zone position')
    return trans_list

# %% [markdown]
# ## New bearish zone position

# %%
def new_position_bearish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bearish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening bearish put spread in bearish zone
    #
    
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-2].c, date, 1.0, leg_name='bearish'),
                Transaction(opt_chain[5].c, date, -1.0),                
                ]
    log_transactions(trans_list,'New bearish zone position')
    return trans_list

# %% [markdown]
# ## New neutral zone position

# %%
def new_position_neutral_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for neutral zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening long asymmetric butterfly in neutral zone
    #    
    # https://files.slack.com/files-tmb/T0484J7T7-F2PGU8QNQ-6344e6a04c/pasted_image_at_2016_10_14_09_43_am_720.png
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-2].c, date, 1.0, leg_name='neutral'),
                Transaction(opt_chain[5].c, date, -1.0),
                
                #Transaction(opt_chain[8].c, date, -3.0),
                #Transaction(opt_chain[3].c, date,  0.0),
           ]
    log_transactions(trans_list,'New neutral zone position')
    return trans_list

# %% [markdown]
# ## Manage opened positions

# %%
def manage_opened_position(date, fut, opt_chain, regime, opened_position):
    logging.debug('Current position delta: {0}'.format(opened_position.delta))
    
    # By default: do nothing
    return []

# %% [markdown]
# # Define EXO builder class

# %%
class SmartEXOIchimoku(ExoEngineBase):
    def __init__(self, symbol, direction, date, datasource, log_file_path=''):
        self._symbol = symbol
        super().__init__(symbol, direction, date, datasource, log_file_path=log_file_path)

    @staticmethod
    def direction_type():
        return 0

    @staticmethod
    def names_list(symbol):
        return ['{0}_{1}'.format(self._symbol, EXO_NAME)]

    @property
    def exo_name(self):
            return '{0}_{1}'.format(self._symbol, EXO_NAME)

    def is_rollover(self):
        if len(self.position) != 0:
            for p in self.position.legs.values():
                rh = RolloverHelper(p.instrument)
                if rh.is_rollover(p):
                    return True
        return False

    def process_rollover(self):
        trans_list = self.position.close_all_translist()
        logging.info('Rollover occured, new series used')
        return trans_list

    

    def process_day(self):
        """
        Main EXO's position management method
        :return: list of Transactions to process
        """

        # Get cont futures price for EXO
        exo_df, exo_info = self.datasource.exostorage.load_series("{0}_ContFut".format(self._symbol))

        regime = ichimoku_regimes(self.date, exo_df['exo'])

        trans_list = []

        if regime is None and len(self.position) > 0:
            return self.position.close_all_translist()
        
        instr = self.datasource.get(self._symbol, self.date)
        rh = RolloverHelper(instr)
        fut, opt_chain = rh.get_active_chains()

        if regime == 1 and 'bullish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bullish_zone(self.date, fut, opt_chain)
            
            return trans_list
        if regime == -1 and 'bearish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bearish_zone(self.date, fut, opt_chain)
            return trans_list

        if regime == 0 and 'neutral' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_neutral_zone(self.date, fut, opt_chain)
            return trans_list
        
        #
        # Manage opened position
        #
        return manage_opened_position(self.date, fut, opt_chain, regime, self.position)

# %% [markdown]
# # Run EXO build process (WARN: long-running task!)

# %%
from pymongo import MongoClient

if verbosive_logging:
    logging.basicConfig(format='%(message)s', level=logging.DEBUG)
else:
    logging.basicConfig(format='%(message)s', level=logging.INFO)

mongo_connstr = 'mongodb://exowriter:qmWSy4K3@10.0.1.2/tmldb?authMechanism=SCRAM-SHA-1'
mongo_db_name = 'tmldb'
assetindex = AssetIndexMongo(mongo_connstr, mongo_db_name)
exostorage = EXOStorage(mongo_connstr, mongo_db_name)

#base_date = datetime(2011, 6, 13, 12, 45, 0)


futures_limit = 3
options_limit = 10

DEBUG = '.'

datasource = DataSourceMongo(mongo_connstr, mongo_db_name, assetindex, futures_limit, options_limit, exostorage)

server = 'h9ggwlagd1.database.windows.net'
user = 'modelread'
password = '4fSHRXwd4u'
datasource = DataSourceSQL(server, user, password, assetindex, futures_limit, options_limit, exostorage)

enddate = datetime.combine(datetime.now().date(), dttime(12, 45, 0))
currdate = base_date


logging.info("Deleting all SmartEXO of :" + EXO_NAME)
client = MongoClient(mongo_connstr)
db = client[mongo_db_name]
db['exo_data'].delete_many({'name': {'$regex': '.*{0}*.'.format(EXO_NAME)}})


logging.info("Starting EXO calculation process from: {0}".format(currdate))
for ticker in instruments:
    logging.info("Processing: "+ticker)
    currdate = base_date
    while currdate <= enddate:
        
        start_time = time.time()
        date = currdate

        asset_info = assetindex.get_instrument_info(ticker)
        exec_time_end, decision_time_end = AssetIndexMongo.get_exec_time(date, asset_info)
        
        logging.info("\t\tRun on {0}".format(decision_time_end))

        with SmartEXOIchimoku(ticker, 0, decision_time_end, datasource) as exo_engine:
            # Load EXO information from mongo
            exo_engine.load()
            exo_engine.calculate()

        end_time = time.time()
        currdate += timedelta(days=1)
        logging.debug("Elapsed: {0}".format(end_time-start_time))
logging.info('Done')
# Out:
# Deleting all SmartEXO of :Quandl-EXO-CL-CallSpread
# Starting EXO calculation process from: 2016-01-13 12:45:00
# Processing: CL
# 		Run on 2016-01-13 11:10:00
# Ichi regime at 2016-01-13 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEH163050 x 1.0 Price: 2.697934684309299 Delta: 0.594887754463219
# Leg:  / C.US.CLEH163400 x -1.0 Price: 1.217353913094211 Delta: -0.3555875766720006
# Transactions delta: 0.23930017779121837
# Elapsed: 0.85349440574646
# 		Run on 2016-01-14 11:10:00
# Ichi regime at 2016-01-14 11:10:00: -1
# Current position delta: 0.2508132269875972
# Elapsed: 0.9205420017242432
# 		Run on 2016-01-15 11:10:00
# Ichi regime at 2016-01-15 11:10:00: -1
# Current position delta: 0.2679828818634355
# Elapsed: 0.9328722953796387
# 		Run on 2016-01-16 11:10:00
# Ichi regime at 2016-01-16 11:10:00: -1
# Current position delta: 0.2564718260772043
# Elapsed: 0.9373457431793213
# 		Run on 2016-01-17 11:10:00
# Ichi regime at 2016-01-17 11:10:00: -1
# Current position delta: 0.26005720982168967
# Elapsed: 0.8900914192199707
# 		Run on 2016-01-18 11:10:00
# Ichi regime at 2016-01-18 11:10:00: -1
# Current position delta: 0.25550483072548325
# Elapsed: 0.8977158069610596
# 		Run on 2016-01-19 11:10:00
# Ichi regime at 2016-01-19 11:10:00: -1
# Current position delta: 0.24176385566886952
# Elapsed: 0.9161813259124756
# 		Run on 2016-01-20 11:10:00
# Ichi regime at 2016-01-20 11:10:00: -1
# Current position delta: 0.21164263197968547
# Elapsed: 0.9143466949462891
# 		Run on 2016-01-21 11:10:00
# Ichi regime at 2016-01-21 11:10:00: -1
# Current position delta: 0.23486124616235127
# Elapsed: 0.9206066131591797
# 		Run on 2016-01-22 11:10:00
# Ichi regime at 2016-01-22 11:10:00: -1
# Current position delta: 0.2558492473558924
# Elapsed: 0.9130711555480957
# 		Run on 2016-01-23 11:10:00
# Ichi regime at 2016-01-23 11:10:00: -1
# Current position delta: 0.2767860843373813
# Elapsed: 0.9178526401519775
# 		Run on 2016-01-24 11:10:00
# Ichi regime at 2016-01-24 11:10:00: -1
# Current position delta: 0.28227056658392363
# Elapsed: 0.8979179859161377
# 		Run on 2016-01-25 11:10:00
# Ichi regime at 2016-01-25 11:10:00: -1
# Current position delta: 0.28193239396525493
# Elapsed: 0.908217191696167
# 		Run on 2016-01-26 11:10:00
# Ichi regime at 2016-01-26 11:10:00: -1
# Current position delta: 0.2820336939299346
# Elapsed: 0.9515120983123779
# 		Run on 2016-01-27 11:10:00
# Ichi regime at 2016-01-27 11:10:00: -1
# Current position delta: 0.2831654245317623
# Elapsed: 0.9193239212036133
# 		Run on 2016-01-28 11:10:00
# Ichi regime at 2016-01-28 11:10:00: -1
# Current position delta: 0.2706623696938194
# Elapsed: 1.1987333297729492
# 		Run on 2016-01-29 11:10:00
# Ichi regime at 2016-01-29 11:10:00: -1
# Current position delta: 0.2671868128960459
# Elapsed: 0.9084765911102295
# 		Run on 2016-01-30 11:10:00
# Ichi regime at 2016-01-30 11:10:00: -1
# Current position delta: 0.28643870448852393
# Elapsed: 0.9143252372741699
# 		Run on 2016-01-31 11:10:00
# Ichi regime at 2016-01-31 11:10:00: -1
# Current position delta: 0.29341066905609003
# Elapsed: 0.8882040977478027
# 		Run on 2016-02-01 11:10:00
# Ichi regime at 2016-02-01 11:10:00: -1
# Current position delta: 0.3345874071265754
# Elapsed: 0.8994333744049072
# 		Run on 2016-02-02 11:10:00
# Ichi regime at 2016-02-02 11:10:00: -1
# Current position delta: 0.2891247697409609
# Elapsed: 0.919222354888916
# 		Run on 2016-02-03 11:10:00
# Ichi regime at 2016-02-03 11:10:00: -1
# Current position delta: 0.32085194445683896
# Elapsed: 0.9201867580413818
# 		Run on 2016-02-04 11:10:00
# Ichi regime at 2016-02-04 11:10:00: -1
# Current position delta: 0.3418477403253028
# Elapsed: 0.9225239753723145
# 		Run on 2016-02-05 11:10:00
# Ichi regime at 2016-02-05 11:10:00: -1
# Current position delta: 0.3522106304131977
# Elapsed: 0.9370388984680176
# 		Run on 2016-02-06 11:10:00
# Ichi regime at 2016-02-06 11:10:00: -1
# Current position delta: 0.35566504382109665
# Elapsed: 0.9051365852355957
# 		Run on 2016-02-07 11:10:00
# Ichi regime at 2016-02-07 11:10:00: -1
# Current position delta: 0.3698118938514916
# Elapsed: 0.8842442035675049
# 		Run on 2016-02-08 11:10:00
# Ichi regime at 2016-02-08 11:10:00: -1
# Current position delta: 0.33956344548695916
# Elapsed: 0.8868880271911621
# 		Run on 2016-02-09 11:10:00
# Ichi regime at 2016-02-09 11:10:00: -1
# Current position delta: 0.20621137736733303
# Elapsed: 0.9250760078430176
# 		Run on 2016-02-10 11:10:00
# Ichi regime at 2016-02-10 11:10:00: -1
# Current position delta: 0.13550409240698558
# Elapsed: 0.9004311561584473
# 		Run on 2016-02-11 11:10:00
# Ichi regime at 2016-02-11 11:10:00: -1
# Current position delta: 0.05832082947776228
# Elapsed: 0.908454418182373
# 		Run on 2016-02-12 11:10:00
# Ichi regime at 2016-02-12 11:10:00: -1
# Current position delta: 0.2743352206205862
# Elapsed: 0.9369490146636963
# 		Run on 2016-02-13 11:10:00
# Ichi regime at 2016-02-13 11:10:00: -1
# Current position delta: 0.23929540366970972
# Elapsed: 0.9238641262054443
# 		Run on 2016-02-14 11:10:00
# Ichi regime at 2016-02-14 11:10:00: -1
# Current position delta: 0.22351555629251857
# Elapsed: 0.8708086013793945
# 		Run on 2016-02-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2016-02-15 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEJ163100 x 1.0 Price: 3.365502707295228 Delta: 0.5982008152362487
# Leg:  / C.US.CLEJ163450 x -1.0 Price: 1.8412455938978294 Delta: -0.4081126631786866
# Transactions delta: 0.19008815205756208
# Elapsed: 1.4410569667816162
# 		Run on 2016-02-16 11:10:00
# Ichi regime at 2016-02-16 11:10:00: -1
# Current position delta: 0.18459652528395004
# Elapsed: 1.1125578880310059
# 		Run on 2016-02-17 11:10:00
# Ichi regime at 2016-02-17 11:10:00: -1
# Current position delta: 0.21448209941369656
# Elapsed: 0.9729249477386475
# 		Run on 2016-02-18 11:10:00
# Ichi regime at 2016-02-18 11:10:00: -1
# Current position delta: 0.2268736533326305
# Elapsed: 0.954291582107544
# 		Run on 2016-02-19 11:10:00
# Ichi regime at 2016-02-19 11:10:00: -1
# Current position delta: 0.24335776041523166
# Elapsed: 0.908944845199585
# 		Run on 2016-02-20 11:10:00
# Ichi regime at 2016-02-20 11:10:00: -1
# Current position delta: 0.2730561389437027
# Elapsed: 0.9318082332611084
# 		Run on 2016-02-21 11:10:00
# Ichi regime at 2016-02-21 11:10:00: -1
# Current position delta: 0.2782742623401776
# Elapsed: 0.8902084827423096
# 		Run on 2016-02-22 11:10:00
# Ichi regime at 2016-02-22 11:10:00: -1
# Current position delta: 0.2715000211137937
# Elapsed: 0.9034430980682373
# 		Run on 2016-02-23 11:10:00
# Ichi regime at 2016-02-23 11:10:00: -1
# Current position delta: 0.2703156407796369
# Elapsed: 0.9234316349029541
# 		Run on 2016-02-24 11:10:00
# Ichi regime at 2016-02-24 11:10:00: -1
# Current position delta: 0.277352033251607
# Elapsed: 0.9194409847259521
# 		Run on 2016-02-25 11:10:00
# Ichi regime at 2016-02-25 11:10:00: -1
# Current position delta: 0.27217835667927304
# Elapsed: 0.9295802116394043
# 		Run on 2016-02-26 11:10:00
# Ichi regime at 2016-02-26 11:10:00: -1
# Current position delta: 0.28771571694659026
# Elapsed: 0.9213964939117432
# 		Run on 2016-02-27 11:10:00
# Ichi regime at 2016-02-27 11:10:00: -1
# Current position delta: 0.3070907811314246
# Elapsed: 0.9099862575531006
# 		Run on 2016-02-28 11:10:00
# Ichi regime at 2016-02-28 11:10:00: -1
# Current position delta: 0.31545579274030583
# Elapsed: 0.8731389045715332
# 		Run on 2016-02-29 11:10:00
# Ichi regime at 2016-02-29 11:10:00: -1
# Current position delta: 0.31203180947989495
# Elapsed: 0.9021401405334473
# 		Run on 2016-03-01 11:10:00
# Ichi regime at 2016-03-01 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEJ163350 x 1.0 Price: 2.106893178700261 Delta: 0.6050328295482107
# Leg:  / C.US.CLEJ163700 x -1.0 Price: 0.6190133207903035 Delta: -0.2741607518541656
# Transactions delta: 0.3308720776940451
# Elapsed: 1.2495367527008057
# 		Run on 2016-03-02 11:10:00
# Ichi regime at 2016-03-02 11:10:00: 1
# Current position delta: 0.351612208795299
# Elapsed: 0.9110445976257324
# 		Run on 2016-03-03 11:10:00
# Ichi regime at 2016-03-03 11:10:00: 1
# Current position delta: 0.3830610363910812
# Elapsed: 0.9206333160400391
# 		Run on 2016-03-04 11:10:00
# Ichi regime at 2016-03-04 11:10:00: 1
# Current position delta: 0.3958968343451283
# Elapsed: 0.9148449897766113
# 		Run on 2016-03-05 11:10:00
# Ichi regime at 2016-03-05 11:10:00: 1
# Current position delta: 0.3979875093224557
# Elapsed: 0.9441120624542236
# 		Run on 2016-03-06 11:10:00
# Ichi regime at 2016-03-06 11:10:00: 1
# Current position delta: 0.41350161310695815
# Elapsed: 0.9028191566467285
# 		Run on 2016-03-07 11:10:00
# Ichi regime at 2016-03-07 11:10:00: 1
# Current position delta: 0.31704003187173924
# Elapsed: 0.9007947444915771
# 		Run on 2016-03-08 11:10:00
# Ichi regime at 2016-03-08 11:10:00: 1
# Current position delta: 0.37650981537720296
# Elapsed: 0.9511439800262451
# 		Run on 2016-03-09 11:10:00
# Ichi regime at 2016-03-09 11:10:00: 1
# Current position delta: 0.2837660527118022
# Elapsed: 0.9257640838623047
# 		Run on 2016-03-10 11:10:00
# Ichi regime at 2016-03-10 11:10:00: 1
# Current position delta: 0.28959250357641275
# Elapsed: 0.9219036102294922
# 		Run on 2016-03-11 11:10:00
# Ichi regime at 2016-03-11 11:10:00: 1
# Current position delta: 0.19929119068261003
# Elapsed: 0.9218900203704834
# 		Run on 2016-03-12 11:10:00
# Ichi regime at 2016-03-12 11:10:00: 1
# Current position delta: 0.1837981160298212
# Elapsed: 0.9289524555206299
# 		Run on 2016-03-13 11:10:00
# Ichi regime at 2016-03-13 11:10:00: 1
# Current position delta: 0.1640472386624814
# Elapsed: 0.8809185028076172
# 		Run on 2016-03-14 11:10:00
# Rollover occured, new series used
# Ichi regime at 2016-03-14 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEK163800 x 1.0 Price: 2.581485677453294 Delta: 0.5897272090008732
# Leg:  / C.US.CLEK164150 x -1.0 Price: 1.0617131550060286 Delta: -0.3335405666780958
# Transactions delta: 0.2561866423227774
# Elapsed: 1.4308063983917236
# 		Run on 2016-03-15 11:10:00
# Ichi regime at 2016-03-15 11:10:00: 1
# Current position delta: 0.25599497234382795
# Elapsed: 1.1020100116729736
# 		Run on 2016-03-16 11:10:00
# Ichi regime at 2016-03-16 11:10:00: 1
# Current position delta: 0.27154606245453955
# Elapsed: 0.9490692615509033
# 		Run on 2016-03-17 11:10:00
# Ichi regime at 2016-03-17 11:10:00: 1
# Current position delta: 0.2683085993980652
# Elapsed: 0.938255786895752
# 		Run on 2016-03-18 11:10:00
# Ichi regime at 2016-03-18 11:10:00: 1
# Current position delta: 0.2514059189758553
# Elapsed: 0.9330706596374512
# 		Run on 2016-03-19 11:10:00
# Ichi regime at 2016-03-19 11:10:00: 1
# Current position delta: 0.272223100936089
# Elapsed: 0.9435770511627197
# 		Run on 2016-03-20 11:10:00
# Ichi regime at 2016-03-20 11:10:00: 1
# Current position delta: 0.2767477027625042
# Elapsed: 0.8752415180206299
# 		Run on 2016-03-21 11:10:00
# Ichi regime at 2016-03-21 11:10:00: 1
# Current position delta: 0.27189239642062835
# Elapsed: 0.8902661800384521
# 		Run on 2016-03-22 11:10:00
# Ichi regime at 2016-03-22 11:10:00: 1
# Current position delta: 0.2812977480260528
# Elapsed: 0.9216406345367432
# 		Run on 2016-03-23 11:10:00
# Ichi regime at 2016-03-23 11:10:00: 1
# Current position delta: 0.32396409686118494
# Elapsed: 0.9133164882659912
# 		Run on 2016-03-24 11:10:00
# Ichi regime at 2016-03-24 11:10:00: 1
# Current position delta: 0.3352273824601478
# Elapsed: 0.9362647533416748
# 		Run on 2016-03-25 11:10:00
# Ichi regime at 2016-03-25 11:10:00: 1
# Current position delta: 0.3408844386487781
# Elapsed: 0.9353303909301758
# 		Run on 2016-03-26 11:10:00
# Ichi regime at 2016-03-26 11:10:00: 1
# Current position delta: 0.34117121452255317
# Elapsed: 0.929617166519165
# 		Run on 2016-03-27 11:10:00
# Ichi regime at 2016-03-27 11:10:00: 1
# Current position delta: 0.3493964184125107
# Elapsed: 0.9004971981048584
# 		Run on 2016-03-28 11:10:00
# Ichi regime at 2016-03-28 11:10:00: 1
# Current position delta: 0.35931112494827916
# Elapsed: 0.9174988269805908
# 		Run on 2016-03-29 11:10:00
# Ichi regime at 2016-03-29 11:10:00: 1
# Current position delta: 0.35337287107886733
# Elapsed: 0.9331204891204834
# 		Run on 2016-03-30 11:10:00
# Ichi regime at 2016-03-30 11:10:00: 1
# Current position delta: 0.361892672221758
# Elapsed: 0.9193170070648193
# 		Run on 2016-03-31 11:10:00
# Ichi regime at 2016-03-31 11:10:00: 1
# Current position delta: 0.3700664021789757
# Elapsed: 0.9614636898040771
# 		Run on 2016-04-01 11:10:00
# Ichi regime at 2016-04-01 11:10:00: 1
# Current position delta: 0.3211348842026088
# Elapsed: 0.9443089962005615
# 		Run on 2016-04-02 11:10:00
# Ichi regime at 2016-04-02 11:10:00: 1
# Current position delta: 0.27749257506153574
# Elapsed: 0.9520218372344971
# 		Run on 2016-04-03 11:10:00
# Ichi regime at 2016-04-03 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEK163550 x 1.0 Price: 1.8718897120545783 Delta: 0.6608198160039849
# Leg:  / C.US.CLEK163900 x -1.0 Price: 0.3501892488383014 Delta: -0.2220554846376193
# Transactions delta: 0.4387643313663656
# Elapsed: 1.2270348072052002
# 		Run on 2016-04-04 11:10:00
# Ichi regime at 2016-04-04 11:10:00: -1
# Current position delta: 0.42937886371767187
# Elapsed: 0.9069986343383789
# 		Run on 2016-04-05 11:10:00
# Ichi regime at 2016-04-05 11:10:00: -1
# Current position delta: 0.39798900910760726
# Elapsed: 0.927354097366333
# 		Run on 2016-04-06 11:10:00
# Ichi regime at 2016-04-06 11:10:00: -1
# Current position delta: 0.4797094840443035
# Elapsed: 0.9577677249908447
# 		Run on 2016-04-07 11:10:00
# Ichi regime at 2016-04-07 11:10:00: -1
# Current position delta: 0.5100368836589156
# Elapsed: 0.9320571422576904
# 		Run on 2016-04-08 11:10:00
# Ichi regime at 2016-04-08 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEK163850 x 1.0 Price: 1.4202112341581454 Delta: 0.6515817928247647
# Leg:  / C.US.CLEK164200 x -1.0 Price: 0.1995381461834329 Delta: -0.1577411859166557
# Transactions delta: 0.493840606908109
# Elapsed: 1.2692816257476807
# 		Run on 2016-04-09 11:10:00
# Ichi regime at 2016-04-09 11:10:00: 1
# Current position delta: 0.5304750012029763
# Elapsed: 0.9097626209259033
# 		Run on 2016-04-10 11:10:00
# Ichi regime at 2016-04-10 11:10:00: 1
# Current position delta: 0.5688993676483474
# Elapsed: 0.8957412242889404
# 		Run on 2016-04-11 11:10:00
# Ichi regime at 2016-04-11 11:10:00: 1
# Current position delta: 0.6316483351572251
# Elapsed: 0.9279232025146484
# 		Run on 2016-04-12 11:10:00
# Ichi regime at 2016-04-12 11:10:00: 1
# Current position delta: 0.44952466327996676
# Elapsed: 0.9311957359313965
# 		Run on 2016-04-13 11:10:00
# Rollover occured, new series used
# Ichi regime at 2016-04-13 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEM164250 x 1.0 Price: 2.7973367048794557 Delta: 0.5863308866558099
# Leg:  / C.US.CLEM164600 x -1.0 Price: 1.3035488650451743 Delta: -0.35560228910353525
# Transactions delta: 0.23072859755227465
# Elapsed: 1.4711406230926514
# 		Run on 2016-04-14 11:10:00
# Ichi regime at 2016-04-14 11:10:00: 1
# Current position delta: 0.2354527551009576
# Elapsed: 1.0782485008239746
# 		Run on 2016-04-15 11:10:00
# Ichi regime at 2016-04-15 11:10:00: 1
# Current position delta: 0.23052063461628514
# Elapsed: 0.9482698440551758
# 		Run on 2016-04-16 11:10:00
# Ichi regime at 2016-04-16 11:10:00: 1
# Current position delta: 0.2242032908493269
# Elapsed: 0.9544947147369385
# 		Run on 2016-04-17 11:10:00
# Ichi regime at 2016-04-17 11:10:00: 1
# Current position delta: 0.22710848317567334
# Elapsed: 0.8864552974700928
# 		Run on 2016-04-18 11:10:00
# Ichi regime at 2016-04-18 11:10:00: 1
# Current position delta: 0.21746254529016207
# Elapsed: 0.8965649604797363
# 		Run on 2016-04-19 11:10:00
# Ichi regime at 2016-04-19 11:10:00: 1
# Current position delta: 0.2595643440154818
# Elapsed: 0.9355120658874512
# 		Run on 2016-04-20 11:10:00
# Ichi regime at 2016-04-20 11:10:00: 1
# Current position delta: 0.28794631448442914
# Elapsed: 0.9092080593109131
# 		Run on 2016-04-21 11:10:00
# Ichi regime at 2016-04-21 11:10:00: 1
# Current position delta: 0.28386443724200167
# Elapsed: 0.9339320659637451
# 		Run on 2016-04-22 11:10:00
# Ichi regime at 2016-04-22 11:10:00: 1
# Current position delta: 0.2904793637650182
# Elapsed: 0.9575545787811279
# 		Run on 2016-04-23 11:10:00
# Ichi regime at 2016-04-23 11:10:00: 1
# Current position delta: 0.3030529848828514
# Elapsed: 0.9194169044494629
# 		Run on 2016-04-24 11:10:00
# Ichi regime at 2016-04-24 11:10:00: 1
# Current position delta: 0.3091272494384689
# Elapsed: 0.9023258686065674
# 		Run on 2016-04-25 11:10:00
# Ichi regime at 2016-04-25 11:10:00: 1
# Current position delta: 0.310226978506258
# Elapsed: 0.9001774787902832
# 		Run on 2016-04-26 11:10:00
# Ichi regime at 2016-04-26 11:10:00: 1
# Current position delta: 0.3182442439320883
# Elapsed: 0.935077428817749
# 		Run on 2016-04-27 11:10:00
# Ichi regime at 2016-04-27 11:10:00: 1
# Current position delta: 0.3107861812185356
# Elapsed: 0.9524586200714111
# 		Run on 2016-04-28 11:10:00
# Ichi regime at 2016-04-28 11:10:00: 1
# Current position delta: 0.28014563392870717
# Elapsed: 0.9443292617797852
# 		Run on 2016-04-29 11:10:00
# Ichi regime at 2016-04-29 11:10:00: 1
# Current position delta: 0.32240596133608707
# Elapsed: 0.9225177764892578
# 		Run on 2016-04-30 11:10:00
# Ichi regime at 2016-04-30 11:10:00: 1
# Current position delta: 0.3022474484792046
# Elapsed: 0.9265246391296387
# 		Run on 2016-05-01 11:10:00
# Ichi regime at 2016-05-01 11:10:00: 1
# Current position delta: 0.30935000385796385
# Elapsed: 0.8976669311523438
# 		Run on 2016-05-02 11:10:00
# Ichi regime at 2016-05-02 11:10:00: 1
# Current position delta: 0.36137977929774
# Elapsed: 0.9152779579162598
# 		Run on 2016-05-03 11:10:00
# Ichi regime at 2016-05-03 11:10:00: 1
# Current position delta: 0.36270101930067006
# Elapsed: 0.9360666275024414
# 		Run on 2016-05-04 11:10:00
# Ichi regime at 2016-05-04 11:10:00: 1
# Current position delta: 0.3758913703287772
# Elapsed: 0.9362890720367432
# 		Run on 2016-05-05 11:10:00
# Ichi regime at 2016-05-05 11:10:00: 1
# Current position delta: 0.3982792787290149
# Elapsed: 0.9148807525634766
# 		Run on 2016-05-06 11:10:00
# Ichi regime at 2016-05-06 11:10:00: 1
# Current position delta: 0.41341395521775787
# Elapsed: 0.9356801509857178
# 		Run on 2016-05-07 11:10:00
# Ichi regime at 2016-05-07 11:10:00: 1
# Current position delta: 0.44995626740764244
# Elapsed: 0.927241325378418
# 		Run on 2016-05-08 11:10:00
# Ichi regime at 2016-05-08 11:10:00: 1
# Current position delta: 0.47104257624946366
# Elapsed: 0.873626708984375
# 		Run on 2016-05-09 11:10:00
# Ichi regime at 2016-05-09 11:10:00: 1
# Current position delta: 0.48689049297026055
# Elapsed: 0.896071195602417
# 		Run on 2016-05-10 11:10:00
# Ichi regime at 2016-05-10 11:10:00: 1
# Current position delta: 0.4746462121404766
# Elapsed: 0.945664644241333
# 		Run on 2016-05-11 11:10:00
# Ichi regime at 2016-05-11 11:10:00: 1
# Current position delta: 0.41054786368012686
# Elapsed: 0.9207515716552734
# 		Run on 2016-05-12 11:10:00
# Ichi regime at 2016-05-12 11:10:00: 1
# Current position delta: 0.3589079194796879
# Elapsed: 0.9427502155303955
# 		Run on 2016-05-13 11:10:00
# Ichi regime at 2016-05-13 11:10:00: 1
# Current position delta: 0.4048858100443039
# Elapsed: 0.9883124828338623
# 		Run on 2016-05-14 11:10:00
# Ichi regime at 2016-05-14 11:10:00: 1
# Current position delta: 0.3700152114595433
# Elapsed: 0.9335064888000488
# 		Run on 2016-05-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2016-05-15 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEN164600 x 1.0 Price: 2.798732715865107 Delta: 0.5982574604246773
# Leg:  / C.US.CLEN164950 x -1.0 Price: 1.2228711822775793 Delta: -0.35286064045610155
# Transactions delta: 0.24539681996857576
# Elapsed: 1.4105536937713623
# 		Run on 2016-05-16 11:10:00
# Ichi regime at 2016-05-16 11:10:00: 1
# Current position delta: 0.24238202495205685
# Elapsed: 1.0804622173309326
# 		Run on 2016-05-17 11:10:00
# Ichi regime at 2016-05-17 11:10:00: 1
# Current position delta: 0.23359694868887415
# Elapsed: 0.9320647716522217
# 		Run on 2016-05-18 11:10:00
# Ichi regime at 2016-05-18 11:10:00: 1
# Current position delta: 0.237826699285697
# Elapsed: 0.9401922225952148
# 		Run on 2016-05-19 11:10:00
# Ichi regime at 2016-05-19 11:10:00: 1
# Current position delta: 0.24735685494493242
# Elapsed: 0.9283232688903809
# 		Run on 2016-05-20 11:10:00
# Ichi regime at 2016-05-20 11:10:00: 1
# Current position delta: 0.2504321130939886
# Elapsed: 0.9477474689483643
# 		Run on 2016-05-21 11:10:00
# Ichi regime at 2016-05-21 11:10:00: 1
# Current position delta: 0.27182058650693447
# Elapsed: 0.9438815116882324
# 		Run on 2016-05-22 11:10:00
# Ichi regime at 2016-05-22 11:10:00: 1
# Current position delta: 0.27685721257790835
# Elapsed: 0.8873472213745117
# 		Run on 2016-05-23 11:10:00
# Ichi regime at 2016-05-23 11:10:00: 1
# Current position delta: 0.2879418026869366
# Elapsed: 0.9286682605743408
# 		Run on 2016-05-24 11:10:00
# Ichi regime at 2016-05-24 11:10:00: 1
# Current position delta: 0.28944126526141195
# Elapsed: 0.9501173496246338
# 		Run on 2016-05-25 11:10:00
# Ichi regime at 2016-05-25 11:10:00: 1
# Current position delta: 0.2873876464181252
# Elapsed: 0.9155535697937012
# 		Run on 2016-05-26 11:10:00
# Ichi regime at 2016-05-26 11:10:00: 1
# Current position delta: 0.3005511314797681
# Elapsed: 0.919630765914917
# 		Run on 2016-05-27 11:10:00
# Ichi regime at 2016-05-27 11:10:00: 1
# Current position delta: 0.31537843373679547
# Elapsed: 0.9332900047302246
# 		Run on 2016-05-28 11:10:00
# Ichi regime at 2016-05-28 11:10:00: 1
# Current position delta: 0.3107313358869339
# Elapsed: 0.9145240783691406
# 		Run on 2016-05-29 11:10:00
# Ichi regime at 2016-05-29 11:10:00: 1
# Current position delta: 0.31695838831522016
# Elapsed: 0.8778557777404785
# 		Run on 2016-05-30 11:10:00
# Ichi regime at 2016-05-30 11:10:00: 1
# Current position delta: 0.3215470175231996
# Elapsed: 0.9141783714294434
# 		Run on 2016-05-31 11:10:00
# Ichi regime at 2016-05-31 11:10:00: 1
# Current position delta: 0.32137442847538095
# Elapsed: 0.9213004112243652
# 		Run on 2016-06-01 11:10:00
# Ichi regime at 2016-06-01 11:10:00: 1
# Current position delta: 0.34961702664891353
# Elapsed: 0.9469730854034424
# 		Run on 2016-06-02 11:10:00
# Ichi regime at 2016-06-02 11:10:00: 1
# Current position delta: 0.32217973041623915
# Elapsed: 0.9564464092254639
# 		Run on 2016-06-03 11:10:00
# Ichi regime at 2016-06-03 11:10:00: 1
# Current position delta: 0.39661731609040685
# Elapsed: 0.9215133190155029
# 		Run on 2016-06-04 11:10:00
# Ichi regime at 2016-06-04 11:10:00: 1
# Current position delta: 0.4043233688393299
# Elapsed: 0.9672894477844238
# 		Run on 2016-06-05 11:10:00
# Ichi regime at 2016-06-05 11:10:00: 1
# Current position delta: 0.4182638931313688
# Elapsed: 0.8863379955291748
# 		Run on 2016-06-06 11:10:00
# Ichi regime at 2016-06-06 11:10:00: 1
# Current position delta: 0.39785108931174995
# Elapsed: 0.9175388813018799
# 		Run on 2016-06-07 11:10:00
# Ichi regime at 2016-06-07 11:10:00: 1
# Current position delta: 0.3090389357098814
# Elapsed: 0.9214630126953125
# 		Run on 2016-06-08 11:10:00
# Ichi regime at 2016-06-08 11:10:00: 1
# Current position delta: 0.22604691038713032
# Elapsed: 0.9840445518493652
# 		Run on 2016-06-09 11:10:00
# Ichi regime at 2016-06-09 11:10:00: 1
# Current position delta: 0.26648635321200564
# Elapsed: 0.9384486675262451
# 		Run on 2016-06-10 11:10:00
# Ichi regime at 2016-06-10 11:10:00: 1
# Current position delta: 0.4810437922793999
# Elapsed: 0.9169483184814453
# 		Run on 2016-06-11 11:10:00
# Ichi regime at 2016-06-11 11:10:00: 1
# Current position delta: 0.5085480180305697
# Elapsed: 0.9246468544006348
# 		Run on 2016-06-12 11:10:00
# Ichi regime at 2016-06-12 11:10:00: 1
# Current position delta: 0.5476441418976425
# Elapsed: 0.8803682327270508
# 		Run on 2016-06-13 11:10:00
# Ichi regime at 2016-06-13 11:10:00: 1
# Current position delta: 0.6353610554180781
# Elapsed: 0.8956694602966309
# 		Run on 2016-06-14 11:10:00
# Rollover occured, new series used
# Ichi regime at 2016-06-14 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEQ164800 x 1.0 Price: 2.7461795593730045 Delta: 0.5825311614557215
# Leg:  / C.US.CLEQ165150 x -1.0 Price: 1.1466707601421273 Delta: -0.3378220053193922
# Transactions delta: 0.24470915613632926
# Elapsed: 1.5163545608520508
# 		Run on 2016-06-15 11:10:00
# Ichi regime at 2016-06-15 11:10:00: 1
# Current position delta: 0.24716946785641314
# Elapsed: 1.1128559112548828
# 		Run on 2016-06-16 11:10:00
# Ichi regime at 2016-06-16 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEQ164600 x 1.0 Price: 2.764103380678918 Delta: 0.606796971624742
# Leg:  / C.US.CLEQ164950 x -1.0 Price: 1.1161969140050427 Delta: -0.34612839832157005
# Transactions delta: 0.26066857330317195
# Elapsed: 1.2903356552124023
# 		Run on 2016-06-17 11:10:00
# Ichi regime at 2016-06-17 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEQ164700 x 1.0 Price: 2.814860034680297 Delta: 0.6127435851291825
# Leg:  / C.US.CLEQ165050 x -1.0 Price: 1.1662621738986356 Delta: -0.3539618269159326
# Transactions delta: 0.2587817582132499
# Elapsed: 1.305495023727417
# 		Run on 2016-06-18 11:10:00
# Ichi regime at 2016-06-18 11:10:00: 1
# Current position delta: 0.26235398800283855
# Elapsed: 0.9355945587158203
# 		Run on 2016-06-19 11:10:00
# Ichi regime at 2016-06-19 11:10:00: 1
# Current position delta: 0.267134118031181
# Elapsed: 0.88942551612854
# 		Run on 2016-06-20 11:10:00
# Ichi regime at 2016-06-20 11:10:00: 1
# Current position delta: 0.2618922915573511
# Elapsed: 0.9020137786865234
# 		Run on 2016-06-21 11:10:00
# Ichi regime at 2016-06-21 11:10:00: 1
# Current position delta: 0.26867757564378825
# Elapsed: 0.937720537185669
# 		Run on 2016-06-22 11:10:00
# Ichi regime at 2016-06-22 11:10:00: 1
# Current position delta: 0.2771766760683825
# Elapsed: 0.9384939670562744
# 		Run on 2016-06-23 11:10:00
# Ichi regime at 2016-06-23 11:10:00: 1
# Current position delta: 0.2601484832181812
# Elapsed: 0.9196500778198242
# 		Run on 2016-06-24 11:10:00
# Ichi regime at 2016-06-24 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEQ164700 x 1.0 Price: 2.371928094000559 Delta: 0.5919125783188146
# Leg:  / C.US.CLEQ165050 x -1.0 Price: 0.7689858795285254 Delta: -0.29382574426474295
# Transactions delta: 0.29808683405407166
# Elapsed: 1.3539597988128662
# 		Run on 2016-06-25 11:10:00
# Ichi regime at 2016-06-25 11:10:00: -1
# Current position delta: 0.30747715325179825
# Elapsed: 0.9116215705871582
# 		Run on 2016-06-26 11:10:00
# Ichi regime at 2016-06-26 11:10:00: -1
# Current position delta: 0.31439380841953324
# Elapsed: 0.889354944229126
# 		Run on 2016-06-27 11:10:00
# Ichi regime at 2016-06-27 11:10:00: -1
# Current position delta: 0.2812851441070688
# Elapsed: 0.9008409976959229
# 		Run on 2016-06-28 11:10:00
# Ichi regime at 2016-06-28 11:10:00: -1
# Current position delta: 0.3326455667836996
# Elapsed: 0.9662675857543945
# 		Run on 2016-06-29 11:10:00
# Ichi regime at 2016-06-29 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEQ164850 x 1.0 Price: 2.086468661632402 Delta: 0.6193572247752159
# Leg:  / C.US.CLEQ165200 x -1.0 Price: 0.5459908880782205 Delta: -0.2609995497213375
# Transactions delta: 0.35835767505387844
# Elapsed: 1.3376808166503906
# 		Run on 2016-06-30 11:10:00
# Ichi regime at 2016-06-30 11:10:00: 1
# Current position delta: 0.37063552768595176
# Elapsed: 0.9495658874511719
# 		Run on 2016-07-01 11:10:00
# Ichi regime at 2016-07-01 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEQ164750 x 1.0 Price: 2.1324937849213903 Delta: 0.6496506653251739
# Leg:  / C.US.CLEQ165100 x -1.0 Price: 0.5125033905870495 Delta: -0.2636765287591995
# Transactions delta: 0.3859741365659744
# Elapsed: 1.2748162746429443
# 		Run on 2016-07-02 11:10:00
# Ichi regime at 2016-07-02 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEQ164850 x 1.0 Price: 1.6948072242695638 Delta: 0.6113529575230561
# Leg:  / C.US.CLEQ165200 x -1.0 Price: 0.2936396513881352 Delta: -0.18937502374369886
# Transactions delta: 0.4219779337793572
# Elapsed: 1.2837321758270264
# 		Run on 2016-07-03 11:10:00
# Ichi regime at 2016-07-03 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEQ164850 x 1.0 Price: 1.646474538045208 Delta: 0.6146735358776125
# Leg:  / C.US.CLEQ165200 x -1.0 Price: 0.2632095131712653 Delta: -0.17909623961600454
# Transactions delta: 0.435577296261608
# Elapsed: 1.1826651096343994
# 		Run on 2016-07-04 11:10:00
# Ichi regime at 2016-07-04 11:10:00: -1
# Current position delta: 0.4256267220178139
# Elapsed: 0.935699462890625
# 		Run on 2016-07-05 11:10:00
# Ichi regime at 2016-07-05 11:10:00: -1
# Current position delta: 0.2619880255276954
# Elapsed: 0.9318099021911621
# 		Run on 2016-07-06 11:10:00
# Ichi regime at 2016-07-06 11:10:00: -1
# Current position delta: 0.29999321618147
# Elapsed: 0.945749044418335
# 		Run on 2016-07-07 11:10:00
# Ichi regime at 2016-07-07 11:10:00: -1
# Current position delta: 0.10178778689081201
# Elapsed: 0.965742826461792
# 		Run on 2016-07-08 11:10:00
# Ichi regime at 2016-07-08 11:10:00: -1
# Current position delta: 0.09844450269948518
# Elapsed: 0.9203987121582031
# 		Run on 2016-07-09 11:10:00
# Ichi regime at 2016-07-09 11:10:00: -1
# Current position delta: 0.0653911940973245
# Elapsed: 0.9373073577880859
# 		Run on 2016-07-10 11:10:00
# Ichi regime at 2016-07-10 11:10:00: -1
# Current position delta: 0.05172177538901847
# Elapsed: 0.8874304294586182
# 		Run on 2016-07-11 11:10:00
# Ichi regime at 2016-07-11 11:10:00: -1
# Current position delta: 0.028201555430349936
# Elapsed: 0.9097294807434082
# 		Run on 2016-07-12 11:10:00
# Ichi regime at 2016-07-12 11:10:00: -1
# Current position delta: 0.17751695239023343
# Elapsed: 0.9546754360198975
# 		Run on 2016-07-13 11:10:00
# Rollover occured, new series used
# Ichi regime at 2016-07-13 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEU164450 x 1.0 Price: 2.6883067455648266 Delta: 0.58871816713085
# Leg:  / C.US.CLEU164800 x -1.0 Price: 1.0705396521116022 Delta: -0.33315532611357657
# Transactions delta: 0.25556284101727345
# Elapsed: 1.4803292751312256
# 		Run on 2016-07-14 11:10:00
# Ichi regime at 2016-07-14 11:10:00: -1
# Current position delta: 0.2463493960830595
# Elapsed: 1.1115431785583496
# 		Run on 2016-07-15 11:10:00
# Ichi regime at 2016-07-15 11:10:00: -1
# Current position delta: 0.26569655228775974
# Elapsed: 0.9555447101593018
# 		Run on 2016-07-16 11:10:00
# Ichi regime at 2016-07-16 11:10:00: -1
# Current position delta: 0.2691471065238855
# Elapsed: 0.936084508895874
# 		Run on 2016-07-17 11:10:00
# Ichi regime at 2016-07-17 11:10:00: -1
# Current position delta: 0.27317582567272675
# Elapsed: 0.8774127960205078
# 		Run on 2016-07-18 11:10:00
# Ichi regime at 2016-07-18 11:10:00: -1
# Current position delta: 0.2884995029109842
# Elapsed: 0.8976352214813232
# 		Run on 2016-07-19 11:10:00
# Ichi regime at 2016-07-19 11:10:00: -1
# Current position delta: 0.28792168040276983
# Elapsed: 0.9267573356628418
# 		Run on 2016-07-20 11:10:00
# Ichi regime at 2016-07-20 11:10:00: -1
# Current position delta: 0.2954761888237961
# Elapsed: 0.9217133522033691
# 		Run on 2016-07-21 11:10:00
# Ichi regime at 2016-07-21 11:10:00: -1
# Current position delta: 0.30861691562635485
# Elapsed: 1.0237550735473633
# 		Run on 2016-07-22 11:10:00
# Ichi regime at 2016-07-22 11:10:00: -1
# Current position delta: 0.294689865711552
# Elapsed: 0.9581501483917236
# 		Run on 2016-07-23 11:10:00
# Ichi regime at 2016-07-23 11:10:00: -1
# Current position delta: 0.2983753386183199
# Elapsed: 0.9663920402526855
# 		Run on 2016-07-24 11:10:00
# Ichi regime at 2016-07-24 11:10:00: -1
# Current position delta: 0.30287967891793355
# Elapsed: 0.8802018165588379
# 		Run on 2016-07-25 11:10:00
# Ichi regime at 2016-07-25 11:10:00: -1
# Current position delta: 0.2682103270732632
# Elapsed: 0.9034075736999512
# 		Run on 2016-07-26 11:10:00
# Ichi regime at 2016-07-26 11:10:00: -1
# Current position delta: 0.24796960975856047
# Elapsed: 0.9315135478973389
# 		Run on 2016-07-27 11:10:00
# Ichi regime at 2016-07-27 11:10:00: -1
# Current position delta: 0.1963405753501402
# Elapsed: 0.9494709968566895
# 		Run on 2016-07-28 11:10:00
# Ichi regime at 2016-07-28 11:10:00: -1
# Current position delta: 0.1504126027307654
# Elapsed: 0.9246225357055664
# 		Run on 2016-07-29 11:10:00
# Ichi regime at 2016-07-29 11:10:00: -1
# Current position delta: 0.16101267173663558
# Elapsed: 0.9273979663848877
# 		Run on 2016-07-30 11:10:00
# Ichi regime at 2016-07-30 11:10:00: -1
# Current position delta: 0.14765560910737244
# Elapsed: 0.9314329624176025
# 		Run on 2016-07-31 11:10:00
# Ichi regime at 2016-07-31 11:10:00: -1
# Current position delta: 0.1458279910853703
# Elapsed: 0.8981523513793945
# 		Run on 2016-08-01 11:10:00
# Ichi regime at 2016-08-01 11:10:00: -1
# Current position delta: 0.07477061157963626
# Elapsed: 0.8982067108154297
# 		Run on 2016-08-02 11:10:00
# Ichi regime at 2016-08-02 11:10:00: -1
# Current position delta: 0.06745313325651324
# Elapsed: 0.9428408145904541
# 		Run on 2016-08-03 11:10:00
# Ichi regime at 2016-08-03 11:10:00: -1
# Current position delta: 0.11307060552706347
# Elapsed: 0.9480934143066406
# 		Run on 2016-08-04 11:10:00
# Ichi regime at 2016-08-04 11:10:00: -1
# Current position delta: 0.16244872234599306
# Elapsed: 0.9311716556549072
# 		Run on 2016-08-05 11:10:00
# Ichi regime at 2016-08-05 11:10:00: -1
# Current position delta: 0.1509764823387919
# Elapsed: 0.9187743663787842
# 		Run on 2016-08-06 11:10:00
# Ichi regime at 2016-08-06 11:10:00: -1
# Current position delta: 0.15334166758486095
# Elapsed: 0.9521217346191406
# 		Run on 2016-08-07 11:10:00
# Ichi regime at 2016-08-07 11:10:00: -1
# Current position delta: 0.14853067463631844
# Elapsed: 0.9098050594329834
# 		Run on 2016-08-08 11:10:00
# Ichi regime at 2016-08-08 11:10:00: -1
# Current position delta: 0.2632110484248724
# Elapsed: 0.8995516300201416
# 		Run on 2016-08-09 11:10:00
# Ichi regime at 2016-08-09 11:10:00: -1
# Current position delta: 0.2131886595749624
# Elapsed: 0.9384479522705078
# 		Run on 2016-08-10 11:10:00
# Ichi regime at 2016-08-10 11:10:00: -1
# Current position delta: 0.13205966964135368
# Elapsed: 0.9344568252563477
# 		Run on 2016-08-11 11:10:00
# Ichi regime at 2016-08-11 11:10:00: -1
# Current position delta: 0.297195087587929
# Elapsed: 0.952261209487915
# 		Run on 2016-08-12 11:10:00
# Ichi regime at 2016-08-12 11:10:00: -1
# Current position delta: 0.3994997739074962
# Elapsed: 0.939342737197876
# 		Run on 2016-08-13 11:10:00
# Ichi regime at 2016-08-13 11:10:00: -1
# Current position delta: 0.4867747235107318
# Elapsed: 0.9692120552062988
# 		Run on 2016-08-14 11:10:00
# Ichi regime at 2016-08-14 11:10:00: -1
# Current position delta: 0.5184640484624707
# Elapsed: 0.871666431427002
# 		Run on 2016-08-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2016-08-15 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEV164550 x 1.0 Price: 2.3807816275312064 Delta: 0.5878449603666012
# Leg:  / C.US.CLEV164900 x -1.0 Price: 0.8687545751621535 Delta: -0.3063986816525882
# Transactions delta: 0.28144627871401295
# Elapsed: 1.4366602897644043
# 		Run on 2016-08-16 11:10:00
# Ichi regime at 2016-08-16 11:10:00: -1
# Current position delta: 0.2855637336265715
# Elapsed: 1.1114528179168701
# 		Run on 2016-08-17 11:10:00
# Ichi regime at 2016-08-17 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEV164650 x 1.0 Price: 2.3050370445815958 Delta: 0.5901226656992249
# Leg:  / C.US.CLEV165000 x -1.0 Price: 0.7877504572319083 Delta: -0.29531197401062576
# Transactions delta: 0.29481069168859914
# Elapsed: 1.2453184127807617
# 		Run on 2016-08-18 11:10:00
# Ichi regime at 2016-08-18 11:10:00: 1
# Current position delta: 0.2984737514323689
# Elapsed: 0.9492063522338867
# 		Run on 2016-08-19 11:10:00
# Ichi regime at 2016-08-19 11:10:00: 1
# Current position delta: 0.29736958854030676
# Elapsed: 0.9396882057189941
# 		Run on 2016-08-20 11:10:00
# Ichi regime at 2016-08-20 11:10:00: 1
# Current position delta: 0.3021230278969886
# Elapsed: 0.9222958087921143
# 		Run on 2016-08-21 11:10:00
# Ichi regime at 2016-08-21 11:10:00: 1
# Current position delta: 0.3075640542584968
# Elapsed: 0.9016242027282715
# 		Run on 2016-08-22 11:10:00
# Ichi regime at 2016-08-22 11:10:00: 1
# Current position delta: 0.3305022563112029
# Elapsed: 0.9037964344024658
# 		Run on 2016-08-23 11:10:00
# Ichi regime at 2016-08-23 11:10:00: 1
# Current position delta: 0.3313843871062809
# Elapsed: 0.9472684860229492
# 		Run on 2016-08-24 11:10:00
# Ichi regime at 2016-08-24 11:10:00: 1
# Current position delta: 0.31440155578993356
# Elapsed: 0.9165618419647217
# 		Run on 2016-08-25 11:10:00
# Ichi regime at 2016-08-25 11:10:00: 1
# Current position delta: 0.3399671535693266
# Elapsed: 0.9133877754211426
# 		Run on 2016-08-26 11:10:00
# Ichi regime at 2016-08-26 11:10:00: 1
# Current position delta: 0.3720687762937625
# Elapsed: 0.9615790843963623
# 		Run on 2016-08-27 11:10:00
# Ichi regime at 2016-08-27 11:10:00: 1
# Current position delta: 0.39063300577865534
# Elapsed: 0.936913013458252
# 		Run on 2016-08-28 11:10:00
# Ichi regime at 2016-08-28 11:10:00: 1
# Current position delta: 0.39947485625953527
# Elapsed: 0.9018039703369141
# 		Run on 2016-08-29 11:10:00
# Ichi regime at 2016-08-29 11:10:00: 1
# Current position delta: 0.4015284259851869
# Elapsed: 0.9125702381134033
# 		Run on 2016-08-30 11:10:00
# Ichi regime at 2016-08-30 11:10:00: 1
# Current position delta: 0.36319018139032294
# Elapsed: 0.9543106555938721
# 		Run on 2016-08-31 11:10:00
# Ichi regime at 2016-08-31 11:10:00: 1
# Current position delta: 0.24533858380574516
# Elapsed: 0.9516587257385254
# 		Run on 2016-09-01 11:10:00
# Ichi regime at 2016-09-01 11:10:00: 1
# Current position delta: 0.12824856169215892
# Elapsed: 0.9233298301696777
# 		Run on 2016-09-02 11:10:00
# Ichi regime at 2016-09-02 11:10:00: 1
# Current position delta: 0.20642404834534236
# Elapsed: 0.9585978984832764
# 		Run on 2016-09-03 11:10:00
# Ichi regime at 2016-09-03 11:10:00: 1
# Current position delta: 0.17053810444227208
# Elapsed: 0.9405560493469238
# 		Run on 2016-09-04 11:10:00
# Ichi regime at 2016-09-04 11:10:00: 1
# Current position delta: 0.165459741453776
# Elapsed: 0.891228437423706
# 		Run on 2016-09-05 11:10:00
# Ichi regime at 2016-09-05 11:10:00: 1
# Current position delta: 0.2557078011115771
# Elapsed: 0.9082012176513672
# 		Run on 2016-09-06 11:10:00
# Ichi regime at 2016-09-06 11:10:00: 1
# Current position delta: 0.20548343725853024
# Elapsed: 0.9419851303100586
# 		Run on 2016-09-07 11:10:00
# Ichi regime at 2016-09-07 11:10:00: 1
# Current position delta: 0.2787470366480906
# Elapsed: 0.9257040023803711
# 		Run on 2016-09-08 11:10:00
# Ichi regime at 2016-09-08 11:10:00: 1
# Current position delta: 0.47424858853569696
# Elapsed: 0.9506361484527588
# 		Run on 2016-09-09 11:10:00
# Ichi regime at 2016-09-09 11:10:00: 1
# Current position delta: 0.3690638267713579
# Elapsed: 0.9121346473693848
# 		Run on 2016-09-10 11:10:00
# Ichi regime at 2016-09-10 11:10:00: 1
# Current position delta: 0.3224279923054819
# Elapsed: 0.9375035762786865
# 		Run on 2016-09-11 11:10:00
# Ichi regime at 2016-09-11 11:10:00: 1
# Current position delta: 0.31677275123269316
# Elapsed: 0.881763219833374
# 		Run on 2016-09-12 11:10:00
# Ichi regime at 2016-09-12 11:10:00: 1
# Current position delta: 0.4228462814771988
# Elapsed: 0.8906817436218262
# 		Run on 2016-09-13 11:10:00
# Rollover occured, new series used
# Ichi regime at 2016-09-13 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX164450 x 1.0 Price: 2.7138652877157377 Delta: 0.608092084704549
# Leg:  / C.US.CLEX164800 x -1.0 Price: 1.0866067904017758 Delta: -0.34344850670062915
# Transactions delta: 0.26464357800391985
# Elapsed: 1.4692485332489014
# 		Run on 2016-09-14 11:10:00
# Ichi regime at 2016-09-14 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEX164300 x 1.0 Price: 2.784352718899246 Delta: 0.6182834584361367
# Leg:  / C.US.CLEX164650 x -1.0 Price: 1.1375556009190042 Delta: -0.35413833746057277
# Transactions delta: 0.264145120975564
# Elapsed: 1.4499759674072266
# 		Run on 2016-09-15 11:10:00
# Ichi regime at 2016-09-15 11:10:00: -1
# Current position delta: 0.2660239174650207
# Elapsed: 0.9303524494171143
# 		Run on 2016-09-16 11:10:00
# Ichi regime at 2016-09-16 11:10:00: -1
# Current position delta: 0.28478470744254486
# Elapsed: 0.9405221939086914
# 		Run on 2016-09-17 11:10:00
# Ichi regime at 2016-09-17 11:10:00: -1
# Current position delta: 0.2921966187311338
# Elapsed: 0.8989193439483643
# 		Run on 2016-09-18 11:10:00
# Ichi regime at 2016-09-18 11:10:00: -1
# Current position delta: 0.2967197386817571
# Elapsed: 0.8957107067108154
# 		Run on 2016-09-19 11:10:00
# Ichi regime at 2016-09-19 11:10:00: -1
# Current position delta: 0.3022807125695234
# Elapsed: 0.8949267864227295
# 		Run on 2016-09-20 11:10:00
# Ichi regime at 2016-09-20 11:10:00: -1
# Current position delta: 0.3020172555646365
# Elapsed: 0.9065821170806885
# 		Run on 2016-09-21 11:10:00
# Ichi regime at 2016-09-21 11:10:00: -1
# Current position delta: 0.2902155165610706
# Elapsed: 0.9175465106964111
# 		Run on 2016-09-22 11:10:00
# Ichi regime at 2016-09-22 11:10:00: -1
# Current position delta: 0.27909532889761457
# Elapsed: 0.9152417182922363
# 		Run on 2016-09-23 11:10:00
# Ichi regime at 2016-09-23 11:10:00: -1
# Current position delta: 0.31082569481605077
# Elapsed: 0.9463367462158203
# 		Run on 2016-09-24 11:10:00
# Ichi regime at 2016-09-24 11:10:00: -1
# Current position delta: 0.2934628780989857
# Elapsed: 0.9025366306304932
# 		Run on 2016-09-25 11:10:00
# Ichi regime at 2016-09-25 11:10:00: -1
# Current position delta: 0.2997345495763886
# Elapsed: 0.8734076023101807
# 		Run on 2016-09-26 11:10:00
# Ichi regime at 2016-09-26 11:10:00: -1
# Current position delta: 0.2859814766390061
# Elapsed: 0.8973023891448975
# 		Run on 2016-09-27 11:10:00
# Ichi regime at 2016-09-27 11:10:00: -1
# Current position delta: 0.30449378294288565
# Elapsed: 0.9197607040405273
# 		Run on 2016-09-28 11:10:00
# Ichi regime at 2016-09-28 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX164550 x 1.0 Price: 2.2342654449444694 Delta: 0.6044969966521708
# Leg:  / C.US.CLEX164900 x -1.0 Price: 0.7798263266582595 Delta: -0.29853680984830994
# Transactions delta: 0.3059601868038609
# Elapsed: 1.281543254852295
# 		Run on 2016-09-29 11:10:00
# Ichi regime at 2016-09-29 11:10:00: 1
# Current position delta: 0.3021493232911662
# Elapsed: 0.9324023723602295
# 		Run on 2016-09-30 11:10:00
# Ichi regime at 2016-09-30 11:10:00: 1
# Current position delta: 0.3286274207973195
# Elapsed: 0.9406454563140869
# 		Run on 2016-10-01 11:10:00
# Ichi regime at 2016-10-01 11:10:00: 1
# Current position delta: 0.36219556971320677
# Elapsed: 0.9171621799468994
# 		Run on 2016-10-02 11:10:00
# Ichi regime at 2016-10-02 11:10:00: 1
# Current position delta: 0.3726188890244084
# Elapsed: 0.8890409469604492
# 		Run on 2016-10-03 11:10:00
# Ichi regime at 2016-10-03 11:10:00: 1
# Current position delta: 0.35087456900947106
# Elapsed: 0.9004638195037842
# 		Run on 2016-10-04 11:10:00
# Ichi regime at 2016-10-04 11:10:00: 1
# Current position delta: 0.36645767196311313
# Elapsed: 0.9334473609924316
# 		Run on 2016-10-05 11:10:00
# Ichi regime at 2016-10-05 11:10:00: 1
# Current position delta: 0.3011068584116614
# Elapsed: 0.9265444278717041
# 		Run on 2016-10-06 11:10:00
# Date not found at 2016-10-06
# Ichi regime at 2016-10-06 11:10:00: None
# Elapsed: 0.775078296661377
# 		Run on 2016-10-07 11:10:00
# Ichi regime at 2016-10-07 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX164850 x 1.0 Price: 1.8438346549498377 Delta: 0.6866214123795139
# Leg:  / C.US.CLEX165200 x -1.0 Price: 0.3028175862479525 Delta: -0.209461595425851
# Transactions delta: 0.47715981695366294
# Elapsed: 0.6475293636322021
# 		Run on 2016-10-08 11:10:00
# Date not found at 2016-10-08
# Ichi regime at 2016-10-08 11:10:00: None
# Elapsed: 0.7458233833312988
# 		Run on 2016-10-09 11:10:00
# Date not found at 2016-10-09
# Ichi regime at 2016-10-09 11:10:00: None
# Current position delta: 0.0
# Elapsed: 0.17838740348815918
# 		Run on 2016-10-10 11:10:00
# Ichi regime at 2016-10-10 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX165050 x 1.0 Price: 1.4061637000438338 Delta: 0.6546448164184253
# Leg:  / C.US.CLEX165400 x -1.0 Price: 0.1687256402173647 Delta: -0.142633147103079
# Transactions delta: 0.5120116693153463
# Elapsed: 0.6334881782531738
# 		Run on 2016-10-11 11:10:00
# Ichi regime at 2016-10-11 11:10:00: 1
# Current position delta: 0.45577704623249937
# Elapsed: 0.9336187839508057
# 		Run on 2016-10-12 11:10:00
# Ichi regime at 2016-10-12 11:10:00: 1
# Current position delta: 0.40522671408502375
# Elapsed: 0.9142634868621826
# 		Run on 2016-10-13 11:10:00
# Date not found at 2016-10-13
# Ichi regime at 2016-10-13 11:10:00: None
# Elapsed: 0.8206877708435059
# 		Run on 2016-10-14 11:10:00
# Ichi regime at 2016-10-14 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX164900 x 1.0 Price: 1.1817251573729308 Delta: 0.7638343069201748
# Leg:  / C.US.CLEX165250 x -1.0 Price: 0.020289346057325464 Delta: -0.03746976236361969
# Transactions delta: 0.7263645445565552
# Elapsed: 0.6411330699920654
# 		Run on 2016-10-15 11:10:00
# Rollover occured, new series used
# Date not found at 2016-10-15
# Ichi regime at 2016-10-15 11:10:00: None
# Current position delta: 0.0
# Elapsed: 1.1235930919647217
# 		Run on 2016-10-16 11:10:00
# Ichi regime at 2016-10-16 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEZ164950 x 1.0 Price: 2.6139044248942973 Delta: 0.6237431227487737
# Leg:  / C.US.CLEZ165300 x -1.0 Price: 0.9626037975880894 Delta: -0.3339576289333378
# Transactions delta: 0.28978549381543595
# Elapsed: 0.7501153945922852
# 		Run on 2016-10-17 11:10:00
# Ichi regime at 2016-10-17 11:10:00: 1
# Current position delta: 0.29338302014589657
# Elapsed: 0.906257152557373
# 		Run on 2016-10-18 11:10:00
# Ichi regime at 2016-10-18 11:10:00: 1
# Current position delta: 0.30128330292875255
# Elapsed: 0.9267945289611816
# 		Run on 2016-10-19 11:10:00
# Ichi regime at 2016-10-19 11:10:00: 1
# Current position delta: 0.3045705144911399
# Elapsed: 0.9225568771362305
# 		Run on 2016-10-20 11:10:00
# Ichi regime at 2016-10-20 11:10:00: 1
# Current position delta: 0.3215441671509431
# Elapsed: 0.9610457420349121
# 		Run on 2016-10-21 11:10:00
# Ichi regime at 2016-10-21 11:10:00: 1
# Current position delta: 0.32896189948133214
# Elapsed: 0.9428389072418213
# 		Run on 2016-10-22 11:10:00
# Date not found at 2016-10-22
# Ichi regime at 2016-10-22 11:10:00: None
# Elapsed: 0.7740483283996582
# 		Run on 2016-10-23 11:10:00
# Ichi regime at 2016-10-23 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEZ165000 x 1.0 Price: 2.1568756439173207 Delta: 0.6172994621200805
# Leg:  / C.US.CLEZ165350 x -1.0 Price: 0.6382456953162734 Delta: -0.2784483982273398
# Transactions delta: 0.33885106389274067
# Elapsed: 0.6114158630371094
# 		Run on 2016-10-24 11:10:00
# Ichi regime at 2016-10-24 11:10:00: 1
# Current position delta: 0.33489154297370716
# Elapsed: 0.9410064220428467
# 		Run on 2016-10-25 11:10:00
# Ichi regime at 2016-10-25 11:10:00: 1
# Current position delta: 0.32873401878469943
# Elapsed: 0.9801554679870605
# 		Run on 2016-10-26 11:10:00
# Ichi regime at 2016-10-26 11:10:00: 1
# Current position delta: 0.29589619741748174
# Elapsed: 0.9283220767974854
# 		Run on 2016-10-27 11:10:00
# Ichi regime at 2016-10-27 11:10:00: 1
# Current position delta: 0.3146853308862778
# Elapsed: 0.9317588806152344
# 		Run on 2016-10-28 11:10:00
# Ichi regime at 2016-10-28 11:10:00: 1
# Current position delta: 0.2590509959936131
# Elapsed: 0.9514899253845215
# 		Run on 2016-10-29 11:10:00
# Date not found at 2016-10-29
# Ichi regime at 2016-10-29 11:10:00: None
# Elapsed: 0.7940335273742676
# 		Run on 2016-10-30 11:10:00
# Date not found at 2016-10-30
# Ichi regime at 2016-10-30 11:10:00: None
# Current position delta: 0.0
# Elapsed: 0.1915583610534668
# 		Run on 2016-10-31 11:10:00
# Ichi regime at 2016-10-31 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEZ164600 x 1.0 Price: 2.111939882893491 Delta: 0.6390871536834027
# Leg:  / C.US.CLEZ164950 x -1.0 Price: 0.5277834559147063 Delta: -0.263770390323888
# Transactions delta: 0.37531676335951475
# Elapsed: 0.6028845310211182
# 		Run on 2016-11-01 11:10:00
# Ichi regime at 2016-11-01 11:10:00: 1
# Current position delta: 0.3603019548327106
# Elapsed: 0.9230735301971436
# 		Run on 2016-11-02 11:10:00
# Ichi regime at 2016-11-02 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEZ164400 x 1.0 Price: 2.006165978680638 Delta: 0.6511405323266788
# Leg:  / C.US.CLEZ164750 x -1.0 Price: 0.4478647271252161 Delta: -0.2472175094669967
# Transactions delta: 0.40392302285968207
# Elapsed: 1.287093162536621
# 		Run on 2016-11-03 11:10:00
# Ichi regime at 2016-11-03 11:10:00: -1
# Current position delta: 0.4110227860522996
# Elapsed: 0.9449946880340576
# 		Run on 2016-11-04 11:10:00
# Ichi regime at 2016-11-04 11:10:00: -1
# Current position delta: 0.42045476638257007
# Elapsed: 0.883265495300293
# Done

# %% [markdown]
# # View EXO price series

# %%
for ticker in instruments:
    exo_df, exo_info = exostorage.load_series('{0}_{1}'.format(ticker, EXO_NAME))    
    exo_df['exo'].plot(title='{0}_{1}'.format(ticker, EXO_NAME))
    plt.show()
