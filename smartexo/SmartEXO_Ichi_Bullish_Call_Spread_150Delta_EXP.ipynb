# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from exobuilder.contracts.futureschain import FuturesChain
from exobuilder.contracts.futurecontract import FutureContract
from exobuilder.tests.assetindexdict import AssetIndexDicts
from datetime import datetime, date, timedelta, time as dttime
from exobuilder.contracts.instrument import Instrument
from exobuilder.data.datasource_mongo import DataSourceMongo
from exobuilder.data.datasource_sql import DataSourceSQL
from exobuilder.data.assetindex_mongo import AssetIndexMongo
from exobuilder.data.exostorage import EXOStorage
from exobuilder.exo.exoenginebase import ExoEngineBase
from exobuilder.exo.transaction import Transaction
import time
from exobuilder.algorithms.rollover_helper import RolloverHelper

import importlib
import logging
importlib.reload(logging);
import matplotlib.pyplot as plt

# %%
EXO_NAME = 'SmartEXO_Ichi__BullCall_Spread_Delta_150_EXP'

# TODO: set to 'False' if EXO building output is too verbosive
verbosive_logging = True # or True - for debug log feed

# TODO: select instruments list for SMART EXO calculation
#instruments = ['CL', 'ES', 'NG', 'ZC', 'ZS', 'ZW', 'ZN']
instruments = ['CL']


# TODO: select start date for SmartEXO calculation
base_date = datetime(2014, 1, 13, 12, 45, 0)

# %% [markdown]
# # Define Bull/Bear/Neutral areas rules

# %%
def ichimoku_regimes(date, price_series):    
    '''
    Calculates Bull/Bear/Neutral areas based on Ichimoku zones
    
    param date: Current date time
    param price_series: price Pandas.Series
    
    Returns:
        -1 - for bearish zone
        0  - for neutral zone
        +1 - for bullish zone
        None - for unknown
    '''
    #
    #  TODO: Change values to fine tune zoning algorithm
    #
    conversion_line_period = 9 # subject of optimization
    base_line_period = 26  # subject of optimization
    leading_spans_lookahead_period = 52  # subject of optimization
    leading_span_b_period = 52 # subject of optimization
        
        
    conversion_line_high = price_series.rolling(window=conversion_line_period).max()
    conversion_line_low = price_series.rolling(window=conversion_line_period).min()
    conversion_line = (conversion_line_high + conversion_line_low) / 2

    base_line_high = price_series.rolling(window=base_line_period).max()
    base_line_low = price_series.rolling(window=base_line_period).min()
    base_line = (base_line_high + base_line_low) / 2

    leading_span_a = ((conversion_line + base_line) / 2).shift(leading_spans_lookahead_period)
    leading_span_b = ((price_series.rolling(window=leading_span_b_period).max() + price_series.rolling(
        window=leading_span_b_period).min()) / 2).shift(leading_spans_lookahead_period)


    #
    # Rules calculation
    #

    # Cloud top and bottom series are defined using leading span A and B
    cloud_top = leading_span_a.rolling(1).max()
    cloud_bottom = leading_span_a.rolling(1).min()

    rule_price_above_cloud_top = price_series > cloud_top
    rule_price_below_cloud_bottom = price_series < cloud_bottom
    rule_price_in_cloud = (price_series < cloud_top) & (price_series > cloud_bottom)

    def get_regime(date):
        if date not in rule_price_above_cloud_top.index:
            logging.debug("Date not found at {0}".format(date))
            return None


        if rule_price_above_cloud_top[date]:
            return 1
        elif rule_price_below_cloud_bottom[date]:
            return -1
        elif rule_price_in_cloud[date]:
            return 0
        return None

    regime = get_regime(date.date())
    logging.debug("Ichi regime at {0}: {1}".format(date, regime))
    return regime

# %%
# Toolbox
def transactions_delta(trans_list):
    return sum([t.delta for t in trans_list])

def log_transactions(trans_list, msg):
    logging.debug(msg)
    [logging.debug(t) for t in trans_list]
    logging.debug('Transactions delta: {0}'.format(transactions_delta(trans_list)))

# %% [markdown]
# # Option position management

# %% [markdown]
# According to https://tmqrexo.slack.com/files/nikolasjoyce/F2PHLEETZ/pasted_image_at_2016_10_14_10_05_am.png

# %% [markdown]
# ## New bullish zone position

# %%
#emphasis the bullish areas 

def new_position_bullish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bullish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening long call spread in bullish zone
    #
    # https://files.slack.com/files-tmb/T0484J7T7-F2QBLK53R-93b4252806/pasted_image_at_2016_10_17_10_08_am_720.png
    
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-2].c, date, 6.0, leg_name='bullish'),
                Transaction(opt_chain[3].c, date, -6.0),
                
                Transaction(opt_chain[3].c, date, 0.0),
                Transaction(opt_chain[6].c, date,  0.0),
           ]
    log_transactions(trans_list,'New bullish zone position')
    return trans_list

# %% [markdown]
# ## New bearish zone position

# %%
def new_position_bearish_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for bearish zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening small ITM straddle in bearish zone
    #
    
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[2].c, date, 1.0, leg_name='bearish'),
                Transaction(opt_chain[2].p, date, 1.0),                
                ]
    log_transactions(trans_list,'New bearish zone position')
    return trans_list

# %% [markdown]
# ## New neutral zone position

# %%
def new_position_neutral_zone(date, fut, opt_chain):
    """
    Returns transaction to open new Smart EXO position for neutral zone
    
    params date: current date
    params fut: current actual future contract
    params opt_chain: current actual options chain
    
    returns: List of Transactions to open    
    """
    
    #
    # Opening long asymmetric butterfly in neutral zone
    #    
    # https://files.slack.com/files-tmb/T0484J7T7-F2PGU8QNQ-6344e6a04c/pasted_image_at_2016_10_14_09_43_am_720.png
    trans_list = [
                #Transaction(asset, date, qty, price=[MktPrice], leg_name=['' or unique name])
                Transaction(opt_chain[-2].c, date, -3.0, leg_name='neutral'),
                Transaction(opt_chain[2].c, date, 6.0),
                
                Transaction(opt_chain[8].c, date, -3.0),
                Transaction(opt_chain[3].c, date,  0.0),
           ]
    log_transactions(trans_list,'New neutral zone position')
    return trans_list

# %% [markdown]
# ## Manage opened positions

# %%
def manage_opened_position(date, fut, opt_chain, regime, opened_position):
    logging.debug('Current position delta: {0}'.format(opened_position.delta))
    
    # By default: do nothing
    return []

# %% [markdown]
# # Define EXO builder class

# %%
class SmartEXOIchimoku(ExoEngineBase):
    def __init__(self, symbol, direction, date, datasource, log_file_path=''):
        self._symbol = symbol
        self.custom_values = {}
        super().__init__(symbol, direction, date, datasource, log_file_path=log_file_path)

    @staticmethod
    def direction_type():
        return 0

    @staticmethod
    def names_list(symbol):
        return ['{0}_{1}'.format(self._symbol, EXO_NAME)]

    @property
    def exo_name(self):
            return '{0}_{1}'.format(self._symbol, EXO_NAME)

    def is_rollover(self):
        if len(self.position) != 0:
            for p in self.position.legs.values():
                rh = RolloverHelper(p.instrument)
                if rh.is_rollover(p):
                    return True
        return False

    def process_rollover(self):
        trans_list = self.position.close_all_translist()
        logging.info('Rollover occured, new series used')
        return trans_list
    
    def get_custom_values(self):
        """
        Method that return custom EXO data frame values, to store inside EXO Dataframe in the DB
        :return: dictionary {'string_key': (int or float) value}
        """
        return self.custom_values
    

    def process_day(self):
        """
        Main EXO's position management method
        :return: list of Transactions to process
        """

        # Get cont futures price for EXO
        exo_df, exo_info = self.datasource.exostorage.load_series("{0}_ContFut".format(self._symbol))

        regime = ichimoku_regimes(self.date, exo_df['exo'])

        trans_list = []

        if regime is None and len(self.position) > 0:
            return self.position.close_all_translist()
        
        instr = self.datasource.get(self._symbol, self.date)
        rh = RolloverHelper(instr)
        fut, opt_chain = rh.get_active_chains()

        if regime == 1 and 'bullish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bullish_zone(self.date, fut, opt_chain)
            
            return trans_list
        if regime == -1 and 'bearish' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_bearish_zone(self.date, fut, opt_chain)
            return trans_list

        if regime == 0 and 'neutral' not in self.position.legs:
            # Close all
            trans_list += self.position.close_all_translist()
            trans_list += new_position_neutral_zone(self.date, fut, opt_chain)
            return trans_list
        
        #
        # Writing custom values to store inside DB 
        #
        self.custom_values = {
            'ichi_regime': regime if regime is not None else float('nan')
        }
        
        #
        # Manage opened position
        #
        return manage_opened_position(self.date, fut, opt_chain, regime, self.position)

# %% [markdown]
# # Run EXO build process (WARN: long-running task!)

# %%
from pymongo import MongoClient

if verbosive_logging:
    logging.basicConfig(format='%(message)s', level=logging.DEBUG)
else:
    logging.basicConfig(format='%(message)s', level=logging.INFO)

mongo_connstr = 'mongodb://exowriter:qmWSy4K3@10.0.1.2/tmldb?authMechanism=SCRAM-SHA-1'
mongo_db_name = 'tmldb'
assetindex = AssetIndexMongo(mongo_connstr, mongo_db_name)
exostorage = EXOStorage(mongo_connstr, mongo_db_name)

#base_date = datetime(2011, 6, 13, 12, 45, 0)


futures_limit = 3
options_limit = 10

DEBUG = '.'

datasource = DataSourceMongo(mongo_connstr, mongo_db_name, assetindex, futures_limit, options_limit, exostorage)

server = 'h9ggwlagd1.database.windows.net'
user = 'modelread'
password = '4fSHRXwd4u'
datasource = DataSourceSQL(server, user, password, assetindex, futures_limit, options_limit, exostorage)

enddate = datetime.combine(datetime.now().date(), dttime(12, 45, 0))
currdate = base_date


logging.info("Deleting all SmartEXO of :" + EXO_NAME)
client = MongoClient(mongo_connstr)
db = client[mongo_db_name]
db['exo_data'].delete_many({'name': {'$regex': '.*{0}*.'.format(EXO_NAME)}})


logging.info("Starting EXO calculation process from: {0}".format(currdate))
for ticker in instruments:
    logging.info("Processing: "+ticker)
    currdate = base_date
    while currdate <= enddate:
        
        start_time = time.time()
        date = currdate

        asset_info = assetindex.get_instrument_info(ticker)
        exec_time_end, decision_time_end = AssetIndexMongo.get_exec_time(date, asset_info)
        
        logging.info("\t\tRun on {0}".format(decision_time_end))

        with SmartEXOIchimoku(ticker, 0, decision_time_end, datasource) as exo_engine:
            # Load EXO information from mongo
            exo_engine.load()
            exo_engine.calculate()

        end_time = time.time()
        currdate += timedelta(days=1)
        logging.debug("Elapsed: {0}".format(end_time-start_time))
logging.info('Done')
# Out:
# Deleting all SmartEXO of :SmartEXO_Ichi__BullCall_Spread_Delta_150_EXP
# Starting EXO calculation process from: 2014-01-13 12:45:00
# Processing: CL
# 		Run on 2014-01-13 11:10:00
# Ichi regime at 2014-01-13 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEH149300 x 1.0 Price: 1.4967183824791803 Delta: 0.42610119820107073
# Leg:  / P.US.CLEH149300 x 1.0 Price: 2.5770828236036962 Delta: -0.572861081457148
# Transactions delta: -0.14675988325607725
# Elapsed: 0.8750019073486328
# 		Run on 2014-01-14 11:10:00
# Ichi regime at 2014-01-14 11:10:00: -1
# Current position delta: -0.03749907138867803
# Elapsed: 1.1875805854797363
# 		Run on 2014-01-15 11:10:00
# Ichi regime at 2014-01-15 11:10:00: -1
# Current position delta: 0.24768007063849823
# Elapsed: 0.9829621315002441
# 		Run on 2014-01-16 11:10:00
# Ichi regime at 2014-01-16 11:10:00: -1
# Current position delta: 0.21078502057067566
# Elapsed: 0.9844932556152344
# 		Run on 2014-01-17 11:10:00
# Ichi regime at 2014-01-17 11:10:00: -1
# Current position delta: 0.2717488918381208
# Elapsed: 0.9863572120666504
# 		Run on 2014-01-18 11:10:00
# Ichi regime at 2014-01-18 11:10:00: -1
# Current position delta: 0.2501042930805219
# Elapsed: 1.0428640842437744
# 		Run on 2014-01-19 11:10:00
# Ichi regime at 2014-01-19 11:10:00: -1
# Current position delta: 0.2539174325171404
# Elapsed: 0.9431247711181641
# 		Run on 2014-01-20 11:10:00
# Ichi regime at 2014-01-20 11:10:00: -1
# Current position delta: 0.21168435171353583
# Elapsed: 0.9534757137298584
# 		Run on 2014-01-21 11:10:00
# Ichi regime at 2014-01-21 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEH149400 x 6.0 Price: 2.3355258393186844 Delta: 3.643196813392891
# Leg:  / C.US.CLEH149650 x -6.0 Price: 1.079529347309844 Delta: -2.2675280564125253
# Leg:  / C.US.CLEH149650 x 0.0 Price: 1.079529347309844 Delta: 0.0
# Leg:  / C.US.CLEH149800 x 0.0 Price: 0.6277763325284589 Delta: 0.0
# Transactions delta: 1.3756687569803656
# Elapsed: 1.5192501544952393
# 		Run on 2014-01-22 11:10:00
# Ichi regime at 2014-01-22 11:10:00: 1
# Current position delta: 1.2874266823135518
# Elapsed: 1.2989037036895752
# 		Run on 2014-01-23 11:10:00
# Ichi regime at 2014-01-23 11:10:00: 1
# Current position delta: 1.1372662185362894
# Elapsed: 1.3127171993255615
# 		Run on 2014-01-24 11:10:00
# Ichi regime at 2014-01-24 11:10:00: 1
# Current position delta: 1.2761299029808244
# Elapsed: 1.3105652332305908
# 		Run on 2014-01-25 11:10:00
# Ichi regime at 2014-01-25 11:10:00: 1
# Current position delta: 1.2523072724329696
# Elapsed: 1.298224687576294
# 		Run on 2014-01-26 11:10:00
# Ichi regime at 2014-01-26 11:10:00: 1
# Current position delta: 1.2791552966041295
# Elapsed: 1.2796542644500732
# 		Run on 2014-01-27 11:10:00
# Ichi regime at 2014-01-27 11:10:00: 1
# Current position delta: 1.4610079918280876
# Elapsed: 1.2813096046447754
# 		Run on 2014-01-28 11:10:00
# Ichi regime at 2014-01-28 11:10:00: 1
# Current position delta: 1.1744406555636253
# Elapsed: 1.316619873046875
# 		Run on 2014-01-29 11:10:00
# Ichi regime at 2014-01-29 11:10:00: 1
# Current position delta: 1.2078800330734527
# Elapsed: 1.2962465286254883
# 		Run on 2014-01-30 11:10:00
# Ichi regime at 2014-01-30 11:10:00: 1
# Current position delta: 1.0289386918431482
# Elapsed: 1.3199043273925781
# 		Run on 2014-01-31 11:10:00
# Ichi regime at 2014-01-31 11:10:00: 1
# Current position delta: 1.1450778209965708
# Elapsed: 1.303337574005127
# 		Run on 2014-02-01 11:10:00
# Ichi regime at 2014-02-01 11:10:00: 1
# Current position delta: 1.2990014077456689
# Elapsed: 1.2996885776519775
# 		Run on 2014-02-02 11:10:00
# Ichi regime at 2014-02-02 11:10:00: 1
# Current position delta: 1.3319881146144579
# Elapsed: 1.281224012374878
# 		Run on 2014-02-03 11:10:00
# Ichi regime at 2014-02-03 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEH149750 x 1.0 Price: 0.8463858459045852 Delta: 0.3891058176504394
# Leg:  / P.US.CLEH149750 x 1.0 Price: 1.7969472807312599 Delta: -0.6101098006765895
# Transactions delta: -0.2210039830261501
# Elapsed: 1.6389164924621582
# 		Run on 2014-02-04 11:10:00
# Ichi regime at 2014-02-04 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEH149600 x 6.0 Price: 2.0592359254236214 Delta: 3.852442811581816
# Leg:  / C.US.CLEH149850 x -6.0 Price: 0.7839955588683054 Delta: -2.1293998837366033
# Leg:  / C.US.CLEH149850 x 0.0 Price: 0.7839955588683054 Delta: 0.0
# Leg:  / C.US.CLEH1410000 x 0.0 Price: 0.38675204066462854 Delta: 0.0
# Transactions delta: 1.7230429278452126
# Elapsed: 1.48781418800354
# 		Run on 2014-02-05 11:10:00
# Ichi regime at 2014-02-05 11:10:00: 1
# Current position delta: 1.8071716647640979
# Elapsed: 1.3228273391723633
# 		Run on 2014-02-06 11:10:00
# Ichi regime at 2014-02-06 11:10:00: 1
# Current position delta: 1.9533818051710705
# Elapsed: 1.3056094646453857
# 		Run on 2014-02-07 11:10:00
# Ichi regime at 2014-02-07 11:10:00: 1
# Current position delta: 1.6589226445236323
# Elapsed: 1.2877106666564941
# 		Run on 2014-02-08 11:10:00
# Ichi regime at 2014-02-08 11:10:00: 1
# Current position delta: 1.0845190497558805
# Elapsed: 1.30519700050354
# 		Run on 2014-02-09 11:10:00
# Ichi regime at 2014-02-09 11:10:00: 1
# Current position delta: 1.0567360294172037
# Elapsed: 1.2773730754852295
# 		Run on 2014-02-10 11:10:00
# Ichi regime at 2014-02-10 11:10:00: 1
# Current position delta: 1.0937839724760847
# Elapsed: 1.2990448474884033
# 		Run on 2014-02-11 11:10:00
# Ichi regime at 2014-02-11 11:10:00: 1
# Current position delta: 1.1021553421805592
# Elapsed: 1.2819626331329346
# 		Run on 2014-02-12 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-02-12 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEJ149850 x 6.0 Price: 2.774891228031983 Delta: 3.6218002590918394
# Leg:  / C.US.CLEJ1410100 x -6.0 Price: 1.473064724785246 Delta: -2.476609089001985
# Leg:  / C.US.CLEJ1410100 x 0.0 Price: 1.473064724785246 Delta: 0.0
# Leg:  / C.US.CLEJ1410250 x 0.0 Price: 0.9260892816288724 Delta: 0.0
# Transactions delta: 1.1451911700898543
# Elapsed: 2.06654691696167
# 		Run on 2014-02-13 11:10:00
# Ichi regime at 2014-02-13 11:10:00: 1
# Current position delta: 1.1331463681437968
# Elapsed: 1.4793272018432617
# 		Run on 2014-02-14 11:10:00
# Ichi regime at 2014-02-14 11:10:00: 1
# Current position delta: 1.1811869554971466
# Elapsed: 1.3157896995544434
# 		Run on 2014-02-15 11:10:00
15 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEQ1410500 x 6.0 Price: 2.630094395751435 Delta: 3.5464352329767506
# Leg:  / C.US.CLEQ1410750 x -6.0 Price: 1.5501859335179589 Delta: -2.441121630233152
# Leg:  / C.US.CLEQ1410750 x 0.0 Price: 1.5501859335179589 Delta: 0.0
# Leg:  / C.US.CLEQ1410900 x 0.0 Price: 1.1157298790257002 Delta: 0.0
# Transactions delta: 1.1053136027435984
# Elapsed: 2.0527169704437256
# 		Run on 2014-06-16 11:10:00
# Ichi regime at 2014-06-16 11:10:00: 1
# Current position delta: 1.1254092651767782
# Elapsed: 1.48714280128479
# 		Run on 2014-06-17 11:10:00
# Ichi regime at 2014-06-17 11:10:00: 1
# Current position delta: 1.174964265955107
# Elapsed: 1.309957504272461
# 		Run on 2014-06-18 11:10:00
# Ichi regime at 2014-06-18 11:10:00: 1
# Current position delta: 1.27880229775817
# Elapsed: 1.3314080238342285
# 		Run on 2014-06-19 11:10:00
# Ichi regime at 2014-06-19 11:10:00: 1
# Current position delta: 1.3114983198949997
# Elapsed: 1.3094255924224854
# 		Run on 2014-06-20 11:10:00
# Ichi regime at 2014-06-20 11:10:00: 1
# Current position delta: 1.3614894196053111
# Elapsed: 1.2933855056762695
# 		Run on 2014-06-21 11:10:00
# Ichi regime at 2014-06-21 11:10:00: 1
# Current position delta: 1.3274588631977928
# Elapsed: 1.2969775199890137
# 		Run on 2014-06-22 11:10:00
# Ichi regime at 2014-06-22 11:10:00: 1
# Current position delta: 1.352881783298705
# Elapsed: 1.2636632919311523
# 		Run on 2014-06-23 11:10:00
# Ichi regime at 2014-06-23 11:10:00: 1
# Current position delta: 1.3801532263342233
# Elapsed: 1.290022850036621
# 		Run on 2014-06-24 11:10:00
# Ichi regime at 2014-06-24 11:10:00: 1
# Current position delta: 1.462261594794661
# Elapsed: 1.3324894905090332
# 		Run on 2014-06-25 11:10:00
# Ichi regime at 2014-06-25 11:10:00: 1
# Current position delta: 1.5504924023002302
# Elapsed: 1.3317911624908447
# 		Run on 2014-06-26 11:10:00
# Ichi regime at 2014-06-26 11:10:00: 1
# Current position delta: 1.5875812834194618
# Elapsed: 1.300994634628296
# 		Run on 2014-06-27 11:10:00
# Ichi regime at 2014-06-27 11:10:00: 1
# Current position delta: 1.6641280558150733
# Elapsed: 1.3457350730895996
# 		Run on 2014-06-28 11:10:00
# Ichi regime at 2014-06-28 11:10:00: 1
# Current position delta: 1.7320402977194003
# Elapsed: 1.3474879264831543
# 		Run on 2014-06-29 11:10:00
# Ichi regime at 2014-06-29 11:10:00: 1
# Current position delta: 1.7764786908805266
# Elapsed: 1.2792894840240479
# 		Run on 2014-06-30 11:10:00
# Ichi regime at 2014-06-30 11:10:00: 1
# Current position delta: 1.782812501093562
# Elapsed: 1.351567268371582
# 		Run on 2014-07-01 11:10:00
# Ichi regime at 2014-07-01 11:10:00: 1
# Current position delta: 1.7598964594202355
# Elapsed: 1.3384230136871338
# 		Run on 2014-07-02 11:10:00
# Ichi regime at 2014-07-02 11:10:00: 1
# Current position delta: 1.658657459938544
# Elapsed: 1.3258655071258545
# 		Run on 2014-07-03 11:10:00
# Ichi regime at 2014-07-03 11:10:00: 1
# Current position delta: 1.4540994723396912
# Elapsed: 1.3027031421661377
# 		Run on 2014-07-04 11:10:00
# Ichi regime at 2014-07-04 11:10:00: 1
# Current position delta: 1.364334593054521
# Elapsed: 1.3342235088348389
# 		Run on 2014-07-05 11:10:00
# Ichi regime at 2014-07-05 11:10:00: 1
# Current position delta: 1.3649290177697324
# Elapsed: 1.2929046154022217
# 		Run on 2014-07-06 11:10:00
# Ichi regime at 2014-07-06 11:10:00: 1
# Current position delta: 1.3739668079863758
# Elapsed: 1.261765480041504
# 		Run on 2014-07-07 11:10:00
# Ichi regime at 2014-07-07 11:10:00: 1
# Current position delta: 1.1284088194744846
# Elapsed: 1.3005359172821045
# 		Run on 2014-07-08 11:10:00
# Ichi regime at 2014-07-08 11:10:00: 1
# Current position delta: 1.0283212783917388
# Elapsed: 1.350707769393921
# 		Run on 2014-07-09 11:10:00
# Ichi regime at 2014-07-09 11:10:00: 1
# Current position delta: 0.4476016534512209
# Elapsed: 1.3106834888458252
# 		Run on 2014-07-10 11:10:00
# Ichi regime at 2014-07-10 11:10:00: 1
# Current position delta: 0.7910494627279995
# Elapsed: 1.317089557647705
# 		Run on 2014-07-11 11:10:00
# Ichi regime at 2014-07-11 11:10:00: 1
# Current position delta: 0.057731796034225985
# Elapsed: 1.3164825439453125
# 		Run on 2014-07-12 11:10:00
# Ichi regime at 2014-07-12 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEQ1410150 x 1.0 Price: 0.34961718580193946 Delta: 0.2987845610269521
# Leg:  / P.US.CLEQ1410150 x 1.0 Price: 1.3595889920740092 Delta: -0.7002506337951098
# Transactions delta: -0.40146607276815766
# Elapsed: 1.6716771125793457
# 		Run on 2014-07-13 11:10:00
# Ichi regime at 2014-07-13 11:10:00: -1
# Current position delta: -0.4455673827967954
# Elapsed: 0.9526503086090088
# 		Run on 2014-07-14 11:10:00
# Ichi regime at 2014-07-14 11:10:00: -1
# Current position delta: -0.4937720833183096
# Elapsed: 0.967963695526123
# 		Run on 2014-07-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-07-15 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEU1410000 x 1.0 Price: 1.4484375190184693 Delta: 0.44286314742035215
# Leg:  / P.US.CLEU1410000 x 1.0 Price: 2.2184656520871258 Delta: -0.5563042985070522
# Transactions delta: -0.11344115108670005
# Elapsed: 1.5965192317962646
# 		Run on 2014-07-16 11:10:00
# Ichi regime at 2014-07-16 11:10:00: -1
# Current position delta: 0.1304223041874118
# Elapsed: 1.1653859615325928
# 		Run on 2014-07-17 11:10:00
# Ichi regime at 2014-07-17 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEU1410100 x 6.0 Price: 2.2878303412820955 Delta: 3.6573957568773316
# Leg:  / C.US.CLEU1410350 x -6.0 Price: 1.1367401583180907 Delta: -2.2931392328026474
# Leg:  / C.US.CLEU1410350 x 0.0 Price: 1.1367401583180907 Delta: 0.0
# Leg:  / C.US.CLEU1410500 x 0.0 Price: 0.7343129626564497 Delta: 0.0
# Transactions delta: 1.3642565240746842
# Elapsed: 1.5972809791564941
# 		Run on 2014-07-18 11:10:00
# Ichi regime at 2014-07-18 11:10:00: 1
# Current position delta: 1.3457672823916513
# Elapsed: 1.3398406505584717
# 		Run on 2014-07-19 11:10:00
# Ichi regime at 2014-07-19 11:10:00: 1
# Current position delta: 1.3996281816275724
# Elapsed: 1.3418560028076172
# 		Run on 2014-07-20 11:10:00
# Ichi regime at 2014-07-20 11:10:00: 1
# Current position delta: 1.4250594800597818
# Elapsed: 1.2705912590026855
# 		Run on 2014-07-21 11:10:00
# Ichi regime at 2014-07-21 11:10:00: 1
# Current position delta: 1.460699100379263
# Elapsed: 1.2812161445617676
# 		Run on 2014-07-22 11:10:00
# Ichi regime at 2014-07-22 11:10:00: 1
# Current position delta: 1.5036420167682998
# Elapsed: 1.3064243793487549
# 		Run on 2014-07-23 11:10:00
# Ichi regime at 2014-07-23 11:10:00: 1
# Current position delta: 1.4956005542623236
# Elapsed: 1.3433542251586914
# 		Run on 2014-07-24 11:10:00
# Ichi regime at 2014-07-24 11:10:00: 1
# Current position delta: 1.6134972258697937
# Elapsed: 1.3977198600769043
# 		Run on 2014-07-25 11:10:00
# Ichi regime at 2014-07-25 11:10:00: 1
# Current position delta: 1.6940762259502358
# Elapsed: 1.3090825080871582
# 		Run on 2014-07-26 11:10:00
# Ichi regime at 2014-07-26 11:10:00: 1
# Current position delta: 1.666049662917482
# Elapsed: 1.3322350978851318
# 		Run on 2014-07-27 11:10:00
# Ichi regime at 2014-07-27 11:10:00: 1
# Current position delta: 1.706995835883016
# Elapsed: 1.297597885131836
# 		Run on 2014-07-28 11:10:00
# Ichi regime at 2014-07-28 11:10:00: 1
# Current position delta: 1.7531920071473177
# Elapsed: 1.287724256515503
# 		Run on 2014-07-29 11:10:00
# Ichi regime at 2014-07-29 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEU1410200 x 1.0 Price: 0.8369025537101109 Delta: 0.3762280074836719
# Leg:  / P.US.CLEU1410200 x 1.0 Price: 1.9366548991550445 Delta: -0.6226193485456128
# Transactions delta: -0.24639134106194094
# Elapsed: 1.7058203220367432
# 		Run on 2014-07-30 11:10:00
# Ichi regime at 2014-07-30 11:10:00: -1
# Current position delta: -0.3892581122822263
# Elapsed: 0.995671272277832
# 		Run on 2014-07-31 11:10:00
# Ichi regime at 2014-07-31 11:10:00: -1
# Current position delta: -0.6958388941414666
# Elapsed: 0.9938709735870361
# 		Run on 2014-08-01 11:10:00
# Ichi regime at 2014-08-01 11:10:00: -1
# Current position delta: -0.7995302833669735
# Elapsed: 0.9968702793121338
# 		Run on 2014-08-02 11:10:00
# Ichi regime at 2014-08-02 11:10:00: -1
# Current position delta: -0.8521015084517989
# Elapsed: 0.9902939796447754
# 		Run on 2014-08-03 11:10:00
# Ichi regime at 2014-08-03 11:10:00: -1
# Current position delta: -0.868316492625226
# Elapsed: 0.934734582901001
# 		Run on 2014-08-04 11:10:00
# Ichi regime at 2014-08-04 11:10:00: -1
# Current position delta: -0.81941581646502
# Elapsed: 0.9491684436798096
# 		Run on 2014-08-05 11:10:00
# Ichi regime at 2014-08-05 11:10:00: -1
# Current position delta: -0.9250478151998025
# Elapsed: 0.9999475479125977
# 		Run on 2014-08-06 11:10:00
# Ichi regime at 2014-08-06 11:10:00: -1
# Current position delta: -0.9230717787129392
# Elapsed: 0.9783017635345459
# 		Run on 2014-08-07 11:10:00
# Ichi regime at 2014-08-07 11:10:00: -1
# Current position delta: -0.9001448899970594
# Elapsed: 0.989067554473877
# 		Run on 2014-08-08 11:10:00
# Ichi regime at 2014-08-08 11:10:00: -1
# Current position delta: -0.8792548416146405
# Elapsed: 0.9985721111297607
# 		Run on 2014-08-09 11:10:00
# Ichi regime at 2014-08-09 11:10:00: -1
# Current position delta: -0.9127399331801128
# Elapsed: 0.9849534034729004
# 		Run on 2014-08-10 11:10:00
# Ichi regime at 2014-08-10 11:10:00: -1
# Current position delta: -0.9393376331785035
# Elapsed: 0.9357004165649414
# 		Run on 2014-08-11 11:10:00
# Ichi regime at 2014-08-11 11:10:00: -1
# Current position delta: -0.9155229811290949
# Elapsed: 0.9661827087402344
# 		Run on 2014-08-12 11:10:00
# Ichi regime at 2014-08-12 11:10:00: -1
# Current position delta: -0.9608644848791317
# Elapsed: 0.9790744781494141
# 		Run on 2014-08-13 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-08-13 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEV149750 x 1.0 Price: 1.466297728720761 Delta: 0.4399154295943328
# Leg:  / P.US.CLEV149750 x 1.0 Price: 2.2967659674584837 Delta: -0.5591253259272557
# Transactions delta: -0.11920989633292295
# Elapsed: 1.625758171081543
# 		Run on 2014-08-14 11:10:00
# Ichi regime at 2014-08-14 11:10:00: -1
# Current position delta: -0.5340391111294049
# Elapsed: 1.4745943546295166
# 		Run on 2014-08-15 11:10:00
# Ichi regime at 2014-08-15 11:10:00: -1
# Current position delta: -0.3426828078883986
# Elapsed: 0.9952845573425293
# 		Run on 2014-08-16 11:10:00
# Ichi regime at 2014-08-16 11:10:00: -1
# Current position delta: -0.3600643960743448
# Elapsed: 1.0274348258972168
# 		Run on 2014-08-17 11:10:00
# Ichi regime at 2014-08-17 11:10:00: -1
# Current position delta: -0.3660512652613519
# Elapsed: 0.9354550838470459
# 		Run on 2014-08-18 11:10:00
# Ichi regime at 2014-08-18 11:10:00: -1
# Current position delta: -0.5706206444445531
# Elapsed: 0.9776120185852051
# 		Run on 2014-08-19 11:10:00
# Ichi regime at 2014-08-19 11:10:00: -1
# Current position delta: -0.6917545434726915
# Elapsed: 1.011188268661499
# 		Run on 2014-08-20 11:10:00
# Ichi regime at 2014-08-20 11:10:00: -1
# Current position delta: -0.6553578769274618
# Elapsed: 1.015721321105957
# 		Run on 2014-08-21 11:10:00
# Ichi regime at 2014-08-21 11:10:00: -1
# Current position delta: -0.5677671625989886
# Elapsed: 0.9826374053955078
# 		Run on 2014-08-22 11:10:00
# Ichi regime at 2014-08-22 11:10:00: -1
# Current position delta: -0.7055145051421455
# Elapsed: 1.0246999263763428
# 		Run on 2014-08-23 11:10:00
# Ichi regime at 2014-08-23 11:10:00: -1
# Current position delta: -0.7481877450137345
# Elapsed: 0.9843268394470215
# 		Run on 2014-08-24 11:10:00
# Ichi regime at 2014-08-24 11:10:00: -1
# Current position delta: -0.7582090577225855
# Elapsed: 0.9699106216430664
# 		Run on 2014-08-25 11:10:00
# Ichi regime at 2014-08-25 11:10:00: -1
# Current position delta: -0.7823378210427254
# Elapsed: 0.9656269550323486
# 		Run on 2014-08-26 11:10:00
# Ichi regime at 2014-08-26 11:10:00: -1
# Current position delta: -0.6800135205166378
# Elapsed: 1.0012881755828857
# 		Run on 2014-08-27 11:10:00
# Ichi regime at 2014-08-27 11:10:00: -1
# Current position delta: -0.708682177113992
# Elapsed: 0.9869797229766846
# 		Run on 2014-08-28 11:10:00
# Ichi regime at 2014-08-28 11:10:00: -1
# Current position delta: -0.6162992646859421
# Elapsed: 1.0401263236999512
# 		Run on 2014-08-29 11:10:00
# Ichi regime at 2014-08-29 11:10:00: -1
# Current position delta: -0.39101237159693303
# Elapsed: 1.007338047027588
# 		Run on 2014-08-30 11:10:00
# Ichi regime at 2014-08-30 11:10:00: -1
# Current position delta: -0.3989625316325566
# Elapsed: 0.9991333484649658
# 		Run on 2014-08-31 11:10:00
# Ichi regime at 2014-08-31 11:10:00: -1
# Current position delta: -0.4102395400224723
# Elapsed: 0.9322595596313477
# 		Run on 2014-09-01 11:10:00
# Ichi regime at 2014-09-01 11:10:00: -1
# Current position delta: -0.4176362215728667
# Elapsed: 0.962364912033081
# 		Run on 2014-09-02 11:10:00
# Ichi regime at 2014-09-02 11:10:00: -1
# Current position delta: -0.861629441615036
# Elapsed: 0.9927792549133301
# 		Run on 2014-09-03 11:10:00
# Ichi regime at 2014-09-03 11:10:00: -1
# Current position delta: -0.44050448770693834
# Elapsed: 1.2570936679840088
# 		Run on 2014-09-04 11:10:00
# Ichi regime at 2014-09-04 11:10:00: -1
# Current position delta: -0.6776684654405367
# Elapsed: 0.996572732925415
# 		Run on 2014-09-05 11:10:00
# Ichi regime at 2014-09-05 11:10:00: -1
# Current position delta: -0.8398474332505315
# Elapsed: 0.9808239936828613
# 		Run on 2014-09-06 11:10:00
# Ichi regime at 2014-09-06 11:10:00: -1
# Current position delta: -0.8321719138213058
# Elapsed: 0.9803919792175293
# 		Run on 2014-09-07 11:10:00
# Ichi regime at 2014-09-07 11:10:00: -1
# Current position delta: -0.8524367894450373
# Elapsed: 0.9462521076202393
# 		Run on 2014-09-08 11:10:00
# Ichi regime at 2014-09-08 11:10:00: -1
# Current position delta: -0.9451104803223364
# Elapsed: 0.9533956050872803
# 		Run on 2014-09-09 11:10:00
# Ichi regime at 2014-09-09 11:10:00: -1
# Current position delta: -0.8888873354616467
# Elapsed: 0.9897811412811279
# 		Run on 2014-09-10 11:10:00
# Ichi regime at 2014-09-10 11:10:00: -1
# Current position delta: -0.9676647438077377
# Elapsed: 0.9867417812347412
# 		Run on 2014-09-11 11:10:00
# Ichi regime at 2014-09-11 11:10:00: -1
# Current position delta: -0.9171279224113368
# Elapsed: 0.9841880798339844
# 		Run on 2014-09-12 11:10:00
# Ichi regime at 2014-09-12 11:10:00: -1
# Current position delta: -0.9512327030031258
# Elapsed: 0.9987435340881348
# 		Run on 2014-09-13 11:10:00
# Ichi regime at 2014-09-13 11:10:00: -1
# Current position delta: -0.9682590027190412
# Elapsed: 0.9801828861236572
# 		Run on 2014-09-14 11:10:00
# Ichi regime at 2014-09-14 11:10:00: -1
# Current position delta: -0.9870016144589271
# Elapsed: 0.9477300643920898
# 		Run on 2014-09-15 11:10:00
# Rollover occured, new series used
# Ichi regime at 2014-09-15 11:10:00: -1
# New bearish zone position
# Leg: bearish / C.US.CLEX149250 x 1.0 Price: 1.5350706838520622 Delta: 0.4437424835239681
# Leg:  / P.US.CLEX149250 x 1.0 Price: 2.3562416647483886 Delta: -0.5554676292556883
# Transactions delta: -0.11172514573172015
# Elapsed: 1.5508930683135986
# 		Run on 2014-09-16 11:10:00
# Ichi regime at 2014-09-16 11:10:00: -1
# Current position delta: 0.23565165651644865
# Elapsed: 1.2382683753967285
# 		Run on 2014-09-17 11:10:00
# Ichi regime at 2014-09-17 11:10:00: -1
# Current position delta: 0.11485553370364332
# Elapsed: 0.9748916625976562
# 		Run on 2014-09-18 11:10:00
# Ichi regime at 2014-09-18 11:10:00: -1
# Current position delta: -0.040266802665106904
# Elapsed: 1.0024161338806152
# 		Run on 2014-09-19 11:10:00
# Ichi regime at 2014-09-19 11:10:00: -1
# Current position delta: -0.1956540543516262
# Elapsed: 0.9866435527801514
# 		Run on 2014-09-20 11:10:00
# Ichi regime at 2014-09-20 11:10:00: -1
# Current position delta: -0.12187726611655714
# Elapsed: 0.9828140735626221
# 		Run on 2014-09-21 11:10:00
# Ichi regime at 2014-09-21 11:10:00: -1
# Current position delta: -0.12508086026262788
# Elapsed: 0.9371554851531982
# 		Run on 2014-09-22 11:10:00
# Ichi regime at 2014-09-22 11:10:00: -1
# Current position delta: -0.31608198254119274
# Elapsed: 0.9536807537078857
# 		Run on 2014-09-23 11:10:00
# Ichi regime at 2014-09-23 11:10:00: -1
# Current position delta: -0.15897273964555636
# Elapsed: 0.9841158390045166
# 		Run on 2014-09-24 11:10:00
# Ichi regime at 2014-09-24 11:10:00: -1
# Current position delta: -0.010771493875896543
# Elapsed: 0.9974918365478516
# 		Run on 2014-09-25 11:10:00
# Ichi regime at 2014-09-25 11:10:00: -1
# Current position delta: -0.03510717449936429
# Elapsed: 0.996192455291748
# 		Run on 2014-09-26 11:10:00
# Ichi regime at 2014-09-26 11:10:00: -1
# Current position delta: 0.20484479355808688
# Elapsed: 0.9853665828704834
# 		Run on 2014-09-27 11:10:00
# Ichi regime at 2014-09-27 11:10:00: -1
# Current position delta: 0.1945522730707372
# Elapsed: 1.0120482444763184
# 		Run on 2014-09-28 11:10:00
# Ichi regime at 2014-09-28 11:10:00: -1
# Current position delta: 0.19878393614742812
# Elapsed: 0.9360857009887695
# 		Run on 2014-09-29 11:10:00
# Ichi regime at 2014-09-29 11:10:00: -1
# Current position delta: 0.40713249669675794
# Elapsed: 0.960073709487915
# 		Run on 2014-09-30 11:10:00
# Ichi regime at 2014-09-30 11:10:00: -1
# Current position delta: -0.2641998981666449
# Elapsed: 0.9827828407287598
11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX164450 x 6.0 Price: 2.39021200079846 Delta: 3.664077078398168
# Leg:  / C.US.CLEX164700 x -6.0 Price: 1.1924575470693064 Delta: -2.3689202310490893
# Leg:  / C.US.CLEX164700 x 0.0 Price: 1.1924575470693064 Delta: 0.0
# Leg:  / C.US.CLEX164850 x 0.0 Price: 0.7303999775798218 Delta: 0.0
# Transactions delta: 1.2951568473490789
# Elapsed: 1.439563512802124
# 		Run on 2016-09-22 11:10:00
# Ichi regime at 2016-09-22 11:10:00: 1
# Current position delta: 1.3016803255981508
# Elapsed: 1.2650394439697266
# 		Run on 2016-09-23 11:10:00
# Ichi regime at 2016-09-23 11:10:00: 1
# Current position delta: 1.316568620461493
# Elapsed: 1.3090941905975342
# 		Run on 2016-09-24 11:10:00
# Ichi regime at 2016-09-24 11:10:00: 1
# Current position delta: 1.2373747112068916
# Elapsed: 1.2759523391723633
# 		Run on 2016-09-25 11:10:00
# Ichi regime at 2016-09-25 11:10:00: 1
# Current position delta: 1.2628604719248293
# Elapsed: 1.2821826934814453
# 		Run on 2016-09-26 11:10:00
# Ichi regime at 2016-09-26 11:10:00: 1
# Current position delta: 1.295716557797201
# Elapsed: 1.2685465812683105
# 		Run on 2016-09-27 11:10:00
# Ichi regime at 2016-09-27 11:10:00: 1
# Current position delta: 1.2785455608232454
# Elapsed: 1.278412103652954
# 		Run on 2016-09-28 11:10:00
# Ichi regime at 2016-09-28 11:10:00: 1
# Current position delta: 1.335320171085539
# Elapsed: 1.2841541767120361
# 		Run on 2016-09-29 11:10:00
# Ichi regime at 2016-09-29 11:10:00: 1
# Current position delta: 1.182523719375129
# Elapsed: 1.292421817779541
# 		Run on 2016-09-30 11:10:00
# Ichi regime at 2016-09-30 11:10:00: 1
# Current position delta: 1.2016773383222703
# Elapsed: 1.335360050201416
# 		Run on 2016-10-01 11:10:00
# Ichi regime at 2016-10-01 11:10:00: 1
# Current position delta: 1.2703141803756832
# Elapsed: 1.2742371559143066
# 		Run on 2016-10-02 11:10:00
# Ichi regime at 2016-10-02 11:10:00: 1
# Current position delta: 1.2943136999973195
# Elapsed: 1.2830743789672852
# 		Run on 2016-10-03 11:10:00
# Ichi regime at 2016-10-03 11:10:00: 1
# Current position delta: 1.0910264239837053
# Elapsed: 1.2693133354187012
# 		Run on 2016-10-04 11:10:00
# Ichi regime at 2016-10-04 11:10:00: 1
# Current position delta: 1.1098282274577151
# Elapsed: 1.27797532081604
# 		Run on 2016-10-05 11:10:00
# Ichi regime at 2016-10-05 11:10:00: 1
# Current position delta: 0.759450282641871
# Elapsed: 1.2807466983795166
# 		Run on 2016-10-06 11:10:00
# Date not found at 2016-10-06
# Ichi regime at 2016-10-06 11:10:00: None
# Elapsed: 1.0957293510437012
# 		Run on 2016-10-07 11:10:00
# Ichi regime at 2016-10-07 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX164850 x 6.0 Price: 1.8438346549498377 Delta: 4.119728474277084
# Leg:  / C.US.CLEX165100 x -6.0 Price: 0.5563282681556352 Delta: -1.9840654688655808
# Leg:  / C.US.CLEX165100 x 0.0 Price: 0.5563282681556352 Delta: 0.0
# Leg:  / C.US.CLEX165250 x 0.0 Price: 0.21510137312155386 Delta: 0.0
# Transactions delta: 2.135663005411503
# Elapsed: 0.7748198509216309
# 		Run on 2016-10-08 11:10:00
# Date not found at 2016-10-08
# Ichi regime at 2016-10-08 11:10:00: None
# Elapsed: 1.0976917743682861
# 		Run on 2016-10-09 11:10:00
# Date not found at 2016-10-09
# Ichi regime at 2016-10-09 11:10:00: None
# Current position delta: 0.0
# Elapsed: 0.20009946823120117
# 		Run on 2016-10-10 11:10:00
# Ichi regime at 2016-10-10 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX165050 x 6.0 Price: 1.4061637000438338 Delta: 3.927868898510552
# Leg:  / C.US.CLEX165300 x -6.0 Price: 0.3343368527393409 Delta: -1.493404508961446
# Leg:  / C.US.CLEX165300 x 0.0 Price: 0.3343368527393409 Delta: 0.0
# Leg:  / C.US.CLEX165450 x 0.0 Price: 0.110982517499008 Delta: 0.0
# Transactions delta: 2.434464389549106
# Elapsed: 0.7821753025054932
# 		Run on 2016-10-11 11:10:00
# Ichi regime at 2016-10-11 11:10:00: 1
# Current position delta: 2.2717636780125545
# Elapsed: 1.2731759548187256
# 		Run on 2016-10-12 11:10:00
# Ichi regime at 2016-10-12 11:10:00: 1
# Current position delta: 2.116441525237736
# Elapsed: 1.2787551879882812
# 		Run on 2016-10-13 11:10:00
# Date not found at 2016-10-13
# Ichi regime at 2016-10-13 11:10:00: None
# Elapsed: 1.1412451267242432
# 		Run on 2016-10-14 11:10:00
# Ichi regime at 2016-10-14 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEX164900 x 6.0 Price: 1.1817251573729308 Delta: 4.583005841521049
# Leg:  / C.US.CLEX165150 x -6.0 Price: 0.08055851749676624 Delta: -0.7595688046154445
# Leg:  / C.US.CLEX165150 x 0.0 Price: 0.08055851749676624 Delta: 0.0
# Leg:  / C.US.CLEX165300 x 0.0 Price: 0.010811758069505073 Delta: 0.0
# Transactions delta: 3.823437036905605
# Elapsed: 0.7825655937194824
# 		Run on 2016-10-15 11:10:00
# Rollover occured, new series used
# Date not found at 2016-10-15
# Ichi regime at 2016-10-15 11:10:00: None
# Current position delta: 0.0
# Elapsed: 1.4715766906738281
# 		Run on 2016-10-16 11:10:00
# Ichi regime at 2016-10-16 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEZ164950 x 6.0 Price: 2.6139044248942973 Delta: 3.7424587364926425
# Leg:  / C.US.CLEZ165200 x -6.0 Price: 1.32722176734314 Delta: -2.492531992629619
# Leg:  / C.US.CLEZ165200 x 0.0 Price: 1.32722176734314 Delta: 0.0
# Leg:  / C.US.CLEZ165350 x 0.0 Price: 0.8161291198123788 Delta: 0.0
# Transactions delta: 1.2499267438630235
# Elapsed: 0.9477176666259766
# 		Run on 2016-10-17 11:10:00
# Ichi regime at 2016-10-17 11:10:00: 1
# Current position delta: 1.2794778431309228
# Elapsed: 1.2834303379058838
# 		Run on 2016-10-18 11:10:00
# Ichi regime at 2016-10-18 11:10:00: 1
# Current position delta: 1.3050299689108975
# Elapsed: 1.2978689670562744
# 		Run on 2016-10-19 11:10:00
# Ichi regime at 2016-10-19 11:10:00: 1
# Current position delta: 1.2724872097779172
# Elapsed: 1.290464162826538
# 		Run on 2016-10-20 11:10:00
# Ichi regime at 2016-10-20 11:10:00: 1
# Current position delta: 1.3989392226143638
# Elapsed: 1.2705848217010498
# 		Run on 2016-10-21 11:10:00
# Ichi regime at 2016-10-21 11:10:00: 1
# Current position delta: 1.4291066037898346
# Elapsed: 1.2854487895965576
# 		Run on 2016-10-22 11:10:00
# Date not found at 2016-10-22
# Ichi regime at 2016-10-22 11:10:00: None
# Elapsed: 1.1048510074615479
# 		Run on 2016-10-23 11:10:00
# Ichi regime at 2016-10-23 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEZ165000 x 6.0 Price: 2.1568756439173207 Delta: 3.703796772720483
# Leg:  / C.US.CLEZ165250 x -6.0 Price: 0.9443069219304085 Delta: -2.213612534833786
# Leg:  / C.US.CLEZ165250 x 0.0 Price: 0.9443069219304085 Delta: 0.0
# Leg:  / C.US.CLEZ165400 x 0.0 Price: 0.5263179221056813 Delta: 0.0
# Transactions delta: 1.4901842378866967
# Elapsed: 0.7788431644439697
# 		Run on 2016-10-24 11:10:00
# Ichi regime at 2016-10-24 11:10:00: 1
# Current position delta: 1.5076356973799023
# Elapsed: 1.284231424331665
# 		Run on 2016-10-25 11:10:00
# Ichi regime at 2016-10-25 11:10:00: 1
# Current position delta: 1.5068937366600705
# Elapsed: 1.2891778945922852
# 		Run on 2016-10-26 11:10:00
# Ichi regime at 2016-10-26 11:10:00: 1
# Current position delta: 1.3884930800260284
# Elapsed: 1.291382074356079
# 		Run on 2016-10-27 11:10:00
# Ichi regime at 2016-10-27 11:10:00: 1
# Current position delta: 1.470912490005313
# Elapsed: 1.2816946506500244
# 		Run on 2016-10-28 11:10:00
# Ichi regime at 2016-10-28 11:10:00: 1
# Current position delta: 1.2525826095893016
# Elapsed: 1.2749216556549072
# 		Run on 2016-10-29 11:10:00
# Date not found at 2016-10-29
# Ichi regime at 2016-10-29 11:10:00: None
# Elapsed: 1.0957238674163818
# 		Run on 2016-10-30 11:10:00
# Date not found at 2016-10-30
# Ichi regime at 2016-10-30 11:10:00: None
# Current position delta: 0.0
# Elapsed: 0.1916811466217041
# 		Run on 2016-10-31 11:10:00
# Ichi regime at 2016-10-31 11:10:00: 1
# New bullish zone position
# Leg: bullish / C.US.CLEZ164600 x 6.0 Price: 2.111939882893491 Delta: 3.8345229221004162
# Leg:  / C.US.CLEZ164850 x -6.0 Price: 0.843454195671395 Delta: -2.199318522429331
# Leg:  / C.US.CLEZ164850 x 0.0 Price: 0.843454195671395 Delta: 0.0
# Leg:  / C.US.CLEZ165000 x 0.0 Price: 0.4044972284714241 Delta: 0.0
# Transactions delta: 1.6352043996710854
# Elapsed: 0.7880167961120605
# 		Run on 2016-11-01 11:10:00
# Date not found at 2016-11-01
# Ichi regime at 2016-11-01 11:10:00: None
# Elapsed: 1.0978014469146729
# Done

# %% [markdown]
# # View EXO price series

# %%
for ticker in instruments:
    exo_df, exo_info = exostorage.load_series('{0}_{1}'.format(ticker, EXO_NAME))    
    
    exo_df['exo'].plot(title='{0}_{1}'.format(ticker, EXO_NAME))
    ax = exo_df['ichi_regime'].plot(secondary_y=True)
    ax.set_ylim(-2,2)
    plt.show()
