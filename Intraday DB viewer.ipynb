# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pymongo import MongoClient
import pymongo
import pandas as pd

# %%
MONGO_CONNSTR = 'mongodb://tml:tml@10.0.1.2/tmldb_test?authMechanism=SCRAM-SHA-1'
MONGO_EXO_DB = 'tmldb_test'

# %%
client = MongoClient(MONGO_CONNSTR)
db = client[MONGO_EXO_DB]

# %%
data = []
for c in  db.futurebarcol.find({'idcontract': 6570, 'errorbar': False}).sort('bartime', pymongo.ASCENDING):
    data.append(c)

# %%
df = pd.DataFrame(data)
df = df.set_index('bartime')

# %% [markdown]
# ## Table view

# %%
# Particular date
df.ix['2016-09-23']
# Out:
#                                           _id    close errorbar     high  \
# bartime
# 2016-09-23 19:51:00  57e9832eb33f83c9a12b74ae  2158.75    False  2158.75
# 2016-09-23 19:52:00  57e9832e36cfba5ae408c530  2158.75    False  2159.50
# 2016-09-23 19:53:00  57e9832e36cfba5ae408c531  2159.75    False  2160.00
# 2016-09-23 19:54:00  57e9832e36cfba5ae408c532  2160.00    False  2160.25
# 2016-09-23 19:55:00  57e9832e36cfba5ae408c533  2159.50    False  2160.25
# 2016-09-23 19:56:00  57e9832e36cfba5ae408c534  2159.25    False  2159.75
# 2016-09-23 19:57:00  57e9832e36cfba5ae408c535  2158.75    False  2159.50
# 2016-09-23 19:58:00  57e9832e36cfba5ae408c536  2158.50    False  2159.00
# 2016-09-23 19:59:00  57e9832e36cfba5ae408c537  2157.00    False  2158.75
# 2016-09-23 20:00:00  57e9832e36cfba5ae408c538  2159.00    False  2159.50
# 2016-09-23 20:01:00  57e9832e36cfba5ae408c539  2158.75    False  2159.25
# 2016-09-23 20:02:00  57e9832e36cfba5ae408c53a  2158.25    False  2159.00
# ...

# %%
figsize(15, 7)
df['close'].plot()

# %%
df['open'].plot()

# %%
df['high'].plot()

# %%
df['low'].plot()
