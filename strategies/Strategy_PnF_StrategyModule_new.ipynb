# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys,os
sys.path.append('..')
from backtester import matlab, backtester
from backtester.analysis import *
from backtester.strategy import StrategyBase, OptParam, OptParamArray
from backtester.swarms.ranking import SwarmRanker
from backtester.swarms.rebalancing import SwarmRebalance
from backtester.swarms.filters import SwarmFilter
from backtester.costs import CostsManagerEXOFixed
from backtester.exoinfo import EXOInfo
from backtester.swarms.rankingclasses import *
from backtester.swarms.swarm import Swarm


import pandas as pd
import numpy as np
import scipy

# %%
from strategies.strategy_pnf import StrategyPointAndFigurePatterns

# %%
from scripts.settings import *
try:
    from scripts.settings_local import *
except:
    pass

from exobuilder.data.exostorage import EXOStorage

storage = EXOStorage(MONGO_CONNSTR, MONGO_EXO_DB)


exo_filter = '*'     # All 
#exo_filter = 'ES_'  # ES only
exo_filter = ''  # ES Collars (incl Bearish, Bullish, BW and vanilla)

[print(exo) for exo in storage.exo_list(exo_filter)];
# Out:
# ES_BullishCollarBW
# ES_BearishCollarBW
# ES_CallSpread
# ES_PutSpread
# ES_ContFut
# ZS_BullishCollarBW
# ZS_BearishCollarBW
# ZS_CallSpread
# ZS_PutSpread
# ZS_ContFut
# CL_BullishCollarBW
# CL_BearishCollarBW
# CL_CallSpread
# CL_PutSpread
# CL_ContFut
# ZW_BullishCollarBW
# ZW_BearishCollarBW
# ZW_CallSpread
# ZW_PutSpread
# ZW_ContFut
# ZN_BullishCollarBW
# ZN_BearishCollarBW
# ZN_CallSpread
# ZN_PutSpread
# ZN_ContFut
# NG_BullishCollarBW
# NG_BearishCollarBW
# NG_CallSpread
# NG_PutSpread
# NG_ContFut
# ZC_BullishCollarBW
# ZC_BearishCollarBW
# ZC_CallSpread
# ZC_PutSpread
# ZC_ContFut
# CL_SMART_Ichimoku_Long
# ES_SMART_Ichimoku_Long
# NG_SMART_Ichimoku_Long
# ZC_SMART_Ichimoku_Long
# ZS_SMART_Ichimoku_Long
# ZW_SMART_Ichimoku_Long
# ZN_SMART_Ichimoku_Long
# CL_SMART_Ichimoku_VerticalSpread_Bullish
# CL_SMART_Ichimoku_Straddle_Bullish
# ES_SMART_Ichimoku_Straddle_Bullish
# NG_SMART_Ichimoku_Straddle_Bullish
# ZC_SMART_Ichimoku_Straddle_Bullish
# ZS_SMART_Ichimoku_Straddle_Bullish
# ZW_SMART_Ichimoku_Straddle_Bullish
# ZN_SMART_Ichimoku_Straddle_Bullish
# CL_SmartEXO_Ichi_Bullish_Straddle_150Delta
# CL_SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged
# CL_SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged_test
# CL_SMART_Ichimoku_Straddle_Bullish_CustomInfo
# CL_SmartEXO_Ichi_Bearish_Straddle_BullCall_Spread_0Delta_EXP
# ZC_SmartEXO_Ichi_Bearish_Straddle_150Delta

# %% [markdown]
# ## Script settings

# %%
STRATEGY_CONTEXT = {
    'strategy': { 
        'class': StrategyPointAndFigurePatterns,
        'exo_name': 'CL_SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged_test',        # <---- Select and paste EXO name from cell above
        'exo_storage': storage,
        'opt_params': [
                        #OptParam(name, default_value, min_value, max_value, step)
                        OptParamArray('Direction', [-1]),
                        OptParam('BoxSize', 1, 200, 300, 50),
                        OptParam('Reversal', 2, 2, 6, 2),
                        OptParamArray('MaxMinWindowPercent', [0.05]),
                        OptParam('ColumnConsecMoveCount', 2, 1, 1, 1),
                        OptParamArray('RulesIndex', np.arange(1)),
                        OptParam('MedianPeriod', 5, 38, 39, 10),
            
            ],
    },
    'swarm': {
        'members_count': 2,
        'ranking_class': RankerBestWithCorrel(window_size=-1, correl_threshold=0.5),
        'rebalance_time_function': SwarmRebalance.every_friday,

    },
    'costs':{
        'manager': CostsManagerEXOFixed,
        'context': {
            'costs_options': 3.0,
            'costs_futures': 3.0,
        }
    }
}

# %% [markdown]
# # Backtest class based strategy

# %%
smgr = Swarm(STRATEGY_CONTEXT)
smgr.run_swarm()
smgr.pick()

# Saving results to swarms directory
smgr.save('./swarms/')

# %% [markdown]
# ### WARNING! Loading swarm from file (don't run next cell if you want new swarm instance)

# %%
#smgr = Swarm.load(strategy_context=STRATEGY_CONTEXT, directory='./swarms/')
#print('Loading: '+smgr.get_swarm_name())

# %%
figsize(10,10)
smgr.picked_equity.plot(label='Picked swarm equity');
smgr.raw_equity.plot(label='Average swarm equity');
legend(loc=2);

# %%
figsize(10,10)
smgr.raw_swarm.plot(legend=True)
legend(loc='lower right');

# %%
#
# To export swarms above to .csv, uncomment this
#

#swarm_df = smgr.swarm
#swarm_df.to_csv('./temp_swarms/ichi_swarm.csv')

# %%
figsize(10,10)
smgr.picked_equity.plot(label='Picked swarm equity');
smgr.raw_equity.plot(label='Average swarm equity');
legend(loc=2);

# %%
smgr.picked_swarm.plot()

# %% [markdown]
# # Swarm exposure

# %%
smgr.picked_exposure.sum(axis=1).rolling(10).mean().plot()

# %% [markdown]
# # Swarm statistics

# %% [markdown]
# #### Non-picked swarm stats

# %%
smgr.picked_stats
# Out:
# {'note:Not implemented yet'}

# %% [markdown]
# ## Exo information

# %%
smgr.strategy.exoinfo.exo_info
# Out:
# {'dbdata': {'_id': ObjectId('5817ce7520bb1d0dfe615bcd'),
#   'name': 'CL_SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged_test',
#   'position': {'_realized_pnl': -17832.48030661934,
#    'positions': {'203171332': {'leg_name': 'bullish',
#      'qty': 2.0,
#      'value': 4223.879765786983},
#     '203179171': {'leg_name': '', 'qty': -2.0, 'value': -352.1255013551734},
#     '203183071': {'leg_name': '', 'qty': -4.0, 'value': -1008.598230725159},
#     '203183077': {'leg_name': '', 'qty': 1.0, 'value': 977.1626018232205}}},
#   'series': b'\x80\x03cpandas.core.frame\nDataFrame\nq\x00)\x81q\x01}q\x02(X\x05\x00\x00\x00_dataq\x03cpandas.core.internals\nBlockManager\nq\x04)\x81q\x05(]q\x06(cpandas.indexes.base\n_new_Index\nq\x07cpandas.indexes.base\nIndex\nq\x08}q\t(X\x04\x00\x00\x00dataq\ncnumpy.core.multiarray\n_reconstruct\nq\x0bcnumpy\nndarray\nq\x0cK\x00\x85q\rC\x01bq\x0e\x87q\x0fRq\x10(K\x01K\x01\x85q\x11cnumpy\ndtype\nq\x12X\x02\x00\x00\x00O8q\x13K\x00K\x01\x87q\x14Rq\x15(K\x03X\x01\x00\x00\x00|q\x16NNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK?tq\x17b\x89]q\x18X\x03\x00\x00\x00exoq\x19atq\x1abX\x04\x00\x00\x00nameq\x1bNu\x86q\x1cRq\x1dcpandas.tseries.index\n_new_DatetimeIndex\nq\x1ecpandas.tseries.index\nDatetimeIndex\nq\x1f}q (h\nh\x0bh\x0cK\x00\x85q!h\x0e\x87q"Rq#(K\x01Ml\x05\x85q$h\x12X\x02\x00\x00\x00M8q%K\x00K\x01\x87q&Rq\'(K\x04X\x01\x00\x00\x00<q(NNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00}q)(C\x02nsq*K\x01K\x01K\x01tq+\x86q,tq-b\x89B`+\x00\x00\x00\x00z\xb8\xd1\xb5\xd8\x12\x00\x00\xc9If\x04\xd9\x12\x00\x00\x18\xdb\xfaR\xd9\x12\x00\x00gl\x8f\xa1\xd9\x12\x00\x00\xb6\xfd#\xf0\xd9\x12\x00\x00\x05\x8f\xb8>\xda\x12\x00\x00T M\x8d\xda\x12\x00\x00\xa3\xb1\xe1\xdb\xda\x12\x00\x00\xf2Bv*\xdb\x12\x00\x00A\xd4\ny\xdb\x12\x00\x00\x90e\x9f\xc7\xdb\x12\x00\x00\xdf\xf63\x16\xdc\x12\x00\x00.\x88\xc8d\xdc\x12\x00\x00}\x19]\xb3\xdc\x12\x00\x00\xcc\xaa\xf1\x01\xdd\x12\x00\x00\x1b<\x86P\xdd\x12\x00\x00j\xcd\x1a\x9f\xdd\x12\x00\x00\xb9^\xaf\xed\xdd\x12\x00\x00\x08\xf0C<\xde\x12\x00\x00W\x81\xd8\x8a\xde\x12\x00\x00\xa6\x12m\xd9\xde\x12\x00\x00\xf5\xa3\x01(\xdf\x12\x00\x00D5\x96v\xdf\x12\x00\x00\x93\xc6*\xc5\xdf\x12\x00\x00\xe2W\xbf\x13\xe0\x12\x00\x001\xe9Sb\xe0\x12\x00\x00\x80z\xe8\xb0\xe0\x12\x00\x00\xcf\x0b}\xff\xe0\x12\x00\x00\x1e\x9d\x11N\xe1\x12\x00\x00m.\xa6\x9c\xe1\x12\x00\x00\xbc\xbf:\xeb\xe1\x12\x00\x00\x0bQ\xcf9\xe2\x12\x00\x00Z\xe2c\x88\xe2\x12\x00\x00\xa9s\xf8\xd6\xe2\x12\x00\x00\xf8\x04\x8d%\xe3\x12\x00\x00G\x96!t\xe3\x12\x00\x00\x96\'\xb6\xc2\xe3\x12\x00\x00\xe5\xb8J\x11\xe4\x12\x00\x004J\xdf_\xe4\x12\x00\x00\x83\xdbs\xae\xe4\x12\x00\x00\xd2l\x08\xfd\xe4\x12\x00\x00!\xfe\x9cK\xe5\x12\x00\x00p\x8f1\x9a\xe5\x12\x00\x00\xbf \xc6\xe8\xe5\x12\x00\x00\x0e\xb2Z7\xe6\x12\x00\x00]C\xef\x85\xe6\x12\x00\x00\xac\xd4\x83\xd4\xe6\x12\x00\x00\xfbe\x18#\xe7\x12\x00\x00J\xf7\xacq\xe7\x12\x00\x00\x99\x88A\xc0\xe7\x12\x00\x00\xe8\x19\xd6\x0e\xe8\x12\x00\x007\xabj]\xe8\x12\x00\x00\x86<\xff\xab\xe8\x12\x00\x00\xd5\xcd\x93\xfa\xe8\x12\x00\x00$_(I\xe9\x12\x00\x00s\xf0\xbc\x97\xe9\x12\x00\x00\xc2\x81Q\xe6\xe9\x12\x00\x00\x11\x13\xe64\xea\x12\x00\x00`\xa4z\x83\xea\x12\x00\x00\xaf5\x0f\xd2\xea\x12\x00\x00\xfe\xc6\xa3 \xeb\x12\x00\x00MX8o\xeb\x12\x00\x00\x9c\xe9\xcc\xbd\xeb\x12\x00\x00\xebza\x0c\xec\x12\x00\x00:\x0c\xf6Z\xec\x12\x00\x00\x89\x9d\x8a\xa9\xec\x12\x00\x00\xd8.\x1f\xf8\xec\x12\x00\x00\'\xc0\xb3F\xed\x12\x00\x00vQH\x95\xed\x12\x00\x00\xc5\xe2\xdc\xe3\xed\x12\x00\x00\x14tq2\xee\x12\x00\x00c\x05\x06\x81\xee\x12\x00\x00\xb2\x96\x9a\xcf\xee\x12\x00\x00\x01(/\x1e\xef\x12\x00\x00P\xb9\xc3l\xef\x12\x00\x00\x9fJX\xbb\xef\x12\x00\x00\xee\xdb\xec\t\xf0\x12\x00\x00=m\x81X\xf0\x12\x00\x00\x8c\xfe\x15\xa7\xf0\x12\x00\x00\xdb\x8f\xaa\xf5\xf0\x12\x00\x00*!?D\xf1\x12\x00\x00y\xb2\xd3\x92\xf1\x12\x00\x00\xc8Ch\xe1\xf1\x12\x00\x00\x17\xd5\xfc/\xf2\x12\x00\x00ff\x91~\xf2\x12\x00\x00\xb5\xf7%\xcd\xf2\x12\x00\x00\x04\x89\xba\x1b\xf3\x12\x00\x00S\x1aOj\xf3\x12\x00\x00\xa2\xab\xe3\xb8\xf3\x12\x00\x00\xf1<x\x07\xf4\x12\x00\x00@\xce\x0cV\xf4\x12\x00\x00\x8f_\xa1\xa4\xf4\x12\x00\x00\xde\xf05\xf3\xf4\x12\x00\x00-\x82\xcaA\xf5\x12\x00\x00|\x13_\x90\xf5\x12\x00\x00\xcb\xa4\xf3\xde\xf5\x12\x00\x00\x1a6\x88-\xf6\x12\x00\x00i\xc7\x1c|\xf6\x12\x00\x00\xb8X\xb1\xca\xf6\x12\x00\x00\x07\xeaE\x19\xf7\x12\x00\x00V{\xdag\xf7\x12\x00\x00\xa5\x0co\xb6\xf7\x12\x00\x00\xf4\x9d\x03\x05\xf8\x12\x00\x00C/\x98S\xf8\x12\x00\x00\x92\xc0,\xa2\xf8\x12\x00\x00\xe1Q\xc1\xf0\xf8\x12\x00\x000\xe3U?\xf9\x12\x00\x00\x7ft\xea\x8d\xf9\x12\x00\x00\xce\x05\x7f\xdc\xf9\x12\x00\x00\x1d\x97\x13+\xfa\x12\x00\x00l(\xa8y\xfa\x12\x00\x ...
#   'transactions': [{'asset': {'dbid': 34285,
#      'hash': 200034285,
#      'name': 'C.US.CLEG139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 1, 13, 11, 10),
#     'price': 1.0791097160161058,
#     'qty': 2.0,
#     'usdvalue': 2158.2194320322114},
#    {'asset': {'dbid': 40035,
#      'hash': 200040035,
#      'name': 'P.US.CLEG139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 1, 13, 11, 10),
#     'price': 0.30954900759183346,
#     'qty': 1.0,
#     'usdvalue': 309.54900759183346},
#    {'asset': {'dbid': 40028,
#      'hash': 200040028,
#      'name': 'P.US.CLEG138950',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 1, 13, 11, 10),
#     'price': 0.013586934479616009,
#     'qty': -4.0,
#     'usdvalue': -54.347737918464034},
#    {'asset': {'dbid': 34296,
#      'hash': 200034296,
#      'name': 'C.US.CLEG139850',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 1, 13, 11, 10),
#     'price': 0.010008749255600469,
#     'qty': -2.0,
#     'usdvalue': -20.017498511200937},
#    {'asset': {'dbid': 34296,
#      'hash': 200034296,
#      'name': 'C.US.CLEG139850',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 1, 14, 11, 10),
#     'price': 0.0011956887328837262,
#     'qty': 2.0,
#     'usdvalue': 2.3913774657674525},
#    {'asset': {'dbid': 40035,
#      'hash': 200040035,
#      'name': 'P.US.CLEG139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 1, 14, 11, 10),
#     'price': 0.27103885817594175,
#     'qty': -1.0,
#     'usdvalue': -271.03885817594175},
#    {'asset': {'dbid': 40028,
#      'hash': 200040028,
#      'name': 'P.US.CLEG138950',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 1, 14, 11, 10),
#     'price': 0.003990639704258614,
#     'qty': 4.0,
#     'usdvalue': 15.962558817034456},
#    {'asset': {'dbid': 34285,
#      'hash': 200034285,
#      'name': 'C.US.CLEG139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 1, 14, 11, 10),
#     'price': 0.8403024401651393,
#     'qty': -2.0,
#     'usdvalue': -1680.6048803302788},
#    {'asset': {'dbid': 34438,
#      'hash': 200034438,
#      'name': 'C.US.CLEH139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 1, 14, 11, 10),
#     'price': 3.027019254864676,
#     'qty': 2.0,
#     'usdvalue': 6054.038509729352},
#    {'asset': {'dbid': 40182,
#      'hash': 200040182,
#      'name': 'P.US.CLEH139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 1, 14, 11, 10),
#     'price': 1.9979989685098474,
#     'qty': 1.0,
#     'usdvalue': 1997.9989685098474},
#    {'asset': {'dbid': 41687,
#      'hash': 200041687,
#      'name': 'P.US.CLEH138950',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 1, 14, 11, 10),
#     'price': 0.9802228673097915,
#     'qty': -4.0,
#     'usdvalue': -3920.891469239166},
#    {'asset': {'dbid': 34449,
#      'hash': 200034449,
#      'name': 'C.US.CLEH139850',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 1, 14, 11, 10),
#     'price': 0.792843202449312,
#     'qty': -2.0,
#     'usdvalue': -1585.686404898624},
#    {'asset': {'dbid': 34449,
#      'hash': 200034449,
#      'name': 'C.US.CLEH139850',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 12, 11, 10),
#     'price': 0.27957608386048705,
#     'qty': 2.0,
#     'usdvalue': 559.1521677209741},
#    {'asset': {'dbid': 40182,
#      'hash': 200040182,
#      'name': 'P.US.CLEH139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 12, 11, 10),
#     'price': 0.01901870206709999,
#     'qty': -1.0,
#     'usdvalue': -19.01870206709999},
#    {'asset': {'dbid': 34438,
#      'hash': 200034438,
#      'name': 'C.US.CLEH139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 12, 11, 10),
#     'price': 4.709863275514579,
#     'qty': -2.0,
#     'usdvalue': -9419.726551029158},
#    {'asset': {'dbid': 41687,
#      'hash': 200041687,
#      'name': 'P.US.CLEH138950',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 12, 11, 10),
#     'price': 0.0034674637202314895,
#     'qty': 4.0,
#     'usdvalue': 13.869854880925958},
#    {'asset': {'dbid': 29059,
#      'hash': 200029059,
#      'name': 'C.US.CLEJ139700',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 12, 11, 10),
#     'price': 2.835800192647831,
#     'qty': 2.0,
#     'usdvalue': 5671.600385295662},
#    {'asset': {'dbid': 40337,
#      'hash': 200040337,
#      'name': 'P.US.CLEJ139700',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 12, 11, 10),
#     'price': 1.6158086483616927,
#     'qty': 1.0,
#     'usdvalue': 1615.8086483616926},
#    {'asset': {'dbid': 40331,
#      'hash': 200040331,
#      'name': 'P.US.CLEJ139350',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 12, 11, 10),
#     'price': 0.7653560740454601,
#     'qty': -4.0,
#     'usdvalue': -3061.4242961818404},
#    {'asset': {'dbid': 29070,
#      'hash': 200029070,
#      'name': 'C.US.CLEJ1310250',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 12, 11, 10),
#     'price': 0.5823510301527328,
#     'qty': -2.0,
#     'usdvalue': -1164.7020603054657},
#    {'asset': {'dbid': 40337,
#      'hash': 200040337,
#      'name': 'P.US.CLEJ139700',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 20, 11, 10),
#     'price': 3.1093396731684635,
#     'qty': -1.0,
#     'usdvalue': -3109.3396731684634},
#    {'asset': {'dbid': 40331,
#      'hash': 200040331,
#      'name': 'P.US.CLEJ139350',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 20, 11, 10),
#     'price': 1.5394933191825046,
#     'qty': 4.0,
#     'usdvalue': 6157.973276730018},
#    {'asset': {'dbid': 29059,
#      'hash': 200029059,
#      'name': 'C.US.CLEJ139700',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 20, 11, 10),
#     'price': 1.0207894164556528,
#     'qty': -2.0,
#     'usdvalue': -2041.5788329113057},
#    {'asset': {'dbid': 29070,
#      'hash': 200029070,
#      'name': 'C.US.CLEJ1310250',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 20, 11, 10),
#     'price': 0.07048460183962924,
#     'qty': 2.0,
#     'usdvalue': 140.96920367925847},
#    {'asset': {'dbid': 29060,
#      'hash': 200029060,
#      'name': 'C.US.CLEJ139750',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 20, 11, 10),
#     'price': 0.8444188269597355,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29060,
#      'hash': 200029060,
#      'name': 'C.US.CLEJ139750',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 21, 11, 10),
#     'price': 0.43044015122275425,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29056,
#      'hash': 200029056,
#      'name': 'C.US.CLEJ139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 21, 11, 10),
#     'price': 0.981461735432017,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29056,
#      'hash': 200029056,
#      'name': 'C.US.CLEJ139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 22, 11, 10),
#     'price': 1.0987000898588164,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29056,
#      'hash': 200029056,
#      'name': 'C.US.CLEJ139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 22, 11, 10),
#     'price': 1.0987000898588164,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29056,
#      'hash': 200029056,
#      'name': 'C.US.CLEJ139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 23, 11, 10),
#     'price': 0.9248339228734572,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29057,
#      'hash': 200029057,
#      'name': 'C.US.CLEJ139600',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 23, 11, 10),
#     'price': 0.7676934230060368,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29057,
#      'hash': 200029057,
#      'name': 'C.US.CLEJ139600',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 24, 11, 10),
#     'price': 0.7297346591768985,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29057,
#      'hash': 200029057,
#      'name': 'C.US.CLEJ139600',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 24, 11, 10),
#     'price': 0.7297346591768985,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29057,
#      'hash': 200029057,
#      'name': 'C.US.CLEJ139600',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 25, 11, 10),
#     'price': 0.547029131179368,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29056,
#      'hash': 200029056,
#      'name': 'C.US.CLEJ139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 25, 11, 10),
#     'price': 0.6756795951279351,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29056,
#      'hash': 200029056,
#      'name': 'C.US.CLEJ139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 26, 11, 10),
#     'price': 0.5705823884057004,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29055,
#      'hash': 200029055,
#      'name': 'C.US.CLEJ139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 26, 11, 10),
#     'price': 0.7173862351834472,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29055,
#      'hash': 200029055,
#      'name': 'C.US.CLEJ139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 27, 11, 10),
#     'price': 0.7744219665113121,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29055,
#      'hash': 200029055,
#      'name': 'C.US.CLEJ139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 27, 11, 10),
#     'price': 0.7744219665113121,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29055,
#      'hash': 200029055,
#      'name': 'C.US.CLEJ139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 28, 11, 10),
#     'price': 0.6248349047762503,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29055,
#      'hash': 200029055,
#      'name': 'C.US.CLEJ139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 2, 28, 11, 10),
#     'price': 0.6248349047762503,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29055,
#      'hash': 200029055,
#      'name': 'C.US.CLEJ139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 1, 11, 10),
#     'price': 0.1625743167948155,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29051,
#      'hash': 200029051,
#      'name': 'C.US.CLEJ139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 1, 11, 10),
#     'price': 0.5275207040822387,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29051,
#      'hash': 200029051,
#      'name': 'C.US.CLEJ139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 2, 11, 10),
#     'price': 0.6009282907773006,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29052,
#      'hash': 200029052,
#      'name': 'C.US.CLEJ139350',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 2, 11, 10),
#     'price': 0.4693258597607972,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29052,
#      'hash': 200029052,
#      'name': 'C.US.CLEJ139350',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 3, 11, 10),
#     'price': 0.42843481088250357,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29052,
#      'hash': 200029052,
#      'name': 'C.US.CLEJ139350',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 3, 11, 10),
#     'price': 0.42843481088250357,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29052,
#      'hash': 200029052,
#      'name': 'C.US.CLEJ139350',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 4, 11, 10),
#     'price': 0.18267948498002085,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29050,
#      'hash': 200029050,
#      'name': 'C.US.CLEJ139250',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 4, 11, 10),
#     'price': 0.35371351975049237,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29050,
#      'hash': 200029050,
#      'name': 'C.US.CLEJ139250',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 5, 11, 10),
#     'price': 0.6046226470249394,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29051,
#      'hash': 200029051,
#      'name': 'C.US.CLEJ139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 5, 11, 10),
#     'price': 0.4708341047278033,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29051,
#      'hash': 200029051,
#      'name': 'C.US.CLEJ139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 6, 11, 10),
#     'price': 0.21498567438934835,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29050,
#      'hash': 200029050,
#      'name': 'C.US.CLEJ139250',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 6, 11, 10),
#     'price': 0.2966611823581644,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29050,
#      'hash': 200029050,
#      'name': 'C.US.CLEJ139250',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 7, 11, 10),
#     'price': 0.5859022588829461,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29053,
#      'hash': 200029053,
#      'name': 'C.US.CLEJ139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 7, 11, 10),
#     'price': 0.2519965295369797,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29053,
#      'hash': 200029053,
#      'name': 'C.US.CLEJ139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 8, 11, 10),
#     'price': 0.17557480964976513,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29053,
#      'hash': 200029053,
#      'name': 'C.US.CLEJ139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 8, 11, 10),
#     'price': 0.17557480964976513,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29053,
#      'hash': 200029053,
#      'name': 'C.US.CLEJ139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 9, 11, 10),
#     'price': 0.14829064177966167,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29054,
#      'hash': 200029054,
#      'name': 'C.US.CLEJ139450',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 9, 11, 10),
#     'price': 0.09941332608989839,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29054,
#      'hash': 200029054,
#      'name': 'C.US.CLEJ139450',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 10, 11, 10),
#     'price': 0.06981497749880816,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29054,
#      'hash': 200029054,
#      'name': 'C.US.CLEJ139450',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 10, 11, 10),
#     'price': 0.06981497749880816,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29054,
#      'hash': 200029054,
#      'name': 'C.US.CLEJ139450',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 11, 11, 10),
#     'price': 0.034692488464289184,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29053,
#      'hash': 200029053,
#      'name': 'C.US.CLEJ139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 11, 11, 10),
#     'price': 0.0607788195937502,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29053,
#      'hash': 200029053,
#      'name': 'C.US.CLEJ139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 12, 11, 10),
#     'price': 0.17632207370920483,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29055,
#      'hash': 200029055,
#      'name': 'C.US.CLEJ139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 12, 11, 10),
#     'price': 0.06322718992641185,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29055,
#      'hash': 200029055,
#      'name': 'C.US.CLEJ139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 13, 11, 10),
#     'price': 0.03897550185493959,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29208,
#      'hash': 200029208,
#      'name': 'C.US.CLEK139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 13, 11, 10),
#     'price': 1.1328387546000158,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29208,
#      'hash': 200029208,
#      'name': 'C.US.CLEK139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 14, 11, 10),
#     'price': 1.2771411391797969,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29209,
#      'hash': 200029209,
#      'name': 'C.US.CLEK139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 14, 11, 10),
#     'price': 1.1053535296715395,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29209,
#      'hash': 200029209,
#      'name': 'C.US.CLEK139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 15, 11, 10),
#     'price': 1.1945378855252429,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29211,
#      'hash': 200029211,
#      'name': 'C.US.CLEK139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 15, 11, 10),
#     'price': 0.8634483164932156,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29211,
#      'hash': 200029211,
#      'name': 'C.US.CLEK139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 16, 11, 10),
#     'price': 0.8427939416998846,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29211,
#      'hash': 200029211,
#      'name': 'C.US.CLEK139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 16, 11, 10),
#     'price': 0.8427939416998846,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29211,
#      'hash': 200029211,
#      'name': 'C.US.CLEK139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 17, 11, 10),
#     'price': 0.817372867790791,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29211,
#      'hash': 200029211,
#      'name': 'C.US.CLEK139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 17, 11, 10),
#     'price': 0.817372867790791,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29211,
#      'hash': 200029211,
#      'name': 'C.US.CLEK139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 18, 11, 10),
#     'price': 0.8238092048036414,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29211,
#      'hash': 200029211,
#      'name': 'C.US.CLEK139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 18, 11, 10),
#     'price': 0.8238092048036414,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29211,
#      'hash': 200029211,
#      'name': 'C.US.CLEK139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 19, 11, 10),
#     'price': 0.5157277150859834,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29209,
#      'hash': 200029209,
#      'name': 'C.US.CLEK139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 19, 11, 10),
#     'price': 0.7718481477169092,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29209,
#      'hash': 200029209,
#      'name': 'C.US.CLEK139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 20, 11, 10),
#     'price': 0.9271245170629925,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29209,
#      'hash': 200029209,
#      'name': 'C.US.CLEK139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 20, 11, 10),
#     'price': 0.9271245170629925,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29209,
#      'hash': 200029209,
#      'name': 'C.US.CLEK139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 21, 11, 10),
#     'price': 0.6327998160685979,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29208,
#      'hash': 200029208,
#      'name': 'C.US.CLEK139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 21, 11, 10),
#     'price': 0.774957818156448,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29208,
#      'hash': 200029208,
#      'name': 'C.US.CLEK139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 22, 11, 10),
#     'price': 1.05893738686229,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29210,
#      'hash': 200029210,
#      'name': 'C.US.CLEK139600',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 22, 11, 10),
#     'price': 0.7392525734933244,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29210,
#      'hash': 200029210,
#      'name': 'C.US.CLEK139600',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 23, 11, 10),
#     'price': 0.7993650945410025,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29211,
#      'hash': 200029211,
#      'name': 'C.US.CLEK139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 23, 11, 10),
#     'price': 0.6570018086167018,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29211,
#      'hash': 200029211,
#      'name': 'C.US.CLEK139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 24, 11, 10),
#     'price': 0.629531729724107,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29211,
#      'hash': 200029211,
#      'name': 'C.US.CLEK139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 24, 11, 10),
#     'price': 0.629531729724107,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29211,
#      'hash': 200029211,
#      'name': 'C.US.CLEK139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 25, 11, 10),
#     'price': 0.865485865121272,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29212,
#      'hash': 200029212,
#      'name': 'C.US.CLEK139700',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 25, 11, 10),
#     'price': 0.7120089694259661,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29212,
#      'hash': 200029212,
#      'name': 'C.US.CLEK139700',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 26, 11, 10),
#     'price': 1.0710603380572081,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29208,
#      'hash': 200029208,
#      'name': 'C.US.CLEK139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 26, 11, 10),
#     'price': 2.094883526213607,
#     'qty': 2.0,
#     'usdvalue': 4189.767052427214},
#    {'asset': {'dbid': 40488,
#      'hash': 200040488,
#      'name': 'P.US.CLEK139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 26, 11, 10),
#     'price': 1.1848993422104144,
#     'qty': 1.0,
#     'usdvalue': 1184.8993422104145},
#    {'asset': {'dbid': 40482,
#      'hash': 200040482,
#      'name': 'P.US.CLEK139150',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 26, 11, 10),
#     'price': 0.344649990774748,
#     'qty': -4.0,
#     'usdvalue': -1378.599963098992},
#    {'asset': {'dbid': 29219,
#      'hash': 200029219,
#      'name': 'C.US.CLEK1310050',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 3, 26, 11, 10),
#     'price': 0.2234160815255244,
#     'qty': -2.0,
#     'usdvalue': -446.8321630510488},
#    {'asset': {'dbid': 29208,
#      'hash': 200029208,
#      'name': 'C.US.CLEK139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 11, 11, 10),
#     'price': 0.25559880357297615,
#     'qty': -2.0,
#     'usdvalue': -511.1976071459523},
#    {'asset': {'dbid': 40488,
#      'hash': 200040488,
#      'name': 'P.US.CLEK139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 11, 11, 10),
#     'price': 2.034583547834373,
#     'qty': -1.0,
#     'usdvalue': -2034.583547834373},
#    {'asset': {'dbid': 40482,
#      'hash': 200040482,
#      'name': 'P.US.CLEK139150',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 11, 11, 10),
#     'price': 0.36905134452232247,
#     'qty': 4.0,
#     'usdvalue': 1476.2053780892898},
#    {'asset': {'dbid': 29219,
#      'hash': 200029219,
#      'name': 'C.US.CLEK1310050',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 11, 11, 10),
#     'price': 0.00376439125359751,
#     'qty': 2.0,
#     'usdvalue': 7.52878250719502},
#    {'asset': {'dbid': 29209,
#      'hash': 200029209,
#      'name': 'C.US.CLEK139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 11, 11, 10),
#     'price': 0.16703078852669861,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29209,
#      'hash': 200029209,
#      'name': 'C.US.CLEK139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 12, 11, 10),
#     'price': 0.026783885622433168,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29206,
#      'hash': 200029206,
#      'name': 'C.US.CLEK139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 12, 11, 10),
#     'price': 0.13656301179342734,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29206,
#      'hash': 200029206,
#      'name': 'C.US.CLEK139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 13, 11, 10),
#     'price': 0.03750527797098968,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29204,
#      'hash': 200029204,
#      'name': 'C.US.CLEK139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 13, 11, 10),
#     'price': 0.10247457166724594,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29204,
#      'hash': 200029204,
#      'name': 'C.US.CLEK139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 14, 11, 10),
#     'price': 0.05916727376650055,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29204,
#      'hash': 200029204,
#      'name': 'C.US.CLEK139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 14, 11, 10),
#     'price': 0.05916727376650055,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29204,
#      'hash': 200029204,
#      'name': 'C.US.CLEK139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 15, 11, 10),
#     'price': 0.00017112080743974384,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29384,
#      'hash': 200029384,
#      'name': 'C.US.CLEM139150',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 15, 11, 10),
#     'price': 1.1195845231174317,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29384,
#      'hash': 200029384,
#      'name': 'C.US.CLEM139150',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 16, 11, 10),
#     'price': 1.4363381403212685,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29384,
#      'hash': 200029384,
#      'name': 'C.US.CLEM139150',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 16, 11, 10),
#     'price': 1.4363381403212685,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29384,
#      'hash': 200029384,
#      'name': 'C.US.CLEM139150',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 17, 11, 10),
#     'price': 0.8032906355837284,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29380,
#      'hash': 200029380,
#      'name': 'C.US.CLEM138950',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 17, 11, 10),
#     'price': 1.442606343141147,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29380,
#      'hash': 200029380,
#      'name': 'C.US.CLEM138950',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 18, 11, 10),
#     'price': 1.6892623507799698,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29381,
#      'hash': 200029381,
#      'name': 'C.US.CLEM139000',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 18, 11, 10),
#     'price': 1.4942175502101165,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29381,
#      'hash': 200029381,
#      'name': 'C.US.CLEM139000',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 19, 11, 10),
#     'price': 1.6472842904071001,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29383,
#      'hash': 200029383,
#      'name': 'C.US.CLEM139100',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 19, 11, 10),
#     'price': 1.247669340818959,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29383,
#      'hash': 200029383,
#      'name': 'C.US.CLEM139100',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 20, 11, 10),
#     'price': 1.1030211433548374,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29383,
#      'hash': 200029383,
#      'name': 'C.US.CLEM139100',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 20, 11, 10),
#     'price': 1.1030211433548374,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29383,
#      'hash': 200029383,
#      'name': 'C.US.CLEM139100',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 21, 11, 10),
#     'price': 1.0650982126074489,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29383,
#      'hash': 200029383,
#      'name': 'C.US.CLEM139100',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 21, 11, 10),
#     'price': 1.0650982126074489,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29383,
#      'hash': 200029383,
#      'name': 'C.US.CLEM139100',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 22, 11, 10),
#     'price': 1.33037987474777,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29384,
#      'hash': 200029384,
#      'name': 'C.US.CLEM139150',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 22, 11, 10),
#     'price': 1.1353628904589215,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29384,
#      'hash': 200029384,
#      'name': 'C.US.CLEM139150',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 23, 11, 10),
#     'price': 1.09409512450911,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29384,
#      'hash': 200029384,
#      'name': 'C.US.CLEM139150',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 23, 11, 10),
#     'price': 1.09409512450911,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29384,
#      'hash': 200029384,
#      'name': 'C.US.CLEM139150',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 24, 11, 10),
#     'price': 1.8565471550797241,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29388,
#      'hash': 200029388,
#      'name': 'C.US.CLEM139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 24, 11, 10),
#     'price': 0.8537293686278531,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29388,
#      'hash': 200029388,
#      'name': 'C.US.CLEM139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 25, 11, 10),
#     'price': 1.7512688323411254,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29393,
#      'hash': 200029393,
#      'name': 'C.US.CLEM139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 25, 11, 10),
#     'price': 0.8138371670877476,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29393,
#      'hash': 200029393,
#      'name': 'C.US.CLEM139650',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 26, 11, 10),
#     'price': 0.5927411983713142,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29391,
#      'hash': 200029391,
#      'name': 'C.US.CLEM139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 26, 11, 10),
#     'price': 0.8548366098980402,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29391,
#      'hash': 200029391,
#      'name': 'C.US.CLEM139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 27, 11, 10),
#     'price': 0.6527170508302902,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29391,
#      'hash': 200029391,
#      'name': 'C.US.CLEM139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 27, 11, 10),
#     'price': 0.6527170508302902,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29391,
#      'hash': 200029391,
#      'name': 'C.US.CLEM139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 28, 11, 10),
#     'price': 0.616663559480525,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29391,
#      'hash': 200029391,
#      'name': 'C.US.CLEM139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 28, 11, 10),
#     'price': 0.616663559480525,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29391,
#      'hash': 200029391,
#      'name': 'C.US.CLEM139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 29, 11, 10),
#     'price': 1.2055589785319683,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29394,
#      'hash': 200029394,
#      'name': 'C.US.CLEM139700',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 29, 11, 10),
#     'price': 0.699693482916306,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29394,
#      'hash': 200029394,
#      'name': 'C.US.CLEM139700',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 30, 11, 10),
#     'price': 0.4157030041622889,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29392,
#      'hash': 200029392,
#      'name': 'C.US.CLEM139600',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 4, 30, 11, 10),
#     'price': 0.6488085334341136,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29392,
#      'hash': 200029392,
#      'name': 'C.US.CLEM139600',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 1, 11, 10),
#     'price': 0.19154286458826597,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29387,
#      'hash': 200029387,
#      'name': 'C.US.CLEM139350',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 1, 11, 10),
#     'price': 0.6698401851710578,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29387,
#      'hash': 200029387,
#      'name': 'C.US.CLEM139350',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 2, 11, 10),
#     'price': 1.5557286909773325,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29391,
#      'hash': 200029391,
#      'name': 'C.US.CLEM139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 2, 11, 10),
#     'price': 0.7602686610672187,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 29391,
#      'hash': 200029391,
#      'name': 'C.US.CLEM139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 3, 11, 10),
#     'price': 1.5135861713962484,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 29389,
#      'hash': 200029389,
#      'name': 'C.US.CLEM139450',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 3, 11, 10),
#     'price': 2.0966243881319286,
#     'qty': 2.0,
#     'usdvalue': 4193.2487762638575},
#    {'asset': {'dbid': 40670,
#      'hash': 200040670,
#      'name': 'P.US.CLEM139450',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 3, 11, 10),
#     'price': 1.2268629025304705,
#     'qty': 1.0,
#     'usdvalue': 1226.8629025304704},
#    {'asset': {'dbid': 40663,
#      'hash': 200040663,
#      'name': 'P.US.CLEM139100',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 3, 11, 10),
#     'price': 0.42922203113630353,
#     'qty': -4.0,
#     'usdvalue': -1716.8881245452142},
#    {'asset': {'dbid': 29400,
#      'hash': 200029400,
#      'name': 'C.US.CLEM1310000',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 3, 11, 10),
#     'price': 0.22644929703340821,
#     'qty': -2.0,
#     'usdvalue': -452.89859406681643},
#    {'asset': {'dbid': 29400,
#      'hash': 200029400,
#      'name': 'C.US.CLEM1310000',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 14, 11, 10),
#     'price': 0.0046355479775501696,
#     'qty': 2.0,
#     'usdvalue': 9.27109595510034},
#    {'asset': {'dbid': 29389,
#      'hash': 200029389,
#      'name': 'C.US.CLEM139450',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 14, 11, 10),
#     'price': 0.630245806465787,
#     'qty': -2.0,
#     'usdvalue': -1260.4916129315739},
#    {'asset': {'dbid': 40670,
#      'hash': 200040670,
#      'name': 'P.US.CLEM139450',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 14, 11, 10),
#     'price': 0.8706186319652787,
#     'qty': -1.0,
#     'usdvalue': -870.6186319652786},
#    {'asset': {'dbid': 40663,
#      'hash': 200040663,
#      'name': 'P.US.CLEM139100',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 14, 11, 10),
#     'price': 0.08288243311883203,
#     'qty': 4.0,
#     'usdvalue': 331.52973247532816},
#    {'asset': {'dbid': 34563,
#      'hash': 200034563,
#      'name': 'C.US.CLEN139350',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 14, 11, 10),
#     'price': 3.089548719633946,
#     'qty': 2.0,
#     'usdvalue': 6179.097439267892},
#    {'asset': {'dbid': 40848,
#      'hash': 200040848,
#      'name': 'P.US.CLEN139350',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 14, 11, 10),
#     'price': 2.0805498144842858,
#     'qty': 1.0,
#     'usdvalue': 2080.549814484286},
#    {'asset': {'dbid': 41560,
#      'hash': 200041560,
#      'name': 'P.US.CLEN139000',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 14, 11, 10),
#     'price': 1.0839039056005753,
#     'qty': -4.0,
#     'usdvalue': -4335.615622402301},
#    {'asset': {'dbid': 34574,
#      'hash': 200034574,
#      'name': 'C.US.CLEN139900',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 14, 11, 10),
#     'price': 0.7414427808549107,
#     'qty': -2.0,
#     'usdvalue': -1482.8855617098213},
#    {'asset': {'dbid': 41560,
#      'hash': 200041560,
#      'name': 'P.US.CLEN139000',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 31, 11, 10),
#     'price': 0.9466051691467321,
#     'qty': 4.0,
#     'usdvalue': 3786.4206765869285},
#    {'asset': {'dbid': 40848,
#      'hash': 200040848,
#      'name': 'P.US.CLEN139350',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 31, 11, 10),
#     'price': 2.386821272950492,
#     'qty': -1.0,
#     'usdvalue': -2386.8212729504917},
#    {'asset': {'dbid': 34563,
#      'hash': 200034563,
#      'name': 'C.US.CLEN139350',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 31, 11, 10),
#     'price': 1.296888402042029,
#     'qty': -2.0,
#     'usdvalue': -2593.7768040840583},
#    {'asset': {'dbid': 34574,
#      'hash': 200034574,
#      'name': 'C.US.CLEN139900',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 31, 11, 10),
#     'price': 0.089845519636512,
#     'qty': 2.0,
#     'usdvalue': 179.691039273024},
#    {'asset': {'dbid': 34566,
#      'hash': 200034566,
#      'name': 'C.US.CLEN139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 5, 31, 11, 10),
#     'price': 0.732371946444939,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 34566,
#      'hash': 200034566,
#      'name': 'C.US.CLEN139500',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 1, 11, 10),
#     'price': 0.4526085158783708,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 34564,
#      'hash': 200034564,
#      'name': 'C.US.CLEN139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 1, 11, 10),
#     'price': 0.7248823533585238,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 34564,
#      'hash': 200034564,
#      'name': 'C.US.CLEN139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 2, 11, 10),
#     'price': 0.6805872018839381,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 34564,
#      'hash': 200034564,
#      'name': 'C.US.CLEN139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 2, 11, 10),
#     'price': 0.6805872018839381,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 34564,
#      'hash': 200034564,
#      'name': 'C.US.CLEN139400',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 3, 11, 10),
#     'price': 1.2931056066119169,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 34561,
#      'hash': 200034561,
#      'name': 'C.US.CLEN139250',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 3, 11, 10),
#     'price': 2.111447247613768,
#     'qty': 2.0,
#     'usdvalue': 4222.894495227536},
#    {'asset': {'dbid': 40846,
#      'hash': 200040846,
#      'name': 'P.US.CLEN139250',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 3, 11, 10),
#     'price': 1.1823236143776015,
#     'qty': 1.0,
#     'usdvalue': 1182.3236143776014},
#    {'asset': {'dbid': 40840,
#      'hash': 200040840,
#      'name': 'P.US.CLEN138900',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 3, 11, 10),
#     'price': 0.3500528759604933,
#     'qty': -4.0,
#     'usdvalue': -1400.2115038419731},
#    {'asset': {'dbid': 34572,
#      'hash': 200034572,
#      'name': 'C.US.CLEN139800',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 3, 11, 10),
#     'price': 0.20456178551268778,
#     'qty': -2.0,
#     'usdvalue': -409.12357102537555},
#    {'asset': {'dbid': 40840,
#      'hash': 200040840,
#      'name': 'P.US.CLEN138900',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 4, 11, 10),
#     'price': 0.47791969159224124,
#     'qty': 4.0,
#     'usdvalue': 1911.678766368965},
#    {'asset': {'dbid': 34561,
#      'hash': 200034561,
#      'name': 'C.US.CLEN139250',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 4, 11, 10),
#     'price': 1.9129794856805447,
#     'qty': -2.0,
#     'usdvalue': -3825.9589713610894},
#    {'asset': {'dbid': 34572,
#      'hash': 200034572,
#      'name': 'C.US.CLEN139800',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 4, 11, 10),
#     'price': 0.17161963712490014,
#     'qty': 2.0,
#     'usdvalue': 343.23927424980025},
#    {'asset': {'dbid': 40846,
#      'hash': 200040846,
#      'name': 'P.US.CLEN139250',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 4, 11, 10),
#     'price': 1.4934311148331787,
#     'qty': -1.0,
#     'usdvalue': -1493.4311148331788},
#    {'asset': {'dbid': 34567,
#      'hash': 200034567,
#      'name': 'C.US.CLEN139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 4, 11, 10),
#     'price': 0.6239717272957463,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 34567,
#      'hash': 200034567,
#      'name': 'C.US.CLEN139550',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 5, 11, 10),
#     'price': 0.9761371012968496,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 34562,
#      'hash': 200034562,
#      'name': 'C.US.CLEN139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 5, 11, 10),
#     'price': 2.2623076069948382,
#     'qty': 2.0,
#     'usdvalue': 4524.615213989677},
#    {'asset': {'dbid': 40847,
#      'hash': 200040847,
#      'name': 'P.US.CLEN139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 5, 11, 10),
#     'price': 1.1124116738830665,
#     'qty': 1.0,
#     'usdvalue': 1112.4116738830664},
#    {'asset': {'dbid': 40841,
#      'hash': 200040841,
#      'name': 'P.US.CLEN138950',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 5, 11, 10),
#     'price': 0.3020600504244193,
#     'qty': -4.0,
#     'usdvalue': -1208.240201697677},
#    {'asset': {'dbid': 34573,
#      'hash': 200034573,
#      'name': 'C.US.CLEN139850',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 5, 11, 10),
#     'price': 0.24747157169637113,
#     'qty': -2.0,
#     'usdvalue': -494.9431433927423},
#    {'asset': {'dbid': 40841,
#      'hash': 200040841,
#      'name': 'P.US.CLEN138950',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 15, 11, 10),
#     'price': 0.0013926001013765399,
#     'qty': 4.0,
#     'usdvalue': 5.57040040550616},
#    {'asset': {'dbid': 34562,
#      'hash': 200034562,
#      'name': 'C.US.CLEN139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 15, 11, 10),
#     'price': 4.89505895330548,
#     'qty': -2.0,
#     'usdvalue': -9790.11790661096},
#    {'asset': {'dbid': 34573,
#      'hash': 200034573,
#      'name': 'C.US.CLEN139850',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 15, 11, 10),
#     'price': 0.1967956964849087,
#     'qty': 2.0,
#     'usdvalue': 393.5913929698174},
#    {'asset': {'dbid': 40847,
#      'hash': 200040847,
#      'name': 'P.US.CLEN139300',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 15, 11, 10),
#     'price': 0.004234039956003244,
#     'qty': -1.0,
#     'usdvalue': -4.234039956003244},
#    {'asset': {'dbid': 34725,
#      'hash': 200034725,
#      'name': 'C.US.CLEQ139700',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 15, 11, 10),
#     'price': 2.809856299459504,
#     'qty': 2.0,
#     'usdvalue': 5619.712598919008},
#    {'asset': {'dbid': 41010,
#      'hash': 200041010,
#      'name': 'P.US.CLEQ139700',
#      'type': 'O'},
#     'date': datetime.datetime(2013, 6, 15, 11, 10),
#     'price': 1.7502063447276157,
#     'qty': 1.0,
#     'usdvalue': 1750.2063447276157},
#    {'asset': {'dbid': 41003,
#      'hash': 200041003,
#      'name': 'P.US.CLEQ139350',
#      'type': 'O'},
# ...
#     'date': datetime.datetime(2014, 12, 12, 11, 10),
#     'price': 0.041536267003781546,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11583955,
#      'hash': 211583955,
#      'name': 'C.US.CLEF156050',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 12, 11, 10),
#     'price': 0.21200431652861873,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11583955,
#      'hash': 211583955,
#      'name': 'C.US.CLEF156050',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 13, 11, 10),
#     'price': 0.11042863315182316,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11583954,
#      'hash': 211583954,
#      'name': 'C.US.CLEF156000',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 13, 11, 10),
#     'price': 0.1553571534222309,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11583954,
#      'hash': 211583954,
#      'name': 'C.US.CLEF156000',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 14, 11, 10),
#     'price': 0.0759011147541031,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584121,
#      'hash': 211584121,
#      'name': 'C.US.CLEG156000',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 14, 11, 10),
#     'price': 1.7910620034853473,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584121,
#      'hash': 211584121,
#      'name': 'C.US.CLEG156000',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 15, 11, 10),
#     'price': 1.3037753515048784,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584119,
#      'hash': 211584119,
#      'name': 'C.US.CLEG155900',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 15, 11, 10),
#     'price': 1.6494417630688751,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584119,
#      'hash': 211584119,
#      'name': 'C.US.CLEG155900',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 16, 11, 10),
#     'price': 1.9311314119474794,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584119,
#      'hash': 211584119,
#      'name': 'C.US.CLEG155900',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 16, 11, 10),
#     'price': 1.9311314119474794,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584119,
#      'hash': 211584119,
#      'name': 'C.US.CLEG155900',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 17, 11, 10),
#     'price': 2.3175831565532405,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584121,
#      'hash': 211584121,
#      'name': 'C.US.CLEG156000',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 17, 11, 10),
#     'price': 1.910430180665415,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584121,
#      'hash': 211584121,
#      'name': 'C.US.CLEG156000',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 18, 11, 10),
#     'price': 1.0404871777689966,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584116,
#      'hash': 211584116,
#      'name': 'C.US.CLEG155750',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 18, 11, 10),
#     'price': 1.7940356647820686,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584116,
#      'hash': 211584116,
#      'name': 'C.US.CLEG155750',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 19, 11, 10),
#     'price': 2.596490634696373,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584119,
#      'hash': 211584119,
#      'name': 'C.US.CLEG155900',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 19, 11, 10),
#     'price': 1.9770675905301474,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584119,
#      'hash': 211584119,
#      'name': 'C.US.CLEG155900',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 20, 11, 10),
#     'price': 2.51707945877914,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584122,
#      'hash': 211584122,
#      'name': 'C.US.CLEG156050',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 20, 11, 10),
#     'price': 1.9022061433755972,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584122,
#      'hash': 211584122,
#      'name': 'C.US.CLEG156050',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 21, 11, 10),
#     'price': 1.8438840858163523,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584122,
#      'hash': 211584122,
#      'name': 'C.US.CLEG156050',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 21, 11, 10),
#     'price': 1.8438840858163523,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584122,
#      'hash': 211584122,
#      'name': 'C.US.CLEG156050',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 22, 11, 10),
#     'price': 1.0593082276917567,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584117,
#      'hash': 211584117,
#      'name': 'C.US.CLEG155800',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 22, 11, 10),
#     'price': 1.8426518809442243,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584117,
#      'hash': 211584117,
#      'name': 'C.US.CLEG155800',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 23, 11, 10),
#     'price': 2.2659963257128126,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584119,
#      'hash': 211584119,
#      'name': 'C.US.CLEG155900',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 23, 11, 10),
#     'price': 1.8778524818904465,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584119,
#      'hash': 211584119,
#      'name': 'C.US.CLEG155900',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 24, 11, 10),
#     'price': 1.3898268058759875,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584118,
#      'hash': 211584118,
#      'name': 'C.US.CLEG155850',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 24, 11, 10),
#     'price': 1.552859986662174,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584118,
#      'hash': 211584118,
#      'name': 'C.US.CLEG155850',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 25, 11, 10),
#     'price': 1.542999862464466,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584118,
#      'hash': 211584118,
#      'name': 'C.US.CLEG155850',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 25, 11, 10),
#     'price': 1.542999862464466,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584118,
#      'hash': 211584118,
#      'name': 'C.US.CLEG155850',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 26, 11, 10),
#     'price': 1.1218747234113629,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584115,
#      'hash': 211584115,
#      'name': 'C.US.CLEG155700',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 26, 11, 10),
#     'price': 1.590928573695507,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584115,
#      'hash': 211584115,
#      'name': 'C.US.CLEG155700',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 27, 11, 10),
#     'price': 1.676729115423349,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584116,
#      'hash': 211584116,
#      'name': 'C.US.CLEG155750',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 27, 11, 10),
#     'price': 1.496298494671425,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584116,
#      'hash': 211584116,
#      'name': 'C.US.CLEG155750',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 28, 11, 10),
#     'price': 1.4307582289144456,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584116,
#      'hash': 211584116,
#      'name': 'C.US.CLEG155750',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 28, 11, 10),
#     'price': 1.4307582289144456,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584116,
#      'hash': 211584116,
#      'name': 'C.US.CLEG155750',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 29, 11, 10),
#     'price': 0.8012895741652688,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584113,
#      'hash': 211584113,
#      'name': 'C.US.CLEG155600',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 29, 11, 10),
#     'price': 1.2213495417146945,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584113,
#      'hash': 211584113,
#      'name': 'C.US.CLEG155600',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 30, 11, 10),
#     'price': 1.291826937786805,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584113,
#      'hash': 211584113,
#      'name': 'C.US.CLEG155600',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 30, 11, 10),
#     'price': 1.291826937786805,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584113,
#      'hash': 211584113,
#      'name': 'C.US.CLEG155600',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 31, 11, 10),
#     'price': 0.7673760076092577,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584112,
#      'hash': 211584112,
#      'name': 'C.US.CLEG155550',
#      'type': 'O'},
#     'date': datetime.datetime(2014, 12, 31, 11, 10),
#     'price': 0.9068391104931308,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584112,
#      'hash': 211584112,
#      'name': 'C.US.CLEG155550',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 1, 11, 10),
#     'price': 1.0809898062356318,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584113,
#      'hash': 211584113,
#      'name': 'C.US.CLEG155600',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 1, 11, 10),
#     'price': 0.9178209948503024,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584113,
#      'hash': 211584113,
#      'name': 'C.US.CLEG155600',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 2, 11, 10),
#     'price': 0.5461772968229379,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11542890,
#      'hash': 211542890,
#      'name': 'C.US.CLEG155500',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 2, 11, 10),
#     'price': 0.7983370922667294,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11542890,
#      'hash': 211542890,
#      'name': 'C.US.CLEG155500',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 3, 11, 10),
#     'price': 0.9663484767558934,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584112,
#      'hash': 211584112,
#      'name': 'C.US.CLEG155550',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 3, 11, 10),
#     'price': 0.8165120300681323,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584112,
#      'hash': 211584112,
#      'name': 'C.US.CLEG155550',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 4, 11, 10),
#     'price': 0.7437696075061027,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584112,
#      'hash': 211584112,
#      'name': 'C.US.CLEG155550',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 4, 11, 10),
#     'price': 0.7437696075061027,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584112,
#      'hash': 211584112,
#      'name': 'C.US.CLEG155550',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 5, 11, 10),
#     'price': 0.22931179447168226,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584108,
#      'hash': 211584108,
#      'name': 'C.US.CLEG155300',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 5, 11, 10),
#     'price': 0.7042685289717472,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584108,
#      'hash': 211584108,
#      'name': 'C.US.CLEG155300',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 6, 11, 10),
#     'price': 0.23333478428882426,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584103,
#      'hash': 211584103,
#      'name': 'C.US.CLEG155050',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 6, 11, 10),
#     'price': 0.7047739869873162,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584103,
#      'hash': 211584103,
#      'name': 'C.US.CLEG155050',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 7, 11, 10),
#     'price': 0.7223410620966906,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584104,
#      'hash': 211584104,
#      'name': 'C.US.CLEG155100',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 7, 11, 10),
#     'price': 0.5766050279715209,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584104,
#      'hash': 211584104,
#      'name': 'C.US.CLEG155100',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 8, 11, 10),
#     'price': 0.3413435529526243,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584103,
#      'hash': 211584103,
#      'name': 'C.US.CLEG155050',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 8, 11, 10),
#     'price': 0.4501828999864532,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584103,
#      'hash': 211584103,
#      'name': 'C.US.CLEG155050',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 9, 11, 10),
#     'price': 0.43653734135399347,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584104,
#      'hash': 211584104,
#      'name': 'C.US.CLEG155100',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 9, 11, 10),
#     'price': 0.32809176285740094,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584104,
#      'hash': 211584104,
#      'name': 'C.US.CLEG155100',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 10, 11, 10),
#     'price': 0.16645741347346554,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584103,
#      'hash': 211584103,
#      'name': 'C.US.CLEG155050',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 10, 11, 10),
#     'price': 0.229535064148374,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584103,
#      'hash': 211584103,
#      'name': 'C.US.CLEG155050',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 11, 11, 10),
#     'price': 0.1506833503790359,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584103,
#      'hash': 211584103,
#      'name': 'C.US.CLEG155050',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 11, 11, 10),
#     'price': 0.1506833503790359,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584103,
#      'hash': 211584103,
#      'name': 'C.US.CLEG155050',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 12, 11, 10),
#     'price': 0.0038386927594241116,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584271,
#      'hash': 211584271,
#      'name': 'C.US.CLEH154950',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 12, 11, 10),
#     'price': 1.6859046654987218,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584271,
#      'hash': 211584271,
#      'name': 'C.US.CLEH154950',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 13, 11, 10),
#     'price': 1.276202842634346,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584269,
#      'hash': 211584269,
#      'name': 'C.US.CLEH154850',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 13, 11, 10),
#     'price': 1.5980547909777805,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584269,
#      'hash': 211584269,
#      'name': 'C.US.CLEH154850',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 14, 11, 10),
#     'price': 2.186346050741914,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    {'asset': {'dbid': 11584271,
#      'hash': 211584271,
#      'name': 'C.US.CLEH154950',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 14, 11, 10),
#     'price': 1.7891251049909016,
#     'qty': 0.0,
#     'usdvalue': 0.0},
#    {'asset': {'dbid': 11584271,
#      'hash': 211584271,
#      'name': 'C.US.CLEH154950',
#      'type': 'O'},
#     'date': datetime.datetime(2015, 1, 15, 11, 10),
#     'price': 1.8959404245014646,
#     'qty': -0.0,
#     'usdvalue': -0.0},
#    ...]},
#  'margin': 0,
#  'name': 'CL_SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged_test',
#  'pcf': [],
#  'pcfqty': [],
#  'underlying': ''}

# %%
smgr.strategy.exoinfo.data.exo.plot()

# %% [markdown]
# ### Global filter information (obsolete)

# %% [markdown]
# ## Costs information (per 1-exo unit)

# %%
figsize(10,5)
smgr.strategy.costs.plot()

# %% [markdown]
# ## Margin graphs

# %% [markdown]
# ### EXO Margin (per 1 EXO unit)

# %%
smgr.strategy.exoinfo.margin().plot()

# %% [markdown]
# # Saving results

# %%
smgr.save('./swarms/')
