# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys,os
sys.path.append('..')
sys.path.append('../..')
from backtester import matlab, backtester
from backtester.analysis import *
from backtester.swarms.swarm import Swarm
from backtester.exoinfo import EXOInfo
from exobuilder.data.exostorage import EXOStorage


import pandas as pd
import numpy as np
import scipy
import pprint

# %%
# Loading global setting for MongoDB etc.
from scripts.settings import *

try:
    from scripts.settings_local import *
except:
    pass

# %%
storage = EXOStorage(MONGO_CONNSTR, MONGO_EXO_DB)

# %% [markdown]
# ## List of available products in Mongo

# %%
swm_info = storage.swarms_info()
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(swm_info)
# Out:
# {   '_id': None,
#     'alphas': [   'RenkoPatternsNoExits',
#                   'SwingPoint',
#                   'EXO',
#                   'PointAndFigure',
#                   'IchimokuCloud',
#                   'MACross',
#                   'BolllingerBands'],
#     'exo_types': [   'SMART',
#                      'CallSpread',
#                      'PutSpread',
#                      'ContFut',
#                      'BullishCollarBW',
#                      'BearishCollarBW'],
#     'instruments': ['ZC', 'NG', 'ZN', 'ES', 'ZS', 'CL', 'ZW']}

# %% [markdown]
# ## Getting swarm using filter

# %%
instruments_filter = ['*']  # Select ALL
#instruments_filter = ['ES', 'CL']

exo_filter = ['*'] # Select ALL
#exo_filter = ['BullishCollar']

direction_filter = [0, -1, 1] # Select ALL
#direction_filter = [1]

alpha_filter = ['-custom']  # Select ALL
#alpha_filter = ['MaCross', 'PointAndFigurePatterns']

swmdf, swm_data = storage.swarms_list(instruments_filter, direction_filter, alpha_filter, exo_filter)

# %% [markdown]
# ## Swarms loaded

# %%
[print(s) for s in sorted(swmdf.columns)];
# Out:
# CL_BearishCollarBW_Long_PointAndFigure_largebox-bearish-sample-custom
# CL_BearishCollarBW_Long_PointAndFigure_smallbox-bearish-sample-custom
# CL_BearishCollarBW_Short_SwingPoint_bearish-sample-custom
# CL_BearishCollarBW_Short_SwingPoint_bullish-sample-custom
# CL_CallSpread_Long_PointAndFigure_largebox-bearish-custom
# CL_CallSpread_Long_PointAndFigure_smallbox-bearish-custom
# CL_CallSpread_Short_SwingPoint_bearish-custom
# CL_CallSpread_Short_SwingPoint_bullish-custom
# CL_PutSpread_Long_BolllingerBands_bullish-custom
# CL_PutSpread_Long_IchimokuCloud_bullish-custom
# CL_PutSpread_Long_RenkoPatternsNoExits_bullish-custom
# CL_PutSpread_Short_IchimokuCloud_bearish-custom
# CL_PutSpread_Short_SwingPoint_bearish-custom
# ES_CallSpread_Long_SwingPoint_bullish-custom
# ES_CallSpread_Short_IchimokuCloud_bearish-custom
# ES_CallSpread_Short_MACross_bearish-custom
# ES_PutSpread_Long_BolllingerBands_bearish-custom
# ES_PutSpread_Long_IchimokuCloud_bearish-custom
# ES_PutSpread_Long_SwingPoint_bearish-custom
# ES_PutSpread_Short_BolllingerBands_bullish-custom
# ES_PutSpread_Short_IchimokuCloud_alt2-bullish-custom
# ES_PutSpread_Short_IchimokuCloud_bullish-custom
# NG_CallSpread_Long_BolllingerBands_alt2-bullish-custom
# NG_CallSpread_Long_BolllingerBands_alt3-bullish-custom
# NG_CallSpread_Long_BolllingerBands_bullish-custom
# NG_CallSpread_Long_IchimokuCloud_bullish-custom
# NG_CallSpread_Long_SwingPoint_bearish-custom
# NG_CallSpread_Long_SwingPoint_bullish-custom
# NG_CallSpread_Short_MACross_bearish-custom
# NG_CallSpread_Short_SwingPoint_bearish-custom
# NG_PutSpread_Long_BolllingerBands_alt2-bearish-custom
# NG_PutSpread_Long_BolllingerBands_bearish-custom
# NG_PutSpread_Long_IchimokuCloud_alt2-bearish-custom
# NG_PutSpread_Long_IchimokuCloud_alt3-bullish-custom
# NG_PutSpread_Long_IchimokuCloud_bearish-custom
# NG_PutSpread_Long_IchimokuCloud_bullish-custom
# NG_PutSpread_Short_IchimokuCloud_alt2-bullish-custom
# ZC_CallSpread_Long_BolllingerBands_bullish-custom
# ZC_CallSpread_Long_IchimokuCloud_alt2-bullish-custom
# ZC_CallSpread_Long_IchimokuCloud_bullish-custom
# ZC_CallSpread_Long_SwingPoint_bullish-custom
# ZC_CallSpread_Short_IchimokuCloud_bearish-custom
# ZC_CallSpread_Short_IchimokuCloud_bullish-custom
# ZC_CallSpread_Short_MACross_bearish-custom
# ZC_PutSpread_Long_BolllingerBands_alt2-bearish-custom
# ZC_PutSpread_Long_BolllingerBands_bearish-custom
# ZC_PutSpread_Long_IchimokuCloud_bearish-custom
# ZC_PutSpread_Long_MACross_bearish-custom
# ZC_PutSpread_Short_BolllingerBands_bullish-custom
# ZN_CallSpread_Long_IchimokuCloud_alt2-bearish-custom
# ZN_CallSpread_Long_MACross_bullish-custom
# ZN_CallSpread_Long_SwingPoint_bullish-custom
# ZN_CallSpread_Short_BolllingerBands_alt2-bearish-custom
# ZN_CallSpread_Short_BolllingerBands_alt3-bearish-custom
# ZN_CallSpread_Short_BolllingerBands_bearish-custom
# ZN_CallSpread_Short_BolllingerBands_bullish-custom
# ZN_CallSpread_Short_IchimokuCloud_bearish-custom
# ZN_PutSpread_Long_IchimokuCloud_bearish-custom
# ZN_PutSpread_Short_BolllingerBands_alt2-bullish-custom
# ZN_PutSpread_Short_BolllingerBands_bullish-custom
# ZN_PutSpread_Short_IchimokuCloud_alt2-bearish-custom
# ZN_PutSpread_Short_IchimokuCloud_alt2-bullish-custom
# ZN_PutSpread_Short_IchimokuCloud_alt3-bullish-custom
# ZN_PutSpread_Short_IchimokuCloud_bullish-custom
# ZN_PutSpread_Short_MACross_bullish-custom
# ZS_CallSpread_Long_IchimokuCloud_bearish-custom
# ZS_CallSpread_Long_IchimokuCloud_bullish-custom
# ZS_CallSpread_Long_SwingPoint_bearish-custom
# ZS_CallSpread_Long_SwingPoint_bullish-custom
# ZS_CallSpread_Short_BolllingerBands_bearish-custom
# ZS_CallSpread_Short_BolllingerBands_bullish-custom
# ZS_PutSpread_Short_BolllingerBands_alt2-bearish-custom
# ZS_PutSpread_Short_BolllingerBands_alt2-bullish-custom
# ZS_PutSpread_Short_BolllingerBands_bearish-custom
# ZS_PutSpread_Short_BolllingerBands_bullish-custom
# ZS_PutSpread_Short_IchimokuCloud_bearish-custom
# ZS_PutSpread_Short_IchimokuCloud_bullish-custom
# ZW_CallSpread_Short_BolllingerBands_bearish-custom
# ZW_CallSpread_Short_BolllingerBands_bullish-custom
# ZW_CallSpread_Short_IchimokuCloud_alt2-bearish-custom
# ZW_CallSpread_Short_IchimokuCloud_alt2-bullish-custom
# ZW_CallSpread_Short_IchimokuCloud_bearish-custom
# ZW_CallSpread_Short_IchimokuCloud_bullish-custom
# ZW_CallSpread_Short_MACross_bearish-custom
# ZW_CallSpread_Short_MACross_bullish-custom
# ZW_CallSpread_Short_SwingPoint_bearish-custom
# ZW_CallSpread_Short_SwingPoint_bullish-custom
# ZW_PutSpread_Long_MACross_bearish-custom
# ZW_PutSpread_Long_MACross_bullish-custom
# ZW_PutSpread_Short_BolllingerBands_bearish-custom
# ZW_PutSpread_Short_BolllingerBands_bullish-custom

# %% [markdown]
# ### Swarms equities

# %%
swmdf.plot().legend(loc='best', bbox_to_anchor=(1, 0.5));

# %% [markdown]
# ## Individual swarm equity

# %% [markdown]
# #""""
#
# CL_BearishCollarBW_Long_PointAndFigure_largebox-bearish-sample-custom
# CL_BearishCollarBW_Long_PointAndFigure_smallbox-bearish-sample-custom
# CL_BearishCollarBW_Short_SwingPoint_bearish-sample-custom
# CL_BearishCollarBW_Short_SwingPoint_bullish-sample-custom
# CL_CallSpread_Long_PointAndFigure_largebox-bearish-custom
# CL_CallSpread_Long_PointAndFigure_smallbox-bearish-custom
# CL_CallSpread_Short_SwingPoint_bearish-custom
# CL_CallSpread_Short_SwingPoint_bullish-custom
# CL_PutSpread_Long_BolllingerBands_bullish-custom
# CL_PutSpread_Long_IchimokuCloud_bullish-custom
# CL_PutSpread_Long_RenkoPatternsNoExits_bullish-custom
# CL_PutSpread_Short_IchimokuCloud_bearish-custom
# CL_PutSpread_Short_SwingPoint_bearish-custom
#
# #""""

# %%
#_swarm_name = "ES_BullishCollarBW_Long_BollingerBands"
_swarm_name = "CL_PutSpread_Short_SwingPoint_bearish-custom"



swmdf[_swarm_name].plot();
title(_swarm_name);

# %% [markdown]
# ### Available products EXOs

# %%
passive_exo = {}

exo_filter = '*'     # All 
#exo_filter = 'ES_'  # ES only
exo_filter = 'CL'  # ES Collars (incl Bearish, Bullish, BW and vanilla)


print('==== Passive EXO list')
for exo_name in storage.exo_list(exo_filter):
    passive_exo[exo_name], exo_dict = storage.load_series(exo_name)

for exo in sorted(passive_exo.keys()):
    print(exo)
    
print('==== Alphas EXO list')
[print(s) for s in sorted(swmdf.columns)];
# Out:
# ==== Passive EXO list
# CL_BearishCollarBW
# CL_BullishCollarBW
# CL_CallSpread
# CL_ContFut
# CL_PutSpread
# CL_SMART_Ichimoku_Long
# ==== Alphas EXO list
# CL_BearishCollarBW_Long_PointAndFigure_largebox-bearish-sample-custom
# CL_BearishCollarBW_Long_PointAndFigure_smallbox-bearish-sample-custom
# CL_BearishCollarBW_Short_SwingPoint_bearish-sample-custom
# CL_BearishCollarBW_Short_SwingPoint_bullish-sample-custom
# CL_CallSpread_Long_PointAndFigure_largebox-bearish-custom
# CL_CallSpread_Long_PointAndFigure_smallbox-bearish-custom
# CL_CallSpread_Short_SwingPoint_bearish-custom
# CL_CallSpread_Short_SwingPoint_bullish-custom
# CL_PutSpread_Long_BolllingerBands_bullish-custom
# CL_PutSpread_Long_IchimokuCloud_bullish-custom
# CL_PutSpread_Long_RenkoPatternsNoExits_bullish-custom
# CL_PutSpread_Short_IchimokuCloud_bearish-custom
# CL_PutSpread_Short_SwingPoint_bearish-custom
# ES_CallSpread_Long_SwingPoint_bullish-custom
# ES_CallSpread_Short_IchimokuCloud_bearish-custom
# ES_CallSpread_Short_MACross_bearish-custom
# ES_PutSpread_Long_BolllingerBands_bearish-custom
# ES_PutSpread_Long_IchimokuCloud_bearish-custom
# ES_PutSpread_Long_SwingPoint_bearish-custom
# ES_PutSpread_Short_BolllingerBands_bullish-custom
# ES_PutSpread_Short_IchimokuCloud_alt2-bullish-custom
# ES_PutSpread_Short_IchimokuCloud_bullish-custom
# NG_CallSpread_Long_BolllingerBands_alt2-bullish-custom
# NG_CallSpread_Long_BolllingerBands_alt3-bullish-custom
# NG_CallSpread_Long_BolllingerBands_bullish-custom
# NG_CallSpread_Long_IchimokuCloud_bullish-custom
# NG_CallSpread_Long_SwingPoint_bearish-custom
# NG_CallSpread_Long_SwingPoint_bullish-custom
# NG_CallSpread_Short_MACross_bearish-custom
# NG_CallSpread_Short_SwingPoint_bearish-custom
# NG_PutSpread_Long_BolllingerBands_alt2-bearish-custom
# NG_PutSpread_Long_BolllingerBands_bearish-custom
# NG_PutSpread_Long_IchimokuCloud_alt2-bearish-custom
# NG_PutSpread_Long_IchimokuCloud_alt3-bullish-custom
# NG_PutSpread_Long_IchimokuCloud_bearish-custom
# NG_PutSpread_Long_IchimokuCloud_bullish-custom
# NG_PutSpread_Short_IchimokuCloud_alt2-bullish-custom
# ZC_CallSpread_Long_BolllingerBands_bullish-custom
# ZC_CallSpread_Long_IchimokuCloud_alt2-bullish-custom
# ZC_CallSpread_Long_IchimokuCloud_bullish-custom
# ZC_CallSpread_Long_SwingPoint_bullish-custom
# ZC_CallSpread_Short_IchimokuCloud_bearish-custom
# ZC_CallSpread_Short_IchimokuCloud_bullish-custom
# ZC_CallSpread_Short_MACross_bearish-custom
# ZC_PutSpread_Long_BolllingerBands_alt2-bearish-custom
# ZC_PutSpread_Long_BolllingerBands_bearish-custom
# ZC_PutSpread_Long_IchimokuCloud_bearish-custom
# ZC_PutSpread_Long_MACross_bearish-custom
# ZC_PutSpread_Short_BolllingerBands_bullish-custom
# ZN_CallSpread_Long_IchimokuCloud_alt2-bearish-custom
# ZN_CallSpread_Long_MACross_bullish-custom
# ZN_CallSpread_Long_SwingPoint_bullish-custom
# ZN_CallSpread_Short_BolllingerBands_alt2-bearish-custom
# ZN_CallSpread_Short_BolllingerBands_alt3-bearish-custom
# ZN_CallSpread_Short_BolllingerBands_bearish-custom
# ZN_CallSpread_Short_BolllingerBands_bullish-custom
# ZN_CallSpread_Short_IchimokuCloud_bearish-custom
# ZN_PutSpread_Long_IchimokuCloud_bearish-custom
# ZN_PutSpread_Short_BolllingerBands_alt2-bullish-custom
# ZN_PutSpread_Short_BolllingerBands_bullish-custom
# ZN_PutSpread_Short_IchimokuCloud_alt2-bearish-custom
# ZN_PutSpread_Short_IchimokuCloud_alt2-bullish-custom
# ZN_PutSpread_Short_IchimokuCloud_alt3-bullish-custom
# ZN_PutSpread_Short_IchimokuCloud_bullish-custom
# ZN_PutSpread_Short_MACross_bullish-custom
# ZS_CallSpread_Long_IchimokuCloud_bearish-custom
# ZS_CallSpread_Long_IchimokuCloud_bullish-custom
# ZS_CallSpread_Long_SwingPoint_bearish-custom
# ZS_CallSpread_Long_SwingPoint_bullish-custom
# ZS_CallSpread_Short_BolllingerBands_bearish-custom
# ZS_CallSpread_Short_BolllingerBands_bullish-custom
# ZS_PutSpread_Short_BolllingerBands_alt2-bearish-custom
# ZS_PutSpread_Short_BolllingerBands_alt2-bullish-custom
# ZS_PutSpread_Short_BolllingerBands_bearish-custom
# ZS_PutSpread_Short_BolllingerBands_bullish-custom
# ZS_PutSpread_Short_IchimokuCloud_bearish-custom
# ZS_PutSpread_Short_IchimokuCloud_bullish-custom
# ZW_CallSpread_Short_BolllingerBands_bearish-custom
# ZW_CallSpread_Short_BolllingerBands_bullish-custom
# ZW_CallSpread_Short_IchimokuCloud_alt2-bearish-custom
# ZW_CallSpread_Short_IchimokuCloud_alt2-bullish-custom
# ZW_CallSpread_Short_IchimokuCloud_bearish-custom
# ZW_CallSpread_Short_IchimokuCloud_bullish-custom
# ZW_CallSpread_Short_MACross_bearish-custom
# ZW_CallSpread_Short_MACross_bullish-custom
# ZW_CallSpread_Short_SwingPoint_bearish-custom
# ZW_CallSpread_Short_SwingPoint_bullish-custom
# ZW_PutSpread_Long_MACross_bearish-custom
# ZW_PutSpread_Long_MACross_bullish-custom
# ZW_PutSpread_Short_BolllingerBands_bearish-custom
# ZW_PutSpread_Short_BolllingerBands_bullish-custom

# %% [markdown]
# # Campaign composition

# %% [markdown]
# Copy/paste EXO or swarm names to the 'campaign_exposure' dictionary from lists above

# %%
campaign_exposure = {
     'CL_CallSpread_Long_PointAndFigurePatterns_largebox-bearish-custom': 1,
     'CL_CallSpread_Long_PointAndFigurePatterns_smallbox-bearish-custom': 1,
     'CL_CallSpread_Short_SwingPoint_bearish-custom': 1,
    'CL_PutSpread_Short_IchimokuCloud_bearish-custom': 1,
     'CL_PutSpread_Short_SwingPoint_bearish-custom': 1,
    
    
     #
     # Passive EXO positions
     #
     'CL_CallSpread': -1, # Short 1 EXO units
     #'CL_ContFut': -1, # Short 1 EXO units
   
}

# %%
#def campaign_equity(swarms, exposure):

campaign_dict = {}
campaign_stats = {'NetProfit': 0.0, 'TradesCount': 0, 'CommissionSum': 0.0}

for camp_name, exposure in campaign_exposure.items():
    if camp_name in swmdf:
        swarm_name = camp_name
        campaign_dict[swarm_name] = swmdf[swarm_name] * exposure
        
        # TODO: implement swarm statistics
        '''
        s = smgr.picked_stats        
        campaign_stats['NetProfit'] += s['NetProfit']
        campaign_stats['TradesCount'] += s['TradesCount']
        campaign_stats['CommissionSum'] += s['CommissionSum']
        '''
        
    elif camp_name in passive_exo:
        exo_equity = passive_exo[camp_name]
        campaign_dict[camp_name] = exo_equity.diff() * exposure
    
    
campaign_portfolio = pd.DataFrame(campaign_dict)
campaign_equity = campaign_portfolio.sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    3999         blocks = form_blocks(arrays, names, axes)
# -> 4000         mgr = BlockManager(blocks, axes)
#    4001         mgr._consolidate_inplace()
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in __init__(self, blocks, axes, do_integrity_check, fastpath)
#    2593         if do_integrity_check:
# -> 2594             self._verify_integrity()
#    2595
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in _verify_integrity(self)
#    2803             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# -> 2804                 construction_error(tot_items, block.shape[1:], self.axes)
#    2805         if len(self.items) != tot_items:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    3969     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 3970         passed, implied))
#    3971
#
# ValueError: Shape of passed values is (4, 1969), indices imply (4, 2059)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-5d7a8c51193a> in <module>()
#      22
#      23
# ---> 24 campaign_portfolio = pd.DataFrame(campaign_dict)
#      25 campaign_equity = campaign_portfolio.sum(axis=1)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     222                                  dtype=dtype, copy=copy)
#     223         elif isinstance(data, dict):
# --> 224             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     225         elif isinstance(data, ma.MaskedArray):
#     226             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     358             arrays = [data[k] for k in keys]
#     359
# --> 360         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     361
#     362     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5239     axes = [_ensure_index(columns), _ensure_index(index)]
#    5240
# -> 5241     return create_block_manager_from_arrays(arrays, arr_names, axes)
#    5242
#    5243
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4002         return mgr
#    4003     except ValueError as e:
# -> 4004         construction_error(len(arrays), arrays[0].shape, axes, e)
#    4005
#    4006
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    3968         raise ValueError("Empty data passed with indices specified.")
#    3969     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 3970         passed, implied))
#    3971
#    3972
#
# ValueError: Shape of passed values is (4, 1969), indices imply (4, 2059)

# %%
campaign_portfolio = pd.DataFrame(campaign_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    3999         blocks = form_blocks(arrays, names, axes)
# -> 4000         mgr = BlockManager(blocks, axes)
#    4001         mgr._consolidate_inplace()
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in __init__(self, blocks, axes, do_integrity_check, fastpath)
#    2593         if do_integrity_check:
# -> 2594             self._verify_integrity()
#    2595
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in _verify_integrity(self)
#    2803             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# -> 2804                 construction_error(tot_items, block.shape[1:], self.axes)
#    2805         if len(self.items) != tot_items:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    3969     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 3970         passed, implied))
#    3971
#
# ValueError: Shape of passed values is (4, 1969), indices imply (4, 2059)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-2d43e2a50ed3> in <module>()
# ----> 1 campaign_portfolio = pd.DataFrame(campaign_dict)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     222                                  dtype=dtype, copy=copy)
#     223         elif isinstance(data, dict):
# --> 224             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     225         elif isinstance(data, ma.MaskedArray):
#     226             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     358             arrays = [data[k] for k in keys]
#     359
# --> 360         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     361
#     362     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5239     axes = [_ensure_index(columns), _ensure_index(index)]
#    5240
# -> 5241     return create_block_manager_from_arrays(arrays, arr_names, axes)
#    5242
#    5243
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4002         return mgr
#    4003     except ValueError as e:
# -> 4004         construction_error(len(arrays), arrays[0].shape, axes, e)
#    4005
#    4006
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    3968         raise ValueError("Empty data passed with indices specified.")
#    3969     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 3970         passed, implied))
#    3971
#    3972
#
# ValueError: Shape of passed values is (4, 1969), indices imply (4, 2059)

# %% [markdown]
# ### Campaign members equities

# %%
figsize(10,10)
campaign_portfolio.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-929185c9ba07> in <module>()
#       1 figsize(10,10)
# ----> 2 campaign_portfolio.plot()
#
# NameError: name 'campaign_portfolio' is not defined

# %% [markdown]
# ### Cumulative campaign equity

# %%
campaign_portfolio.sum(axis=1).plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-73d4a97df260> in <module>()
# ----> 1 campaign_portfolio.sum(axis=1).plot()
#
# NameError: name 'campaign_portfolio' is not defined

# %% [markdown]
# # Campaign statistics

# %%
print(campaign_stats)
# Out:
# {'NetProfit': 0.0, 'TradesCount': 0, 'CommissionSum': 0.0}
