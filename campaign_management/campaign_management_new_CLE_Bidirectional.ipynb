# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tradingcore.execution_manager import ExecutionManager
from tradingcore.campaign import Campaign
from tradingcore.account import Account
from tradingcore.moneymanagement import PlainMM

from exobuilder.data.datasource_mongo import DataSourceMongo
from exobuilder.data.datasource_sql import DataSourceSQL
from exobuilder.data.assetindex_mongo import AssetIndexMongo
from exobuilder.data.exostorage import EXOStorage

import pprint

# %%
try:
    from .settings import *
except SystemError:
    from scripts.settings import *

try:
    from .settings_local import *
except SystemError:
    try:
        from scripts.settings_local import *
    except ImportError:
        pass
    pass

# %%
assetindex = AssetIndexMongo(MONGO_CONNSTR, MONGO_EXO_DB)
storage = EXOStorage(MONGO_CONNSTR, MONGO_EXO_DB)
#datasource = DataSourceSQL(SQL_HOST, SQL_USER, SQL_PASS, assetindex, futures_limit=10, options_limit=10)
datasource = DataSourceMongo(MONGO_CONNSTR, MONGO_EXO_DB, assetindex, futures_limit=10, options_limit=10, exostorage=storage)

# %%
exmgr = ExecutionManager(MONGO_CONNSTR, datasource, dbname=MONGO_EXO_DB)

# %%
campaigns = exmgr.campaign_load_all()
accounts = exmgr.account_load_all()
pp = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# ## List of available campaigns

# %%
[print(x) for x in campaigns.keys()];
# Out:
# CL_Bidirectional
# CL_Bull
# ES_Bull
# NG_Bull
# NG_Bear
# ZN_Bear
# ZS_Bidirectional
# CL_Sample
# ES_Bidirectional
# ZS_Bear
# ZS_Bull
# CL_Bullish
# ES_Bear
# ZW_Bear
# ZC_Bear
# test_campaign
# ZN_Bull
# CL_Bear
# ZW_Bull
# NG_Bidirectional

# %%
swm_info = storage.swarms_info()
pp.pprint(swm_info)
# Out:
# {   '_id': None,
#     'alphas': [   'BollingerBands',
#                   'RenkoPatternsNoExits',
#                   'SwingPoint',
#                   'EXO',
#                   'PointAndFigure',
#                   'IchimokuCloud',
#                   'MACross',
#                   'BolllingerBands'],
#     'exo_types': [   'SMART',
#                      'SmartEXO',
#                      'CallSpread',
#                      'PutSpread',
#                      'ContFut',
#                      'BullishCollarBW',
#                      'BearishCollarBW'],
#     'instruments': ['ZC', 'NG', 'ZN', 'ES', 'ZS', 'CL', 'ZW']}

# %% [markdown]
# # Alphas list

# %%
instruments_filter = ['CL']  # Select ALL
#instruments_filter = ['ES', 'CL']

exo_filter = ['*'] # Select ALL
#exo_filter = ['BullishCollar']

direction_filter = [0, -1, 1] # Select ALL
#direction_filter = [1]

alpha_filter = ['-custom']  # Select ALL
#alpha_filter = ['MaCross', 'PointAndFigurePatterns']

swmdf, swm_data = storage.swarms_list(instruments_filter, direction_filter, alpha_filter, exo_filter)

[print(s) for s in sorted(swmdf.columns)];
# Out:
# CL_BearishCollarBW_Long_PointAndFigure_largebox-bearish-sample-custom
# CL_BearishCollarBW_Long_PointAndFigure_smallbox-bearish-sample-custom
# CL_BearishCollarBW_Short_SwingPoint_bearish-sample-custom
# CL_BearishCollarBW_Short_SwingPoint_bullish-sample-custom
# CL_CallSpread_Long_PointAndFigure_largebox-bearish-custom
# CL_CallSpread_Long_PointAndFigure_smallbox-bearish-custom
# CL_CallSpread_Short_SwingPoint_bearish-custom
# CL_CallSpread_Short_SwingPoint_bullish-custom
# CL_PutSpread_Long_BollingerBands_bullish-custom
# CL_PutSpread_Long_BolllingerBands_bullish-custom
# CL_PutSpread_Long_IchimokuCloud_bullish-custom
# CL_PutSpread_Long_RenkoPatternsNoExits_bullish-custom
# CL_PutSpread_Short_IchimokuCloud_bearish-custom
# CL_PutSpread_Short_SwingPoint_bearish-custom

# %%
passive_exo = {}

exo_filter = '*'     # All 
#exo_filter = 'ES_'  # ES only
exo_filter = 'CL'  # ES Collars (incl Bearish, Bullish, BW and vanilla)


print('==== Passive EXO list')
for exo_name in storage.exo_list(exo_filter):
    passive_exo[exo_name], exo_dict = storage.load_series(exo_name)

for exo in sorted(passive_exo.keys()):
    print(exo)
    
print('==== Alphas EXO list')
[print(s) for s in sorted(swmdf.columns)];
# Out:
# ==== Passive EXO list
# CL_BearishCollarBW
# CL_BullishCollarBW
# CL_CallSpread
# CL_ContFut
# CL_PutSpread
# CL_SMART_Ichimoku_Long
# CL_SMART_Ichimoku_Straddle_Bullish
# CL_SMART_Ichimoku_Straddle_Bullish_CustomInfo
# CL_SMART_Ichimoku_VerticalSpread_Bullish
# CL_SmartEXO_Ichi_Bearish_Put_Spread_150Delta
# CL_SmartEXO_Ichi_Bearish_Straddle_150Delta
# CL_SmartEXO_Ichi_Bearish_Straddle_BullCall_Spread_0Delta_EXP
# CL_SmartEXO_Ichi_Bullish_Straddle_150Delta
# CL_SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged
# CL_SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged_small_BearStraddle
# CL_SmartEXO_Ichi_Bullish_Straddle_150Delta_ExpHedged_test
# CL_SmartEXO_Ichi__BullCall_Spread_Delta_150_EXP
# ==== Alphas EXO list
# CL_BearishCollarBW_Long_PointAndFigure_largebox-bearish-sample-custom
# CL_BearishCollarBW_Long_PointAndFigure_smallbox-bearish-sample-custom
# CL_BearishCollarBW_Short_SwingPoint_bearish-sample-custom
# CL_BearishCollarBW_Short_SwingPoint_bullish-sample-custom
# CL_CallSpread_Long_PointAndFigure_largebox-bearish-custom
# CL_CallSpread_Long_PointAndFigure_smallbox-bearish-custom
# CL_CallSpread_Short_SwingPoint_bearish-custom
# CL_CallSpread_Short_SwingPoint_bullish-custom
# CL_PutSpread_Long_BolllingerBands_bullish-custom
# CL_PutSpread_Long_IchimokuCloud_bullish-custom
# CL_PutSpread_Long_RenkoPatternsNoExits_bullish-custom
# CL_PutSpread_Short_IchimokuCloud_bearish-custom
# CL_PutSpread_Short_SwingPoint_bearish-custom

# %%
swmdf.plot().legend(loc='best', bbox_to_anchor=(1, 0.5));

# %% [markdown]
# # Campaign composition

# %%
 

campaign_dict = {
        'name': 'CL_Bidirectional',
        'description': 'Bullish+Bearish Expression of Crude Oil',
        'alphas': {
            'CL_CallSpread_Short_SwingPoint_bullish-custom': {
                'qty': 1.0,
            },
         'CL_PutSpread_Long_BollingerBands_bullish-custom': {
                'qty': 1.0,
            },
         'CL_PutSpread_Long_IchimokuCloud_bullish-custom': {
                'qty': 1.0,
            },
         'CL_PutSpread_Long_RenkoPatternsNoExits_bullish-custom': {
                'qty': 1.0,
            },
         'CL_CallSpread_Short_SwingPoint_bullish-custom': {
                'qty': 1.0,
            },            
        'CL_CallSpread_Long_PointAndFigure_largebox-bearish-custom': {
                'qty': 1.0,
            },
         'CL_CallSpread_Long_PointAndFigure_smallbox-bearish-custom': {
                'qty': 1.0,
            },
         'CL_CallSpread_Short_SwingPoint_bearish-custom': {
                'qty': 1.0,
            },
         'CL_PutSpread_Short_IchimokuCloud_bearish-custom': {
                'qty': 1.0,
            },
         'CL_PutSpread_Short_SwingPoint_bearish-custom': {
                'qty': 1.0,
            },            
        }
    }

# %%
cmp = Campaign(campaign_dict, datasource)

# %% [markdown]
# ### Save campaign

# %%
exmgr.campaign_save(cmp)

# %% [markdown]
# ## Campaign positions

# %% [markdown]
# ### Alphas positions

# %%
pp.pprint(cmp.alphas_positions)
# Out:
# {   'CL_CallSpread_Short_SwingPoint_bearish-custom': {   'exo_name': 'CL_CallSpread',
#                                                          'exposure': 0.0,
#                                                          'prev_exposure': 0.0},
#     'CL_CallSpread_Short_SwingPoint_bullish-custom': {   'exo_name': 'CL_CallSpread',
#                                                          'exposure': -2.0,
#                                                          'prev_exposure': -2.0},
#     'CL_PutSpread_Long_IchimokuCloud_bullish-custom': {   'exo_name': 'CL_PutSpread',
#                                                           'exposure': 0.0,
#                                                           'prev_exposure': 0.0},
#     'CL_PutSpread_Short_IchimokuCloud_bearish-custom': {   'exo_name': 'CL_PutSpread',
#                                                            'exposure': 0.0,
#                                                            'prev_exposure': 0.0},
#     'CL_PutSpread_Short_SwingPoint_bearish-custom': {   'exo_name': 'CL_PutSpread',
#                                                         'exposure': -1.0,
#                                                         'prev_exposure': -1.0}}

# %% [markdown]
# ### EXO net positions

# %%
pp.pprint(cmp.exo_positions)
# Out:
# {   'CL_CallSpread': {'exposure': -2.0, 'prev_exposure': -2.0},
#     'CL_PutSpread': {'exposure': -1.0, 'prev_exposure': -1.0}}

# %% [markdown]
# ### Contracts positions

# %%
pp.pprint(cmp.positions)
# Out:
# {   'C_US_CLEZ164950': {   'asset': {   '_id': ObjectId('57aae75034ac2255e5903a23'),
#                                         '_type': 'opt',
#                                         'callorput': 'C',
#                                         'cqgsymbol': 'C.US.CLEZ164950',
#                                         'expirationdate': datetime.datetime(2016, 11, 16, 0, 0),
#                                         'idcontract': 393,
#                                         'idinstrument': 21,
#                                         'idoption': 3178810,
#                                         'name': 'C.US.CLEZ164950',
#                                         'optionmonth': 'Z',
#                                         'optionmonthint': 12,
#                                         'optionname': 'C.US.CLEZ164950',
#                                         'optionyear': 2016,
#                                         'strikeprice': 49.5},
#                            'prev_qty': -2.0,
#                            'qty': -2.0},
#     'C_US_CLEZ165550': {   'asset': {   '_id': ObjectId('57aae75034ac2255e5903a1d'),
#                                         '_type': 'opt',
#                                         'callorput': 'C',
#                                         'cqgsymbol': 'C.US.CLEZ165550',
#                                         'expirationdate': datetime.datetime(2016, 11, 16, 0, 0),
#                                         'idcontract': 393,
#                                         'idinstrument': 21,
#                                         'idoption': 3178804,
#                                         'name': 'C.US.CLEZ165550',
#                                         'optionmonth': 'Z',
#                                         'optionmonthint': 12,
#                                         'optionname': 'C.US.CLEZ165550',
#                                         'optionyear': 2016,
#                                         'strikeprice': 55.5},
#                            'prev_qty': 2.0,
#                            'qty': 2.0},
#     'P_US_CLEZ164550': {   'asset': {   '_id': ObjectId('57aae75134ac2255e5904881'),
#                                         '_type': 'opt',
#                                         'callorput': 'P',
#                                         'cqgsymbol': 'P.US.CLEZ164550',
#                                         'expirationdate': datetime.datetime(2016, 11, 16, 0, 0),
#                                         'idcontract': 393,
#                                         'idinstrument': 21,
#                                         'idoption': 3183076,
#                                         'name': 'P.US.CLEZ164550',
#                                         'optionmonth': 'Z',
#                                         'optionmonthint': 12,
#                                         'optionname': 'P.US.CLEZ164550',
#                                         'optionyear': 2016,
#                                         'strikeprice': 45.5},
#                            'prev_qty': 1.0,
#                            'qty': 1.0},
#     'P_US_CLEZ165150': {   'asset': {   '_id': ObjectId('57aae75334ac2255e590659b'),
#                                         '_type': 'opt',
#                                         'callorput': 'P',
#                                         'cqgsymbol': 'P.US.CLEZ165150',
#                                         'expirationdate': datetime.datetime(2016, 11, 16, 0, 0),
#                                         'idcontract': 393,
#                                         'idinstrument': 21,
#                                         'idoption': 3190526,
#                                         'name': 'P.US.CLEZ165150',
#                                         'optionmonth': 'Z',
#                                         'optionmonthint': 12,
#                                         'optionname': 'P.US.CLEZ165150',
#                                         'optionyear': 2016,
#                                         'strikeprice': 51.5},
#                            'prev_qty': -1.0,
#                            'qty': -1.0}}
